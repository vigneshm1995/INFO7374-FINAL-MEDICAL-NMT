# %% [markdown]
# ### 1.We called nltk's sentence_bleu function for BLEU SCORE calculation.
#
# ### 2.The test set contains 400 sentence from WMT's biomedical dataset
#
# ### 3.Average BLEU per sentence for google translator is 0.30, for our med-nmt is 0.37
#
# ### 4.There's limitations of using BLEU to compare, given BLEU doesn't include semantic evaluation. Just for reference here.

# %% [markdown]
# # SET UP FOR OUR NMT

# %% [markdown]
# This Note book is mainly adapted from [WuJiaocan's Github](https://github.com/WuJiaocan/tensorflow) and Tensorflow Seq2Seq Tutorial

# %%
import tensorflow as tf
import numpy as np

# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
print(tf.__version__)
# Out:
# 1.13.1

# %% [markdown]
# ### 1.Get Test Data Set

# %%
src_path = 'en_clean.txt'
tgt_path = 'fr_clean.txt'

# %%
def read_data(txt_path, num_examples):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[:num_examples]

# %%
src = read_data(src_path, 102000)
tgt = read_data(tgt_path, 102000)

# %%
src_test = src[101600:]
tgt_test = tgt[101600:]

# %%
len(tgt_test)
len(src_test)
# Out:
# 400

# %% [markdown]
# ### 2. Reload Vocab

# %%
def read_vocab(vocab_path):
  text = []
  with open(vocab_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      text.append(line.strip('\n'))
    return text

# %%
vocab_src = read_vocab('vocab.en')
vocab_tgt = read_vocab('vocab.fr')

# %%
vocab_size_src = len(vocab_src)
vocab_size_tgt = len(vocab_tgt)

print('size of source vocab {}'.format(vocab_size_src))
print('size of target vocab {}'.format(vocab_size_tgt))
# Out:
# size of source vocab 40396
# size of target vocab 49303

# %% [markdown]
# ### 3.Define Model Structure, Hyper Parameter Used in Training, Inference Function

# %%
import tensorflow as tf
import codecs
import sys

# %%
# read checkpoint path, number indicates the latest step
LAST_CKPT_PATH = "INFO7374-12200"

# Model HyperParameters, need to keep consistent with trained model
HIDDEN_SIZE = 256
DECODER_LAYERS = 2
SRC_VOCAB_SIZE = vocab_size_src
TRG_VOCAB_SIZE = vocab_size_tgt
SHARE_EMB_AND_SOFTMAX = True

# file for vocab
SRC_VOCAB = "vocab.en"
TRG_VOCAB = "vocab.fr"

# ID for <sos> and <eos> in vocab
SOS_ID = 1
EOS_ID = 2

# %%
class NMTModel(object):

    def __init__(self):
        # Define RNN CELL for Encoder and Decoder
        self.enc_cell_fw = tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE)
        self.enc_cell_bw = tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE)
        self.dec_cell = tf.nn.rnn_cell.MultiRNNCell(
          [tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE) 
           for _ in range(DECODER_LAYERS)])

        # Define EMBEDDING LAYER for Source/Target Language
        self.src_embedding = tf.get_variable(
            "src_emb", [SRC_VOCAB_SIZE, HIDDEN_SIZE])
        self.trg_embedding = tf.get_variable(
            "trg_emb", [TRG_VOCAB_SIZE, HIDDEN_SIZE])

        # Define SOFTMAX LAYER (share with Embedding or not share)
        if SHARE_EMB_AND_SOFTMAX:
            self.softmax_weight = tf.transpose(self.trg_embedding)
        else:
            self.softmax_weight = tf.get_variable(
               "weight", [HIDDEN_SIZE, TRG_VOCAB_SIZE])
        self.softmax_bias = tf.get_variable(
            "softmax_bias", [TRG_VOCAB_SIZE])

    def inference(self, src_input):
        # As dynamic rnn requires batch input, 
        # to infer one single sentence, we set batch = 1
        src_size = tf.convert_to_tensor([len(src_input)], dtype=tf.int32)
        src_input = tf.convert_to_tensor([src_input], dtype=tf.int32)
        src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)

        with tf.variable_scope("encoder"):
            # Use bidirectional_dynamic_rnn for encoder as in training step
            enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(
                self.enc_cell_fw, self.enc_cell_bw, src_emb, src_size, 
                dtype=tf.float32)
            # concatenate two outputs of LSTM cell as 1 tensor
            # enc_outputs = (output_fw, output_bw)
            enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)    
        
        with tf.variable_scope("decoder"):
            # define ATTENTION MECHANISM for decoder
            attention_mechanism = tf.contrib.seq2seq.LuongAttention(
                HIDDEN_SIZE, enc_outputs,
                memory_sequence_length=src_size)

            # wrap decoder cell and attention mechanism as an ATTENTION CELL
            attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                self.dec_cell, 
                attention_mechanism,
                attention_layer_size=HIDDEN_SIZE,
                alignment_history = True)
   
        # Set the max step for decoder
        MAX_DEC_LEN=100

        with tf.variable_scope("decoder/rnn/attention_wrapper"):
            # use TensorArray store produced sentence
            init_array = tf.TensorArray(dtype=tf.int32, size=0,
                dynamic_size=True, clear_after_read=False)
            # start input for decoder with <sos> tag
            init_array = init_array.write(0, SOS_ID)
            # initilize attention cell
            init_loop_var = (
                attention_cell.zero_state(batch_size=1, dtype=tf.float32),
                init_array, 0)

            # condition for tf.while_loop：
            # loop until decoder outputs <eos> or hit max length setting
            def continue_loop_condition(state, trg_ids, step):
                return tf.reduce_all(tf.logical_and(
                    tf.not_equal(trg_ids.read(step), EOS_ID),
                    tf.less(step, MAX_DEC_LEN-1)))

            def loop_body(state, trg_ids, step):
                # read last step output as input for attention cell
                trg_input = [trg_ids.read(step)]
                trg_emb = tf.nn.embedding_lookup(self.trg_embedding,
                                                 trg_input)
                # FORWARD calc ATTENTION CELL and output decoder outputs/state
                dec_outputs, next_state = attention_cell.call(
                    state=state, inputs=trg_emb)
       
                # calc logit for each candidate target vocab
                # select the max as output
                output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
                logits = (tf.matmul(output, self.softmax_weight)
                          + self.softmax_bias)
                next_id = tf.argmax(logits, axis=1, output_type=tf.int32)
                # write output word into trg_ids
                trg_ids = trg_ids.write(step+1, next_id[0])
                return next_state, trg_ids, step+1

            # execute tf.while_loop return trg_ides
            state, trg_ids, step = tf.while_loop(
                continue_loop_condition, loop_body, init_loop_var)
            return trg_ids.stack(), state

# %% [markdown]
# ### 7. Test and Evaluate

# %%
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu

def levenshtein(seq1, seq2):  
    size_x = len(seq1) + 1
    size_y = len(seq2) + 1
    matrix = np.zeros ((size_x, size_y))
    for x in range(size_x):
        matrix [x, 0] = x
    for y in range(size_y):
        matrix [0, y] = y

    for x in range(1, size_x):
        for y in range(1, size_y):
            if seq1[x-1] == seq2[y-1]:
                matrix [x,y] = min(
                    matrix[x-1, y] + 1,
                    matrix[x-1, y-1],
                    matrix[x, y-1] + 1
                )
            else:
                matrix [x,y] = min(
                    matrix[x-1,y] + 1,
                    matrix[x-1,y-1] + 1,
                    matrix[x,y-1] + 1
                )

    return matrix[size_x - 1, size_y - 1]

def translate_en_fr(src_sent, trgt_sent, plot_att = False, verbose = False):
    
    tf.reset_default_graph()
        
    # define the trained model
    with tf.variable_scope("nmt_model", reuse=None):
        model = NMTModel()
       
    # convert sentence to word_index according to vocab
    with codecs.open(SRC_VOCAB, "r", "utf-8") as f_vocab:
        src_vocab = [w.strip() for w in f_vocab.readlines()]
        src_id_dict = dict((src_vocab[x], x) for x in range(len(src_vocab)))
    test_en_ids = [(src_id_dict[token] if token in src_id_dict else src_id_dict['<unk>'])
                   for token in src_sent.split()]

    # build inference based on saved model weights
    output_op, state_op = model.inference(test_en_ids)
    sess = tf.Session()
    saver = tf.train.Saver()
    saver.restore(sess, LAST_CKPT_PATH)

    # read translation output
    output_ids = sess.run(output_op)
    
    # convert translation idx into word
    with codecs.open(TRG_VOCAB, "r", "utf-8") as f_vocab:
        trg_vocab = [w.strip() for w in f_vocab.readlines()]
    output_text = ' '.join([trg_vocab[x] for x in output_ids])
    
    # output translation
    final_output_text = output_text.encode('utf8').decode(sys.stdout.encoding).strip('<eos>')
    
    bleu = sentence_bleu(trgt_sent.split(), final_output_text.split())
    lst = levenshtein(trgt_sent,final_output_text)
    
    if verbose:
      print("Source Sentence: " + src_sent)
      print("Real Translation: " + trgt_sent)
      print("Predicted Translation: " + final_output_text)
      print("Levenshetein Distance: {}".format(lst))
      print("***BLEU Score***: {} ".format(bleu))
    
    
    # PLOT ATTENTION PLOT OPTION
    
    def plot_attention(attention, src_sent, pred_sent):

      fig = plt.figure(figsize=(10,10))
      ax = fig.add_subplot(1, 1, 1)
      ax.matshow(attention, cmap='viridis')

      fontdict = {'fontsize': 14}
      
      ax.set_xticks(np.arange(len(list(src_sent.split()))))
      ax.set_yticks(np.arange(len(list(pred_sent.split()))))

      ax.set_xticklabels([''] + list(src_sent.split()), fontdict=fontdict, rotation=90)
      ax.set_yticklabels([''] + list(pred_sent.split()), fontdict=fontdict)

      plt.show()
      
    if plot_att:
      alignments = sess.run(state_op.alignment_history.stack())
      alignments = np.squeeze(alignments)
      plot_attention(alignments, src_sent, final_output_text)
      
    return final_output_text, bleu, lst
    
    sess.close()

# %%
# prediction for total test set

def test_set_pred(src_test, tgt_test, verbose = False):
  src_test = src_test
  tgt_test = tgt_test
 
  size = len(src_test)
  
  pred_list = []
  bleu_list = []
  lst_list = []

  for i in range(size):

      pred, bleu, lst = translate_en_fr(src_test[i], tgt_test[i], verbose = verbose)
      print("                                                                                         ")
      pred_list.append(pred)
      bleu_list.append(bleu)
      lst_list.append(lst)
      
      
  c_bleu = sum(bleu_list) / len(bleu_list)
  c_lst = sum(lst_list) / len(lst_list)  
   
  print("                                                                                         ")
  print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
  print("Prediction Output and Metrics on {} test sentences: ".format(size))
  print("Average BLEU Score on our test corpus is {}".format(c_bleu)) 
  print("Average Levenshetein distance Score on our test corpus is {}".format(c_lst))

# %% [markdown]
# ### 3. Test

# %%
src_sent = 'comment on the misappropriation of bibliographical references in science . the example of anti aging medicine'
tgt_sent = 'du detournement des references bibliographiques en science . l exemple de la medecine anti age '


translate_en_fr(src_sent,
                tgt_sent, 
                verbose = True,
                plot_att = True)
# Out:
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Source Sentence: comment on the misappropriation of bibliographical references in science . the example of anti aging medicine
# Real Translation: du detournement des references bibliographiques en science . l exemple de la medecine anti age
# Predicted Translation:  du detournement des references bibliographiques en science . l exemple de la medecine anti age
# Levenshetein Distance: 1.0
# ***BLEU Score***: 0.5653035577259873
# (' du detournement des references bibliographiques en science . l exemple de la medecine anti age ',
#  0.5653035577259873,
#  1.0)

# %% [markdown]
# # RESULT FROM OUR MED-NMT

# %%
test_set_pred(src_test, tgt_test, verbose = True)
# Out:
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Source Sentence:  shelf acetabuloplasty in legg perthes calve disease
# Real Translation:  la butee osteoplastique dans l osteochondrite primitive de la hanche
# Predicted Translation:  interet de l utilisation de la duree de l utilisation de l utilisation de la prise en charge de la maladie de legg primitive dans le traitement de la maladie de legg primitive
# Levenshetein Distance: 131.0
# ***BLEU Score***: 0.4172261448611506
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  failure of primary management of developmental dislocation of the hip years experience in normandy
# Real Translation:  echecs de la prise en charge initiale de la maladie luxante de la hanche en haute normandie analyse sur une periode de annees consecutives
# Predicted Translation:  echec de la prise en charge de la luxation congenitale de la hanche l experience de la normandie en algerie en algerie en algerie en algerie
# Levenshetein Distance: 71.0
# ***BLEU Score***: 0.4428500142691474
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  validation of a tool to measure pelvic and spinal parameters of sagittal balance
# Real Translation:  validation d un outil de mesure des parametres pelviens et rachidiens de l equilibre sagittal du rachis
# Predicted Translation:  validation d un outil de mesure des examens bacteriennes et rachidiens des etudes de l equilibre sagittal et rachidiens des etudes de l equilibre sagittal et rachidiens des etudes de l equilibre sagittal
# Levenshetein Distance: 108.0
# ***BLEU Score***: 0.49616830003403634
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  guepar i total elbow arthroplasty in rheumatoid arthritis implants followed an average of months
# Real Translation:  prothese totale de coude guepar i dans la polyarthrite rhumatoide cas avec un recul moyen de mois
# Predicted Translation:  arthroplastie totale de type ii de type ii dans les implants de polyarthrite rhumatoide resultats a moyen terme et moyenne de mois a moyen terme
# Levenshetein Distance: 70.0
# ***BLEU Score***: 0.447213595499958
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  dynamic radiographic evaluation of the antero inferior gleno humeral ligament
# Real Translation:  etude radiographique dynamique du ligament gleno humeral inferieur
# Predicted Translation:  evaluation radiographique dynamique du ligament gleno humeral inferieur du membre inferieur antero marchant
# Levenshetein Distance: 44.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  giant cell tumor of the patella with lung metastases a case report
# Real Translation:  tumeur a cellules geantes de la rotule avec metastases pulmonaires a propos d un cas
# Predicted Translation:  tumeur a cellules geantes de la patella et metastases pulmonaires a propos d un cas
# Levenshetein Distance: 7.0
# ***BLEU Score***: 0.668740304976422
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  ossifying parosteal lipoma of the rib a case report
# Real Translation:  lipome para osteal ossifiant costal a propos d un cas
# Predicted Translation:  lipome congenital de la loge de la cote a propos d un cas a propos d un cas
# Levenshetein Distance: 39.0
# ***BLEU Score***: 0.6389431042462724
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  bifocal schwannoma of the sciatic nerve a case report
# Real Translation:  schwannome bifocal de la bifurcation sciatique a propos d un cas
# Predicted Translation:  schwannome bifocale du nerf sciatique a propos d un cas a propos d un cas
# Levenshetein Distance: 28.0
# ***BLEU Score***: 0.6042750794713536
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  pinctada margaritifera nacre mother of pearl physico chemical and biomechanical properties , and in vitro cytocompatibility
# Real Translation:  la nacre pinctada margaritifera caracterisation physico chimique , proprietes biomecaniques et cytocompatibilite in vitro
# Predicted Translation:  transmission de l embryon de transmission a l insuline transmission des proprietes biomecaniques et biomecaniques , et des bilans biomecaniques , in vitro et d hydrochlorothiazide humaine , et d etude in vitro
# Levenshetein Distance: 140.0
# ***BLEU Score***: 0.5900468726392808
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  aneurismal bone cyst in children cases
# Real Translation:  le kyste osseux anevrysmal chez l enfant a propos de cas
# Predicted Translation:  kyste anevrismal de l enfant a propos de cas de cas de cas
# Levenshetein Distance: 28.0
# ***BLEU Score***: 0.6262844962765469
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  treatment of solitary bone cysts by intra medullary nailing or steroid injection in children
# Real Translation:  place de l embrochage centro medullaire et de l injection de corticoides dans le traitement des kystes osseux essentiels de l enfant
# Predicted Translation:  traitement des kystes solitaires osseux a enclouage centromedullaire ou non injection de corticoides chez l enfant de l enfant
# Levenshetein Distance: 85.0
# ***BLEU Score***: 0.6303647413359293
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  peri lunate wrist dislocation long term outcome
# Real Translation:  luxation peri lunaire du carpe resultats a long terme
# Predicted Translation:  luxation peri lunaire du scaphoide evolution a long terme a long terme
# Levenshetein Distance: 24.0
# ***BLEU Score***: 0.537284965911771
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  ganglions of the wrist proposals for topographical systematization and natural history
# Real Translation:  kystes dits quot synoviaux quot du poignet systematisation topographique et pathogenie
# Predicted Translation:  la moitie du poignet proposition de systematisation d histoire naturelle et histoire naturelle et histoire naturelle histoire naturelle et histoire naturelle
# Levenshetein Distance: 115.0
# ***BLEU Score***: 0.4671379777282001
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  guepar radial head prosthesis for recent and old fractures a series of cases
# Real Translation:  la prothese de tete radiale guepar dans les fractures recentes et anciennes a propos d une serie de cas
# Predicted Translation:  prothese de tete radiale par prothese de tete radiale et grand fracture etude de cas a propos de cas
# Levenshetein Distance: 55.0
# ***BLEU Score***: 0.47897362544357464
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  re infection with a different strain after prosthesis revision for bacterial infection cases
# Real Translation:  reinfection avec changement de germe apres reimplantation de protheses pour infection a propos de cas
# Predicted Translation:  une tumeur de prothese prolongee apres une revision de fractures bacteriennes a propos de cas
# Levenshetein Distance: 58.0
# ***BLEU Score***: 0.5081327481546147
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  use of combined gallium technetium scintigraphy to determine the interval before second stage prosthetic reimplantation in hip arthroplasty infection a consecutive series of cases
# Real Translation:  interet de la scintigraphie couplee gallium technetium afin d optimiser le delai de reimplantation prothetique en deux temps des infections sur arthroplastie de hanche a propos d une serie continue de cas
# Predicted Translation:  utilisation de la scintigraphie au temps reel systematique pour determiner l intervalle avant les reprises de protheses intra mandibulaires de hanche serie consecutive de cas
# Levenshetein Distance: 121.0
# ***BLEU Score***: 0.447213595499958
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  updated guidelines of the societe de pneumologie de langue francaise for the management of chronic obstructive pulmonary disease essential points
# Real Translation:  actualisation des recommandations de la splf pour la prise en charge de la bpco points essentiels
# Predicted Translation:  recommandations actualisees de la societe de pneumologie de langue francaise pour la prise en charge des patients atteints de bronchopneumopathie chronique obstructive points essentiels indispensables en cancerologie de la bronchopneumopathie chronique obstructive points essentiels indispensables en france
# Levenshetein Distance: 228.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  simvastatin induced chylothorax
# Real Translation:  chylothorax sous simvastatine
# Predicted Translation:  chylothorax induit par la simvastatine
# Levenshetein Distance: 12.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  pollen count
# Real Translation:  comptes polliniques
# Predicted Translation:  contenu des activities par contenu par contenu
# Levenshetein Distance: 36.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  unusual progression of pulmonary opaque cavitation
# Real Translation:  opacites pulmonaires excavees d evolution inhabituelle
# Predicted Translation:  evolution inhabituelle d une pneumopathie d apparition posterieure des neuropathies pulmonaires
# Levenshetein Distance: 73.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  chylothorax an unexpected complication of artificial ventilation in severe acute asthma
# Real Translation:  une complication inattendue de l asthme aigu grave sous ventilation artificielle le chylothorax
# Predicted Translation:  une ventilation artificielle chez le sujet de crise d asthme aigu severe au decours d un asthme aigu grave severe
# Levenshetein Distance: 76.0
# ***BLEU Score***: 0.4728708045015879
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  acute respiratory distress syndrome due to pneumonitis following intrathecal methotrexate administration
# Real Translation:  insuffisance respiratoire aigue avec pneumopathie apres administration intrathecale de methotrexate
# Predicted Translation:  syndrome de detresse respiratoire aigue par pneumonie severe par une administration de sous au propofol
# Levenshetein Distance: 62.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  bronchial anthracosis and pulmonary mica overload
# Real Translation:  anthracose bronchique et surcharge pulmonaire en micas
# Predicted Translation:  etat des lieux de l hallucination bronchique et des attentes pulmonaires pulmonaires surcharges en fonction pulmonaire
# Levenshetein Distance: 79.0
# ***BLEU Score***: 0.5
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  graft immunity in lung transplantation
# Real Translation:  immunite de greffe en transplantation pulmonaire
# Predicted Translation:  reponse de l immunite par le greffon en transplantation pulmonaire
# Levenshetein Distance: 20.0
# ***BLEU Score***: 0.5623413251903491
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  clinical prediction rules a reader s guide
# Real Translation:  les regles de prediction un guide de lecture
# Predicted Translation:  les grandes regles un guide de lecture de lecture
# Levenshetein Distance: 25.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  smoking , asthma and associated phenotypes . an epidemiological approach
# Real Translation:  tabagisme , asthme et phenotypes associes . approche epidemiologique
# Predicted Translation:  tabagisme , asthme et phenotypes associes . approche epidemiologique d une approche epidemiologique
# Levenshetein Distance: 31.0
# ***BLEU Score***: 0.5942647088781684
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  pathophysiology of obliterative bronchiolitis in lung transplants
# Real Translation:  physiopathologie de la bronchiolite obliterante des transplantes pulmonaires
# Predicted Translation:  physiopathologie de la bronchiolite obliterante des patients transplantes pulmonaires
# Levenshetein Distance: 9.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  value of induced sputum in the investigation of asthma
# Real Translation:  interet des expectorations induites dans l exploration de l asthme
# Predicted Translation:  expectoration induite dans l evaluation de l asthme
# Levenshetein Distance: 18.0
# ***BLEU Score***: 0.5946035575013605
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  value of ct scanning in the investigation of thoracic sarcoidosis
# Real Translation:  apport de la tdm dans l exploration de la sarcoidose thoracique
# Predicted Translation:  apport du scanner dans l exploration de sarcoidose thoracique
# Levenshetein Distance: 10.0
# ***BLEU Score***: 0.5166357204442371
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  acute pulmonary toxicity due to gemcitabine a role for asbestos exposure ?
# Real Translation:  toxicite pulmonaire aigue de la gemcitabine un role pour l exposition a l amiante ?
# Predicted Translation:  toxicite aigue pulmonaire par gemcitabine un role pour l exposition a l amiante ?
# Levenshetein Distance: 17.0
# ***BLEU Score***: 0.6803749333171202
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  factors predicting the severity and the degree of symptom control of asthma in a recently diagnosed cohort of adult patients a . s . m . a study
# Real Translation:  facteurs lies a la severite et au controle de l asthme recemment diagnostique dans une cohorte de patients adultes
# Predicted Translation:  prediction de la severite et du degre de severite de symptomes d asthme au cours d une cohorte de patients adultes d un tableau de diagnostic recente de patients adultes a . s . etude de cas . m . m . a . etude d une etude de cas
# Levenshetein Distance: 156.0
# ***BLEU Score***: 0.5623413251903491
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  asbestos gemcitabin . combined risk for pulmonary toxicity ?
# Real Translation:  amiante gemcitabine . risques conjoints de toxicite pulmonaire ?
# Predicted Translation:  l amiante , un risque combine pour la toxicite pulmonaire ? ?
# Levenshetein Distance: 28.0
# ***BLEU Score***: 0.6389431042462724
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  mineral analysis of biological samples and respiratory pathologies
# Real Translation:  analyses mineralogiques d echantillons biologiques et pathologies respiratoires
# Predicted Translation:  analyse minerale des specimens biologiques et pathologies respiratoires
# Levenshetein Distance: 15.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  clinical scores and clinical judgment
# Real Translation:  les scores et le jugement clinique
# Predicted Translation:  scores cliniques et jugement clinique
# Levenshetein Distance: 14.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  treatment of localised forms of non small cell bronchial cancers perspectives in
# Real Translation:  traitement des formes localisees du cancer bronchique non a petites cellules perspectives en
# Predicted Translation:  traitement des formes localisees de cancers bronchiques non a petites cellules perspectives en cours de cbnpc
# Levenshetein Distance: 18.0
# ***BLEU Score***: 0.5
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  tuberculosis and poverty
# Real Translation:  tuberculose et pauvrete
# Predicted Translation:  tuberculose et pauvrete la pauvrete
# Levenshetein Distance: 12.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  anti ige and future treatments for respiratory allergies
# Real Translation:  les anti ige et les traitements du futur des allergies respiratoires
# Predicted Translation:  traitements anti ige et traitements d avenir pour les allergies respiratoires
# Levenshetein Distance: 24.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  food allergy and asthma in children
# Real Translation:  allergie alimentaire et asthme chez l enfant
# Predicted Translation:  allergies alimentaires et asthme chez l enfant de l enfant
# Levenshetein Distance: 14.0
# ***BLEU Score***: 0.6051012508914458
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  complementary tests in respiratory allergy
# Real Translation:  les examens complementaires en allergie respiratoire
# Predicted Translation:  epreuves complementaires dans l allergie respiratoire
# Levenshetein Distance: 12.0
# ***BLEU Score***: 0.5408536609893481
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  respiratory allergies current data
# Real Translation:  les allergenes respiratoires donnees actuelles
# Predicted Translation:  allergies respiratoires donnees actuelles
# Levenshetein Distance: 6.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  intrinsic asthma
# Real Translation:  asthme allergique et non allergique similitudes et differences
# Predicted Translation:  asthme intrinseque sur asthme intrinseque
# Levenshetein Distance: 40.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  pathophysiology of the ige dependent reaction in respiratory allergy
# Real Translation:  physiopathologie de la reaction ige dependante dans l allergie respiratoire
# Predicted Translation:  physiopathologie de l hypersensibilite anti ige dans l allergie respiratoire
# Levenshetein Distance: 21.0
# ***BLEU Score***: 0.668740304976422
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  respiratory allergic disease genes
# Real Translation:  genes de l allergie respiratoire
# Predicted Translation:  maladies allergiques respiratoires allergiques des genes allergiques
# Levenshetein Distance: 47.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  critical analysis of hypotheses explaining the increase in respiratory allergens
# Real Translation:  etude critique des hypotheses explicatives de l augmentation des allergies respiratoires
# Predicted Translation:  analyse critique de la hypotheses dans les pollinoses respiratoires les facteurs de l incidence des allergenes respiratoires
# Levenshetein Distance: 56.0
# ***BLEU Score***: 0.4924790605054523
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  respiratory allergy a changing world
# Real Translation:  l allergie respiratoire un monde qui change
# Predicted Translation:  allergie respiratoire un monde en pleine evolution
# Levenshetein Distance: 19.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  clinical practice guidelines . recurrent laryngeal nerve paralysis in adults . full text
# Real Translation:  quot paralysies recurrentielles de l adulte quot . texte long october
# Predicted Translation:  recommandations pour la pratique clinique . paralysies laryngees recidivantes chez l adulte . texte tout de patients . a propos de cas
# Levenshetein Distance: 91.0
# ***BLEU Score***: 0.6076795808137692
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  systemic antibiotic therapy in routine practice lower respiratory tract infections in adults guidelines . update
# Real Translation:  antibiotherapie par voie generale en pratique courante infections respiratoires basses de l adulte . actualisation
# Predicted Translation:  antibiotherapie par voie generale en pratique courante chez l adulte . recommandations de l adulte . mise a jour . mise au point
# Levenshetein Distance: 47.0
# ***BLEU Score***: 0.6009638585283708
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  systemic antibiotic therapy in routine practice acute pharyngitis guidelines . update
# Real Translation:  antibiotherapie par voie generale en pratique courante angine . actualisation
# Predicted Translation:  antibiotherapie par voie generale en pratique courante pour une prise en charge de la maladie de gaucher
# Levenshetein Distance: 39.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  nasal obstruction and compliance to nasal positive airway pressure
# Real Translation:  obstruction nasale et compliance a la ventilation nasale a pression positive
# Predicted Translation:  obstruction nasale et observance a la pression positive positive nasale
# Levenshetein Distance: 33.0
# ***BLEU Score***: 0.5623413251903491
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  cellular and neoplastic otorhinolaryngologic changes , molecular markers and therapeutic potential
# Real Translation:  alterations cellulaires et cancerogenese orl , marqueurs moleculaires et cibles therapeutiques potentielles
# Predicted Translation:  les bases cellulaires et cancereuses , marqueurs moleculaires et potentiel therapeutique potentiel therapeutique potentielles potentielles
# Levenshetein Distance: 58.0
# ***BLEU Score***: 0.5081327481546147
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  pediatric cochlear implants
# Real Translation:  les implants cochleaires pediatriques
# Predicted Translation:  implant cochleaire chez l enfant de l enfant de l enfant
# Levenshetein Distance: 37.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  possible diagnostic pitfalls of c kit immunohistochemistry
# Real Translation:  c kit parfois un faux ami !
# Predicted Translation:  interet diagnostique de l immunohistochimie de c kit dans l immunohistochimie de f kit
# Levenshetein Distance: 72.0
# ***BLEU Score***: 0.6147881529512643
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  leiomyoma of the urinary bladder
# Real Translation:  leiomyome de la vessie . a propos d un cas
# Predicted Translation:  leiomyome de vessie vesical
# Levenshetein Distance: 19.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  an unusual tumor of the central nervous system
# Real Translation:  tumeur inhabituelle du systeme nerveux central
# Predicted Translation:  une tumeur inhabituelle du systeme nerveux central du systeme nerveux central
# Levenshetein Distance: 31.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  a composite tumor of the skin
# Real Translation:  une tumeur cutanee composite
# Predicted Translation:  une tumeur composite de la peau cutanee
# Levenshetein Distance: 21.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  cutaneous tumor of the low back in an adult woman
# Real Translation:  tumeur cutanee du bas du dos chez une femme adulte
# Predicted Translation:  tumeur cutanee du nourrisson chez une adulte adulte
# Levenshetein Distance: 14.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  a congenital renal tumor
# Real Translation:  une tumeur renale congenitale
# Predicted Translation:  une tumeur congenitale du rein une tumeur congenitale
# Levenshetein Distance: 25.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  abdominal mass with calcifications
# Real Translation:  une masse abdominale avec calcifications
# Predicted Translation:  masses abdominales secondaires a une calcifications des calcifications
# Levenshetein Distance: 39.0
# ***BLEU Score***: 0.4630777161991027
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  recurring bone epithelioid hemangioma
# Real Translation:  hemangiome epithelioide osseux recidivant
# Predicted Translation:  hemangiome epithelioide intraosseux recidivant a couple a recidivants a couple recidivants a couple recidivants a couple recidivants a couple recidivants
# Levenshetein Distance: 112.0
# ***BLEU Score***: 0.4728708045015879
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  antenatal solitary intestinal fibromatosis
# Real Translation:  fibromatose intestinale solitaire congenitale
# Predicted Translation:  fibromatose intestinale solitaire prenatale retroperitoneale et prenatale retroperitoneale
# Levenshetein Distance: 47.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  clear cell carcinoma of the ovary simulating a yolk sac tumor
# Real Translation:  carcinome a cellules claires de l ovaire simulant une tumeur vitelline
# Predicted Translation:  le carcinome a cellules claires de l ovaire simulant une tumeur vitelline d une tumeur vitelline
# Levenshetein Distance: 26.0
# ***BLEU Score***: 0.6580370064762462
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  an oral infection not to be underestimated actinomycosis . a study of cases with extensive bone necrosis
# Real Translation:  une infection buccale a ne pas sous estimer l actinomycose . etude de observations avec necrose osseuse extensive
# Predicted Translation:  une infection orale peu d actinomycose sous estimee . etude de cas avec necroses osseuses internes
# Levenshetein Distance: 52.0
# ***BLEU Score***: 0.5946035575013605
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  retrorectal cystic hamartomas . report of one case
# Real Translation:  hamartome kystique retrorectal . a propos d une observation
# Predicted Translation:  keratose kystique retrorectal hkrr a propos d un cas
# Levenshetein Distance: 20.0
# ***BLEU Score***: 0.6865890479690392
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  infantile and maternal choriocarcinoma
# Real Translation:  choriocarcinome infantile et maternel
# Predicted Translation:  choriocarcinome maternel et grossesse infantile et maternelle
# Levenshetein Distance: 24.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  nasal nk t lymphoma . a case report
# Real Translation:  lymphome nk t nasal . a propos d un cas
# Predicted Translation:  lymphome nasal t nk nasal . a propos d un cas a propos d un cas
# Levenshetein Distance: 25.0
# ***BLEU Score***: 0.7476743906106103
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  recent entities in soft tissue tumor pathology . part
# Real Translation:  entites recentes en pathologie tumorale des tissus mous . e partie
# Predicted Translation:  entites recentes dans la pathologie tumorale des tissus mous . partie partie
# Levenshetein Distance: 11.0
# ***BLEU Score***: 0.537284965911771
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  scar tissues of the posterior segment of the eye histological and etiological features
# Real Translation:  les membranes proliferatives et cicatricielles du segment posterieur de l oeil . caracteristiques histologiques et etiologiques
# Predicted Translation:  les parties de papillon du segment posterieur de l oeil aspects histologique et etiologique etiologique et etiologique etiologique
# Levenshetein Distance: 72.0
# ***BLEU Score***: 0.4854917717073234
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  amyloid neuropathies . histopathological study of peripheral nerve biopsy in cases
# Real Translation:  les neuropathies amyloides . etude histopathologique de nerf peripherique dans cas
# Predicted Translation:  les neuropathies amyloides . etude histopathologique de la biopsie nerveuse peripherique en cas de cas
# Levenshetein Distance: 24.0
# ***BLEU Score***: 0.44470422371688834
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  soft tissue pathology current issues and perspectives
# Real Translation:  pathologie des tissus mous evolutions actuelles et perspectives
# Predicted Translation:  pathologie des tissus mous enjeux actuels et perspectives actuels et perspectives
# Levenshetein Distance: 27.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  helicobacter pylori , gastric inflammation and its consequences
# Real Translation:  helicobacter pylori , l inflammation gastrique et ses consequences
# Predicted Translation:  helicobacter pylori , inflammation gastrique et ses consequences
# Levenshetein Distance: 2.0
# ***BLEU Score***: 0.5247357977607321
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  intestinal flora and crohn s disease
# Real Translation:  flore intestinale et maladie de crohn
# Predicted Translation:  flore intestinale et maladie de crohn
# Levenshetein Distance: 0.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  bacterial aggression
# Real Translation:  l immunite innee contre les agressions bacteriennes
# Predicted Translation:  l agressivite bacterienne d origine bacterienne due au bacille d origine bacterienne
# Levenshetein Distance: 51.0
# ***BLEU Score***: 0.537284965911771
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  hydroxycinnamic acid levels of various batches from mugwort flowering tops
# Real Translation:  teneur en acides hydroxycinnamiques de differents lots de sommites fleuries d armoise
# Predicted Translation:  les niveaux d acide phenylacetique les trois portions de communication de salon
# Levenshetein Distance: 58.0
# ***BLEU Score***: 0.537284965911771
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  molecular diagnosis of viral materno fetal infections
# Real Translation:  diagnostic moleculaire des infections virales materno foetales
# Predicted Translation:  diagnostic moleculaire des infections materno f tales
# Levenshetein Distance: 10.0
# ***BLEU Score***: 0.6147881529512643
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  new therapeutic approaches to cystic fibrosis
# Real Translation:  recentes approches therapeutiques de la mucoviscidose
# Predicted Translation:  nouvelles approches therapeutiques de la mucoviscidose de nouvelles approches therapeutiques de mucoviscidose
# Levenshetein Distance: 61.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  compared viability of planctonic bacteria and bacteria in biofilms by flow cytometry
# Real Translation:  comparaison de la vitalite des bacteries libres et des bacteries en biofilm par cytometrie en flux
# Predicted Translation:  seance comparee d echantillons d amorces et de bacteries dans les biofilms par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en flux par cytometrie en
# Levenshetein Distance: 489.0
# ***BLEU Score***: 0.31702331385234306
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  cytochromes p , vascular tone varicosis
# Real Translation:  les cytochromes p , le tonus vasculaire et la pathologie variqueuse
# Predicted Translation:  les cytochromes p , tonus vasculaire et cancer du detrusor
# Levenshetein Distance: 23.0
# ***BLEU Score***: 0.668740304976422
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  dna vaccines
# Real Translation:  les vaccins a adn
# Predicted Translation:  vaccins de l adn les vaccins de l adn
# Levenshetein Distance: 21.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  a small sized cancer of the lower rectum
# Real Translation:  un petit cancer du bas rectum
# Predicted Translation:  un cancer du bas rectum du bas rectum
# Levenshetein Distance: 16.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  a small sized hepatocellular carcinoma
# Real Translation:  un petit carcinome hepatocellulaire
# Predicted Translation:  carcinome hepatocellulaire a petites cellules de petit debit un petit carcinome a petites cellules
# Levenshetein Distance: 73.0
# ***BLEU Score***: 0.5329462628216854
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  asymptomatic multinodular liver disease
# Real Translation:  un foie multinodulaire asymptomatique
# Predicted Translation:  steatopathies juveniles asymptomatiques
# Levenshetein Distance: 22.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  first line metastatic cancer of the colon
# Real Translation:  un cancer colique metastatique d emblee
# Predicted Translation:  cancer du colon metastatique de premiere ligne du colon
# Levenshetein Distance: 30.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  cancer of the pancreas from resection work up to palliative treatment
# Real Translation:  cancer du pancreas du bilan de resecabilite au traitement palliatif
# Predicted Translation:  cancer du pancreas du travail en soins palliatifs parcours de traitement palliatif a la strategie therapeutique palliative
# Levenshetein Distance: 67.0
# ***BLEU Score***: 0.4924790605054523
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  from dysplasia to dysphagia
# Real Translation:  de la dysplasie a la dysphagie
# Predicted Translation:  de la dysplasie aux dysphagie
# Levenshetein Distance: 3.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  a quot helping hand quot an ordinary clinical story
# Real Translation:  un quot coup de main quot pour exonerer une histoire clinique bien banale
# Predicted Translation:  une histoire quot anesthesie quot une histoire clinique ordinaire d histoire clinique ordinaire histoire de l histoire clinique ordinaire
# Levenshetein Distance: 89.0
# ***BLEU Score***: 0.5695988432761473
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  non viral fulminant hepatitis
# Real Translation:  hepatites fulminantes non virales
# Predicted Translation:  hepatite aigue non virale a virus non infecte
# Levenshetein Distance: 28.0
# ***BLEU Score***: 0.5946035575013605
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  anorectal functional disorders new evidence based therapeutic options for fecal incontinence treatment
# Real Translation:  les troubles fonctionnels anorectaux a l epreuve de la medecine factuelle nouvelles options therapeutiques pour le traitement de l incontinence fecale
# Predicted Translation:  troubles fonctionnels ano rectales de nouvelles options therapeutiques basees sur le traitement de l incontinence fecale
# Levenshetein Distance: 47.0
# ***BLEU Score***: 0.5
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  conventional surgical treatments for anal incontinence and rectal disorders
# Real Translation:  therapeutiques chirurgicales conventionnelles pour le traitement de l incontinence anale et des troubles de la statique rectale
# Predicted Translation:  traitements conventionnels conventionnel de l incontinence anale et des troubles du rectum
# Levenshetein Distance: 52.0
# ***BLEU Score***: 0.537284965911771
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  functional anorectal disorders . evidence based non surgical therapies
# Real Translation:  troubles fonctionnels anorectaux . therapeutiques non chirurgicales a l epreuve de la medecine factuelle
# Predicted Translation:  troubles ano ano dentaires . traitements non chirurgicaux a priori evidence de traitements non chirurgicaux
# Levenshetein Distance: 63.0
# ***BLEU Score***: 0.6042750794713536
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  useful and less useful routine anorectal physiological tests in patients with functional anorectal disorders
# Real Translation:  explorations fonctionnelles usuelles utiles et moins utiles dans les troubles fonctionnels anorectaux
# Predicted Translation:  tests physiologiques d antibiotiques a visee colorectale en troubles endo muqueuses fonctionnels a l aide de patients a temoins fonctionnels
# Levenshetein Distance: 100.0
# ***BLEU Score***: 0.668740304976422
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Source Sentence:  value and limits of clinical examination to functional anorectal disorders except for chronic anorectal pain
# Real Translation:  valeur et limites de la clinique dans les troubles fonctionnels ano rectaux hors algies chroniques
# Predicted Translation:  interets et limites de l examen clinique a la prevention des algies fonctionnelles chroniques a l exclusion de algies chroniques constrictives a l aide de algies chroniques keratozyste
# Levenshetein Distance: 107.0
# ***BLEU Score***: 0.22679164443904004
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  endoscopic ultrasound guided biopsy when is it indispensable ?
# Real Translation:  biopsie echo endoscopiquement guidee quand est elle irremplacable ?
# Predicted Translation:  biopsies sous echoendoscopie quand est ce indispensable ?
# Levenshetein Distance: 30.0
# ***BLEU Score***: 0.5946035575013605
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  positron emission tomography and gastrointestinal oncology
# Real Translation:  la tomographie par emission de positons tep en cancerologie digestive
# Predicted Translation:  tomographie par emission de positons et oncologie digestive oncologie digestive
# Levenshetein Distance: 25.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  contrast ultrasonography value in diagnosis and characterisation of hepatic tumors
# Real Translation:  echographie de contraste place dans le diagnostic et la caracterisation des tumeurs du foie
# Predicted Translation:  interet de l echographie de contraste dans le diagnostic et la caracterisation des tumeurs hepatiques
# Levenshetein Distance: 27.0
# ***BLEU Score***: 0.5081327481546147
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  magnetic resonance imaging of the pancreas value and limits
# Real Translation:  irm du pancreas place et limites
# Predicted Translation:  imagerie par resonance magnetique du pancreas interet et limites des limites et des limites
# Levenshetein Distance: 62.0
# ***BLEU Score***: 0
#
# ...
# Levenshetein Distance: 68.0
# ***BLEU Score***: 0.5318295896944989
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  how does one localize a disease gene without a genetic linkage study ?
# Real Translation:  comment localiser un gene morbide sans etude de liaison genetique ?
# Predicted Translation:  existe t il une etude sur les genes sans etude genetique sur une etude genetique genetique ? ?
# Levenshetein Distance: 56.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  neurotrypsin mutations and mental retardation
# Real Translation:  mutations de la neurotrypsine et retard mental
# Predicted Translation:  mutations de mutations et deficience intellectuelle
# Levenshetein Distance: 31.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  sequencing the human genome chromosome , the th chromosome completed
# Real Translation:  sequencage du genome humain le chromosome , quatrieme chromosome termine
# Predicted Translation:  sequenzierung du chromosome embryon , il n . e h pas le e cycle formule de doigts
# Levenshetein Distance: 54.0
# ***BLEU Score***: 0.7364279629037999
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  catalytic antibodies or quot abzymes quot
# Real Translation:  anticorps catalytiques ou abzymes
# Predicted Translation:  anticorps endocriniens ou quot rasoir quot
# Levenshetein Distance: 25.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  word of the month quot physiology quot
# Real Translation:  lle mot du mois physiologie
# Predicted Translation:  le mot du mois de l enfant quot physiologie quot physiologie quot de physiologie quot de physiologie quot
# Levenshetein Distance: 80.0
# ***BLEU Score***: 0.4854917717073234
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  neurosciences progress and prospects
# Real Translation:  neurosciences progres et perspectives
# Predicted Translation:  neurosciences avancees et perspectives
# Levenshetein Distance: 6.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  science , communication and policy sequencing the rice genome
# Real Translation:  science , mediatisation et politique le sequencage du genome du riz
# Predicted Translation:  quot science , communication et politique quot sequencage du quot groupe du quot groupe du quot groupe quot du quot groupe de serpents quot du quot groupe numerique du quot groupe du quot groupe v
# Levenshetein Distance: 140.0
# ***BLEU Score***: 0.41113361690051975
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  in the genomic great plains country . episode the double helix market
# Real Translation:  dans les grandes plaines de la genomique . episode . le marche de la double helice
# Predicted Translation:  a partir du pays du quot pied des genomes . episode le retard de la double entree se resserre le marche a la double entree le marche a l etranger marche l hallux marche l hallux marche
# Levenshetein Distance: 132.0
# ***BLEU Score***: 0.5336172773868456
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  the double helix and after from the gene to the human
# Real Translation:  apres la double helice du gene a l humain
# Predicted Translation:  la double helice et apres du gene a l humain
# Levenshetein Distance: 15.0
# ***BLEU Score***: 0.668740304976422
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  the helix of life
# Real Translation:  l helice de la vie
# Predicted Translation:  l augmentation de la vie l helices de la vie l helices de l helices
# Levenshetein Distance: 49.0
# ***BLEU Score***: 0.5081327481546147
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  travel medicine
# Real Translation:  medecine des voyages
# Predicted Translation:  medecine des voyages medecine des voyages
# Levenshetein Distance: 21.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  quality control of gene therapy products approach of the french agency for the safety of health products
# Real Translation:  le controle de la qualite des produits de therapie genique approche de l afssaps
# Predicted Translation:  controle de qualite de la therapie genique produits actifs de l agence francaise de securite des produits de sante
# Levenshetein Distance: 71.0
# ***BLEU Score***: 0.47897362544357464
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  dna methyltransferases from chromatin remodeling to cancer
# Real Translation:  les methyltransferases de l adn du remodelage de la chromatine au cancer
# Predicted Translation:  l adn histone du remodelage de la chromatine a du cancer du cancer
# Levenshetein Distance: 38.0
# ***BLEU Score***: 0.6262844962765469
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  glucocorticoids , beta hydroxysteroid dehydrogenase type , and visceral obesity
# Real Translation:  glucocorticoides , beta hydroxysteroide deshydrogenase de type et obesite viscerale
# Predicted Translation:  corticoides , beta p delta et obesite viscerale de type et de l obesite viscerale
# Levenshetein Distance: 34.0
# ***BLEU Score***: 0.668740304976422
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  regeneration of vertebrate appendage an old experimental model to study stem cells in the adult
# Real Translation:  la regeneration des appendices chez les vertebres un modele experimental ancien pour etudier les cellules souches chez l adulte
# Predicted Translation:  regeneration du tissu moteur un modele experimental d etude des cellules souches de l adulte
# Levenshetein Distance: 45.0
# ***BLEU Score***: 0.6042750794713536
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  when the mother further impacts the destiny of her offspring maternal effect mutations
# Real Translation:  quand la mere est plus que responsable du devenir de sa progeniture les mutations a effet maternel
# Predicted Translation:  quand la mere a impacts le destin de her de her . mutations maternelles issues de mutations maternelles maternelles de type effet genetique maternal gt
# Levenshetein Distance: 92.0
# ***BLEU Score***: 0.447213595499958
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  within colony relatedness asymmetry and social conflicts in ants
# Real Translation:  asymetries de parente et conflits d interet genetique chez les fourmis
# Predicted Translation:  a travers des anomalies de la noblesse elastique signification et conflits sociaux dans des fourmis des meninges
# Levenshetein Distance: 75.0
# ***BLEU Score***: 0.4924790605054523
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  the ehlers danlos syndrome the extracellular matrix scaffold in question
# Real Translation:  le syndrome d ehlers danlos l architecture matricielle en question
# Predicted Translation:  syndrome d ehlers danlos matrice extracellulaire en question d une meme partie
# Levenshetein Distance: 40.0
# ***BLEU Score***: 0.537284965911771
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  cerebellar long term depression a mechanism for learning and memory
# Real Translation:  la depression synaptique a long terme un mecanisme pour la memoire et l apprentissage au niveau du cervelet
# Predicted Translation:  depression du tronc cerebelleux un mecanisme pour l apprentissage et la memoire memoire
# Levenshetein Distance: 54.0
# ***BLEU Score***: 0.5266403878479265
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  immunological synapses and neuronal synapses
# Real Translation:  synapses immunologiques et synapses neuronales
# Predicted Translation:  synapses immunologie et synapses neuronale synapses et synapses synapses synapses et synapses synapses neuronale synapses et synapses
# Levenshetein Distance: 88.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  severe neuropathy with agenesis of the corpus callosum
# Real Translation:  la neuropathie sensitivo motrice hereditaire avec agenesie du corps calleux
# Predicted Translation:  neuropathies severes avec agenesie du corps calleux du corps calleux
# Levenshetein Distance: 38.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  genetic polymorphisms linked to myocardial ischemia in a japanese population
# Real Translation:  polymorphismes genetiques et risque d infarctus du myocarde
# Predicted Translation:  polymorphisme genetique associes a l ischemie myocardique dans une population de niveau du japonaise une population de niveau et de ses japonais
# Levenshetein Distance: 100.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  the orphan nuclear receptor rev erb alpha is a major component of the circadian clock
# Real Translation:  le recepteur nucleaire orphelin rev erb alpha oscille entre repression et activation
# Predicted Translation:  le recepteur nucleaire du nucleaire la glande c est une transformation majeure de l horloge circadienne circadienne
# Levenshetein Distance: 70.0
# ***BLEU Score***: 0.5856596027429395
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  origin of gabaergic cortical interneurons in mice and humans
# Real Translation:  un nouveau rebondissement dans la quete de l origine des interneurones gabaergiques du cortex cerebral ?
# Predicted Translation:  origine du propionate du cortex thermique chez la souris et l humain et humain
# Levenshetein Distance: 79.0
# ***BLEU Score***: 0.5169731539571706
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  cd involvement as a regulator of cell proliferation
# Real Translation:  cd , un regulateur de la croissance et de l invasion cellulaire
# Predicted Translation:  le role de la proliferation des lymphocytes c est un regulateur de proliferation
# Levenshetein Distance: 57.0
# ***BLEU Score***: 0.5266403878479265
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  action of cytotoxic necrotizing factor from e . coli
# Real Translation:  l activation degradation proteasomique des gtpases rho par cnf confere des capacites invasives aux e . coli uropathogenes
# Predicted Translation:  action de l effet de l inter . coli a h . coli a h . coli a
# Levenshetein Distance: 84.0
# ***BLEU Score***: 0.7259795291154771
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  a cryptic protease couples deubiquitination and degradation by the proteasome
# Real Translation:  le motif jamm pour une nouvelle classe de proteases du signalosome au proteasome
# Predicted Translation:  une protease cryptique , des couples
# Levenshetein Distance: 61.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  enzymes that relax supercoiled dna
# Real Translation:  les enzymes qui controlent la torsion de l adn
# Predicted Translation:  les enzymes de l adn phosphocalcique
# Levenshetein Distance: 29.0
# ***BLEU Score***: 0.5408536609893481
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  fibulin is essential for elastic fiber development
# Real Translation:  l invalidation du gene de la fibuline induit une elastinopathie
# Predicted Translation:  la reserve est essentiel de la formation des fibres elastiques
# Levenshetein Distance: 45.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  clefts and webs same etiology for two syndromes that at first sight are very different
# Real Translation:  fentes et brides une meme etiologie pour deux syndromes a priori bien differents
# Predicted Translation:  les fentes et les fictions endocriniennes une meme cause pour deux syndromes apparentes a la premiere vue sont differentes differentes differents sont differentes differents sont differentes differents sont differentes differents differents sont differentes differents differents sont differentes differents differents sont differentes differents differents sont differentes differents
# Levenshetein Distance: 318.0
# ***BLEU Score***: 0.3839817133079349
#
# INFO:tensorflow:Restoring parameters from INFO7374-12200
# Source Sentence:  control of body mass by leptin occurs through the sympathetic nervous system
# Real Translation:  le gros arbre qui cachait la foret
# Predicted Translation:  controle de masse corporelle par la leptine au secours du systeme nerveux sympathique
# Levenshetein Distance: 67.0
# ***BLEU Score***: 0
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Prediction Output and Metrics on 400 test sentences:
# Average BLEU Score on our test corpus is 0.3705584122841522
# Average Levenshetein distance Score on our test corpus is 67.845

# %% [markdown]
# # RESULT FROM GOOGLE TRANSLATOR

# %%
import unicodedata
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')
  
import re

def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())

    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)

    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

    w = w.rstrip().strip()

    # adding a start and an end token to the sentence
    # so that the model know when to start and stop predicting.
#     w = '<start> ' + w + ' <end>'
    return w

# %%
googletrans = []

with open('400_google_test_trans.txt', 'r') as f:
    for line in f:
        googletrans.append(preprocess_sentence(line.strip('\n')))

# %%
googletrans[:5]
# Out:
# ['acetabuloplastie de conservation dans le syndrome de la jambe',
#  'echec de la prise en charge primaire de la luxation du developpement des annees hanches experience en normandie',
#  'validation d un outil de mesure des parametres pelviens et vertebraux de l equilibre sagittal',
#  'arthroplastie totale du coude guepar i dans les implants de polyarthrite rhumatoide suivie en moyenne de mois',
#  'evaluation radiographique dynamique du ligament gleno humeral inferieur anterieur']

# %%
tgt_label = []

with open('400-test-tgt.txt', 'r') as f:
    for line in f:
        tgt_label.append(line.strip('\n'))

# %%
tgt_label[:5]
# Out:
# [' la butee osteoplastique dans l osteochondrite primitive de la hanche ',
#  ' echecs de la prise en charge initiale de la maladie luxante de la hanche en haute normandie analyse sur une periode de annees consecutives ',
#  ' validation d un outil de mesure des parametres pelviens et rachidiens de l equilibre sagittal du rachis ',
#  ' prothese totale de coude guepar i dans la polyarthrite rhumatoide cas avec un recul moyen de mois ',
#  ' etude radiographique dynamique du ligament gleno humeral inferieur ']

# %%
import numpy as np
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu



bleu_score = []

for i in range(len(googletrans)):
    bleu = sentence_bleu(tgt_label[i].split(), googletrans[i].split())
    bleu_score.append(bleu)
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
np.average(bleu_score)
# Out:
# 0.30739238633728705

# %%
for i in range(400):
  print('target sentence: {}'.format(tgt_label[i]))
  print('google translate: {}'.format(googletrans[i]))
  print('bleu score: {}'.format(bleu_score[i]))
  print('                                                                      ')
# Out:
# target sentence:  la butee osteoplastique dans l osteochondrite primitive de la hanche
# google translate: acetabuloplastie de conservation dans le syndrome de la jambe
# bleu score: 0
#
# target sentence:  echecs de la prise en charge initiale de la maladie luxante de la hanche en haute normandie analyse sur une periode de annees consecutives
# google translate: echec de la prise en charge primaire de la luxation du developpement des annees hanches experience en normandie
# bleu score: 0
#
# target sentence:  validation d un outil de mesure des parametres pelviens et rachidiens de l equilibre sagittal du rachis
# google translate: validation d un outil de mesure des parametres pelviens et vertebraux de l equilibre sagittal
# bleu score: 0.6042750794713536
#
# target sentence:  prothese totale de coude guepar i dans la polyarthrite rhumatoide cas avec un recul moyen de mois
# google translate: arthroplastie totale du coude guepar i dans les implants de polyarthrite rhumatoide suivie en moyenne de mois
# bleu score: 0.4924790605054523
#
# target sentence:  etude radiographique dynamique du ligament gleno humeral inferieur
# google translate: evaluation radiographique dynamique du ligament gleno humeral inferieur anterieur
# bleu score: 0
#
# target sentence:  tumeur a cellules geantes de la rotule avec metastases pulmonaires a propos d un cas
# google translate: tumeur a cellules geantes de la rotule avec metastases au poumon un rapport de cas
# bleu score: 0.5081327481546147
#
# target sentence:  lipome para osteal ossifiant costal a propos d un cas
# google translate: lipome parosteal osseux de la cote rapport de cas
# bleu score: 0
#
# target sentence:  schwannome bifocal de la bifurcation sciatique a propos d un cas
# google translate: schwannome bifocal du nerf sciatique un rapport de cas
# bleu score: 0
#
# target sentence:  la nacre pinctada margaritifera caracterisation physico chimique , proprietes biomecaniques et cytocompatibilite in vitro
# google translate: pinctada margaritifera nacre nacre proprietes physico chimiques et biomecaniques et cytocompatibilite in vitro
# bleu score: 0
#
# target sentence:  le kyste osseux anevrysmal chez l enfant a propos de cas
# google translate: kyste osseux anevrismal chez les enfants
# bleu score: 0
#
# target sentence:  place de l embrochage centro medullaire et de l injection de corticoides dans le traitement des kystes osseux essentiels de l enfant
# google translate: traitement des kystes osseux solitaires par clouage intra medullaire ou injection de steroides chez les enfants
# bleu score: 0
#
# target sentence:  luxation peri lunaire du carpe resultats a long terme
# google translate: luxation du poignet peri lunaire a long terme
# bleu score: 0.5946035575013605
#
# target sentence:  kystes dits quot synoviaux quot du poignet systematisation topographique et pathogenie
# google translate: ganglions du poignet propositions de systematisation topographique et d histoire naturelle
# bleu score: 0.5491004867761125
#
# target sentence:  la prothese de tete radiale guepar dans les fractures recentes et anciennes a propos d une serie de cas
# google translate: prothese radiale de guepar pour fractures recentes et anciennes une serie de cas
# bleu score: 0
#
# target sentence:  reinfection avec changement de germe apres reimplantation de protheses pour infection a propos de cas
# google translate: nouvelle infection avec une souche differente apres la revision de la prothese pour les cas d infection bacterienne
# bleu score: 0.4854917717073234
#
# target sentence:  interet de la scintigraphie couplee gallium technetium afin d optimiser le delai de reimplantation prothetique en deux temps des infections sur arthroplastie de hanche a propos d une serie continue de cas
# google translate: utilisation de la scintigraphie combinee de gallium et de technetium pour determiner l intervalle avant la deuxieme etape de la reimplantation prothetique en cas d infection par arthroplastie de hanche , serie consecutive de cas
# bleu score: 0.488923022434901
#
# target sentence:  actualisation des recommandations de la splf pour la prise en charge de la bpco points essentiels
# google translate: directives actualisees de la societe de pneumologie de langue francaise pour la prise en charge de la maladie pulmonaire obstructive chronique points essentiels
# bleu score: 0
#
# target sentence:  chylothorax sous simvastatine
# google translate: chylothorax induit par la simvastatine
# bleu score: 0
#
# target sentence:  comptes polliniques
# google translate: pollinique
# bleu score: 0
#
# target sentence:  opacites pulmonaires excavees d evolution inhabituelle
# google translate: progression inhabituelle de la cavitation pulmonaire opaque
# bleu score: 0
#
# target sentence:  une complication inattendue de l asthme aigu grave sous ventilation artificielle le chylothorax
# google translate: chylothorax complication inattendue de la ventilation artificielle dans l asthme aigu severe
# bleu score: 0.537284965911771
#
# target sentence:  insuffisance respiratoire aigue avec pneumopathie apres administration intrathecale de methotrexate
# google translate: syndrome de detresse respiratoire aigue du a une pneumonite apres administration intrathecale de methotrexate
# bleu score: 0.5169731539571706
#
# target sentence:  anthracose bronchique et surcharge pulmonaire en micas
# google translate: anthracose bronchique et surcharge pulmonaire en mica
# bleu score: 0
#
# target sentence:  immunite de greffe en transplantation pulmonaire
# google translate: l immunite du greffon dans la transplantation pulmonaire
# bleu score: 0.5946035575013605
#
# target sentence:  les regles de prediction un guide de lecture
# google translate: regles de prediction clinique guide du lecteur
# bleu score: 0
#
# target sentence:  tabagisme , asthme et phenotypes associes . approche epidemiologique
# google translate: tabagisme , asthme et phenotypes associes . une approche epidemiologique
# bleu score: 0.668740304976422
#
# target sentence:  physiopathologie de la bronchiolite obliterante des transplantes pulmonaires
# google translate: physiopathologie de la bronchiolite obliterante dans les greffes de poumon
# bleu score: 0
#
# target sentence:  interet des expectorations induites dans l exploration de l asthme
# google translate: valeur des expectorations induites dans l investigation de l asthme
# bleu score: 0.5088274727401554
#
# target sentence:  apport de la tdm dans l exploration de la sarcoidose thoracique
# google translate: valeur de la tomodensitometrie dans l investigation de la sarcoidose thoracique
# bleu score: 0.5491004867761125
#
# target sentence:  toxicite pulmonaire aigue de la gemcitabine un role pour l exposition a l amiante ?
# google translate: toxicite pulmonaire aigue due a la gemcitabine un role pour l exposition a l amiante ?
# bleu score: 0.7071067811865476
#
# target sentence:  facteurs lies a la severite et au controle de l asthme recemment diagnostique dans une cohorte de patients adultes
# google translate: facteurs predictifs de la gravite et du degre de maitrise des symptomes de l asthme dans une cohorte de patients adultes recemment diagnostiquee a . s . m . une etude
# bleu score: 0.5993418090318328
#
# target sentence:  amiante gemcitabine . risques conjoints de toxicite pulmonaire ?
# google translate: l amiante gemcitabin . risque combine de toxicite pulmonaire ?
# bleu score: 0.7400828044922853
#
# target sentence:  analyses mineralogiques d echantillons biologiques et pathologies respiratoires
# google translate: analyse minerale d echantillons biologiques et de pathologies respiratoires
# bleu score: 0.5773502691896257
#
# target sentence:  les scores et le jugement clinique
# google translate: scores cliniques et jugement clinique
# bleu score: 0
#
# target sentence:  traitement des formes localisees du cancer bronchique non a petites cellules perspectives en
# google translate: traitement des formes localisees de cancers bronchiques non a petites cellules dans
# bleu score: 0.537284965911771
#
# target sentence:  tuberculose et pauvrete
# google translate: tuberculose et pauvrete
# bleu score: 0
#
# target sentence:  les anti ige et les traitements du futur des allergies respiratoires
# google translate: traitements anti ige et futurs des allergies respiratoires
# bleu score: 0
#
# target sentence:  allergie alimentaire et asthme chez l enfant
# google translate: allergie alimentaire et asthme chez les enfants
# bleu score: 0
#
# target sentence:  les examens complementaires en allergie respiratoire
# google translate: tests complementaires en allergie respiratoire
# bleu score: 0
#
# target sentence:  les allergenes respiratoires donnees actuelles
# google translate: allergies respiratoires donnees actuelles
# bleu score: 0
#
# target sentence:  asthme allergique et non allergique similitudes et differences
# google translate: asthme intrinseque
# bleu score: 0
#
# target sentence:  physiopathologie de la reaction ige dependante dans l allergie respiratoire
# google translate: physiopathologie de la reaction ige dependante en cas d allergie respiratoire
# bleu score: 0.5491004867761125
#
# target sentence:  genes de l allergie respiratoire
# google translate: genes de maladie allergique respiratoire
# bleu score: 0
#
# target sentence:  etude critique des hypotheses explicatives de l augmentation des allergies respiratoires
# google translate: analyse critique d hypotheses expliquant l augmentation des allergenes respiratoires
# bleu score: 0.668740304976422
#
# target sentence:  l allergie respiratoire un monde qui change
# google translate: allergie respiratoire un monde en mutation
# bleu score: 0
#
# target sentence:  quot paralysies recurrentielles de l adulte quot . texte long october
# google translate: guides de pratique clinique . paralysie recurrente du nerf larynge chez l adulte . texte integral
# bleu score: 0.5946035575013605
#
# target sentence:  antibiotherapie par voie generale en pratique courante infections respiratoires basses de l adulte . actualisation
# google translate: antibiotherapie systemique dans la pratique de routine des infections des voies respiratoires inferieures chez les adultes . mettre a jour
# bleu score: 0.5623413251903491
#
# target sentence:  antibiotherapie par voie generale en pratique courante angine . actualisation
# google translate: antibiotherapie systemique dans la pratique de routine des recommandations pour la pharyngite aigue . mettre a jour
# bleu score: 0.5856596027429395
#
# target sentence:  obstruction nasale et compliance a la ventilation nasale a pression positive
# google translate: obstruction nasale et respect de la pression nasale positive
# bleu score: 0
#
# target sentence:  alterations cellulaires et cancerogenese orl , marqueurs moleculaires et cibles therapeutiques potentielles
# google translate: modifications oto rhino laryngologiques cellulaires et neoplasiques , marqueurs moleculaires et potentiel therapeutique
# bleu score: 0.5266403878479265
#
# target sentence:  les implants cochleaires pediatriques
# google translate: implants cochleaires pediatriques
# bleu score: 0
#
# target sentence:  c kit parfois un faux ami !
# google translate: pieges diagnostiques possibles de l immunohistochimie en kit c
# bleu score: 0.5773502691896257
#
# target sentence:  leiomyome de la vessie . a propos d un cas
# google translate: leiomyoma de la vessie
# bleu score: 0
#
# target sentence:  tumeur inhabituelle du systeme nerveux central
# google translate: une tumeur inhabituelle du systeme nerveux central
# bleu score: 0
#
# target sentence:  une tumeur cutanee composite
# google translate: une tumeur composite de la peau
# bleu score: 0
#
# target sentence:  tumeur cutanee du bas du dos chez une femme adulte
# google translate: tumeur cutanee du bas du dos chez une femme adulte
# bleu score: 0
#
# target sentence:  une tumeur renale congenitale
# google translate: une tumeur renale congenitale
# bleu score: 0
#
# target sentence:  une masse abdominale avec calcifications
# google translate: masse abdominale avec calcifications
# bleu score: 0
#
# target sentence:  hemangiome epithelioide osseux recidivant
# google translate: hemangiome epithelioide osseux recurrent
# bleu score: 0
#
# target sentence:  fibromatose intestinale solitaire congenitale
# google translate: fibromatose intestinale solitaire prenatale
# bleu score: 0
#
# target sentence:  carcinome a cellules claires de l ovaire simulant une tumeur vitelline
# google translate: carcinome a cellules claires de l ovaire simulant une tumeur du sac vitellin
# bleu score: 0.6262844962765469
#
# target sentence:  une infection buccale a ne pas sous estimer l actinomycose . etude de observations avec necrose osseuse extensive
# google translate: une infection orale a ne pas sous estimer actinomycose . une etude de cas de necrose osseuse etendue
# bleu score: 0.5773502691896257
#
# target sentence:  hamartome kystique retrorectal . a propos d une observation
# google translate: hamartomes kystiques retrorectaux . rapport d un cas
# bleu score: 0.7071067811865476
#
# target sentence:  choriocarcinome infantile et maternel
# google translate: choriocarcinome infantile et maternel
# bleu score: 0
#
# target sentence:  lymphome nk t nasal . a propos d un cas
# google translate: lymphome nk t nasal . un rapport de cas
# bleu score: 0.6865890479690392
#
# target sentence:  entites recentes en pathologie tumorale des tissus mous . e partie
# google translate: entites recentes dans la pathologie des tumeurs des tissus mous . partie
# bleu score: 0.537284965911771
#
# target sentence:  les membranes proliferatives et cicatricielles du segment posterieur de l oeil . caracteristiques histologiques et etiologiques
# google translate: tissus cicatriciels du segment posterieur de l oeil traits histologiques et etiologiques
# bleu score: 0.537284965911771
#
# target sentence:  les neuropathies amyloides . etude histopathologique de nerf peripherique dans cas
# google translate: neuropathies amyloides . etude histopathologique de la biopsie du nerf peripherique dans les cas
# bleu score: 0.5169731539571706
#
# target sentence:  pathologie des tissus mous evolutions actuelles et perspectives
# google translate: pathologie des tissus mous enjeux et perspectives actuels
# bleu score: 0
#
# target sentence:  helicobacter pylori , l inflammation gastrique et ses consequences
# google translate: helicobacter pylori , inflammation gastrique et ses consequences
# bleu score: 0.5247357977607321
#
# target sentence:  flore intestinale et maladie de crohn
# google translate: flore intestinale et maladie de crohn
# bleu score: 0
#
# target sentence:  l immunite innee contre les agressions bacteriennes
# google translate: agression bacterienne
# bleu score: 0
#
# target sentence:  teneur en acides hydroxycinnamiques de differents lots de sommites fleuries d armoise
# google translate: taux d acide hydroxycinnamique de divers lots provenant de sommites fleuries d armoise
# bleu score: 0.5266403878479265
#
# target sentence:  diagnostic moleculaire des infections virales materno foetales
# google translate: diagnostic moleculaire des infections viro materno f tales
# bleu score: 0.5946035575013605
#
# target sentence:  recentes approches therapeutiques de la mucoviscidose
# google translate: nouvelles approches therapeutiques de la fibrose kystique
# bleu score: 0
#
# target sentence:  comparaison de la vitalite des bacteries libres et des bacteries en biofilm par cytometrie en flux
# google translate: la viabilite comparee des bacteries planctoniques et des bacteries dans les biofilms par cytometrie en flux
# bleu score: 0
#
# target sentence:  les cytochromes p , le tonus vasculaire et la pathologie variqueuse
# google translate: cytochromes p , varicose de tonus vasculaire
# bleu score: 0.7311104457090247
#
# target sentence:  les vaccins a adn
# google translate: vaccins a l adn
# bleu score: 0.8408964152537145
#
# target sentence:  un petit cancer du bas rectum
# google translate: un cancer de petite taille du bas rectum
# bleu score: 0
#
# target sentence:  un petit carcinome hepatocellulaire
# google translate: un carcinome hepatocellulaire de petite taille
# bleu score: 0
#
# target sentence:  un foie multinodulaire asymptomatique
# google translate: hepatopathie multinodulaire asymptomatique
# bleu score: 0
#
# target sentence:  un cancer colique metastatique d emblee
# google translate: cancer metastatique du colon de premiere ligne
# bleu score: 0
#
# target sentence:  cancer du pancreas du bilan de resecabilite au traitement palliatif
# google translate: cancer du pancreas , du travail de resection au traitement palliatif
# bleu score: 0
#
# target sentence:  de la dysplasie a la dysphagie
# google translate: de la dysplasie a la dysphagie
# bleu score: 0.38753858253732953
#
# target sentence:  un quot coup de main quot pour exonerer une histoire clinique bien banale
# google translate: un quotient coup de main quot une histoire clinique ordinaire
# bleu score: 0
#
# target sentence:  hepatites fulminantes non virales
# google translate: hepatite fulminante non virale
# bleu score: 0
#
# target sentence:  les troubles fonctionnels anorectaux a l epreuve de la medecine factuelle nouvelles options therapeutiques pour le traitement de l incontinence fecale
# google translate: troubles fonctionnels ano rectaux nouvelles options therapeutiques fondees sur des preuves pour le traitement de l incontinence fecale
# bleu score: 0.4854917717073234
#
# target sentence:  therapeutiques chirurgicales conventionnelles pour le traitement de l incontinence anale et des troubles de la statique rectale
# google translate: traitements chirurgicaux conventionnels pour l incontinence anale et les troubles rectaux
# bleu score: 0.5491004867761125
#
# target sentence:  troubles fonctionnels anorectaux . therapeutiques non chirurgicales a l epreuve de la medecine factuelle
# google translate: troubles ano rectaux fonctionnels . therapies non chirurgicales fondees sur des preuves
# bleu score: 0.537284965911771
#
# target sentence:  explorations fonctionnelles usuelles utiles et moins utiles dans les troubles fonctionnels anorectaux
# google translate: tests physiologiques de routine anorectaux utiles et moins utiles chez les patients presentant des troubles ano rectaux fonctionnels
# bleu score: 0
#
# target sentence:  valeur et limites de la clinique dans les troubles fonctionnels ano rectaux hors algies chroniques
# google translate: valeur et limites de l examen clinique par rapport aux troubles ano rectaux fonctionnels , a l exception des douleurs ano rectales chroniques
# bleu score: 0.250737833894674
#
# target sentence:  biopsie echo endoscopiquement guidee quand est elle irremplacable ?
# google translate: biopsie guidee par echographie endoscopique quand est elle indispensable ?
# bleu score: 0.5623413251903491
#
# target sentence:  la tomographie par emission de positons tep en cancerologie digestive
# google translate: tomographie par emission de positrons et oncologie gastro intestinale
# bleu score: 0
#
# target sentence:  echographie de contraste place dans le diagnostic et la caracterisation des tumeurs du foie
# google translate: valeur d echographie de contraste dans le diagnostic et la caracterisation des tumeurs hepatiques
# bleu score: 0.481334461755719
#
# target sentence:  irm du pancreas place et limites
# google translate: imagerie par resonance magnetique de la valeur du pancreas et de ses limites
# bleu score: 0
#
# target sentence:  coloscopie virtuelle mythe ou realite ?
# google translate: coloscopie virtuelle mythe ou realite ?
# bleu score: 0.6389431042462724
#
# target sentence:  la capsule endoscopique principe , premiers resultats cliniques et perspectives
# google translate: les principes de la capsule endoscopique , premiers resultats cliniques et perspectives
# bleu score: 0.537284965911771
#
# target sentence:  hypoxie hepatique aigue , foie cardiaque congestif
# google translate: hepatite hypoxique aigue , foie cardiaque congestif
# bleu score: 0.6147881529512643
#
# target sentence:  hepatites bacteriennes
# google translate: hepatite bacterienne
# bleu score: 0
#
# target sentence:  atteintes hepatiques aigues medicamenteuses . qu apportent les echelles diagnostiques ?
# google translate: lesion hepatique aigue d origine medicamenteuse . quelle est la valeur des echelles de diagnostic ?
# bleu score: 0.6580370064762462
#
# target sentence:  hepatites auto immunes prise en charge therapeutique
# google translate: gestion therapeutique autohepatique de l hepatite
# bleu score: 0
#
# target sentence:  steato hepatite et anomalies metaboliques et nutritionnelles
# google translate: steatohepatite et anomalies metaboliques et nutritionnelles
# bleu score: 0
#
# target sentence:  quelques reflexions sur la biopsie du foie
# google translate: commentaires sur la biopsie du foie
# bleu score: 0
#
# target sentence:  hepatite aigue cytolytique probablement due a la prise de sildenafil viagra
# google translate: hepatite aigue cytolytique probablement due au viagra du sildenafil
# bleu score: 0
#
# target sentence:  insuffisance surrenale reversible au cours d un traitement par interferon alpha d une hepatite chronique c
# google translate: insuffisance surrenale reversible apres traitement par interferon alpha dans le traitement de l hepatite c chronique
# bleu score: 0.5946035575013605
#
# target sentence:  reaction du greffon contre l hote apres transplantation hepatique . guerison apres introduction du tacrolimus
# google translate: maladie du greffon contre l hote suite a une greffe du foie . evolution favorable apres traitement par tacrolimus
# bleu score: 0.6303647413359293
#
# target sentence:  pancreatite aigue associee a un traitement corticoide au cours de la maladie de crohn
# google translate: pancreatite aigue associee a la corticotherapie dans la maladie de crohn
# bleu score: 0.5491004867761125
#
# target sentence:  traitement endoscopique des hemorragies digestives basses d origine diverticulaire
# google translate: traitement endoscopique des hemorragies de l intestin inferieur d origine diverticulaire
# bleu score: 0.6529942057256104
#
# target sentence:  colite aigue induite par une solution de desinfection des endoscopes a base d acide peracetique
# google translate: colite aigue induite par une solution a base d acide peracetique utilisee pour desinfecter les endoscopes
# bleu score: 0.5946035575013605
#
# target sentence:  rechute metastatique renale apres resection a visee curative d un carcinome epidermoide de l oesophage
# google translate: metastase renale apres resection curative d un carcinome epidermoide de l sophage
# bleu score: 0.6389431042462724
#
# target sentence:  vipome hepatique primitif
# google translate: vipoma hepatique primaire
# bleu score: 0
#
# target sentence:  la tuberculose pancreatique . a propos de deux cas
# google translate: tuberculose pancreatique . rapport de deux cas
# bleu score: 0.6147881529512643
#
# target sentence:  foie et vieillissement , aspects cliniques
# google translate: aspects cliniques du foie et du vieillissement
# bleu score: 0
#
# target sentence:  depistage du carcinome hepatocellulaire dans une cohorte de malades porteurs d une cirrhose d origine principalement alcoolique
# google translate: depistage de l hepatocarcinome dans une cohorte avec cirrhose principalement d origine alcoolique
# bleu score: 0.579915067709191
#
# target sentence:  aspects therapeutiques de la co infection par les virus de l immunodeficience humaine et des hepatites b et c
# google translate: aspects therapeutiques du virus de l immunodeficience humaine , de l hepatite b et de la co infection
# bleu score: 0.5773502691896257
#
# target sentence:  depistage du carcinome hepatocellulaire entre cynisme et angelisme ?
# google translate: depistage du cancer hepatocellulaire entre cynisme ou perfectionnisme ?
# bleu score: 0.5773502691896257
#
# target sentence:  questions au professeur jean francois bretagne
# google translate: questions au professeur jean francois bretagne
# bleu score: 0
#
# target sentence:  colite aigue hemorragique chez une malade traitee par rofecoxib associe a une auto medication par aspirine
# google translate: colite ulcereuse aigue chez un patient traite avec le rofecoxib qui prenait de l aspirine en auto medication
# bleu score: 0.4854917717073234
#
# target sentence:  complications gastro intestinales des anti inflammatoires non steroidiens et de l aspirine a faible dose
# google translate: complications gastro intestinales des anti inflammatoires non steroidiens et de l aspirine a faible dose
# bleu score: 0.6042750794713536
#
# target sentence:  xxie reunion du club d etudes des cellules epitheliales digestives ceced . janvier , nantes , france
# google translate: resumes de la xxi reunion du groupe de travail sur les cellules epitheliales digestives . nantes , france , janvier
# bleu score: 0.5623413251903491
#
# target sentence:  suivi d une cohorte de cas d adenomes recto coliques traites en et . recherche de parametres lies a la recidive adenomateuse
# google translate: suivi d une cohorte d adenomes colorectaux traites en et . recherche de parametres lies a la recurrence adenomateuse
# bleu score: 0.6303647413359293
#
# target sentence:  effet de la ventilation assistee et de la position sur le reflux gastro oesophagien acide apres laparotomie
# google translate: effet de la ventilation assistee et de la position sur le reflux acide gastro oesophagien apres laparotomie
# bleu score: 0
#
# target sentence:  resultats a long terme du traitement des rectites radiques hemorragiques par la coagulation au plasma d argon
# google translate: resultats a long terme du traitement de la rectite hemorragique par coagulation au plasma argon
# bleu score: 0.5081327481546147
#
# target sentence:  la mesure de l impedance oesophagienne dans le reflux gastro oesophagien
# google translate: mesure de l impedance oesophagienne dans les resultats et les perspectives de la maladie de reflux gastro oesophagien
# bleu score: 0.4854917717073234
#
# target sentence:  la place croissante de la coagulation au plasma argon en endoscopie digestive therapeutique
# google translate: interet croissant pour la coagulation par plasma d argon dans l endoscopie gastro intestinale
# bleu score: 0.6147881529512643
#
# target sentence:  conduite a tenir devant une migraine ophtalmique
# google translate: gerer une migraine ophtalmique
# bleu score: 0
#
# target sentence:  inflammation palpebrale pseudotumorale . a propos d une observation anatomo clinique
# google translate: inflammation pseudotumorale des paupieres . a propos d un cas clinique anatomo
# bleu score: 0.7071067811865476
#
# target sentence:  naevus du repli semi lunaire de la conjonctive de decouverte tardive
# google translate: plis conjonctivaux semi lunaires d apparition tardive presumee
# bleu score: 0.5946035575013605
#
# target sentence:  melanomes choroidiens
# google translate: melanomes choroidiens
# bleu score: 0
#
# target sentence:  apports de l informatique au diagnostic et au traitement . le principe de l hypothese privilegiee . exemple du glaucome
# google translate: utilite des ordinateurs en diagnostic et en therapie . le principe de l hypothese privilegiee . l exemple du glaucome
# bleu score: 0.5623413251903491
#
# target sentence:  transmission genetique de la cataracte congenitale
# google translate: la genetique de la cataracte hereditaire
# bleu score: 0
#
# target sentence:  l association de substituts lacrymaux est elle toujours synergique ?
# google translate: combinant des larmes artificielles sont ils toujours synergiques ?
# bleu score: 0.5773502691896257
#
# target sentence:  rejet de greffe et iontophorese de corticoides a propos de cas
# google translate: rapport de cas de greffe de cornee et d iontophorese de corticoides
# bleu score: 0.537284965911771
#
# target sentence:  modifications vitreennes au cours d un syndrome de stickler
# google translate: changements vitreux dans le syndrome de stickler
# bleu score: 0
#
# target sentence:  vascularites retiniennes proliferantes et sclerose en plaques . a propos d un cas
# google translate: vascularite retinienne proliferative et sclerose en plaques un rapport de cas
# bleu score: 0
#
# target sentence:  recuperation fonctionnelle apres chirurgie d exerese d un meningiome spheno orbitaire . a propos d une observation
# google translate: amelioration visuelle postoperatoire dans le meningiome spheno orbital rapport de cas
# bleu score: 0
#
# target sentence:  l effet de la brimonidine sur l hypertonie postoperatoire apres une extraction extracapsulaire de la cataracte
# google translate: l effet de la brimonidine sur l hypertonie postoperatoire apres une extraction extracapsulaire de la cataracte
# bleu score: 0.5
#
# target sentence:  pronostic de la chirurgie des membranes epimaculaires secondaires a une dechirure retinienne ou un decollement de retine rhegmatogene
# google translate: pronostic de la chirurgie dans les membranes epimaculaires apres une rupture retinienne ou un decollement rhegmatogene de la retine
# bleu score: 0
#
# target sentence:  correlation entre la refraction et la biometrie oculaire
# google translate: correlation entre la refraction et la biometrie oculaire
# bleu score: 0
#
# target sentence:  ajustement du traitement antiviral apres greffe de cornee par mesure de la production d anticorps dans l humeur aqueuse
# google translate: ajustement du traitement antiviral chez les receveurs de cornee utilisant des tests de detection des anticorps dans l humeur aqueuse
# bleu score: 0.4728708045015879
#
# target sentence:  pourquoi pose t on encore des implants de chambre anterieure a support angulaire chez l aphaque ? incidence et circonstances des implantations sur ans a l hotel dieu de paris
# google translate: pourquoi les lentilles intraoculaires de la chambre anterieure aphaque sont elles encore implantees ? incidence sur cinq ans et circonstances d implantation a l hotel dieu a paris
# bleu score: 0.6500593260343692
#
# target sentence:  cytofluorimetrie sur empreintes conjonctivales au cours de la keratoconjonctivite seche effets de la ciclosporine topique sur l expression d antigene hla dr
# google translate: cytometrie en flux en cytologie de l impression au cours de la keratoconjonctivite seche effets de la cyclosporine a topique sur l expression hla dr
# bleu score: 0.5318295896944989
#
# target sentence:  effets modulateurs de collyres anti allergiques sur l activation du complement induite in vitro par des polluants particulaires
# google translate: effets in vitro des gouttes oculaires antiallergiques sur l activation du complement induite par les particules
# bleu score: 0.5
#
# target sentence:  hysterectomie sans douleurs une technique innovante
# google translate: hysterectomie sans douleur une technique innovante
# bleu score: 0
#
# target sentence:  hyperplasie kystique luteinisee des ovaires au cours d une grossesse normale
# google translate: hyperplasie ovarienne kystique luteinisee pendant une grossesse normale
# bleu score: 0
#
# target sentence:  premiere naissance apres un diagnostic genetique pre implantatoire dpi pratique sur embryons decongeles
# google translate: premiere naissance apres un diagnostic genetique preimplantatoire effectue sur des embryons decongeles
# bleu score: 0
#
# target sentence:  quand la femme enceinte risque d etre en manque d iode
# google translate: quand la femme enceinte risque une carence en iode
# bleu score: 0
#
# target sentence:  perinatalite en guyane francaise . evolution de
# google translate: soins perinatals et mortalite en guyane francaise . de
# bleu score: 0.5773502691896257
#
# target sentence:  resultat de la prise en charge prenatale des foetus avec tachycardie supra ventriculaire . a propos d une serie consecutive de cas
# google translate: resultats de la gestion prenatale des f tus atteints de tachycardie supraventriculaire . une serie de cas
# bleu score: 0.5856596027429395
#
# target sentence:  biomecanique de la reparation et resistance des tissus biologiques dans les cures de prolapsus pourquoi utiliser des protheses ?
# google translate: biomecanique de la repartition du stress et de la resistance des tissus biologiques pourquoi utiliser des protheses pour le traitement du prolapsus genital ?
# bleu score: 0.4518010018049224
#
# target sentence:  proprietes mecaniques des implants biologiques ou synthetiques utilises dans les cures de prolapsus et d incontinence urinaire de la femme quel est le materiau ideal ?
# google translate: proprietes mecaniques des implants biologiques ou synthetiques utilises pour traiter le prolapsus genital et l incontinence de stress chez la femme quel est le materiau ideal ?
# bleu score: 0.5216948600244291
#
# target sentence:  traitement chirurgical du prolapsus genital par une nouvelle technique d hysteropexie laterale prothetique combinant voie vaginale et coelioscopique
# google translate: traitement chirurgical du prolapsus genital avec une nouvelle technique d hysteropexie prothetique laterale combinant des methodes vaginales et laparoscopiques
# bleu score: 0.47897362544357464
#
# target sentence:  prise en charge post natale des uropathies de decouverte antenatale
# google translate: gestion postnatale des anomalies des voies urinaires apres diagnostic prenatal
# bleu score: 0
#
# target sentence:  pyelectasie
# google translate: pyelectasie
# bleu score: 0
#
# target sentence:  meningite tuberculeuse avec abces hypophysaire
# google translate: meningite tuberculeuse avec abces hypophysaire
# bleu score: 0
#
# target sentence:  imagerie du cervelet de l enfant
# google translate: imagerie du cervelet pediatrique
# bleu score: 0
#
# target sentence:  irm et traumatismes cranio encephaliques fermes
# google translate: irm de blessure a la tete fermee
# bleu score: 0.6147881529512643
#
# target sentence:  irm de l oreille
# google translate: irm de l oreille
# bleu score: 0.7071067811865476
#
# target sentence:  thalidomide et thromboses
# google translate: thalidomide et thrombose
# bleu score: 0
#
# target sentence:  examen mycologique
# google translate: examen mycologique
# bleu score: 0
#
# target sentence:  balanite pseudo epitheliomateuse keratosique et micacee
# google translate: balanite pseudoepitheliomateuse keratosique et micacee
# bleu score: 0
#
# target sentence:  les lasers de remodelage
# google translate: lasers dans le resurfacage de la peau
# bleu score: 0
#
# target sentence:  les heparines de bas poids moleculaire a l usage des dermatologues
# google translate: utilisation d heparines de bas poids moleculaire par des dermatologues
# bleu score: 0.5623413251903491
#
# target sentence:  eczema de contact aux cosmetiques
# google translate: dermatite de contact due aux cosmetiques
# bleu score: 0
#
# target sentence:  une hyperpigmentation cutaneo muqueuse reticulee
# google translate: hyperpigmentation cutanee muqueuse reticulee
# bleu score: 0
#
# target sentence:  tumefaction cutanee intermittente au retour du vietnam
# google translate: tumefaction cutanee intermittente apres un voyage au vietnam
# bleu score: 0
#
# target sentence:  maladies sexuellement transmissibles . etudes comparative entre les annees et dans le service de dermatologie du centre hospitalier ibn rochd , casablanca maroc
# google translate: maladies sexuellement transmissibles etude comparative entre les annees et dans le
# bleu score: 0
#
# target sentence:  metastases cutanees de mesotheliome pleural deux observations
# google translate: metastase cutanee de mesotheliome pleural deux cas
# bleu score: 0
#
# target sentence:  folliculite pustuleuse a eosinophiles de l enfant une forme particuliere
# google translate: folliculite pustuleuse eosinophilique dans la petite enfance un cas inhabituel
# bleu score: 0
#
# target sentence:  polynevrite sensitive induite par la dapsone disulone
# google translate: neuropathie peripherique sensorielle induite par la dapsone
# bleu score: 0
#
# target sentence:  eruptions acneiformes induites par le cetuximab
# google translate: eruptions acneiformes induites par le cetuximab
# bleu score: 0
#
# target sentence:  pustulose exanthematique aigue generalisee induite par des medicaments a faible absorption intestinale l acarbose et la nystatine
# google translate: pustulose exanthemateuse generalisee aigue induite par des medicaments a faible absorption digestive acarbose et nystatine
# bleu score: 0.5081327481546147
#
# target sentence:  toxidermie lichenoide au leflunomide arava
# google translate: reaction du medicament lichenoide au leflunomide
# bleu score: 0
#
# ...
# bleu score: 0.5408536609893481
#
# target sentence:  un symbionte de la glossine wigglesworthia glossinidia
# google translate: un symbiote de mouches tse tse wigglesworthia glossinidia
# bleu score: 0
#
# target sentence:  les vagues calciques entre cellules gliales une voie alternative de transmission d informations
# google translate: ondes de calcium entre les cellules gliales comment les astrocytes communiquent
# bleu score: 0
#
# target sentence:  le genome des mycobacteries etude biologique et interpretation evolutive
# google translate: l etude biologique du genome de mycobacterium et l interpretation evolutive
# bleu score: 0.5491004867761125
#
# target sentence:  une methode generale pour detecter des genes soumis a une selection recente
# google translate: une methode generale de detection des genes recemment selectionnes
# bleu score: 0
#
# target sentence:  genes homeotiques et apoptose , d architecte a sculpteur
# google translate: hox genes et apoptose , de l architecture a la sculpture
# bleu score: 0.7226568811456053
#
# target sentence:  l immunotherapie adoptive des tumeurs solides enfin rehabilitee
# google translate: immunotherapie adoptive dans les tumeurs solides nouvel espoir
# bleu score: 0
#
# target sentence:  cellules souches endogenes une vraie perspective therapeutique pour les accidents vasculaires cerebraux ?
# google translate: cellules souches endogenes une veritable perspective therapeutique pour les accidents vasculaires cerebraux ?
# bleu score: 0.5266403878479265
#
# target sentence:  cellules souches neurales adultes de la zone sous ventriculaire et reparation des maladies demyelinisantes
# google translate: cellules souches neurales de la zone sous ventriculaire de l adulte et reparation des maladies demyelinisantes
# bleu score: 0.5
#
# target sentence:  empreintes
# google translate: empreintes
# bleu score: 0
#
# target sentence:  mitose entree , sortie et issues de secours
# google translate: problemes d entree , de sortie et d urgence lies a la mitose
# bleu score: 0.6262844962765469
#
# target sentence:  sur les sentiers escarpes des montagnes de bioethique . episode aux confins de l eugenisme
# google translate: sur le sentier escarpe de la bioethique en montagne . episode dans le royaume de l eugenisme
# bleu score: 0.5856596027429395
#
# target sentence:  les troubles de la reconnaissance de soi une approche neuropsychologique des symptomes positifs de la schizophrenie
# google translate: problemes de reconnaissance du soi une approche neuropsychologique des symptomes positifs de la schizophrenie
# bleu score: 0
#
# target sentence:  la maladie de parkinson que nous apprennent les genes responsables des formes familiales ?
# google translate: la maladie de parkinson qu avons nous appris des genes responsables des formes familiales ?
# bleu score: 0.5081327481546147
#
# target sentence:  impact neurobiologique de la separation mere nouveau ne chez le rongeur
# google translate: impact neurobiologique de la separation des meres des nouveau nes chez les rongeurs
# bleu score: 0
#
# target sentence:  nouveaux aspects du cholesterol dans le systeme nerveux central
# google translate: nouveaux aspects du cholesterol dans le systeme nerveux central
# bleu score: 0
#
# target sentence:  la choree de huntington chez la drosophile et chez la souris vers de nouvelles pistes therapeutiques ?
# google translate: huntington choree chez la drosophile et la souris vers de nouvelles etapes therapeutiques
# bleu score: 0
#
# target sentence:  le codage de l action peut on dissocier l attention de l intention ?
# google translate: la planification de l action peut on separer l attention de l intention ?
# bleu score: 0.6147881529512643
#
# target sentence:  le developpement du systeme nerveux de la mouche au poisson , du poisson a l homme
# google translate: le developpement du systeme nerveux de la mouche au poisson , du poisson a l homme
# bleu score: 0.6580370064762462
#
# target sentence:  neurobiologie de la douleur trigeminale
# google translate: neurobiologie de la douleur trijumeau
# bleu score: 0
#
# target sentence:  comment fonctionne un recepteur couple aux proteines g ? le cas des recepteurs metabotropiques du glutamate et du gaba
# google translate: comment fonctionnent les recepteurs couples aux proteines g ? le cas des recepteurs metabotropiques du glutamate et du gaba
# bleu score: 0.5695988432761473
#
# target sentence:  effets locaux du bdnf et plasticite synaptique vers une specificite synaptique
# google translate: effets locaux de la bdnf et de la plasticite synaptique vers la specificite synaptique
# bleu score: 0
#
# target sentence:  roles physiologiques de l amp activated protein kinase ampk
# google translate: roles physiologiques de la proteine kinase amp amp activee
# bleu score: 0
#
# target sentence:  peut on separer gvh et gvt apres greffe de cellules souches hematopoietiques allogeniques ?
# google translate: peut on separer gvh et gvt apres une greffe allogenique de cellules souches hematopoietiques ?
# bleu score: 0.47536173522195396
#
# target sentence:  le peptide yy , une nouvelle arme therapeutique contre l obesite ?
# google translate: le peptide yy , une nouvelle arme therapeutique contre l obesite ?
# bleu score: 0.6505696445772021
#
# target sentence:  les genes pax et la specification cellulaire
# google translate: genes pax et specification cellulaire
# bleu score: 0
#
# target sentence:  un nouveau marqueur fluorescent pour l imagerie in vivo
# google translate: un nouveau marqueur fluorescent pour l imagerie in vivo
# bleu score: 0.5773502691896257
#
# target sentence:  brassage du genome par recombinaison en meiose analyse d un site d initiation dans le genome de la souris
# google translate: rearrangement du genome par analyse de recombinaison meiotique d un site d initiation dans le genome de la souris
# bleu score: 0.47897362544357464
#
# target sentence:  comment localiser un gene morbide sans etude de liaison genetique ?
# google translate: comment localiser un gene de maladie sans une etude de liaison genetique ?
# bleu score: 0.5266403878479265
#
# target sentence:  mutations de la neurotrypsine et retard mental
# google translate: mutations de la neurotrypsine et retard mental
# bleu score: 0
#
# target sentence:  sequencage du genome humain le chromosome , quatrieme chromosome termine
# google translate: sequencage du chromosome du genome humain , le chromosome e est termine
# bleu score: 0.6389431042462724
#
# target sentence:  anticorps catalytiques ou abzymes
# google translate: anticorps catalytiques ou quotients
# bleu score: 0
#
# target sentence:  lle mot du mois physiologie
# google translate: mot du mois quot physiologie quot
# bleu score: 0
#
# target sentence:  neurosciences progres et perspectives
# google translate: progres et perspectives des neurosciences
# bleu score: 0
#
# target sentence:  science , mediatisation et politique le sequencage du genome du riz
# google translate: science , communication et politique sequencant le genome du riz
# bleu score: 0.5623413251903491
#
# target sentence:  dans les grandes plaines de la genomique . episode . le marche de la double helice
# google translate: dans le pays des grandes plaines genomiques . episode du marche de la double helice
# bleu score: 0.5081327481546147
#
# target sentence:  apres la double helice du gene a l humain
# google translate: la double helice et apres du gene a l homme
# bleu score: 0.668740304976422
#
# target sentence:  l helice de la vie
# google translate: l helice de la vie
# bleu score: 0.5475182535069453
#
# target sentence:  medecine des voyages
# google translate: medecine de voyage
# bleu score: 0
#
# target sentence:  le controle de la qualite des produits de therapie genique approche de l afssaps
# google translate: demarche de controle qualite des produits de therapie genique de l agence francaise de securite des produits de sante
# bleu score: 0.47897362544357464
#
# target sentence:  les methyltransferases de l adn du remodelage de la chromatine au cancer
# google translate: adn methyltransferases du remodelage de la chromatine au cancer
# bleu score: 0
#
# target sentence:  glucocorticoides , beta hydroxysteroide deshydrogenase de type et obesite viscerale
# google translate: glucocorticoides , type beta hydroxysteroide deshydrogenase et obesite viscerale
# bleu score: 0.5773502691896257
#
# target sentence:  la regeneration des appendices chez les vertebres un modele experimental ancien pour etudier les cellules souches chez l adulte
# google translate: regeneration de l appendice des vertebres , un ancien modele experimental pour etudier les cellules souches chez l adulte
# bleu score: 0.5695988432761473
#
# target sentence:  quand la mere est plus que responsable du devenir de sa progeniture les mutations a effet maternel
# google translate: quand la mere influe davantage sur le destin de sa progeniture des mutations a effet maternel
# bleu score: 0.5
#
# target sentence:  asymetries de parente et conflits d interet genetique chez les fourmis
# google translate: au sein de l asymetrie des colonies et des conflits sociaux chez les fourmis
# bleu score: 0.5169731539571706
#
# target sentence:  le syndrome d ehlers danlos l architecture matricielle en question
# google translate: le syndrome d ehlers danlos l echafaudage de matrice extracellulaire en question
# bleu score: 0.6389431042462724
#
# target sentence:  la depression synaptique a long terme un mecanisme pour la memoire et l apprentissage au niveau du cervelet
# google translate: depression a long terme cerebelleuse un mecanisme d apprentissage et de memoire
# bleu score: 0.5878560343277044
#
# target sentence:  synapses immunologiques et synapses neuronales
# google translate: synapses immunologiques et synapses neuronales
# bleu score: 0
#
# target sentence:  la neuropathie sensitivo motrice hereditaire avec agenesie du corps calleux
# google translate: neuropathie severe avec agenesie du corps calleux
# bleu score: 0
#
# target sentence:  polymorphismes genetiques et risque d infarctus du myocarde
# google translate: polymorphismes genetiques lies a l ischemie myocardique dans une population japonaise
# bleu score: 0.6529942057256104
#
# target sentence:  le recepteur nucleaire orphelin rev erb alpha oscille entre repression et activation
# google translate: le recepteur nucleaire orphelin rev erb alpha est un composant majeur de l horloge circadienne
# bleu score: 0.5081327481546147
#
# target sentence:  un nouveau rebondissement dans la quete de l origine des interneurones gabaergiques du cortex cerebral ?
# google translate: origine des interneurones corticaux gabaergiques chez la souris et l homme
# bleu score: 0.5013840477862073
#
# target sentence:  cd , un regulateur de la croissance et de l invasion cellulaire
# google translate: implication de cd en tant que regulateur de la proliferation cellulaire
# bleu score: 0
#
# target sentence:  l activation degradation proteasomique des gtpases rho par cnf confere des capacites invasives aux e . coli uropathogenes
# google translate: action du facteur necrosant cytotoxique de e . coli
# bleu score: 0.6865890479690392
#
# target sentence:  le motif jamm pour une nouvelle classe de proteases du signalosome au proteasome
# google translate: une protease cryptique associe deubiquitination et degradation par le proteasome
# bleu score: 0
#
# target sentence:  les enzymes qui controlent la torsion de l adn
# google translate: enzymes qui relaxent l adn supercoiled
# bleu score: 0.5408536609893481
#
# target sentence:  l invalidation du gene de la fibuline induit une elastinopathie
# google translate: la fibuline est essentielle au developpement des fibres elastiques
# bleu score: 0
#
# target sentence:  fentes et brides une meme etiologie pour deux syndromes a priori bien differents
# google translate: meme etiologie des fentes et des toiles pour deux syndromes a premiere vue tres differents
# bleu score: 0.5081327481546147
#
# target sentence:  le gros arbre qui cachait la foret
# google translate: le controle de la masse corporelle par la leptine se produit par l intermediaire du systeme nerveux sympathique
# bleu score: 0.4854917717073234
