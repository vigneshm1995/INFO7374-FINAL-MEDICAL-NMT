# %% [markdown]
# This Note book is adapted from [WuJiaocan's Github](https://github.com/WuJiaocan/tensorflow)

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
import tensorflow as tf

# %% [markdown]
# ### 1.Create Vocabulary

# %%
src_path = 'en_clean.txt'
tgt_path = 'fr_clean.txt'

# %%
def read_data(txt_path, num_examples):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[:num_examples]

# %%
src = read_data(src_path, 100000)
tgt = read_data(tgt_path, 100000)

# %%
print('size of number of source sentences from dataset {}'.format(len(src)))
print('size of number of target sentences from dataset {}'.format(len(src)))
# Out:
# size of number of source sentences from dataset 100000
# size of number of target sentences from dataset 100000

# %%
for i in range(5):
  print(src[i])
# Out:
#  global health where do physiotherapy and rehabilitation research fit ?
#  carabin
#  comment on the misappropriation of bibliographical references in science . the example of anti aging medicine
#  anti aging medicine , a science based , essential medicine
#  underwater dive in fresh water complicated by a cardiorespiratory arrest on obstructive shock

# %%
for i in range(5):
  print(tgt[i])
# Out:
#  la place des cheveux et des poils dans les rituels et le sacre
#  les carabins
#  du detournement des references bibliographiques en science . l exemple de la medecine anti age
#  la medecine anti age , une medecine scientifique , indispensable
#  plongee subaquatique en eau douce compliquee d un arret cardiorespiratoire sur choc obstructif

# %%
import codecs
import collections
from operator import itemgetter

def create_vocab(RAW_DATA, VOCAB_OUTPUT):
    counter = collections.Counter()

    for line in RAW_DATA:
        for word in line.strip().lower().split():
            counter[word] += 1

    sorted_word_to_cnt = sorted(counter.items(), key=itemgetter(1), reverse=True)
    sorted_words = [x[0] for x in sorted_word_to_cnt]

    sorted_words =  ['<pad>'] + ['<sos>'] + ['<eos>'] + ['<unk>'] + sorted_words 

    with codecs.open(VOCAB_OUTPUT, "w", encoding="utf-8") as file_output:
        for word in sorted_words:
            file_output.write(word + "\n")
    return sorted_words

# %%
vocab_src = create_vocab(src, 'vocab.en')
vocab_tgt = create_vocab(tgt, 'vocab.fr')

# %%
vocab_size_src = len(vocab_src)
vocab_size_tgt = len(vocab_tgt)

print('size of source vocab {}'.format(vocab_size_src))
print('size of target vocab {}'.format(vocab_size_tgt))
# Out:
# size of source vocab 40396
# size of target vocab 49303

# %%
print(vocab_src[-5:])
# Out:
# ['referendum', 'countering', 'discouragement', 'mefenamic', 'stereolithography']

# %%
print(vocab_tgt[-5:])
# Out:
# ['stereolithographie', 'generatives', 'verfahren', 'zahntechnik', 'aortocoronariens']

# %% [markdown]
# ### 2.Convert Text to Numbers

# %%
import codecs
import sys

def text_to_int(RAW_DATA, VOCAB, OUTPUT_DATA):

  with codecs.open(VOCAB, "r", encoding="utf-8") as f_vocab:
      vocab = [w.strip() for w in f_vocab.readlines()]
      word_to_id = {k:v for (k,v) in zip(vocab, range(len(vocab)))}

  def get_id(word):
      return word_to_id[word] if word in word_to_id else word_to_id["<unk>"]

  fout = codecs.open(OUTPUT_DATA, "w", encoding="utf-8")
  for line in RAW_DATA:
      words = line.strip().split() + ["<eos>"]

      out_line = " ".join([str(get_id(w)) for w in words]) + "\n"
      fout.write(out_line)
  fout.close()

# %%
text_to_int(src, 'vocab.en', 'train.en')
text_to_int(tgt, 'vocab.fr', 'train.fr')

# %% [markdown]
# ### 3. Set Hyper Parameters

# %%
SRC_TRAIN_DATA = "train.en"
TRG_TRAIN_DATA = "train.fr"
CHECKPOINT_PATH = "./INFO7374"  

HIDDEN_SIZE = 256
DECODER_LAYERS = 2                    # Num_layer for decoder LSTM
SRC_VOCAB_SIZE = vocab_size_src       
TRG_VOCAB_SIZE = vocab_size_tgt       
BATCH_SIZE = 128
NUM_EPOCH = 20 
KEEP_PROB = 0.9
MAX_GRAD_NORM = 5                      # to contral gradient explosion
SHARE_EMB_AND_SOFTMAX = True           # share weights between softmax layer and embedding layer
LEARNING_RATE = 0.002

MAX_LEN = 100   # max length of a sentence
SOS_ID  = 1    # <sos> ID in target vocab

# %% [markdown]
# ### 4. Create Training Dataset

# %%
def MakeDataset(file_path):
    dataset = tf.data.TextLineDataset(file_path)
    # split by space
    dataset = dataset.map(lambda string: tf.string_split([string]).values)
    # convert string to number
    dataset = dataset.map(
        lambda string: tf.string_to_number(string, tf.int32))
    # calc # word/sentence and put in dataset with sentence
    dataset = dataset.map(lambda x: (x, tf.size(x)))
    return dataset

def MakeSrcTrgDataset(src_path, trg_path, batch_size):

    src_data = MakeDataset(src_path)
    trg_data = MakeDataset(trg_path)
    #   ds[0][0]source sentence
    #   ds[0][1]len of source sentence
    #   ds[1][0]target sentence
    #   ds[1][1]len of target sentence
    dataset = tf.data.Dataset.zip((src_data, trg_data))

    # delete empty and super-long sentence
    def FilterLength(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        src_len_ok = tf.logical_and(
            tf.greater(src_len, 1), tf.less_equal(src_len, MAX_LEN))
        trg_len_ok = tf.logical_and(
            tf.greater(trg_len, 1), tf.less_equal(trg_len, MAX_LEN))
        return tf.logical_and(src_len_ok, trg_len_ok)
    dataset = dataset.filter(FilterLength)
    
    #   1.trg_input: "<sos> X Y Z"
    #   2.trg_label: "X Y Z <eos>"
    #   file: "X Y Z <eos>", need to produce "<sos> X Y Z" and add to dataset
    def MakeTrgInput(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        trg_input = tf.concat([[SOS_ID], trg_label[:-1]], axis=0)
        return ((src_input, src_len), (trg_input, trg_label, trg_len))
    
    dataset = dataset.map(MakeTrgInput)

    dataset = dataset.shuffle(10000)

    # define shape after padding
    padded_shapes = (
        (tf.TensorShape([None]),
         tf.TensorShape([])), 
        (tf.TensorShape([None]),
         tf.TensorShape([None]),
         tf.TensorShape([]))) 
    
    # padded_batch to pad
    batched_dataset = dataset.padded_batch(batch_size, padded_shapes)
    return batched_dataset

# %% [markdown]
# ### 3.Define NMT

# %%
class NMTModel(object):
  """
  defind the nmt model
  
  """
  # define variables needed by nmt
  def __init__(self):
      # define rnn cell needed by encoder and decoder

      # 1 layer bi-directional LSTM for encoder
      self.enc_cell_fw = tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE)
      self.enc_cell_bw = tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE)      

      # # of DECODER_LAYERS layer basic LSTM for decoder
      self.dec_cell = tf.nn.rnn_cell.MultiRNNCell(
        [tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE) for _ in range(DECODER_LAYERS)])

      # set word embeddings for source and target language   
      self.src_embedding = tf.get_variable(
          "src_emb", [SRC_VOCAB_SIZE, HIDDEN_SIZE])
      self.trg_embedding = tf.get_variable(
          "trg_emb", [TRG_VOCAB_SIZE, HIDDEN_SIZE])

      # define variables for softmax layer
      if SHARE_EMB_AND_SOFTMAX:
         self.softmax_weight = tf.transpose(self.trg_embedding)
      else:
         self.softmax_weight = tf.get_variable(
             "weight", [HIDDEN_SIZE, TRG_VOCAB_SIZE])
      self.softmax_bias = tf.get_variable(
          "softmax_bias", [TRG_VOCAB_SIZE])

  # calculate forward graph
  # src_input, src_size, trg_input, trg_label, trg_size are from MakeSrcTrgDataset

  def forward(self, src_input, src_size, trg_input, trg_label, trg_size, LEARNING_RATE):
      batch_size = tf.shape(src_input)[0]

      # convert word_int input to embeddings
      src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
      trg_emb = tf.nn.embedding_lookup(self.trg_embedding, trg_input)

      # set drop_out rate
      src_emb = tf.nn.dropout(src_emb, KEEP_PROB)
      trg_emb = tf.nn.dropout(trg_emb, KEEP_PROB)

      with tf.variable_scope("encoder"):
          # enc_output: a tuple of two tensors, each tensor > [batch_size, max_time, HIDDEN_SIZE]
          # this will be needed when calculating attention

          # enc_state: a tuple of two LSTMStateTuple tensors, each tensor > [batch_size, HIDDEN_SIZE]
          enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(
              self.enc_cell_fw, self.enc_cell_bw, src_emb, src_size, 
              dtype=tf.float32)
          # contact two seperate tensors into one
          enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)     

      with tf.variable_scope("decoder"):

#           attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
#               HIDDEN_SIZE, enc_outputs,
#               memory_sequence_length=src_size)

          attention_mechanism = tf.contrib.seq2seq.LuongAttention(
              HIDDEN_SIZE, enc_outputs,
              memory_sequence_length=src_size)

          # wrap self.dec_cell and attention mechanisim
          attention_cell = tf.contrib.seq2seq.AttentionWrapper(
              self.dec_cell, attention_mechanism,
              attention_layer_size=HIDDEN_SIZE)

          # use attention_cell and dynamic_rnn construct decoder
          # here relay totally on attention as the information source
          dec_outputs, _ = tf.nn.dynamic_rnn(
              attention_cell, trg_emb, trg_size, dtype=tf.float32)

      # calc log perplexity
      output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
      logits = tf.matmul(output, self.softmax_weight) + self.softmax_bias
      loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
          labels=tf.reshape(trg_label, [-1]), logits=logits)

      # set padding weight as 0 when calc average loss
      label_weights = tf.sequence_mask(
          trg_size, maxlen=tf.shape(trg_label)[1], dtype=tf.float32)
      label_weights = tf.reshape(label_weights, [-1])
      cost = tf.reduce_sum(loss * label_weights)
      cost_per_token = cost / tf.reduce_sum(label_weights)

      # define backprop
      trainable_variables = tf.trainable_variables()

      # define optimization method/steps
      grads = tf.gradients(cost / tf.to_float(batch_size),
                           trainable_variables)
      
      grads, _ = tf.clip_by_global_norm(grads, MAX_GRAD_NORM)
      
#       optimizer = tf.train.GradientDescentOptimizer(learning_rate=LEARNING_RATE)
      optimizer = tf.train.AdamOptimizer(learning_rate=LEARNING_RATE)
      
      train_op = optimizer.apply_gradients(
          zip(grads, trainable_variables))
      
      return cost_per_token, train_op

# %% [markdown]
# ### 4.Training

# %%
def run_epoch(session, cost_op, train_op, saver, step):
    while True:
        try:
            # execute train_op and calc loss
            cost, _ = session.run([cost_op, train_op])
            if step % 10 == 0:
                print("After %d steps, per token cost is %.3f" % (step, cost))
            # save checkpoint per 200 steps
            if step % 200 == 0:
                saver.save(session, CHECKPOINT_PATH, global_step=step)
            step += 1
        except tf.errors.OutOfRangeError:
            break
    return step

def main():

    initializer = tf.random_uniform_initializer(-0.05, 0.05)
    
    tf.reset_default_graph()

    with tf.variable_scope("nmt_model", reuse=None, 
                           initializer=initializer):
        train_model = NMTModel()
  
    # define input data
    data = MakeSrcTrgDataset(SRC_TRAIN_DATA, TRG_TRAIN_DATA, BATCH_SIZE)
    iterator = data.make_initializable_iterator()
    (src, src_size), (trg_input, trg_label, trg_size) = iterator.get_next()
 
    # define forward graph
    cost_op, train_op = train_model.forward(src, src_size, trg_input,
                                            trg_label, trg_size, LEARNING_RATE)

    # train
    saver = tf.train.Saver()
    tf.add_to_collection('train_op', train_op)
    tf.add_to_collection('cost_op', cost_op)
    step = 0
    with tf.Session() as sess:
        tf.global_variables_initializer().run()
        for i in range(NUM_EPOCH):
            print("In iteration: %d" % (i + 1))
            sess.run(iterator.initializer)
            step = run_epoch(sess, cost_op, train_op, saver, step)
            
if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From <ipython-input-13-4f0e3b151db6>:11: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# In iteration: 1
# After 0 steps, per token cost is 10.803
# After 10 steps, per token cost is 9.373
# After 20 steps, per token cost is 7.310
# After 30 steps, per token cost is 7.130
# After 40 steps, per token cost is 7.014
# After 50 steps, per token cost is 6.863
# After 60 steps, per token cost is 7.053
# After 70 steps, per token cost is 7.056
# After 80 steps, per token cost is 6.931
# After 90 steps, per token cost is 6.663
# After 100 steps, per token cost is 6.582
# After 110 steps, per token cost is 6.374
# After 120 steps, per token cost is 6.409
# After 130 steps, per token cost is 6.392
# After 140 steps, per token cost is 6.352
# After 150 steps, per token cost is 6.130
# After 160 steps, per token cost is 6.424
# After 170 steps, per token cost is 6.280
# After 180 steps, per token cost is 6.137
# After 190 steps, per token cost is 6.018
# After 200 steps, per token cost is 6.112
# After 210 steps, per token cost is 5.890
# After 220 steps, per token cost is 6.014
# After 230 steps, per token cost is 5.774
# After 240 steps, per token cost is 5.901
# After 250 steps, per token cost is 5.669
# After 260 steps, per token cost is 5.529
# After 270 steps, per token cost is 5.805
# After 280 steps, per token cost is 5.618
# After 290 steps, per token cost is 5.637
# After 300 steps, per token cost is 5.840
# After 310 steps, per token cost is 5.797
# After 320 steps, per token cost is 5.550
# After 330 steps, per token cost is 5.634
# After 340 steps, per token cost is 5.647
# After 350 steps, per token cost is 5.436
# After 360 steps, per token cost is 5.663
# After 370 steps, per token cost is 5.607
# After 380 steps, per token cost is 5.378
# After 390 steps, per token cost is 5.376
# After 400 steps, per token cost is 5.393
# After 410 steps, per token cost is 5.267
# After 420 steps, per token cost is 5.259
# After 430 steps, per token cost is 5.136
# After 440 steps, per token cost is 5.059
# After 450 steps, per token cost is 5.314
# After 460 steps, per token cost is 5.147
# After 470 steps, per token cost is 4.940
# After 480 steps, per token cost is 4.974
# After 490 steps, per token cost is 5.159
# After 500 steps, per token cost is 5.007
# After 510 steps, per token cost is 5.037
# After 520 steps, per token cost is 5.134
# After 530 steps, per token cost is 4.789
# After 540 steps, per token cost is 4.587
# After 550 steps, per token cost is 4.664
# After 560 steps, per token cost is 4.824
# After 570 steps, per token cost is 4.383
# After 580 steps, per token cost is 4.595
# After 590 steps, per token cost is 4.733
# After 600 steps, per token cost is 4.410
# After 610 steps, per token cost is 4.408
# After 620 steps, per token cost is 4.594
# After 630 steps, per token cost is 4.508
# After 640 steps, per token cost is 4.513
# After 650 steps, per token cost is 4.297
# After 660 steps, per token cost is 4.366
# After 670 steps, per token cost is 4.199
# After 680 steps, per token cost is 4.129
# After 690 steps, per token cost is 4.129
# After 700 steps, per token cost is 4.228
# After 710 steps, per token cost is 4.420
# After 720 steps, per token cost is 4.174
# After 730 steps, per token cost is 4.279
# After 740 steps, per token cost is 4.045
# After 750 steps, per token cost is 3.871
# After 760 steps, per token cost is 3.964
# After 770 steps, per token cost is 3.932
# After 780 steps, per token cost is 3.985
# In iteration: 2
# After 790 steps, per token cost is 3.966
# After 800 steps, per token cost is 3.978
# After 810 steps, per token cost is 4.260
# After 820 steps, per token cost is 4.027
# After 830 steps, per token cost is 4.029
# After 840 steps, per token cost is 3.706
# After 850 steps, per token cost is 3.943
# After 860 steps, per token cost is 3.793
# After 870 steps, per token cost is 4.054
# After 880 steps, per token cost is 3.667
# After 890 steps, per token cost is 3.827
# After 900 steps, per token cost is 3.583
# After 910 steps, per token cost is 3.769
# After 920 steps, per token cost is 3.814
# After 930 steps, per token cost is 3.505
# After 940 steps, per token cost is 3.912
# After 950 steps, per token cost is 3.764
# After 960 steps, per token cost is 3.636
# After 970 steps, per token cost is 3.670
# After 980 steps, per token cost is 3.686
# After 990 steps, per token cost is 3.562
# After 1000 steps, per token cost is 3.780
# After 1010 steps, per token cost is 3.575
# After 1020 steps, per token cost is 3.331
# After 1030 steps, per token cost is 3.362
# After 1040 steps, per token cost is 3.611
# After 1050 steps, per token cost is 3.452
# After 1060 steps, per token cost is 3.382
# After 1070 steps, per token cost is 3.285
# After 1080 steps, per token cost is 3.544
# After 1090 steps, per token cost is 3.519
# After 1100 steps, per token cost is 3.202
# After 1110 steps, per token cost is 3.281
# After 1120 steps, per token cost is 3.587
# After 1130 steps, per token cost is 3.075
# After 1140 steps, per token cost is 3.281
# After 1150 steps, per token cost is 3.285
# After 1160 steps, per token cost is 3.484
# After 1170 steps, per token cost is 3.001
# After 1180 steps, per token cost is 3.276
# After 1190 steps, per token cost is 2.927
# After 1200 steps, per token cost is 3.064
# After 1210 steps, per token cost is 3.057
# After 1220 steps, per token cost is 3.285
# After 1230 steps, per token cost is 2.889
# After 1240 steps, per token cost is 3.276
# After 1250 steps, per token cost is 3.174
# After 1260 steps, per token cost is 3.050
# After 1270 steps, per token cost is 3.113
# After 1280 steps, per token cost is 3.223
# After 1290 steps, per token cost is 3.120
# After 1300 steps, per token cost is 2.928
# After 1310 steps, per token cost is 2.966
# After 1320 steps, per token cost is 3.203
# After 1330 steps, per token cost is 3.510
# After 1340 steps, per token cost is 2.918
# After 1350 steps, per token cost is 2.997
# After 1360 steps, per token cost is 2.950
# After 1370 steps, per token cost is 2.897
# After 1380 steps, per token cost is 3.045
# After 1390 steps, per token cost is 2.911
# After 1400 steps, per token cost is 2.906
# After 1410 steps, per token cost is 2.704
# After 1420 steps, per token cost is 2.574
# After 1430 steps, per token cost is 2.683
# After 1440 steps, per token cost is 3.041
# After 1450 steps, per token cost is 2.864
# After 1460 steps, per token cost is 2.728
# After 1470 steps, per token cost is 2.914
# After 1480 steps, per token cost is 2.742
# After 1490 steps, per token cost is 2.571
# After 1500 steps, per token cost is 3.014
# After 1510 steps, per token cost is 2.604
# After 1520 steps, per token cost is 2.904
# After 1530 steps, per token cost is 2.880
# After 1540 steps, per token cost is 2.579
# After 1550 steps, per token cost is 2.697
# After 1560 steps, per token cost is 2.519
# In iteration: 3
# After 1570 steps, per token cost is 2.753
# After 1580 steps, per token cost is 2.550
# After 1590 steps, per token cost is 2.744
# After 1600 steps, per token cost is 2.796
# After 1610 steps, per token cost is 2.671
# After 1620 steps, per token cost is 2.601
# After 1630 steps, per token cost is 2.731
# After 1640 steps, per token cost is 2.434
# After 1650 steps, per token cost is 2.847
# After 1660 steps, per token cost is 2.397
# After 1670 steps, per token cost is 2.321
# After 1680 steps, per token cost is 2.532
# After 1690 steps, per token cost is 2.555
# After 1700 steps, per token cost is 2.702
# After 1710 steps, per token cost is 2.726
# After 1720 steps, per token cost is 2.609
# After 1730 steps, per token cost is 2.497
# After 1740 steps, per token cost is 2.716
# After 1750 steps, per token cost is 2.473
# After 1760 steps, per token cost is 2.459
# After 1770 steps, per token cost is 2.388
# After 1780 steps, per token cost is 2.516
# After 1790 steps, per token cost is 2.713
# After 1800 steps, per token cost is 2.502
# After 1810 steps, per token cost is 2.678
# After 1820 steps, per token cost is 2.459
# After 1830 steps, per token cost is 2.421
# After 1840 steps, per token cost is 2.486
# After 1850 steps, per token cost is 2.530
# After 1860 steps, per token cost is 2.305
# After 1870 steps, per token cost is 2.406
# After 1880 steps, per token cost is 2.270
# After 1890 steps, per token cost is 2.265
# After 1900 steps, per token cost is 2.657
# After 1910 steps, per token cost is 2.497
# After 1920 steps, per token cost is 2.608
# After 1930 steps, per token cost is 2.647
# After 1940 steps, per token cost is 2.431
# After 1950 steps, per token cost is 2.501
# After 1960 steps, per token cost is 2.659
# After 1970 steps, per token cost is 2.321
# After 1980 steps, per token cost is 2.236
# After 1990 steps, per token cost is 2.380
# After 2000 steps, per token cost is 2.450
# After 2010 steps, per token cost is 2.274
# After 2020 steps, per token cost is 2.371
# After 2030 steps, per token cost is 2.459
# After 2040 steps, per token cost is 2.356
# After 2050 steps, per token cost is 2.116
# After 2060 steps, per token cost is 2.213
# After 2070 steps, per token cost is 2.259
# After 2080 steps, per token cost is 2.359
# After 2090 steps, per token cost is 2.371
# After 2100 steps, per token cost is 2.175
# After 2110 steps, per token cost is 2.462
# After 2120 steps, per token cost is 2.319
# After 2130 steps, per token cost is 2.235
# After 2140 steps, per token cost is 2.241
# After 2150 steps, per token cost is 2.249
# After 2160 steps, per token cost is 2.369
# After 2170 steps, per token cost is 2.079
# After 2180 steps, per token cost is 2.265
# After 2190 steps, per token cost is 2.240
# After 2200 steps, per token cost is 2.314
# After 2210 steps, per token cost is 2.205
# After 2220 steps, per token cost is 2.021
# After 2230 steps, per token cost is 2.125
# After 2240 steps, per token cost is 2.159
# After 2250 steps, per token cost is 2.163
# After 2260 steps, per token cost is 2.229
# After 2270 steps, per token cost is 2.089
# After 2280 steps, per token cost is 2.384
# After 2290 steps, per token cost is 2.147
# After 2300 steps, per token cost is 2.063
# After 2310 steps, per token cost is 2.109
# After 2320 steps, per token cost is 1.968
# After 2330 steps, per token cost is 2.070
# After 2340 steps, per token cost is 2.125
# In iteration: 4
# After 2350 steps, per token cost is 2.256
# After 2360 steps, per token cost is 1.992
# After 2370 steps, per token cost is 2.168
# After 2380 steps, per token cost is 1.878
# After 2390 steps, per token cost is 2.014
# After 2400 steps, per token cost is 2.299
# After 2410 steps, per token cost is 2.190
# After 2420 steps, per token cost is 2.160
# After 2430 steps, per token cost is 2.071
# After 2440 steps, per token cost is 2.077
# After 2450 steps, per token cost is 2.215
# After 2460 steps, per token cost is 2.201
# After 2470 steps, per token cost is 1.967
# After 2480 steps, per token cost is 2.069
# After 2490 steps, per token cost is 2.020
# After 2500 steps, per token cost is 1.998
# After 2510 steps, per token cost is 2.044
# After 2520 steps, per token cost is 2.121
# After 2530 steps, per token cost is 1.968
# After 2540 steps, per token cost is 1.940
# After 2550 steps, per token cost is 1.944
# After 2560 steps, per token cost is 1.849
# After 2570 steps, per token cost is 2.108
# After 2580 steps, per token cost is 2.055
# After 2590 steps, per token cost is 1.948
# After 2600 steps, per token cost is 1.962
# After 2610 steps, per token cost is 2.053
# After 2620 steps, per token cost is 2.062
# After 2630 steps, per token cost is 2.070
# After 2640 steps, per token cost is 1.846
# After 2650 steps, per token cost is 2.027
# After 2660 steps, per token cost is 1.928
# After 2670 steps, per token cost is 1.856
# After 2680 steps, per token cost is 1.951
# After 2690 steps, per token cost is 2.020
# After 2700 steps, per token cost is 2.082
# After 2710 steps, per token cost is 1.894
# After 2720 steps, per token cost is 1.970
# After 2730 steps, per token cost is 2.052
# After 2740 steps, per token cost is 1.817
# After 2750 steps, per token cost is 2.090
# After 2760 steps, per token cost is 1.837
# After 2770 steps, per token cost is 2.043
# After 2780 steps, per token cost is 1.880
# After 2790 steps, per token cost is 1.978
# After 2800 steps, per token cost is 1.835
# After 2810 steps, per token cost is 1.680
# After 2820 steps, per token cost is 1.842
# After 2830 steps, per token cost is 1.704
# After 2840 steps, per token cost is 1.906
# After 2850 steps, per token cost is 1.757
# After 2860 steps, per token cost is 1.996
# After 2870 steps, per token cost is 2.083
# After 2880 steps, per token cost is 1.693
# After 2890 steps, per token cost is 1.889
# After 2900 steps, per token cost is 1.781
# After 2910 steps, per token cost is 1.702
# After 2920 steps, per token cost is 1.923
# After 2930 steps, per token cost is 1.914
# After 2940 steps, per token cost is 1.776
# After 2950 steps, per token cost is 1.729
# After 2960 steps, per token cost is 1.678
# After 2970 steps, per token cost is 1.813
# After 2980 steps, per token cost is 1.934
# After 2990 steps, per token cost is 1.728
# After 3000 steps, per token cost is 1.679
# After 3010 steps, per token cost is 1.892
# After 3020 steps, per token cost is 1.602
# After 3030 steps, per token cost is 1.893
# After 3040 steps, per token cost is 1.670
# After 3050 steps, per token cost is 1.580
# After 3060 steps, per token cost is 1.688
# After 3070 steps, per token cost is 1.588
# After 3080 steps, per token cost is 1.621
# After 3090 steps, per token cost is 1.779
# After 3100 steps, per token cost is 1.589
# After 3110 steps, per token cost is 1.523
# After 3120 steps, per token cost is 1.420
# In iteration: 5
# After 3130 steps, per token cost is 1.772
# After 3140 steps, per token cost is 1.631
# After 3150 steps, per token cost is 1.730
# After 3160 steps, per token cost is 1.514
# After 3170 steps, per token cost is 1.496
# After 3180 steps, per token cost is 1.789
# After 3190 steps, per token cost is 1.751
# After 3200 steps, per token cost is 1.784
# After 3210 steps, per token cost is 1.727
# After 3220 steps, per token cost is 1.647
# After 3230 steps, per token cost is 1.580
# After 3240 steps, per token cost is 1.681
# After 3250 steps, per token cost is 1.624
# After 3260 steps, per token cost is 1.617
# After 3270 steps, per token cost is 1.657
# After 3280 steps, per token cost is 1.576
# After 3290 steps, per token cost is 1.644
# After 3300 steps, per token cost is 1.876
# After 3310 steps, per token cost is 1.517
# After 3320 steps, per token cost is 1.633
# After 3330 steps, per token cost is 1.715
# After 3340 steps, per token cost is 1.713
# After 3350 steps, per token cost is 1.713
# After 3360 steps, per token cost is 1.487
# After 3370 steps, per token cost is 1.683
# After 3380 steps, per token cost is 1.790
# After 3390 steps, per token cost is 1.590
# After 3400 steps, per token cost is 1.594
# After 3410 steps, per token cost is 1.614
# After 3420 steps, per token cost is 1.771
# After 3430 steps, per token cost is 1.624
# After 3440 steps, per token cost is 1.520
# After 3450 steps, per token cost is 1.652
# After 3460 steps, per token cost is 1.694
# After 3470 steps, per token cost is 1.523
# After 3480 steps, per token cost is 1.531
# After 3490 steps, per token cost is 1.509
# After 3500 steps, per token cost is 1.566
# After 3510 steps, per token cost is 1.637
# After 3520 steps, per token cost is 1.707
# After 3530 steps, per token cost is 1.795
# After 3540 steps, per token cost is 1.659
# After 3550 steps, per token cost is 1.690
# After 3560 steps, per token cost is 1.490
# After 3570 steps, per token cost is 1.460
# After 3580 steps, per token cost is 1.792
# After 3590 steps, per token cost is 1.589
# After 3600 steps, per token cost is 1.517
# After 3610 steps, per token cost is 1.604
# After 3620 steps, per token cost is 1.534
# After 3630 steps, per token cost is 1.611
# After 3640 steps, per token cost is 1.592
# After 3650 steps, per token cost is 1.501
# After 3660 steps, per token cost is 1.576
# After 3670 steps, per token cost is 1.484
# After 3680 steps, per token cost is 1.477
# After 3690 steps, per token cost is 1.655
# After 3700 steps, per token cost is 1.506
# After 3710 steps, per token cost is 1.666
# After 3720 steps, per token cost is 1.423
# After 3730 steps, per token cost is 1.479
# After 3740 steps, per token cost is 1.584
# After 3750 steps, per token cost is 1.450
# After 3760 steps, per token cost is 1.504
# After 3770 steps, per token cost is 1.636
# After 3780 steps, per token cost is 1.464
# After 3790 steps, per token cost is 1.379
# After 3800 steps, per token cost is 1.444
# After 3810 steps, per token cost is 1.456
# After 3820 steps, per token cost is 1.363
# After 3830 steps, per token cost is 1.346
# After 3840 steps, per token cost is 1.383
# After 3850 steps, per token cost is 1.599
# After 3860 steps, per token cost is 1.433
# After 3870 steps, per token cost is 1.522
# After 3880 steps, per token cost is 1.595
# After 3890 steps, per token cost is 1.290
# After 3900 steps, per token cost is 1.488
# In iteration: 6
# After 3910 steps, per token cost is 1.385
# After 3920 steps, per token cost is 1.554
# After 3930 steps, per token cost is 1.425
# After 3940 steps, per token cost is 1.378
# After 3950 steps, per token cost is 1.196
# After 3960 steps, per token cost is 1.334
# After 3970 steps, per token cost is 1.332
# After 3980 steps, per token cost is 1.333
# After 3990 steps, per token cost is 1.411
# After 4000 steps, per token cost is 1.656
# After 4010 steps, per token cost is 1.267
# After 4020 steps, per token cost is 1.337
# After 4030 steps, per token cost is 1.320
# After 4040 steps, per token cost is 1.279
# After 4050 steps, per token cost is 1.273
# After 4060 steps, per token cost is 1.358
# After 4070 steps, per token cost is 1.518
# After 4080 steps, per token cost is 1.512
# After 4090 steps, per token cost is 1.433
# After 4100 steps, per token cost is 1.518
# After 4110 steps, per token cost is 1.697
# After 4120 steps, per token cost is 1.336
# After 4130 steps, per token cost is 1.406
# After 4140 steps, per token cost is 1.330
# After 4150 steps, per token cost is 1.399
# After 4160 steps, per token cost is 1.394
# After 4170 steps, per token cost is 1.391
# After 4180 steps, per token cost is 1.526
# After 4190 steps, per token cost is 1.529
# After 4200 steps, per token cost is 1.273
# After 4210 steps, per token cost is 1.518
# After 4220 steps, per token cost is 1.451
# After 4230 steps, per token cost is 1.461
# After 4240 steps, per token cost is 1.363
# After 4250 steps, per token cost is 1.612
# After 4260 steps, per token cost is 1.588
# After 4270 steps, per token cost is 1.442
# After 4280 steps, per token cost is 1.408
# After 4290 steps, per token cost is 1.440
# After 4300 steps, per token cost is 1.263
# After 4310 steps, per token cost is 1.386
# After 4320 steps, per token cost is 1.246
# After 4330 steps, per token cost is 1.395
# After 4340 steps, per token cost is 1.308
# After 4350 steps, per token cost is 1.426
# After 4360 steps, per token cost is 1.287
# After 4370 steps, per token cost is 1.216
# After 4380 steps, per token cost is 1.274
# After 4390 steps, per token cost is 1.415
# After 4400 steps, per token cost is 1.340
# After 4410 steps, per token cost is 1.383
# After 4420 steps, per token cost is 1.331
# After 4430 steps, per token cost is 1.312
# After 4440 steps, per token cost is 1.229
# After 4450 steps, per token cost is 1.348
# After 4460 steps, per token cost is 1.159
# After 4470 steps, per token cost is 1.563
# After 4480 steps, per token cost is 1.258
# After 4490 steps, per token cost is 1.330
# After 4500 steps, per token cost is 1.383
# After 4510 steps, per token cost is 1.400
# After 4520 steps, per token cost is 1.291
# After 4530 steps, per token cost is 1.199
# After 4540 steps, per token cost is 1.340
# After 4550 steps, per token cost is 1.244
# After 4560 steps, per token cost is 1.291
# After 4570 steps, per token cost is 1.314
# After 4580 steps, per token cost is 1.223
# After 4590 steps, per token cost is 1.366
# After 4600 steps, per token cost is 1.250
# After 4610 steps, per token cost is 1.117
# After 4620 steps, per token cost is 1.289
# After 4630 steps, per token cost is 1.229
# After 4640 steps, per token cost is 1.307
# After 4650 steps, per token cost is 1.218
# After 4660 steps, per token cost is 1.348
# After 4670 steps, per token cost is 1.168
# After 4680 steps, per token cost is 1.114
# After 4690 steps, per token cost is 1.194
# In iteration: 7
# After 4700 steps, per token cost is 1.347
# After 4710 steps, per token cost is 1.305
# After 4720 steps, per token cost is 1.440
# After 4730 steps, per token cost is 1.308
# After 4740 steps, per token cost is 1.102
# After 4750 steps, per token cost is 1.126
# After 4760 steps, per token cost is 1.250
# After 4770 steps, per token cost is 1.266
# After 4780 steps, per token cost is 1.215
# After 4790 steps, per token cost is 1.242
# After 4800 steps, per token cost is 1.311
# After 4810 steps, per token cost is 1.257
# After 4820 steps, per token cost is 1.145
# After 4830 steps, per token cost is 1.451
# After 4840 steps, per token cost is 1.292
# After 4850 steps, per token cost is 1.034
# After 4860 steps, per token cost is 1.318
# After 4870 steps, per token cost is 1.242
# After 4880 steps, per token cost is 1.338
# After 4890 steps, per token cost is 1.203
# After 4900 steps, per token cost is 1.383
# After 4910 steps, per token cost is 1.207
# After 4920 steps, per token cost is 1.309
# After 4930 steps, per token cost is 1.188
# After 4940 steps, per token cost is 1.272
# After 4950 steps, per token cost is 1.527
# After 4960 steps, per token cost is 1.285
# After 4970 steps, per token cost is 1.174
# After 4980 steps, per token cost is 1.231
# After 4990 steps, per token cost is 1.183
# After 5000 steps, per token cost is 1.215
# After 5010 steps, per token cost is 1.242
# After 5020 steps, per token cost is 1.159
# After 5030 steps, per token cost is 1.349
# After 5040 steps, per token cost is 1.125
# After 5050 steps, per token cost is 1.217
# After 5060 steps, per token cost is 1.291
# After 5070 steps, per token cost is 1.177
# After 5080 steps, per token cost is 1.223
# After 5090 steps, per token cost is 1.315
# After 5100 steps, per token cost is 1.323
# After 5110 steps, per token cost is 1.160
# After 5120 steps, per token cost is 1.375
# After 5130 steps, per token cost is 1.307
# After 5140 steps, per token cost is 1.253
# After 5150 steps, per token cost is 1.211
# After 5160 steps, per token cost is 1.137
# After 5170 steps, per token cost is 1.103
# After 5180 steps, per token cost is 1.223
# After 5190 steps, per token cost is 1.115
# After 5200 steps, per token cost is 1.309
# After 5210 steps, per token cost is 1.432
# After 5220 steps, per token cost is 1.172
# After 5230 steps, per token cost is 1.341
# After 5240 steps, per token cost is 1.203
# After 5250 steps, per token cost is 1.242
# After 5260 steps, per token cost is 1.011
# After 5270 steps, per token cost is 1.357
# After 5280 steps, per token cost is 1.078
# After 5290 steps, per token cost is 1.283
# After 5300 steps, per token cost is 1.271
# After 5310 steps, per token cost is 1.158
# After 5320 steps, per token cost is 1.233
# After 5330 steps, per token cost is 1.016
# After 5340 steps, per token cost is 1.143
# After 5350 steps, per token cost is 1.147
# After 5360 steps, per token cost is 1.034
# After 5370 steps, per token cost is 1.075
# After 5380 steps, per token cost is 0.982
# After 5390 steps, per token cost is 1.021
# After 5400 steps, per token cost is 1.021
# After 5410 steps, per token cost is 1.141
# After 5420 steps, per token cost is 1.123
# After 5430 steps, per token cost is 1.024
# After 5440 steps, per token cost is 1.065
# After 5450 steps, per token cost is 1.203
# After 5460 steps, per token cost is 0.884
# After 5470 steps, per token cost is 1.105
# In iteration: 8
# After 5480 steps, per token cost is 1.073
# After 5490 steps, per token cost is 1.038
# After 5500 steps, per token cost is 1.176
# After 5510 steps, per token cost is 1.168
# After 5520 steps, per token cost is 1.025
# After 5530 steps, per token cost is 1.014
# After 5540 steps, per token cost is 0.933
# After 5550 steps, per token cost is 1.195
# After 5560 steps, per token cost is 1.066
# After 5570 steps, per token cost is 1.026
# After 5580 steps, per token cost is 1.176
# After 5590 steps, per token cost is 1.038
# After 5600 steps, per token cost is 1.024
# After 5610 steps, per token cost is 1.136
# After 5620 steps, per token cost is 1.174
# After 5630 steps, per token cost is 1.115
# After 5640 steps, per token cost is 1.072
# After 5650 steps, per token cost is 1.246
# After 5660 steps, per token cost is 1.269
# After 5670 steps, per token cost is 0.988
# After 5680 steps, per token cost is 1.149
# After 5690 steps, per token cost is 1.164
# After 5700 steps, per token cost is 1.165
# After 5710 steps, per token cost is 1.161
# After 5720 steps, per token cost is 1.111
# After 5730 steps, per token cost is 1.104
# After 5740 steps, per token cost is 0.937
# After 5750 steps, per token cost is 1.081
# After 5760 steps, per token cost is 1.072
# After 5770 steps, per token cost is 1.137
# After 5780 steps, per token cost is 1.166
# After 5790 steps, per token cost is 1.292
# After 5800 steps, per token cost is 1.149
# After 5810 steps, per token cost is 1.181
# After 5820 steps, per token cost is 1.025
# After 5830 steps, per token cost is 1.151
# After 5840 steps, per token cost is 1.161
# After 5850 steps, per token cost is 1.000
# After 5860 steps, per token cost is 1.101
# After 5870 steps, per token cost is 1.130
# After 5880 steps, per token cost is 1.048
# After 5890 steps, per token cost is 0.853
# After 5900 steps, per token cost is 0.966
# After 5910 steps, per token cost is 1.314
# After 5920 steps, per token cost is 1.243
# After 5930 steps, per token cost is 1.067
# After 5940 steps, per token cost is 1.311
# After 5950 steps, per token cost is 1.157
# After 5960 steps, per token cost is 1.035
# After 5970 steps, per token cost is 1.127
# After 5980 steps, per token cost is 0.972
# After 5990 steps, per token cost is 1.168
# After 6000 steps, per token cost is 1.161
# After 6010 steps, per token cost is 1.174
# After 6020 steps, per token cost is 0.984
# After 6030 steps, per token cost is 1.095
# After 6040 steps, per token cost is 0.993
# After 6050 steps, per token cost is 1.067
# After 6060 steps, per token cost is 1.026
# After 6070 steps, per token cost is 0.993
# After 6080 steps, per token cost is 1.069
# After 6090 steps, per token cost is 0.986
# After 6100 steps, per token cost is 0.910
# After 6110 steps, per token cost is 0.942
# After 6120 steps, per token cost is 1.011
# After 6130 steps, per token cost is 0.951
# After 6140 steps, per token cost is 1.079
# After 6150 steps, per token cost is 0.941
# After 6160 steps, per token cost is 0.875
# After 6170 steps, per token cost is 1.168
# After 6180 steps, per token cost is 1.036
# After 6190 steps, per token cost is 1.110
# After 6200 steps, per token cost is 0.838
# After 6210 steps, per token cost is 1.034
# After 6220 steps, per token cost is 0.999
# After 6230 steps, per token cost is 0.952
# After 6240 steps, per token cost is 0.981
# After 6250 steps, per token cost is 0.977
# In iteration: 9
# After 6260 steps, per token cost is 1.023
# After 6270 steps, per token cost is 1.052
# After 6280 steps, per token cost is 0.985
# After 6290 steps, per token cost is 0.997
# After 6300 steps, per token cost is 0.833
# After 6310 steps, per token cost is 1.109
# After 6320 steps, per token cost is 0.904
# After 6330 steps, per token cost is 0.945
# After 6340 steps, per token cost is 1.095
# After 6350 steps, per token cost is 0.986
# After 6360 steps, per token cost is 0.898
# After 6370 steps, per token cost is 0.893
# After 6380 steps, per token cost is 1.044
# After 6390 steps, per token cost is 0.965
# After 6400 steps, per token cost is 0.993
# After 6410 steps, per token cost is 0.926
# After 6420 steps, per token cost is 1.104
# After 6430 steps, per token cost is 0.950
# After 6440 steps, per token cost is 1.012
# After 6450 steps, per token cost is 0.991
# After 6460 steps, per token cost is 0.974
# After 6470 steps, per token cost is 0.991
# After 6480 steps, per token cost is 0.976
# After 6490 steps, per token cost is 1.173
# After 6500 steps, per token cost is 1.144
# After 6510 steps, per token cost is 1.044
# After 6520 steps, per token cost is 0.972
# After 6530 steps, per token cost is 0.894
# After 6540 steps, per token cost is 0.882
# After 6550 steps, per token cost is 1.109
# After 6560 steps, per token cost is 1.084
# After 6570 steps, per token cost is 1.029
# After 6580 steps, per token cost is 0.955
# After 6590 steps, per token cost is 1.093
# After 6600 steps, per token cost is 0.960
# After 6610 steps, per token cost is 1.097
# After 6620 steps, per token cost is 0.903
# After 6630 steps, per token cost is 1.036
# After 6640 steps, per token cost is 1.024
# After 6650 steps, per token cost is 0.983
# After 6660 steps, per token cost is 0.899
# After 6670 steps, per token cost is 1.031
# After 6680 steps, per token cost is 0.869
# After 6690 steps, per token cost is 1.048
# After 6700 steps, per token cost is 1.211
# After 6710 steps, per token cost is 0.878
# After 6720 steps, per token cost is 0.997
# After 6730 steps, per token cost is 1.047
# After 6740 steps, per token cost is 1.044
# After 6750 steps, per token cost is 0.894
# After 6760 steps, per token cost is 0.899
# After 6770 steps, per token cost is 0.909
# After 6780 steps, per token cost is 0.920
# After 6790 steps, per token cost is 1.005
# After 6800 steps, per token cost is 0.842
# After 6810 steps, per token cost is 0.815
# After 6820 steps, per token cost is 1.032
# After 6830 steps, per token cost is 1.013
# After 6840 steps, per token cost is 0.932
# After 6850 steps, per token cost is 0.934
# After 6860 steps, per token cost is 0.831
# After 6870 steps, per token cost is 0.923
# After 6880 steps, per token cost is 1.067
# After 6890 steps, per token cost is 0.978
# After 6900 steps, per token cost is 0.784
# After 6910 steps, per token cost is 0.923
# After 6920 steps, per token cost is 0.868
# After 6930 steps, per token cost is 0.956
# After 6940 steps, per token cost is 0.989
# After 6950 steps, per token cost is 0.886
# After 6960 steps, per token cost is 0.790
# After 6970 steps, per token cost is 0.961
# After 6980 steps, per token cost is 0.927
# After 6990 steps, per token cost is 0.893
# After 7000 steps, per token cost is 0.875
# After 7010 steps, per token cost is 0.923
# After 7020 steps, per token cost is 0.878
# After 7030 steps, per token cost is 0.870
# In iteration: 10
# After 7040 steps, per token cost is 0.963
# After 7050 steps, per token cost is 0.777
# After 7060 steps, per token cost is 0.933
# After 7070 steps, per token cost is 0.880
# After 7080 steps, per token cost is 0.785
# After 7090 steps, per token cost is 0.836
# After 7100 steps, per token cost is 0.943
# After 7110 steps, per token cost is 1.018
# After 7120 steps, per token cost is 0.955
# After 7130 steps, per token cost is 0.838
# After 7140 steps, per token cost is 0.795
# After 7150 steps, per token cost is 0.885
# After 7160 steps, per token cost is 0.936
# After 7170 steps, per token cost is 0.858
# After 7180 steps, per token cost is 0.879
# After 7190 steps, per token cost is 0.987
# After 7200 steps, per token cost is 0.800
# After 7210 steps, per token cost is 0.870
# After 7220 steps, per token cost is 0.905
# After 7230 steps, per token cost is 0.976
# After 7240 steps, per token cost is 0.982
# After 7250 steps, per token cost is 0.913
# After 7260 steps, per token cost is 0.787
# After 7270 steps, per token cost is 0.942
# After 7280 steps, per token cost is 1.098
# After 7290 steps, per token cost is 0.918
# After 7300 steps, per token cost is 0.913
# After 7310 steps, per token cost is 0.785
# After 7320 steps, per token cost is 0.965
# After 7330 steps, per token cost is 0.948
# After 7340 steps, per token cost is 0.909
# After 7350 steps, per token cost is 0.931
# After 7360 steps, per token cost is 0.849
# After 7370 steps, per token cost is 1.055
# After 7380 steps, per token cost is 1.084
# After 7390 steps, per token cost is 0.867
# After 7400 steps, per token cost is 0.831
# After 7410 steps, per token cost is 0.923
# After 7420 steps, per token cost is 0.979
# After 7430 steps, per token cost is 0.924
# After 7440 steps, per token cost is 0.878
# After 7450 steps, per token cost is 0.755
# After 7460 steps, per token cost is 0.951
# After 7470 steps, per token cost is 0.927
# After 7480 steps, per token cost is 0.870
# After 7490 steps, per token cost is 0.978
# After 7500 steps, per token cost is 0.810
# After 7510 steps, per token cost is 0.855
# After 7520 steps, per token cost is 0.904
# After 7530 steps, per token cost is 0.752
# After 7540 steps, per token cost is 0.831
# After 7550 steps, per token cost is 0.953
# After 7560 steps, per token cost is 0.786
# After 7570 steps, per token cost is 0.849
# After 7580 steps, per token cost is 0.893
# After 7590 steps, per token cost is 0.935
# After 7600 steps, per token cost is 0.804
# After 7610 steps, per token cost is 0.863
# After 7620 steps, per token cost is 0.995
# After 7630 steps, per token cost is 0.846
# After 7640 steps, per token cost is 0.783
# After 7650 steps, per token cost is 0.907
# After 7660 steps, per token cost is 0.826
# After 7670 steps, per token cost is 0.719
# After 7680 steps, per token cost is 0.808
# After 7690 steps, per token cost is 0.906
# After 7700 steps, per token cost is 0.963
# After 7710 steps, per token cost is 0.798
# After 7720 steps, per token cost is 0.854
# After 7730 steps, per token cost is 0.810
# After 7740 steps, per token cost is 0.729
# After 7750 steps, per token cost is 0.817
# After 7760 steps, per token cost is 0.751
# After 7770 steps, per token cost is 0.746
# After 7780 steps, per token cost is 0.735
# After 7790 steps, per token cost is 0.794
# After 7800 steps, per token cost is 0.649
# After 7810 steps, per token cost is 0.659
# In iteration: 11
# After 7820 steps, per token cost is 0.872
# After 7830 steps, per token cost is 0.826
# After 7840 steps, per token cost is 0.841
# After 7850 steps, per token cost is 0.814
# After 7860 steps, per token cost is 0.773
# After 7870 steps, per token cost is 0.728
# After 7880 steps, per token cost is 0.919
# After 7890 steps, per token cost is 0.856
# After 7900 steps, per token cost is 0.781
# After 7910 steps, per token cost is 0.798
# After 7920 steps, per token cost is 0.920
# After 7930 steps, per token cost is 0.743
# After 7940 steps, per token cost is 0.840
# After 7950 steps, per token cost is 0.952
# After 7960 steps, per token cost is 0.887
# After 7970 steps, per token cost is 0.875
# After 7980 steps, per token cost is 0.944
# After 7990 steps, per token cost is 0.754
# After 8000 steps, per token cost is 0.881
# After 8010 steps, per token cost is 0.899
# After 8020 steps, per token cost is 0.754
# After 8030 steps, per token cost is 0.893
# After 8040 steps, per token cost is 0.860
# After 8050 steps, per token cost is 0.683
# After 8060 steps, per token cost is 0.944
# After 8070 steps, per token cost is 0.759
# After 8080 steps, per token cost is 0.973
# After 8090 steps, per token cost is 0.922
# After 8100 steps, per token cost is 0.786
# After 8110 steps, per token cost is 0.745
# After 8120 steps, per token cost is 0.821
# After 8130 steps, per token cost is 0.888
# After 8140 steps, per token cost is 0.949
# After 8150 steps, per token cost is 0.751
# After 8160 steps, per token cost is 0.921
# After 8170 steps, per token cost is 0.750
# After 8180 steps, per token cost is 0.772
# After 8190 steps, per token cost is 0.931
# After 8200 steps, per token cost is 0.902
# After 8210 steps, per token cost is 0.846
# After 8220 steps, per token cost is 0.849
# After 8230 steps, per token cost is 0.845
# After 8240 steps, per token cost is 0.917
# After 8250 steps, per token cost is 0.903
# After 8260 steps, per token cost is 0.910
# After 8270 steps, per token cost is 0.893
# After 8280 steps, per token cost is 0.847
# After 8290 steps, per token cost is 0.764
# After 8300 steps, per token cost is 0.896
# After 8310 steps, per token cost is 0.819
# After 8320 steps, per token cost is 0.715
# After 8330 steps, per token cost is 0.765
# After 8340 steps, per token cost is 0.851
# After 8350 steps, per token cost is 0.693
# After 8360 steps, per token cost is 0.778
# After 8370 steps, per token cost is 0.731
# After 8380 steps, per token cost is 0.785
# After 8390 steps, per token cost is 0.800
# After 8400 steps, per token cost is 0.682
# After 8410 steps, per token cost is 0.741
# After 8420 steps, per token cost is 0.690
# After 8430 steps, per token cost is 0.778
# After 8440 steps, per token cost is 0.776
# After 8450 steps, per token cost is 0.693
# After 8460 steps, per token cost is 0.687
# After 8470 steps, per token cost is 0.624
# After 8480 steps, per token cost is 0.694
# After 8490 steps, per token cost is 0.722
# After 8500 steps, per token cost is 0.733
# After 8510 steps, per token cost is 0.704
# After 8520 steps, per token cost is 0.786
# After 8530 steps, per token cost is 0.706
# After 8540 steps, per token cost is 0.842
# After 8550 steps, per token cost is 0.693
# After 8560 steps, per token cost is 0.695
# After 8570 steps, per token cost is 0.741
# After 8580 steps, per token cost is 0.740
# After 8590 steps, per token cost is 0.664
# After 8600 steps, per token cost is 0.757
# In iteration: 12
# After 8610 steps, per token cost is 0.793
# After 8620 steps, per token cost is 0.814
# After 8630 steps, per token cost is 0.733
# After 8640 steps, per token cost is 0.715
# After 8650 steps, per token cost is 0.802
# After 8660 steps, per token cost is 0.731
# After 8670 steps, per token cost is 0.650
# After 8680 steps, per token cost is 0.691
# After 8690 steps, per token cost is 0.739
# After 8700 steps, per token cost is 0.777
# After 8710 steps, per token cost is 0.651
# After 8720 steps, per token cost is 0.816
# After 8730 steps, per token cost is 0.735
# After 8740 steps, per token cost is 0.702
# After 8750 steps, per token cost is 0.829
# After 8760 steps, per token cost is 0.859
# After 8770 steps, per token cost is 0.797
# After 8780 steps, per token cost is 0.795
# After 8790 steps, per token cost is 0.727
# After 8800 steps, per token cost is 0.651
# After 8810 steps, per token cost is 0.782
# After 8820 steps, per token cost is 0.705
# After 8830 steps, per token cost is 0.624
# After 8840 steps, per token cost is 0.734
# After 8850 steps, per token cost is 0.782
# After 8860 steps, per token cost is 0.690
# After 8870 steps, per token cost is 0.821
# After 8880 steps, per token cost is 0.722
# After 8890 steps, per token cost is 0.823
# After 8900 steps, per token cost is 0.853
# After 8910 steps, per token cost is 0.822
# After 8920 steps, per token cost is 0.908
# After 8930 steps, per token cost is 0.781
# After 8940 steps, per token cost is 0.680
# After 8950 steps, per token cost is 0.738
# After 8960 steps, per token cost is 0.765
# After 8970 steps, per token cost is 0.887
# After 8980 steps, per token cost is 0.882
# After 8990 steps, per token cost is 0.763
# After 9000 steps, per token cost is 0.736
# After 9010 steps, per token cost is 0.724
# After 9020 steps, per token cost is 0.685
# After 9030 steps, per token cost is 0.815
# After 9040 steps, per token cost is 0.808
# After 9050 steps, per token cost is 0.806
# After 9060 steps, per token cost is 0.653
# After 9070 steps, per token cost is 0.814
# After 9080 steps, per token cost is 0.648
# After 9090 steps, per token cost is 0.752
# After 9100 steps, per token cost is 0.720
# After 9110 steps, per token cost is 0.876
# After 9120 steps, per token cost is 0.795
# After 9130 steps, per token cost is 0.730
# After 9140 steps, per token cost is 0.600
# After 9150 steps, per token cost is 0.707
# After 9160 steps, per token cost is 0.791
# After 9170 steps, per token cost is 0.670
# After 9180 steps, per token cost is 0.803
# After 9190 steps, per token cost is 0.695
# After 9200 steps, per token cost is 0.614
# After 9210 steps, per token cost is 0.709
# After 9220 steps, per token cost is 0.720
# After 9230 steps, per token cost is 0.665
# After 9240 steps, per token cost is 0.773
# After 9250 steps, per token cost is 0.682
# After 9260 steps, per token cost is 0.679
# After 9270 steps, per token cost is 0.667
# After 9280 steps, per token cost is 0.779
# After 9290 steps, per token cost is 0.554
# After 9300 steps, per token cost is 0.657
# After 9310 steps, per token cost is 0.582
# After 9320 steps, per token cost is 0.695
# After 9330 steps, per token cost is 0.693
# After 9340 steps, per token cost is 0.617
# After 9350 steps, per token cost is 0.675
# After 9360 steps, per token cost is 0.698
# After 9370 steps, per token cost is 0.655
# After 9380 steps, per token cost is 0.670
# In iteration: 13
# After 9390 steps, per token cost is 0.552
# After 9400 steps, per token cost is 0.755
# After 9410 steps, per token cost is 0.703
# After 9420 steps, per token cost is 0.642
# After 9430 steps, per token cost is 0.549
# After 9440 steps, per token cost is 0.688
# After 9450 steps, per token cost is 0.675
# After 9460 steps, per token cost is 0.571
# After 9470 steps, per token cost is 0.704
# After 9480 steps, per token cost is 0.702
# After 9490 steps, per token cost is 0.682
# After 9500 steps, per token cost is 0.657
# After 9510 steps, per token cost is 0.751
# After 9520 steps, per token cost is 0.783
# After 9530 steps, per token cost is 0.748
# After 9540 steps, per token cost is 0.688
# After 9550 steps, per token cost is 0.685
# After 9560 steps, per token cost is 0.628
# After 9570 steps, per token cost is 0.663
# After 9580 steps, per token cost is 0.655
# After 9590 steps, per token cost is 0.748
# After 9600 steps, per token cost is 0.637
# After 9610 steps, per token cost is 0.686
# After 9620 steps, per token cost is 0.769
# After 9630 steps, per token cost is 0.735
# After 9640 steps, per token cost is 0.707
# After 9650 steps, per token cost is 0.548
# After 9660 steps, per token cost is 0.693
# After 9670 steps, per token cost is 0.737
# After 9680 steps, per token cost is 0.663
# After 9690 steps, per token cost is 0.682
# After 9700 steps, per token cost is 0.698
# After 9710 steps, per token cost is 0.647
# After 9720 steps, per token cost is 0.697
# After 9730 steps, per token cost is 0.558
# After 9740 steps, per token cost is 0.822
# After 9750 steps, per token cost is 0.673
# After 9760 steps, per token cost is 0.725
# After 9770 steps, per token cost is 0.557
# After 9780 steps, per token cost is 0.766
# After 9790 steps, per token cost is 0.659
# After 9800 steps, per token cost is 0.629
# After 9810 steps, per token cost is 0.713
# After 9820 steps, per token cost is 0.578
# After 9830 steps, per token cost is 0.660
# After 9840 steps, per token cost is 0.650
# After 9850 steps, per token cost is 0.701
# After 9860 steps, per token cost is 0.658
# After 9870 steps, per token cost is 0.721
# After 9880 steps, per token cost is 0.620
# After 9890 steps, per token cost is 0.628
# After 9900 steps, per token cost is 0.692
# After 9910 steps, per token cost is 0.669
# After 9920 steps, per token cost is 0.714
# After 9930 steps, per token cost is 0.626
# After 9940 steps, per token cost is 0.708
# After 9950 steps, per token cost is 0.711
# After 9960 steps, per token cost is 0.678
# After 9970 steps, per token cost is 0.663
# After 9980 steps, per token cost is 0.582
# After 9990 steps, per token cost is 0.740
# After 10000 steps, per token cost is 0.679
# After 10010 steps, per token cost is 0.662
# After 10020 steps, per token cost is 0.539
# After 10030 steps, per token cost is 0.680
# After 10040 steps, per token cost is 0.666
# After 10050 steps, per token cost is 0.589
# After 10060 steps, per token cost is 0.754
# After 10070 steps, per token cost is 0.559
# After 10080 steps, per token cost is 0.586
# After 10090 steps, per token cost is 0.683
# After 10100 steps, per token cost is 0.695
# After 10110 steps, per token cost is 0.681
# After 10120 steps, per token cost is 0.641
# After 10130 steps, per token cost is 0.674
# After 10140 steps, per token cost is 0.580
# After 10150 steps, per token cost is 0.554
# After 10160 steps, per token cost is 0.718
# In iteration: 14
# After 10170 steps, per token cost is 0.679
# After 10180 steps, per token cost is 0.597
# After 10190 steps, per token cost is 0.649
# After 10200 steps, per token cost is 0.644
# After 10210 steps, per token cost is 0.663
# After 10220 steps, per token cost is 0.627
# After 10230 steps, per token cost is 0.648
# After 10240 steps, per token cost is 0.624
# After 10250 steps, per token cost is 0.624
# After 10260 steps, per token cost is 0.585
# After 10270 steps, per token cost is 0.683
# After 10280 steps, per token cost is 0.732
# After 10290 steps, per token cost is 0.697
# After 10300 steps, per token cost is 0.597
# After 10310 steps, per token cost is 0.612
# After 10320 steps, per token cost is 0.704
# After 10330 steps, per token cost is 0.584
# After 10340 steps, per token cost is 0.632
# After 10350 steps, per token cost is 0.696
# After 10360 steps, per token cost is 0.715
# After 10370 steps, per token cost is 0.663
# After 10380 steps, per token cost is 0.609
# After 10390 steps, per token cost is 0.739
# After 10400 steps, per token cost is 0.559
# After 10410 steps, per token cost is 0.530
# After 10420 steps, per token cost is 0.735
# After 10430 steps, per token cost is 0.663
# After 10440 steps, per token cost is 0.567
# After 10450 steps, per token cost is 0.583
# After 10460 steps, per token cost is 0.655
# After 10470 steps, per token cost is 0.660
# After 10480 steps, per token cost is 0.665
# After 10490 steps, per token cost is 0.604
# After 10500 steps, per token cost is 0.642
# After 10510 steps, per token cost is 0.609
# After 10520 steps, per token cost is 0.701
# After 10530 steps, per token cost is 0.745
# After 10540 steps, per token cost is 0.532
# After 10550 steps, per token cost is 0.713
# After 10560 steps, per token cost is 0.591
# After 10570 steps, per token cost is 0.574
# After 10580 steps, per token cost is 0.705
# After 10590 steps, per token cost is 0.693
# After 10600 steps, per token cost is 0.746
# After 10610 steps, per token cost is 0.590
# After 10620 steps, per token cost is 0.585
# After 10630 steps, per token cost is 0.684
# After 10640 steps, per token cost is 0.632
# After 10650 steps, per token cost is 0.658
# After 10660 steps, per token cost is 0.666
# After 10670 steps, per token cost is 0.684
# After 10680 steps, per token cost is 0.658
# After 10690 steps, per token cost is 0.646
# After 10700 steps, per token cost is 0.681
# After 10710 steps, per token cost is 0.646
# After 10720 steps, per token cost is 0.633
# After 10730 steps, per token cost is 0.686
# After 10740 steps, per token cost is 0.641
# After 10750 steps, per token cost is 0.595
# After 10760 steps, per token cost is 0.593
# After 10770 steps, per token cost is 0.698
# After 10780 steps, per token cost is 0.596
# After 10790 steps, per token cost is 0.598
# After 10800 steps, per token cost is 0.451
# After 10810 steps, per token cost is 0.569
# After 10820 steps, per token cost is 0.669
# After 10830 steps, per token cost is 0.619
# After 10840 steps, per token cost is 0.595
# After 10850 steps, per token cost is 0.477
# After 10860 steps, per token cost is 0.594
# After 10870 steps, per token cost is 0.496
# After 10880 steps, per token cost is 0.560
# After 10890 steps, per token cost is 0.564
# After 10900 steps, per token cost is 0.484
# After 10910 steps, per token cost is 0.546
# After 10920 steps, per token cost is 0.629
# After 10930 steps, per token cost is 0.541
# After 10940 steps, per token cost is 0.607
# In iteration: 15
# After 10950 steps, per token cost is 0.493
# After 10960 steps, per token cost is 0.535
# After 10970 steps, per token cost is 0.669
# After 10980 steps, per token cost is 0.571
# After 10990 steps, per token cost is 0.649
# After 11000 steps, per token cost is 0.557
# After 11010 steps, per token cost is 0.550
# After 11020 steps, per token cost is 0.620
# After 11030 steps, per token cost is 0.557
# After 11040 steps, per token cost is 0.650
# After 11050 steps, per token cost is 0.604
# After 11060 steps, per token cost is 0.567
# After 11070 steps, per token cost is 0.720
# After 11080 steps, per token cost is 0.627
# After 11090 steps, per token cost is 0.633
# After 11100 steps, per token cost is 0.679
# After 11110 steps, per token cost is 0.636
# After 11120 steps, per token cost is 0.650
# After 11130 steps, per token cost is 0.584
# After 11140 steps, per token cost is 0.625
# After 11150 steps, per token cost is 0.551
# After 11160 steps, per token cost is 0.673
# After 11170 steps, per token cost is 0.611
# After 11180 steps, per token cost is 0.629
# After 11190 steps, per token cost is 0.604
# After 11200 steps, per token cost is 0.617
# After 11210 steps, per token cost is 0.643
# After 11220 steps, per token cost is 0.573
# After 11230 steps, per token cost is 0.569
# After 11240 steps, per token cost is 0.665
# After 11250 steps, per token cost is 0.485
# After 11260 steps, per token cost is 0.592
# After 11270 steps, per token cost is 0.633
# After 11280 steps, per token cost is 0.616
# After 11290 steps, per token cost is 0.540
# After 11300 steps, per token cost is 0.618
# After 11310 steps, per token cost is 0.534
# After 11320 steps, per token cost is 0.648
# After 11330 steps, per token cost is 0.736
# After 11340 steps, per token cost is 0.581
# After 11350 steps, per token cost is 0.596
# After 11360 steps, per token cost is 0.537
# After 11370 steps, per token cost is 0.549
# After 11380 steps, per token cost is 0.609
# After 11390 steps, per token cost is 0.566
# After 11400 steps, per token cost is 0.683
# After 11410 steps, per token cost is 0.516
# After 11420 steps, per token cost is 0.473
# After 11430 steps, per token cost is 0.553
# After 11440 steps, per token cost is 0.574
# After 11450 steps, per token cost is 0.617
# After 11460 steps, per token cost is 0.524
# After 11470 steps, per token cost is 0.579
# After 11480 steps, per token cost is 0.575
# After 11490 steps, per token cost is 0.531
# After 11500 steps, per token cost is 0.616
# After 11510 steps, per token cost is 0.600
# After 11520 steps, per token cost is 0.506
# After 11530 steps, per token cost is 0.462
# After 11540 steps, per token cost is 0.542
# After 11550 steps, per token cost is 0.601
# After 11560 steps, per token cost is 0.646
# After 11570 steps, per token cost is 0.550
# After 11580 steps, per token cost is 0.541
# After 11590 steps, per token cost is 0.611
# After 11600 steps, per token cost is 0.566
# After 11610 steps, per token cost is 0.435
# After 11620 steps, per token cost is 0.553
# After 11630 steps, per token cost is 0.564
# After 11640 steps, per token cost is 0.541
# After 11650 steps, per token cost is 0.498
# After 11660 steps, per token cost is 0.547
# After 11670 steps, per token cost is 0.497
# After 11680 steps, per token cost is 0.488
# After 11690 steps, per token cost is 0.493
# After 11700 steps, per token cost is 0.594
# After 11710 steps, per token cost is 0.580
# After 11720 steps, per token cost is 0.524
# In iteration: 16
# After 11730 steps, per token cost is 0.566
# After 11740 steps, per token cost is 0.516
# After 11750 steps, per token cost is 0.703
# After 11760 steps, per token cost is 0.514
# After 11770 steps, per token cost is 0.496
# After 11780 steps, per token cost is 0.551
# After 11790 steps, per token cost is 0.531
# After 11800 steps, per token cost is 0.577
# After 11810 steps, per token cost is 0.517
# After 11820 steps, per token cost is 0.503
# After 11830 steps, per token cost is 0.548
# After 11840 steps, per token cost is 0.556
# After 11850 steps, per token cost is 0.616
# After 11860 steps, per token cost is 0.610
# After 11870 steps, per token cost is 0.480
# After 11880 steps, per token cost is 0.610
# After 11890 steps, per token cost is 0.469
# After 11900 steps, per token cost is 0.531
# After 11910 steps, per token cost is 0.506
# After 11920 steps, per token cost is 0.550
# After 11930 steps, per token cost is 0.563
# After 11940 steps, per token cost is 0.585
# After 11950 steps, per token cost is 0.548
# After 11960 steps, per token cost is 0.547
# After 11970 steps, per token cost is 0.576
# After 11980 steps, per token cost is 0.591
# After 11990 steps, per token cost is 0.509
# After 12000 steps, per token cost is 0.558
# After 12010 steps, per token cost is 0.575
# After 12020 steps, per token cost is 0.556
# After 12030 steps, per token cost is 0.564
# After 12040 steps, per token cost is 0.593
# After 12050 steps, per token cost is 0.658
# After 12060 steps, per token cost is 0.596
# After 12070 steps, per token cost is 0.580
# After 12080 steps, per token cost is 0.548
# After 12090 steps, per token cost is 0.499
# After 12100 steps, per token cost is 0.585
# After 12110 steps, per token cost is 0.607
# After 12120 steps, per token cost is 0.486
# After 12130 steps, per token cost is 0.606
# After 12140 steps, per token cost is 0.528
# After 12150 steps, per token cost is 0.723
# After 12160 steps, per token cost is 0.564
# After 12170 steps, per token cost is 0.540
# After 12180 steps, per token cost is 0.511
# After 12190 steps, per token cost is 0.547
# After 12200 steps, per token cost is 0.564
# After 12210 steps, per token cost is 0.534
