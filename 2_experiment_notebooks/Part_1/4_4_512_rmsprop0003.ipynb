# %% [markdown]
# *This Note book referenced [WuJiaocan's Github](https://github.com/WuJiaocan/tensorflow), [XueYouluo's Github](https://github.com/xueyouluo/my_seq2seq/blob/90c86bacd5cb88ad8d381de28fe3bdf8421a0036/notebooks/MyS2S.ipynb)
#
# *Major contribution of this notebook is: provided a flexible NMT network building (change of layers, cell-type, switch between bi-direction and uni-direction RNN, switch between attention mechanisms) based on Tensorflow through parameter setting

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
import tensorflow as tf
import codecs
import sys
import numpy as np
import time

# %% [markdown]
# # INSTRUCTION -0: RECORD PARAMETERS
#
# !! Please record all hyper parameters [HERE](https://docs.google.com/spreadsheets/d/1VgRGGDv_ynvTORz3vHtH2VgRQnyxv9qBkDkPjSpDj3c/edit?usp=sharing) **BEFORE** start traning.
#
# This is to avoid duplicated/similar experiments among our team

# %% [markdown]
# # INSTRUCTION-1: SET TRAINING DATASET
#
# Set NUM_EXAMPLES AND Run All Cells
#
# Time for 1 Epoch on Colab GPU for reference:
#
# 1. 100,000 sentence pairs: 285s
# 2.  50,000 sentence pairs: 127s

# %% [markdown]
# ### 1.Create Vocabulary

# %%
NUM_SENT = 50000

# %%
src_path = 'en_clean.txt'
tgt_path = 'fr_clean.txt'

# %%
def read_train_data(txt_path, num_examples):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[:num_examples]

# %%
src = read_train_data(src_path, NUM_SENT)
tgt = read_train_data(tgt_path, NUM_SENT)

# %%
def read_test_data(txt_path, num_examples = 400):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[-num_examples:]

# %%
src_test = read_test_data(src_path)
tgt_test = read_test_data(tgt_path)

# %%
print('size of number of source sentences from dataset for training: {}'.format(len(src)))
print('size of number of target sentences from dataset for training: {}'.format(len(tgt)))
# Out:
# size of number of source sentences from dataset for training: 50000
# size of number of target sentences from dataset for training: 50000

# %%
print('size of number of source sentences from dataset for testing: {}'.format(len(src_test)))
print('size of number of target sentences from dataset for testing: {}'.format(len(tgt_test)))
# Out:
# size of number of source sentences from dataset for testing: 400
# size of number of target sentences from dataset for testing: 400

# %%
# Display examples for quick check

for i in range(5):
  print(src[i])
# Out:
#  global health where do physiotherapy and rehabilitation research fit ?
#  carabin
#  comment on the misappropriation of bibliographical references in science . the example of anti aging medicine
#  anti aging medicine , a science based , essential medicine
#  underwater dive in fresh water complicated by a cardiorespiratory arrest on obstructive shock

# %%
for i in range(5):
  print(tgt[i])
# Out:
#  la place des cheveux et des poils dans les rituels et le sacre
#  les carabins
#  du detournement des references bibliographiques en science . l exemple de la medecine anti age
#  la medecine anti age , une medecine scientifique , indispensable
#  plongee subaquatique en eau douce compliquee d un arret cardiorespiratoire sur choc obstructif

# %%
import codecs
import collections
from operator import itemgetter

def create_vocab(RAW_DATA, VOCAB_OUTPUT):
    counter = collections.Counter()

    for line in RAW_DATA:
        for word in line.strip().lower().split():
            counter[word] += 1

    sorted_word_to_cnt = sorted(counter.items(), key=itemgetter(1), reverse=True)
    sorted_words = [x[0] for x in sorted_word_to_cnt]

    sorted_words =  ['<pad>'] + ['<sos>'] + ['<eos>'] + ['<unk>'] + sorted_words 

    with codecs.open(VOCAB_OUTPUT, "w", encoding="utf-8") as file_output:
        for word in sorted_words:
            file_output.write(word + "\n")
    return sorted_words

# %%
vocab_src = create_vocab(src, 'vocab.en')
vocab_tgt = create_vocab(tgt, 'vocab.fr')

# %%
vocab_size_src = len(vocab_src)
vocab_size_tgt = len(vocab_tgt)

print('size of source vocab {}'.format(vocab_size_src))
print('size of target vocab {}'.format(vocab_size_tgt))
# Out:
# size of source vocab 28711
# size of target vocab 35019

# %%
print(vocab_src[-5:])
# Out:
# ['homolateral', 'peritonsillar', 'radt', 'lobbying', 'mediacalcosis']

# %%
print(vocab_tgt[-5:])
# Out:
# ['respective', 'periamygdalien', 'bachelot', 'lobbying', 'mediacalcose']

# %% [markdown]
# ### 2.Convert Text to Numbers

# %%
import codecs
import sys

def text_to_int(RAW_DATA, VOCAB, OUTPUT_DATA):

  with codecs.open(VOCAB, "r", encoding="utf-8") as f_vocab:
      vocab = [w.strip() for w in f_vocab.readlines()]
      word_to_id = {k:v for (k,v) in zip(vocab, range(len(vocab)))}

  def get_id(word):
      return word_to_id[word] if word in word_to_id else word_to_id["<unk>"]

  fout = codecs.open(OUTPUT_DATA, "w", encoding="utf-8")
  for line in RAW_DATA:
      words = line.strip().split() + ["<eos>"]

      out_line = " ".join([str(get_id(w)) for w in words]) + "\n"
      fout.write(out_line)
  fout.close()

# %%
text_to_int(src, 'vocab.en', 'train.en')
text_to_int(tgt, 'vocab.fr', 'train.fr')

# %% [markdown]
# ### 4. Create Training Dataset

# %%
def MakeDataset(file_path):
    dataset = tf.data.TextLineDataset(file_path)
    # split by space
    dataset = dataset.map(lambda string: tf.string_split([string]).values)
    # convert string to number
    dataset = dataset.map(
        lambda string: tf.string_to_number(string, tf.int32))
    # calc # word/sentence and put in dataset with sentence
    dataset = dataset.map(lambda x: (x, tf.size(x)))
    return dataset

def MakeSrcTrgDataset(src_path, trg_path, batch_size):

    src_data = MakeDataset(src_path)
    trg_data = MakeDataset(trg_path)
    #   ds[0][0]source sentence
    #   ds[0][1]len of source sentence
    #   ds[1][0]target sentence
    #   ds[1][1]len of target sentence
    dataset = tf.data.Dataset.zip((src_data, trg_data))

    # delete empty and super-long sentence
    def FilterLength(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        src_len_ok = tf.logical_and(
            tf.greater(src_len, 1), tf.less_equal(src_len, MAX_LEN))
        trg_len_ok = tf.logical_and(
            tf.greater(trg_len, 1), tf.less_equal(trg_len, MAX_LEN))
        return tf.logical_and(src_len_ok, trg_len_ok)
    dataset = dataset.filter(FilterLength)
    
    #   1.trg_input: "<sos> X Y Z"
    #   2.trg_label: "X Y Z <eos>"
    #   file: "X Y Z <eos>", need to produce "<sos> X Y Z" and add to dataset
    def MakeTrgInput(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        trg_input = tf.concat([[SOS_ID], trg_label[:-1]], axis=0)
        return ((src_input, src_len), (trg_input, trg_label, trg_len))
    
    dataset = dataset.map(MakeTrgInput)

    dataset = dataset.shuffle(10000)

    # define shape after padding
    padded_shapes = (
        (tf.TensorShape([None]),
         tf.TensorShape([])), 
        (tf.TensorShape([None]),
         tf.TensorShape([None]),
         tf.TensorShape([]))) 
    
    # padded_batch to pad
    batched_dataset = dataset.padded_batch(batch_size, padded_shapes)
    return batched_dataset

# %% [markdown]
# ### 3.Define NMT

# %%
def single_rnn_cell(cell_name, hid_size, keep_prob):
    if cell_name == "GRU":
        cell = tf.contrib.rnn.GRUCell(hid_size)
    elif cell_name == "LSTM":
        cell = tf.contrib.rnn.LSTMCell(hid_size)
    elif cell_name == "BASIC":
        cell = tf.contrib.rnn.BasicRNNCell(hid_size)
        
    if keep_prob < 1.0:
    cell = tf.contrib.rnn.DropoutWrapper(
          cell=cell,
          input_keep_prob=keep_prob,
          output_keep_prob=keep_prob)
    
    return cell


def multi_rnn_cell(cell_name, hid_size, num_layers, keep_prob):
    cells = []
    for _ in range(num_layers):
        cell = single_rnn_cell(cell_name, hid_size, keep_prob)
        cells.append(cell)
    
    if len(cells) > 1:
        final_cell = tf.contrib.rnn.MultiRNNCell(cells=cells)
    else:
        final_cell = cells[0]
    return final_cell
  
  
def single_biRNN_pair(cell_name, hid_size, keep_prob):
    if cell_name == "bi-GRU":
      enc_cell_fw = single_rnn_cell('GRU', hid_size, keep_prob)
      enc_cell_bw = single_rnn_cell('GRU', hid_size, keep_prob)
    elif cell_name == "bi-LSTM":
      enc_cell_fw = single_rnn_cell('LSTM', hid_size, keep_prob)
      enc_cell_bw = single_rnn_cell('LSTM', hid_size, keep_prob)
    return enc_cell_fw, enc_cell_bw
    
def multi_biRNN_pair(cell_name, hid_size, num_layers, keep_prob):
    stacked_biRNN_fw = []
    stacked_biRNN_bw = []
    for _ in range(num_layers):
        enc_cell_fw, enc_cell_bw = single_biRNN_pair(cell_name, hid_size, keep_prob)
        stacked_biRNN_fw.append(enc_cell_fw)
        stacked_biRNN_bw.append(enc_cell_bw)
    
    if len(stacked_biRNN_fw) > 1:
        final_stacked_biRNN_fw = tf.contrib.rnn.MultiRNNCell(cells=stacked_biRNN_fw)
        final_stacked_biRNN_bw = tf.contrib.rnn.MultiRNNCell(cells=stacked_biRNN_bw)
    else:
        final_stacked_biRNN_fw = stacked_biRNN_fw[0]
        final_stacked_biRNN_bw = stacked_biRNN_bw[0]
    return final_stacked_biRNN_fw, final_stacked_biRNN_bw

# %%
class NMTModel(object):
  """
  defind the nmt model
  
  """
  # define variables needed by nmt
  def __init__(self, 
               dec_layer, 
               enc_layer,
               dec_cell_name, 
               enc_cell_name,
               optimizer, 
               lr,
               hid_size, 
               attention,
               drop_out):
    
    self.dec_cell_name = dec_cell_name
    self.enc_cell_name = enc_cell_name
    self.dec_layer = dec_layer
    self.enc_layer = enc_layer
    self.attention = attention
    
    self.hid_size = hid_size
    self.opt = optimizer
    self.lr = lr
    
    self.keep_prob = 1.0 - drop_out

    # EMBEDDING SETUP
    
    self.src_embedding = tf.get_variable(
          "src_emb", [SRC_VOCAB_SIZE, self.hid_size])
    self.trg_embedding = tf.get_variable(
          "trg_emb", [TRG_VOCAB_SIZE, self.hid_size])

      # define variables for softmax layer
    if SHARE_EMB_AND_SOFTMAX:
         self.softmax_weight = tf.transpose(self.trg_embedding)
    else:
         self.softmax_weight = tf.get_variable(
             "weight", [self.hid_size, TRG_VOCAB_SIZE])
    self.softmax_bias = tf.get_variable(
          "softmax_bias", [TRG_VOCAB_SIZE])
     
  # calculate forward graph
  # src_input, src_size, trg_input, trg_label, trg_size are from MakeSrcTrgDataset
  
  def forward(self, src_input, src_size, trg_input, trg_label, trg_size):
      batch_size = tf.shape(src_input)[0]
      
      # *************************
      # **** EMBEDDING SCOPE ****
      # *************************
      
      with tf.variable_scope("Embeddings"):

        # convert word_int input to embeddings
        src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
        trg_emb = tf.nn.embedding_lookup(self.trg_embedding, trg_input)

        # set drop_out rate
        src_emb = tf.nn.dropout(src_emb, self.keep_prob)
        trg_emb = tf.nn.dropout(trg_emb, self.keep_prob)

      # *************************
      # ***** ENCODER SCOPE *****
      # *************************

      with tf.variable_scope("encoder"):
        
        if not 'bi' in self.enc_cell_name:
        
          enc_cell = multi_rnn_cell(self.enc_cell_name, 
                                    self.hid_size, 
                                    self.enc_layer, 
                                    self.keep_prob)
          enc_outputs, enc_state = tf.nn.dynamic_rnn(enc_cell, 
                                                     inputs=src_emb, 
                                                     sequence_length=src_size, 
                                                     dtype=tf.float32) 
        
        else:
          
          stacked_biRNN_fw, stacked_biRNN_bw = multi_biRNN_pair(self.enc_cell_name, 
                                                                self.hid_size, 
                                                                self.enc_layer, 
                                                                self.keep_prob)
          enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = stacked_biRNN_fw,
                                                                   cell_bw = stacked_biRNN_bw,
                                                                   inputs = src_emb,
                                                                   sequence_length = src_size,
                                                                   dtype = tf.float32)
          
          # concatenate two outputs of LSTM cell as 1 tensor
          # enc_outputs = (output_fw, output_bw)
          enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)
          
    
      # *************************
      # ***** DECODER SCOPE *****
      # *************************
      
      with tf.variable_scope("decoder"):
        
        dec_cell = multi_rnn_cell(self.dec_cell_name, self.hid_size, self.dec_layer, self.keep_prob)
    
    
        # OPTIONS FOR ATTENTION MECHANISM
        if self.attention == 'Bahdanau':
        
          attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                  self.hid_size, 
                  enc_outputs,
                  memory_sequence_length = src_size)
          
        if self.attention == 'Luong':

          attention_mechanism = tf.contrib.seq2seq.LuongAttention(
                  self.hid_size,
                  enc_outputs,
                  memory_sequence_length=src_size)

        # ATTENTION WRAPPER: 
        # wrap dec_cell and attention mechanisim
        attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                dec_cell, 
                attention_mechanism,
                attention_layer_size=self.hid_size)

        # use attention_cell and dynamic_rnn construct decoder
        # here relay totally on attention as the information source
        dec_outputs, _ = tf.nn.dynamic_rnn(
                attention_cell, trg_emb, trg_size, dtype=tf.float32)

        
      # ************************
      # ***** OPTIMIZATION *****
      # ************************
      
      # LOSS/LOG PERPLEXITY
      output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
      logits = tf.matmul(output, self.softmax_weight) + self.softmax_bias
      loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
          labels=tf.reshape(trg_label, [-1]), logits=logits)

      # set padding weight as 0 when calc average loss
      label_weights = tf.sequence_mask(
          trg_size, maxlen=tf.shape(trg_label)[1], dtype=tf.float32)
      label_weights = tf.reshape(label_weights, [-1])
      cost = tf.reduce_sum(loss * label_weights)
      cost_per_token = cost / tf.reduce_sum(label_weights)

      # define backprop
      trainable_variables = tf.trainable_variables()

      # OPTIONS FOR OPTIMIZER
      # define optimization method/steps
      grads = tf.gradients(cost / tf.to_float(batch_size),
                           trainable_variables)
      
      grads, _ = tf.clip_by_global_norm(grads, clip_norm = 5)

      if self.opt == 'adam':
        optimizer = tf.train.AdamOptimizer(learning_rate = self.lr)
      
      elif self.opt == 'sgd':        
        optimizer = tf.train.GradientDescentOptimizer(learning_rate = self.lr)
        
      elif self.opt == 'rmsprop':     
        optimizer = tf.train.RMSPropOptimizer(learning_rate = self.lr)
      
      train_op = optimizer.apply_gradients(zip(grads, trainable_variables))
      
      return cost_per_token, train_op

# %% [markdown]
# ### 4.Training

# %%
def run_epoch(session, cost_op, train_op, saver, step):
    while True:
        try:
            # execute train_op and calc loss
            cost, _ = session.run([cost_op, train_op])
            if step % 10 == 0:
                print("After %d steps, per token cost is %.3f" % (step, cost))
            # save checkpoint per 200 steps
            if step % 200 == 0:
                saver.save(session, CHECKPOINT_PATH, global_step=step)
            step += 1
        except tf.errors.OutOfRangeError:
            break
    return step

# %% [markdown]
# #INSTRUCTION-2: SET TRAINING HYPER PARAMETERS
#
# 1. Normally just leave following things as they are, unless changed training dataset or dataset size:
#   * SRC_TRAIN_DATA,
#   * TRG_TRAIN_DATA,
#   * SRC_VOCAB_SIZE
#   * TRG_VOCAB_SIZE
#
# 2. Need to change CHECKPOINT_PATH each time for a training to distinguish different training setting (for easier recording)
#
# 3. Following Prameters can be tuned for research and experiment purpose:
#
#   * HIDDEN_SIZE (# INTEGER)
#   * DECODER_LAYERS (# INTEGER)
#   * DECODER_CELL_TYPE (OPTIONS: 'LSTM', 'GRU', 'BASIC')
#   * ENCODER_LAYERS (# INTEGER)
#   * ENCODER_CELL_TYPE (OPTIONS: 'LSTM', 'GRU', 'BASIC', 'bi-LSTM', 'bi-GRU')
#   * ATTENTION ('Luong', 'Bahdanau')
#   * DROP_OUT (0~1.0)
#   * OPTIMIZER (OPTIONS: 'adam', 'sgd', 'rmsprop')
#   * LEARNING_RATE (0.0001 ~ 0.1)
#   * NUM_EPOCH (#INTEGER: dont' use big number as it consumes time, could keep consistent across all experiments to compare whose loss decreased the most in certain epochs)
#   * BATCH_SIZE (#INTEGER: 32, 64, 128, 256...)
#
#
#   **NOTICE: ALL PARAM NAMES ARE CASE SENSITIVE**

# %%
CHECKPOINT_PATH = "./ckpt-exp05/google-brain-rmsprop001"  

HIDDEN_SIZE = 512
DECODER_LAYERS = 4                    # Num_layer for decoder LSTM
DECODER_CELL_TYPE = 'LSTM'
ENCODER_LAYERS = 4
ENCODER_CELL_TYPE = 'bi-LSTM'
ATTENTION = 'Luong'
OPTIMIZER = 'rmsprop'
DROPOUT = 0.1
LEARNING_RATE = 0.003

BATCH_SIZE = 128
NUM_EPOCH = 20


SRC_TRAIN_DATA = "train.en"
TRG_TRAIN_DATA = "train.fr"
SRC_VOCAB_SIZE = vocab_size_src       
TRG_VOCAB_SIZE = vocab_size_tgt 
SHARE_EMB_AND_SOFTMAX = True           # share weights between softmax layer and embedding layer
MAX_LEN = 100   # max length of a sentence
SOS_ID  = 1    # <sos> ID in target vocab

import time
def main():
  
    initializer = tf.random_uniform_initializer(-0.05, 0.05)
    
    tf.reset_default_graph()

    with tf.variable_scope("nmt_model", reuse=None, 
                           initializer=initializer):
        train_model = NMTModel(
                dec_layer = DECODER_LAYERS, 
                enc_layer = ENCODER_LAYERS,
                dec_cell_name =  DECODER_CELL_TYPE,
                enc_cell_name = ENCODER_CELL_TYPE,
                optimizer = OPTIMIZER, 
                lr = LEARNING_RATE,
                hid_size = HIDDEN_SIZE, 
                attention = ATTENTION,
                drop_out = DROPOUT)
  
    # define input data
    data = MakeSrcTrgDataset(SRC_TRAIN_DATA, TRG_TRAIN_DATA, BATCH_SIZE)
    iterator = data.make_initializable_iterator()
    (src, src_size), (trg_input, trg_label, trg_size) = iterator.get_next()
 
    # define forward graph
    cost_op, train_op = train_model.forward(src, src_size, trg_input,
                                            trg_label, trg_size)

    # train
    saver = tf.train.Saver()
    tf.add_to_collection('train_op', train_op)
    tf.add_to_collection('cost_op', cost_op)
    step = 0
    with tf.Session() as sess:
        writer = tf.summary.FileWriter('logs', sess.graph)
        writer.close()
        
        tf.global_variables_initializer().run()
        for i in range(NUM_EPOCH):
            time_start=time.time()
            print("-------In iteration: %d" % (i + 1))
            sess.run(iterator.initializer)
            step = run_epoch(sess, cost_op, train_op, saver, step)
            time_end=time.time()
            print('-------time cost',time_end-time_start,'s')
            print('                                        ')
            
if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-22-c090c396d1f3>:63: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-21-fa072cc97634>:5: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-21-fa072cc97634>:41: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-22-c090c396d1f3>:93: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From <ipython-input-22-c090c396d1f3>:159: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# -------In iteration: 1
# After 0 steps, per token cost is 10.468
# After 10 steps, per token cost is 10.457
# After 20 steps, per token cost is 10.443
# After 30 steps, per token cost is 10.415
# After 40 steps, per token cost is 10.359
# After 50 steps, per token cost is 9.739
# After 60 steps, per token cost is 8.533
# After 70 steps, per token cost is 7.985
# After 80 steps, per token cost is 8.125
# After 90 steps, per token cost is 7.782
# After 100 steps, per token cost is 7.936
# After 110 steps, per token cost is 7.101
# After 120 steps, per token cost is 11.303
# After 130 steps, per token cost is 7.486
# After 140 steps, per token cost is 7.180
# After 150 steps, per token cost is 7.292
# After 160 steps, per token cost is 7.294
# After 170 steps, per token cost is 8.553
# After 180 steps, per token cost is 7.033
# After 190 steps, per token cost is 7.280
# After 200 steps, per token cost is 7.292
# After 210 steps, per token cost is 7.111
# After 220 steps, per token cost is 6.915
# After 230 steps, per token cost is 7.438
# After 240 steps, per token cost is 6.951
# After 250 steps, per token cost is 6.954
# After 260 steps, per token cost is 6.840
# After 270 steps, per token cost is 6.862
# After 280 steps, per token cost is 7.044
# After 290 steps, per token cost is 6.802
# After 300 steps, per token cost is 6.987
# After 310 steps, per token cost is 7.060
# After 320 steps, per token cost is 6.669
# After 330 steps, per token cost is 6.956
# After 340 steps, per token cost is 6.422
# After 350 steps, per token cost is 6.494
# After 360 steps, per token cost is 6.444
# After 370 steps, per token cost is 6.407
# After 380 steps, per token cost is 6.433
# After 390 steps, per token cost is 6.378
# -------time cost 289.35876750946045 s
#
# -------In iteration: 2
# After 400 steps, per token cost is 6.374
# After 410 steps, per token cost is 6.198
# After 420 steps, per token cost is 6.381
# After 430 steps, per token cost is 6.246
# After 440 steps, per token cost is 6.227
# After 450 steps, per token cost is 6.094
# After 460 steps, per token cost is 6.196
# After 470 steps, per token cost is 10.147
# After 480 steps, per token cost is 6.195
# After 490 steps, per token cost is 6.069
# After 500 steps, per token cost is 6.035
# After 510 steps, per token cost is 6.213
# After 520 steps, per token cost is 6.070
# After 530 steps, per token cost is 6.241
# After 540 steps, per token cost is 5.935
# After 550 steps, per token cost is 5.923
# After 560 steps, per token cost is 5.946
# After 570 steps, per token cost is 5.966
# After 580 steps, per token cost is 5.801
# After 590 steps, per token cost is 5.932
# After 600 steps, per token cost is 5.802
# After 610 steps, per token cost is 5.814
# After 620 steps, per token cost is 5.911
# After 630 steps, per token cost is 5.788
# After 640 steps, per token cost is 5.762
# After 650 steps, per token cost is 5.673
# After 660 steps, per token cost is 5.540
# After 670 steps, per token cost is 5.635
# After 680 steps, per token cost is 5.690
# After 690 steps, per token cost is 5.636
# After 700 steps, per token cost is 5.387
# After 710 steps, per token cost is 5.517
# After 720 steps, per token cost is 5.269
# After 730 steps, per token cost is 5.514
# After 740 steps, per token cost is 5.338
# After 750 steps, per token cost is 5.488
# After 760 steps, per token cost is 5.494
# After 770 steps, per token cost is 5.317
# After 780 steps, per token cost is 5.326
# -------time cost 285.12336802482605 s
#
# -------In iteration: 3
# After 790 steps, per token cost is 5.060
# After 800 steps, per token cost is 5.183
# After 810 steps, per token cost is 5.281
# After 820 steps, per token cost is 5.109
# After 830 steps, per token cost is 5.047
# After 840 steps, per token cost is 5.071
# After 850 steps, per token cost is 4.869
# After 860 steps, per token cost is 5.040
# After 870 steps, per token cost is 4.988
# After 880 steps, per token cost is 4.749
# After 890 steps, per token cost is 4.959
# After 900 steps, per token cost is 4.794
# After 910 steps, per token cost is 5.069
# After 920 steps, per token cost is 5.016
# After 930 steps, per token cost is 4.909
# After 940 steps, per token cost is 4.827
# After 950 steps, per token cost is 4.899
# After 960 steps, per token cost is 4.806
# After 970 steps, per token cost is 4.899
# After 980 steps, per token cost is 4.752
# After 990 steps, per token cost is 4.702
# After 1000 steps, per token cost is 4.738
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# After 1010 steps, per token cost is 4.544
# After 1020 steps, per token cost is 4.845
# After 1030 steps, per token cost is 4.429
# After 1040 steps, per token cost is 4.558
# After 1050 steps, per token cost is 4.593
# After 1060 steps, per token cost is 4.478
# After 1070 steps, per token cost is 4.582
# After 1080 steps, per token cost is 4.518
# After 1090 steps, per token cost is 4.559
# After 1100 steps, per token cost is 4.316
# After 1110 steps, per token cost is 4.539
# After 1120 steps, per token cost is 4.343
# After 1130 steps, per token cost is 4.499
# After 1140 steps, per token cost is 4.441
# After 1150 steps, per token cost is 4.676
# After 1160 steps, per token cost is 4.313
# After 1170 steps, per token cost is 4.457
# -------time cost 285.42565393447876 s
#
# -------In iteration: 4
# After 1180 steps, per token cost is 4.385
# After 1190 steps, per token cost is 4.341
# After 1200 steps, per token cost is 4.266
# After 1210 steps, per token cost is 4.270
# After 1220 steps, per token cost is 4.221
# After 1230 steps, per token cost is 4.041
# After 1240 steps, per token cost is 4.464
# After 1250 steps, per token cost is 3.990
# After 1260 steps, per token cost is 4.217
# After 1270 steps, per token cost is 4.301
# After 1280 steps, per token cost is 4.137
# After 1290 steps, per token cost is 4.486
# After 1300 steps, per token cost is 4.106
# After 1310 steps, per token cost is 4.126
# After 1320 steps, per token cost is 4.183
# After 1330 steps, per token cost is 4.098
# After 1340 steps, per token cost is 4.235
# After 1350 steps, per token cost is 4.279
# After 1360 steps, per token cost is 4.169
# After 1370 steps, per token cost is 4.284
# After 1380 steps, per token cost is 4.162
# After 1390 steps, per token cost is 4.232
# After 1400 steps, per token cost is 4.052
# After 1410 steps, per token cost is 4.171
# After 1420 steps, per token cost is 4.019
# After 1430 steps, per token cost is 4.038
# After 1440 steps, per token cost is 3.985
# After 1450 steps, per token cost is 3.834
# After 1460 steps, per token cost is 4.095
# After 1470 steps, per token cost is 3.986
# After 1480 steps, per token cost is 3.914
# After 1490 steps, per token cost is 3.932
# After 1500 steps, per token cost is 3.923
# After 1510 steps, per token cost is 4.025
# After 1520 steps, per token cost is 3.855
# After 1530 steps, per token cost is 3.853
# After 1540 steps, per token cost is 4.002
# After 1550 steps, per token cost is 3.987
# After 1560 steps, per token cost is 4.153
# -------time cost 286.01665353775024 s
#
# -------In iteration: 5
# After 1570 steps, per token cost is 3.546
# After 1580 steps, per token cost is 3.779
# After 1590 steps, per token cost is 3.659
# After 1600 steps, per token cost is 3.680
# After 1610 steps, per token cost is 3.610
# After 1620 steps, per token cost is 3.685
# After 1630 steps, per token cost is 3.719
# After 1640 steps, per token cost is 3.804
# After 1650 steps, per token cost is 3.535
# After 1660 steps, per token cost is 3.776
# After 1670 steps, per token cost is 3.518
# After 1680 steps, per token cost is 3.347
# After 1690 steps, per token cost is 3.777
# After 1700 steps, per token cost is 3.689
# After 1710 steps, per token cost is 3.620
# After 1720 steps, per token cost is 3.630
# After 1730 steps, per token cost is 3.505
# After 1740 steps, per token cost is 3.399
# After 1750 steps, per token cost is 3.768
# After 1760 steps, per token cost is 3.944
# After 1770 steps, per token cost is 3.721
# After 1780 steps, per token cost is 3.556
# After 1790 steps, per token cost is 3.494
# After 1800 steps, per token cost is 3.610
# After 1810 steps, per token cost is 3.532
# After 1820 steps, per token cost is 3.647
# After 1830 steps, per token cost is 3.479
# After 1840 steps, per token cost is 3.575
# After 1850 steps, per token cost is 3.555
# After 1860 steps, per token cost is 3.686
# After 1870 steps, per token cost is 3.585
# After 1880 steps, per token cost is 3.825
# After 1890 steps, per token cost is 3.459
# After 1900 steps, per token cost is 3.598
# After 1910 steps, per token cost is 3.563
# After 1920 steps, per token cost is 3.580
# After 1930 steps, per token cost is 3.789
# After 1940 steps, per token cost is 3.594
# After 1950 steps, per token cost is 3.606
# -------time cost 285.8538496494293 s
#
# -------In iteration: 6
# After 1960 steps, per token cost is 3.274
# After 1970 steps, per token cost is 3.207
# After 1980 steps, per token cost is 3.311
# After 1990 steps, per token cost is 3.379
# After 2000 steps, per token cost is 3.653
# After 2010 steps, per token cost is 3.256
# After 2020 steps, per token cost is 3.455
# After 2030 steps, per token cost is 3.456
# After 2040 steps, per token cost is 3.251
# After 2050 steps, per token cost is 3.156
# After 2060 steps, per token cost is 3.695
# After 2070 steps, per token cost is 3.317
# After 2080 steps, per token cost is 3.398
# After 2090 steps, per token cost is 3.454
# After 2100 steps, per token cost is 3.237
# After 2110 steps, per token cost is 3.290
# After 2120 steps, per token cost is 3.227
# After 2130 steps, per token cost is 3.316
# After 2140 steps, per token cost is 3.135
# After 2150 steps, per token cost is 3.527
# After 2160 steps, per token cost is 3.327
# After 2170 steps, per token cost is 3.264
# After 2180 steps, per token cost is 3.184
# After 2190 steps, per token cost is 3.268
# After 2200 steps, per token cost is 3.248
# After 2210 steps, per token cost is 3.178
# After 2220 steps, per token cost is 3.387
# After 2230 steps, per token cost is 3.181
# After 2240 steps, per token cost is 3.307
# After 2250 steps, per token cost is 3.055
# After 2260 steps, per token cost is 3.321
# After 2270 steps, per token cost is 3.521
# After 2280 steps, per token cost is 3.390
# After 2290 steps, per token cost is 3.214
# After 2300 steps, per token cost is 3.280
# After 2310 steps, per token cost is 3.240
# After 2320 steps, per token cost is 3.403
# After 2330 steps, per token cost is 3.392
# After 2340 steps, per token cost is 3.438
# -------time cost 285.3582785129547 s
#
# -------In iteration: 7
# After 2350 steps, per token cost is 3.234
# After 2360 steps, per token cost is 3.272
# After 2370 steps, per token cost is 2.974
# After 2380 steps, per token cost is 3.114
# After 2390 steps, per token cost is 3.200
# After 2400 steps, per token cost is 3.189
# After 2410 steps, per token cost is 3.121
# After 2420 steps, per token cost is 3.219
# After 2430 steps, per token cost is 2.938
# After 2440 steps, per token cost is 3.269
# After 2450 steps, per token cost is 3.138
# After 2460 steps, per token cost is 2.996
# After 2470 steps, per token cost is 3.088
# After 2480 steps, per token cost is 3.154
# After 2490 steps, per token cost is 3.317
# After 2500 steps, per token cost is 3.029
# After 2510 steps, per token cost is 2.918
# After 2520 steps, per token cost is 3.275
# After 2530 steps, per token cost is 3.193
# After 2540 steps, per token cost is 3.280
# After 2550 steps, per token cost is 3.018
# After 2560 steps, per token cost is 2.984
# After 2570 steps, per token cost is 3.246
# After 2580 steps, per token cost is 3.273
# After 2590 steps, per token cost is 3.203
# After 2600 steps, per token cost is 3.402
# After 2610 steps, per token cost is 3.139
# After 2620 steps, per token cost is 3.285
# After 2630 steps, per token cost is 2.870
# After 2640 steps, per token cost is 3.213
# After 2650 steps, per token cost is 2.968
# After 2660 steps, per token cost is 3.126
# After 2670 steps, per token cost is 3.026
# After 2680 steps, per token cost is 3.106
# After 2690 steps, per token cost is 3.014
# After 2700 steps, per token cost is 3.156
# After 2710 steps, per token cost is 3.246
# After 2720 steps, per token cost is 2.984
# After 2730 steps, per token cost is 3.155
# -------time cost 283.4612593650818 s
#
# -------In iteration: 8
# After 2740 steps, per token cost is 2.931
# After 2750 steps, per token cost is 2.918
# After 2760 steps, per token cost is 2.988
# After 2770 steps, per token cost is 3.006
# After 2780 steps, per token cost is 3.116
# After 2790 steps, per token cost is 3.154
# After 2800 steps, per token cost is 2.803
# After 2810 steps, per token cost is 3.086
# After 2820 steps, per token cost is 2.891
# After 2830 steps, per token cost is 3.093
# After 2840 steps, per token cost is 2.776
# After 2850 steps, per token cost is 2.818
# After 2860 steps, per token cost is 2.907
# After 2870 steps, per token cost is 2.775
# After 2880 steps, per token cost is 2.971
# After 2890 steps, per token cost is 2.882
# After 2900 steps, per token cost is 3.181
# After 2910 steps, per token cost is 2.926
# After 2920 steps, per token cost is 2.730
# After 2930 steps, per token cost is 2.879
# After 2940 steps, per token cost is 2.685
# After 2950 steps, per token cost is 3.029
# After 2960 steps, per token cost is 2.849
# After 2970 steps, per token cost is 2.863
# After 2980 steps, per token cost is 3.151
# After 2990 steps, per token cost is 3.127
# After 3000 steps, per token cost is 2.772
# After 3010 steps, per token cost is 2.931
# After 3020 steps, per token cost is 2.815
# After 3030 steps, per token cost is 2.932
# After 3040 steps, per token cost is 2.952
# After 3050 steps, per token cost is 2.765
# After 3060 steps, per token cost is 3.099
# After 3070 steps, per token cost is 2.808
# After 3080 steps, per token cost is 3.002
# After 3090 steps, per token cost is 3.050
# After 3100 steps, per token cost is 2.855
# After 3110 steps, per token cost is 2.905
# After 3120 steps, per token cost is 2.847
# -------time cost 283.7409734725952 s
#
# -------In iteration: 9
# After 3130 steps, per token cost is 2.572
# After 3140 steps, per token cost is 2.874
# After 3150 steps, per token cost is 2.757
# After 3160 steps, per token cost is 2.729
# After 3170 steps, per token cost is 2.664
# After 3180 steps, per token cost is 2.746
# After 3190 steps, per token cost is 2.946
# After 3200 steps, per token cost is 2.749
# After 3210 steps, per token cost is 2.761
# After 3220 steps, per token cost is 2.644
# After 3230 steps, per token cost is 2.851
# After 3240 steps, per token cost is 2.541
# After 3250 steps, per token cost is 2.794
# After 3260 steps, per token cost is 2.549
# After 3270 steps, per token cost is 2.565
# After 3280 steps, per token cost is 2.809
# After 3290 steps, per token cost is 2.617
# After 3300 steps, per token cost is 2.573
# After 3310 steps, per token cost is 2.518
# After 3320 steps, per token cost is 2.630
# After 3330 steps, per token cost is 2.771
# After 3340 steps, per token cost is 2.580
# After 3350 steps, per token cost is 2.786
# After 3360 steps, per token cost is 2.553
# After 3370 steps, per token cost is 2.644
# After 3380 steps, per token cost is 2.904
# After 3390 steps, per token cost is 2.668
# After 3400 steps, per token cost is 2.506
# After 3410 steps, per token cost is 2.553
# After 3420 steps, per token cost is 2.641
# After 3430 steps, per token cost is 2.623
# After 3440 steps, per token cost is 2.864
# After 3450 steps, per token cost is 2.906
# After 3460 steps, per token cost is 2.857
# After 3470 steps, per token cost is 2.681
# After 3480 steps, per token cost is 2.794
# After 3490 steps, per token cost is 2.851
# After 3500 steps, per token cost is 2.679
# After 3510 steps, per token cost is 2.641
# -------time cost 283.91449332237244 s
#
# -------In iteration: 10
# After 3520 steps, per token cost is 2.426
# After 3530 steps, per token cost is 2.335
# After 3540 steps, per token cost is 2.496
# After 3550 steps, per token cost is 2.694
# After 3560 steps, per token cost is 2.514
# After 3570 steps, per token cost is 2.690
# After 3580 steps, per token cost is 2.507
# After 3590 steps, per token cost is 2.540
# After 3600 steps, per token cost is 2.364
# After 3610 steps, per token cost is 2.482
# After 3620 steps, per token cost is 2.576
# After 3630 steps, per token cost is 2.460
# After 3640 steps, per token cost is 2.665
# After 3650 steps, per token cost is 2.499
# After 3660 steps, per token cost is 2.657
# After 3670 steps, per token cost is 2.565
# After 3680 steps, per token cost is 2.336
# After 3690 steps, per token cost is 2.435
# After 3700 steps, per token cost is 2.599
# After 3710 steps, per token cost is 2.488
# After 3720 steps, per token cost is 2.551
# After 3730 steps, per token cost is 2.671
# After 3740 steps, per token cost is 2.317
# After 3750 steps, per token cost is 2.674
# After 3760 steps, per token cost is 2.421
# After 3770 steps, per token cost is 2.649
# After 3780 steps, per token cost is 2.418
# After 3790 steps, per token cost is 2.524
# After 3800 steps, per token cost is 2.476
# After 3810 steps, per token cost is 2.588
# After 3820 steps, per token cost is 2.702
# After 3830 steps, per token cost is 2.372
# After 3840 steps, per token cost is 2.446
# After 3850 steps, per token cost is 2.599
# After 3860 steps, per token cost is 2.656
# After 3870 steps, per token cost is 2.716
# After 3880 steps, per token cost is 2.527
# After 3890 steps, per token cost is 2.625
# After 3900 steps, per token cost is 2.735
# -------time cost 282.8152000904083 s
#
# -------In iteration: 11
# After 3910 steps, per token cost is 2.533
# After 3920 steps, per token cost is 2.317
# After 3930 steps, per token cost is 2.325
# After 3940 steps, per token cost is 2.545
# After 3950 steps, per token cost is 2.322
# After 3960 steps, per token cost is 2.298
# After 3970 steps, per token cost is 2.397
# After 3980 steps, per token cost is 2.440
# After 3990 steps, per token cost is 2.417
# After 4000 steps, per token cost is 2.432
# After 4010 steps, per token cost is 2.278
# After 4020 steps, per token cost is 2.277
# After 4030 steps, per token cost is 2.314
# After 4040 steps, per token cost is 2.347
# After 4050 steps, per token cost is 2.376
# After 4060 steps, per token cost is 2.401
# After 4070 steps, per token cost is 2.251
# After 4080 steps, per token cost is 2.542
# After 4090 steps, per token cost is 2.359
# After 4100 steps, per token cost is 2.385
# After 4110 steps, per token cost is 2.446
# After 4120 steps, per token cost is 2.323
# After 4130 steps, per token cost is 2.123
# After 4140 steps, per token cost is 2.481
# After 4150 steps, per token cost is 2.459
# After 4160 steps, per token cost is 2.396
# After 4170 steps, per token cost is 2.258
# After 4180 steps, per token cost is 2.353
# After 4190 steps, per token cost is 2.614
# After 4200 steps, per token cost is 2.267
# After 4210 steps, per token cost is 2.559
# After 4220 steps, per token cost is 2.268
# After 4230 steps, per token cost is 2.513
# After 4240 steps, per token cost is 2.348
# After 4250 steps, per token cost is 2.447
# After 4260 steps, per token cost is 2.563
# After 4270 steps, per token cost is 2.344
# After 4280 steps, per token cost is 2.752
# After 4290 steps, per token cost is 2.413
# After 4300 steps, per token cost is 2.310
# -------time cost 283.87343859672546 s
#
# -------In iteration: 12
# After 4310 steps, per token cost is 2.127
# After 4320 steps, per token cost is 2.149
# After 4330 steps, per token cost is 2.097
# After 4340 steps, per token cost is 2.164
# After 4350 steps, per token cost is 2.301
# After 4360 steps, per token cost is 2.433
# After 4370 steps, per token cost is 2.515
# After 4380 steps, per token cost is 2.370
# After 4390 steps, per token cost is 2.197
# After 4400 steps, per token cost is 2.358
# After 4410 steps, per token cost is 2.102
# After 4420 steps, per token cost is 2.237
# After 4430 steps, per token cost is 2.351
# After 4440 steps, per token cost is 2.264
# After 4450 steps, per token cost is 2.075
# After 4460 steps, per token cost is 2.203
# After 4470 steps, per token cost is 2.381
# After 4480 steps, per token cost is 2.302
# After 4490 steps, per token cost is 2.009
# After 4500 steps, per token cost is 2.095
# After 4510 steps, per token cost is 2.426
# After 4520 steps, per token cost is 2.337
# After 4530 steps, per token cost is 2.262
# After 4540 steps, per token cost is 2.136
# After 4550 steps, per token cost is 2.219
# After 4560 steps, per token cost is 2.117
# After 4570 steps, per token cost is 2.244
# After 4580 steps, per token cost is 2.402
# After 4590 steps, per token cost is 2.043
# After 4600 steps, per token cost is 2.281
# After 4610 steps, per token cost is 2.265
# After 4620 steps, per token cost is 2.565
# After 4630 steps, per token cost is 2.253
# After 4640 steps, per token cost is 2.402
# After 4650 steps, per token cost is 2.234
# After 4660 steps, per token cost is 2.399
# After 4670 steps, per token cost is 2.224
# After 4680 steps, per token cost is 2.394
# After 4690 steps, per token cost is 2.448
# -------time cost 283.7121727466583 s
#
# -------In iteration: 13
# After 4700 steps, per token cost is 2.158
# After 4710 steps, per token cost is 1.972
# After 4720 steps, per token cost is 1.986
# After 4730 steps, per token cost is 2.158
# After 4740 steps, per token cost is 1.946
# After 4750 steps, per token cost is 2.035
# After 4760 steps, per token cost is 2.130
# After 4770 steps, per token cost is 2.018
# After 4780 steps, per token cost is 2.031
# After 4790 steps, per token cost is 2.111
# After 4800 steps, per token cost is 2.154
# After 4810 steps, per token cost is 2.232
# After 4820 steps, per token cost is 1.940
# After 4830 steps, per token cost is 2.099
# After 4840 steps, per token cost is 2.199
# After 4850 steps, per token cost is 2.116
# After 4860 steps, per token cost is 2.313
# After 4870 steps, per token cost is 2.309
# After 4880 steps, per token cost is 2.077
# After 4890 steps, per token cost is 2.120
# After 4900 steps, per token cost is 2.248
# After 4910 steps, per token cost is 2.108
# After 4920 steps, per token cost is 2.048
# After 4930 steps, per token cost is 2.276
# After 4940 steps, per token cost is 2.300
# After 4950 steps, per token cost is 2.149
# After 4960 steps, per token cost is 2.080
# After 4970 steps, per token cost is 2.174
# After 4980 steps, per token cost is 1.955
# After 4990 steps, per token cost is 2.158
# After 5000 steps, per token cost is 2.137
# After 5010 steps, per token cost is 2.006
# After 5020 steps, per token cost is 2.062
# After 5030 steps, per token cost is 2.260
# After 5040 steps, per token cost is 2.443
# After 5050 steps, per token cost is 2.272
# After 5060 steps, per token cost is 2.137
# After 5070 steps, per token cost is 2.155
# After 5080 steps, per token cost is 2.176
# -------time cost 282.11690044403076 s
#
# -------In iteration: 14
# After 5090 steps, per token cost is 1.958
# After 5100 steps, per token cost is 1.808
# After 5110 steps, per token cost is 2.006
# After 5120 steps, per token cost is 1.589
# After 5130 steps, per token cost is 1.765
# After 5140 steps, per token cost is 1.957
# After 5150 steps, per token cost is 1.736
# After 5160 steps, per token cost is 1.937
# After 5170 steps, per token cost is 1.987
# After 5180 steps, per token cost is 1.835
# After 5190 steps, per token cost is 1.822
# After 5200 steps, per token cost is 1.950
# After 5210 steps, per token cost is 2.137
# After 5220 steps, per token cost is 2.086
# After 5230 steps, per token cost is 2.007
# After 5240 steps, per token cost is 2.004
# After 5250 steps, per token cost is 2.142
# After 5260 steps, per token cost is 2.084
# After 5270 steps, per token cost is 2.035
# After 5280 steps, per token cost is 2.150
# After 5290 steps, per token cost is 2.151
# After 5300 steps, per token cost is 1.913
# After 5310 steps, per token cost is 2.118
# After 5320 steps, per token cost is 1.965
# After 5330 steps, per token cost is 2.079
# After 5340 steps, per token cost is 2.036
# After 5350 steps, per token cost is 2.040
# After 5360 steps, per token cost is 2.129
# After 5370 steps, per token cost is 1.954
# After 5380 steps, per token cost is 2.146
# After 5390 steps, per token cost is 2.216
# After 5400 steps, per token cost is 2.182
# After 5410 steps, per token cost is 2.076
# After 5420 steps, per token cost is 2.246
# After 5430 steps, per token cost is 2.184
# After 5440 steps, per token cost is 2.226
# After 5450 steps, per token cost is 1.980
# After 5460 steps, per token cost is 2.332
# After 5470 steps, per token cost is 2.151
# -------time cost 283.55196142196655 s
#
# -------In iteration: 15
# After 5480 steps, per token cost is 1.934
# After 5490 steps, per token cost is 1.877
# After 5500 steps, per token cost is 2.034
# After 5510 steps, per token cost is 1.677
# After 5520 steps, per token cost is 1.898
# After 5530 steps, per token cost is 2.181
# After 5540 steps, per token cost is 1.889
# After 5550 steps, per token cost is 1.974
# After 5560 steps, per token cost is 1.904
# After 5570 steps, per token cost is 2.062
# After 5580 steps, per token cost is 1.893
# After 5590 steps, per token cost is 1.955
# After 5600 steps, per token cost is 2.226
# After 5610 steps, per token cost is 2.054
# After 5620 steps, per token cost is 2.005
# After 5630 steps, per token cost is 1.830
# After 5640 steps, per token cost is 1.967
# After 5650 steps, per token cost is 1.906
# After 5660 steps, per token cost is 2.071
# After 5670 steps, per token cost is 1.997
# After 5680 steps, per token cost is 1.944
# After 5690 steps, per token cost is 2.171
# After 5700 steps, per token cost is 1.874
# After 5710 steps, per token cost is 1.918
# After 5720 steps, per token cost is 1.991
# After 5730 steps, per token cost is 1.979
# After 5740 steps, per token cost is 1.986
# After 5750 steps, per token cost is 2.052
# After 5760 steps, per token cost is 2.001
# After 5770 steps, per token cost is 1.799
# After 5780 steps, per token cost is 1.936
# After 5790 steps, per token cost is 2.110
# After 5800 steps, per token cost is 1.891
# After 5810 steps, per token cost is 1.942
# After 5820 steps, per token cost is 2.204
# After 5830 steps, per token cost is 2.106
# After 5840 steps, per token cost is 2.159
# After 5850 steps, per token cost is 2.326
# After 5860 steps, per token cost is 1.986
# -------time cost 283.32968401908875 s
#
# -------In iteration: 16
# After 5870 steps, per token cost is 1.863
# After 5880 steps, per token cost is 1.895
# After 5890 steps, per token cost is 1.585
# After 5900 steps, per token cost is 1.715
# After 5910 steps, per token cost is 1.981
# After 5920 steps, per token cost is 1.800
# After 5930 steps, per token cost is 1.903
# After 5940 steps, per token cost is 1.783
# After 5950 steps, per token cost is 1.735
# After 5960 steps, per token cost is 1.872
# After 5970 steps, per token cost is 1.994
# After 5980 steps, per token cost is 2.031
# After 5990 steps, per token cost is 1.940
# After 6000 steps, per token cost is 2.032
# After 6010 steps, per token cost is 2.024
# After 6020 steps, per token cost is 1.922
# After 6030 steps, per token cost is 1.925
# After 6040 steps, per token cost is 1.760
# After 6050 steps, per token cost is 1.738
# After 6060 steps, per token cost is 1.766
# After 6070 steps, per token cost is 1.834
# After 6080 steps, per token cost is 1.892
# After 6090 steps, per token cost is 1.995
# After 6100 steps, per token cost is 1.651
# After 6110 steps, per token cost is 2.032
# After 6120 steps, per token cost is 1.903
# After 6130 steps, per token cost is 2.091
# After 6140 steps, per token cost is 2.030
# After 6150 steps, per token cost is 2.065
# After 6160 steps, per token cost is 1.881
# After 6170 steps, per token cost is 2.007
# After 6180 steps, per token cost is 1.764
# After 6190 steps, per token cost is 2.035
# After 6200 steps, per token cost is 2.086
# After 6210 steps, per token cost is 1.825
# After 6220 steps, per token cost is 1.936
# After 6230 steps, per token cost is 1.812
# After 6240 steps, per token cost is 2.162
# After 6250 steps, per token cost is 1.960
# -------time cost 284.78273010253906 s
#
# -------In iteration: 17
# After 6260 steps, per token cost is 1.788
# After 6270 steps, per token cost is 1.636
# After 6280 steps, per token cost is 1.841
# After 6290 steps, per token cost is 1.737
# After 6300 steps, per token cost is 1.736
# After 6310 steps, per token cost is 1.867
# After 6320 steps, per token cost is 1.736
# After 6330 steps, per token cost is 1.852
# After 6340 steps, per token cost is 1.869
# After 6350 steps, per token cost is 1.835
# After 6360 steps, per token cost is 1.704
# After 6370 steps, per token cost is 1.769
# After 6380 steps, per token cost is 1.753
# After 6390 steps, per token cost is 1.945
# After 6400 steps, per token cost is 1.889
# After 6410 steps, per token cost is 1.968
# After 6420 steps, per token cost is 1.982
# After 6430 steps, per token cost is 1.990
# After 6440 steps, per token cost is 1.639
# After 6450 steps, per token cost is 1.799
# After 6460 steps, per token cost is 1.798
# After 6470 steps, per token cost is 1.866
# After 6480 steps, per token cost is 1.858
# After 6490 steps, per token cost is 1.818
# After 6500 steps, per token cost is 1.892
# After 6510 steps, per token cost is 1.827
# After 6520 steps, per token cost is 1.972
# After 6530 steps, per token cost is 1.746
# After 6540 steps, per token cost is 2.036
# After 6550 steps, per token cost is 2.037
# After 6560 steps, per token cost is 2.075
# After 6570 steps, per token cost is 1.895
# After 6580 steps, per token cost is 1.848
# After 6590 steps, per token cost is 1.946
# After 6600 steps, per token cost is 2.028
# After 6610 steps, per token cost is 2.005
# After 6620 steps, per token cost is 1.813
# After 6630 steps, per token cost is 1.920
# After 6640 steps, per token cost is 2.092
# -------time cost 284.97226428985596 s
#
# -------In iteration: 18
# After 6650 steps, per token cost is 1.844
# After 6660 steps, per token cost is 1.653
# After 6670 steps, per token cost is 1.609
# After 6680 steps, per token cost is 1.669
# After 6690 steps, per token cost is 1.682
# After 6700 steps, per token cost is 1.730
# After 6710 steps, per token cost is 1.677
# After 6720 steps, per token cost is 1.669
# After 6730 steps, per token cost is 1.569
# After 6740 steps, per token cost is 1.859
# After 6750 steps, per token cost is 1.884
# After 6760 steps, per token cost is 1.779
# After 6770 steps, per token cost is 1.783
# After 6780 steps, per token cost is 1.772
# After 6790 steps, per token cost is 1.923
# After 6800 steps, per token cost is 1.858
# After 6810 steps, per token cost is 1.970
# After 6820 steps, per token cost is 1.777
# After 6830 steps, per token cost is 2.157
# After 6840 steps, per token cost is 1.700
# After 6850 steps, per token cost is 1.880
# After 6860 steps, per token cost is 1.981
# After 6870 steps, per token cost is 1.884
# After 6880 steps, per token cost is 1.929
# After 6890 steps, per token cost is 1.975
# After 6900 steps, per token cost is 1.829
# After 6910 steps, per token cost is 1.910
# After 6920 steps, per token cost is 1.986
# After 6930 steps, per token cost is 1.690
# After 6940 steps, per token cost is 1.843
# After 6950 steps, per token cost is 1.894
# After 6960 steps, per token cost is 1.652
# After 6970 steps, per token cost is 2.080
# After 6980 steps, per token cost is 1.877
# After 6990 steps, per token cost is 1.970
# After 7000 steps, per token cost is 1.648
# After 7010 steps, per token cost is 1.985
# After 7020 steps, per token cost is 2.163
# After 7030 steps, per token cost is 1.895
# -------time cost 286.0752694606781 s
#
# -------In iteration: 19
# After 7040 steps, per token cost is 1.611
# After 7050 steps, per token cost is 1.731
# After 7060 steps, per token cost is 1.593
# After 7070 steps, per token cost is 1.675
# After 7080 steps, per token cost is 1.662
# After 7090 steps, per token cost is 1.718
# After 7100 steps, per token cost is 1.621
# After 7110 steps, per token cost is 1.644
# After 7120 steps, per token cost is 1.790
# After 7130 steps, per token cost is 1.889
# After 7140 steps, per token cost is 1.880
# After 7150 steps, per token cost is 1.901
# After 7160 steps, per token cost is 1.785
# After 7170 steps, per token cost is 1.753
# After 7180 steps, per token cost is 1.564
# After 7190 steps, per token cost is 1.642
# After 7200 steps, per token cost is 1.735
# After 7210 steps, per token cost is 1.870
# After 7220 steps, per token cost is 2.028
# After 7230 steps, per token cost is 1.959
# After 7240 steps, per token cost is 1.915
# After 7250 steps, per token cost is 2.105
# After 7260 steps, per token cost is 1.883
# After 7270 steps, per token cost is 1.861
# After 7280 steps, per token cost is 1.703
# After 7290 steps, per token cost is 1.581
# After 7300 steps, per token cost is 1.776
# After 7310 steps, per token cost is 1.837
# After 7320 steps, per token cost is 1.961
# After 7330 steps, per token cost is 1.664
# After 7340 steps, per token cost is 1.764
# After 7350 steps, per token cost is 1.869
# After 7360 steps, per token cost is 2.007
# After 7370 steps, per token cost is 1.851
# After 7380 steps, per token cost is 1.820
# After 7390 steps, per token cost is 2.038
# After 7400 steps, per token cost is 2.028
# After 7410 steps, per token cost is 2.068
# After 7420 steps, per token cost is 1.921
# -------time cost 285.1436347961426 s
#
# -------In iteration: 20
# After 7430 steps, per token cost is 1.634
# After 7440 steps, per token cost is 1.670
# After 7450 steps, per token cost is 1.620
# After 7460 steps, per token cost is 1.631
# After 7470 steps, per token cost is 1.697
# After 7480 steps, per token cost is 1.601
# After 7490 steps, per token cost is 1.696
# After 7500 steps, per token cost is 1.685
# After 7510 steps, per token cost is 1.483
# After 7520 steps, per token cost is 1.722
# After 7530 steps, per token cost is 1.812
# After 7540 steps, per token cost is 1.842
# After 7550 steps, per token cost is 1.815
# After 7560 steps, per token cost is 1.668
# After 7570 steps, per token cost is 1.644
# After 7580 steps, per token cost is 1.786
# After 7590 steps, per token cost is 1.870
# After 7600 steps, per token cost is 1.756
# After 7610 steps, per token cost is 1.860
# After 7620 steps, per token cost is 1.967
# After 7630 steps, per token cost is 1.750
# After 7640 steps, per token cost is 1.946
# After 7650 steps, per token cost is 1.816
# After 7660 steps, per token cost is 1.741
# After 7670 steps, per token cost is 1.868
# After 7680 steps, per token cost is 1.862
# After 7690 steps, per token cost is 1.863
# After 7700 steps, per token cost is 1.821
# After 7710 steps, per token cost is 1.911
# After 7720 steps, per token cost is 1.725
# After 7730 steps, per token cost is 1.914
# After 7740 steps, per token cost is 1.816
# After 7750 steps, per token cost is 1.807
# After 7760 steps, per token cost is 1.902
# After 7770 steps, per token cost is 1.714
# After 7780 steps, per token cost is 2.044
# After 7790 steps, per token cost is 1.803
# After 7800 steps, per token cost is 1.974
# After 7810 steps, per token cost is 1.876
# -------time cost 283.50622844696045 s

# %% [markdown]
# ### 5. Produce Model Structure

# %%
import tensorflow.contrib.slim as slim

def model_summary():
    model_vars = tf.trainable_variables()
    slim.model_analyzer.analyze_vars(model_vars, print_info=True)

model_summary()
# Out:
# ---------
# Variables: name (type shape) [size]
# ---------
# nmt_model/src_emb:0 (float32_ref 28711x512) [14700032, bytes: 58800128]
# nmt_model/trg_emb:0 (float32_ref 35019x512) [17929728, bytes: 71718912]
# nmt_model/softmax_bias:0 (float32_ref 35019) [35019, bytes: 140076]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_2/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_2/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_3/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_3/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_2/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_2/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_3/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_3/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# decoder/memory_layer/kernel:0 (float32_ref 1024x512) [524288, bytes: 2097152]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_0/lstm_cell/kernel:0 (float32_ref 1536x2048) [3145728, bytes: 12582912]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_0/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_1/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_1/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_2/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_2/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_3/lstm_cell/kernel:0 (float32_ref 1024x2048) [2097152, bytes: 8388608]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_3/lstm_cell/bias:0 (float32_ref 2048) [2048, bytes: 8192]
# decoder/rnn/attention_wrapper/attention_layer/kernel:0 (float32_ref 1536x512) [786432, bytes: 3145728]
# Total size of variables: 60214475
# Total bytes of variables: 240857900

# %% [markdown]
# # INSTRUCTION 3 - INFERENCE USING TRAINED MODEL AND WEIGHT

# %% [markdown]
# ### 6.Define Model Structure, Hyper Parameter Used in Training, Inference Function
#
# 1. Need to change LAST_CKPT_PATH every time you train and set it to the latest checkpoint, which is presented by the biggest number in CHECKPOINT_PATH
#
# 2. Keep other parameters as they are in the traning session, no need to change here

# %%
# read checkpoint path, number indicates the latest step
LAST_CKPT_PATH = "ckpt-exp05/google-brain-rmsprop001-7800"

# file for vocab
SRC_VOCAB = "vocab.en"
TRG_VOCAB = "vocab.fr"
SRC_VOCAB_SIZE = vocab_size_src       
TRG_VOCAB_SIZE = vocab_size_tgt 

# ID for <sos> and <eos> in vocab
SOS_ID = 1
EOS_ID = 2

SHARE_EMB_AND_SOFTMAX = True

# %%
class NMTModel(object):
  """
  defind the nmt model
  
  """
  # define variables needed by nmt
  def __init__(self, 
               dec_layer = DECODER_LAYERS, 
               enc_layer = ENCODER_LAYERS,
               dec_cell_name = DECODER_CELL_TYPE, 
               enc_cell_name = ENCODER_CELL_TYPE,
               optimizer = OPTIMIZER, 
               lr = LEARNING_RATE,
               hid_size = HIDDEN_SIZE, 
               attention = ATTENTION,
               drop_out = DROPOUT):
    
    self.dec_cell_name = dec_cell_name
    self.enc_cell_name = enc_cell_name
    self.dec_layer = dec_layer
    self.enc_layer = enc_layer
    self.attention = attention
    
    self.hid_size = hid_size
    self.opt = optimizer
    self.lr = lr
    
    self.keep_prob = 1.0 - drop_out

    # EMBEDDING SETUP
    
    self.src_embedding = tf.get_variable(
          "src_emb", [SRC_VOCAB_SIZE, self.hid_size])
    self.trg_embedding = tf.get_variable(
          "trg_emb", [TRG_VOCAB_SIZE, self.hid_size])

      # define variables for softmax layer
    if SHARE_EMB_AND_SOFTMAX:
         self.softmax_weight = tf.transpose(self.trg_embedding)
    else:
         self.softmax_weight = tf.get_variable(
             "weight", [self.hid_size, TRG_VOCAB_SIZE])
    self.softmax_bias = tf.get_variable(
          "softmax_bias", [TRG_VOCAB_SIZE])
  
  def inference(self, src_input):
      # As dynamic rnn requires batch input, 
      # to infer one single sentence, we set batch = 1
      src_size = tf.convert_to_tensor([len(src_input)], dtype=tf.int32)
      src_input = tf.convert_to_tensor([src_input], dtype=tf.int32)
      src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
      
     
      # *************************
      # ***** ENCODER SCOPE *****
      # *************************

      with tf.variable_scope("encoder"):
        
        if not 'bi' in self.enc_cell_name:
        
          enc_cell = multi_rnn_cell(self.enc_cell_name, 
                                    self.hid_size, 
                                    self.enc_layer, 
                                    self.keep_prob)
          enc_outputs, enc_state = tf.nn.dynamic_rnn(enc_cell, 
                                                     inputs=src_emb, 
                                                     sequence_length=src_size, 
                                                     dtype=tf.float32) 
        
        else:
          
          stacked_biRNN_fw, stacked_biRNN_bw = multi_biRNN_pair(self.enc_cell_name, 
                                                                self.hid_size, 
                                                                self.enc_layer, 
                                                                self.keep_prob)
          enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = stacked_biRNN_fw,
                                                                   cell_bw = stacked_biRNN_bw,
                                                                   inputs = src_emb,
                                                                   sequence_length = src_size,
                                                                   dtype = tf.float32)
          
          # concatenate two outputs of LSTM cell as 1 tensor
          # enc_outputs = (output_fw, output_bw)
          enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)
          
    
      # *************************
      # ***** DECODER SCOPE *****
      # *************************
      
      with tf.variable_scope("decoder"):
        
        dec_cell = multi_rnn_cell(self.dec_cell_name, self.hid_size, self.dec_layer, self.keep_prob)
    
    
        # OPTIONS FOR ATTENTION MECHANISM
        if self.attention == 'Bahdanau':
        
          attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                  self.hid_size, 
                  enc_outputs,
                  memory_sequence_length = src_size)
          
        if self.attention == 'Luong':

          attention_mechanism = tf.contrib.seq2seq.LuongAttention(
                  self.hid_size,
                  enc_outputs,
                  memory_sequence_length=src_size
                  )

        # ATTENTION WRAPPER: 
        # wrap dec_cell and attention mechanisim
        attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                dec_cell, 
                attention_mechanism,
                attention_layer_size=self.hid_size,
                alignment_history=True)

      # Set the max step for decoder
      MAX_DEC_LEN=100

      with tf.variable_scope("decoder/rnn/attention_wrapper"):
        # use TensorArray store produced sentence
        init_array = tf.TensorArray(dtype=tf.int32, size=0,
            dynamic_size=True, clear_after_read=False)
        # start input for decoder with <sos> tag
        init_array = init_array.write(0, SOS_ID)
        # initilize attention cell
        init_loop_var = (
            attention_cell.zero_state(batch_size=1, dtype=tf.float32),
            init_array, 0)

        # condition for tf.while_loop：
        # loop until decoder outputs <eos> or hit max length setting
#         def continue_loop_condition(state, trg_ids, step):
#             return tf.reduce_all(tf.logical_and(
#                 tf.not_equal(trg_ids.read(step), EOS_ID),
#                 tf.less(step, MAX_DEC_LEN-1),
#                 tf.not_equal(trg_ids.read(step), trg_ids.read(step-1))))
          
        def continue_loop_condition(state, trg_ids, step):
            return tf.reduce_all(tf.logical_and(
                tf.not_equal(trg_ids.read(step), EOS_ID),
                tf.less(step, MAX_DEC_LEN-1)))

        def loop_body(state, trg_ids, step):
          
            # read last step output as input for attention cell
            trg_input = [trg_ids.read(step)]
            trg_emb = tf.nn.embedding_lookup(self.trg_embedding,
                                             trg_input)
            # FORWARD calc ATTENTION CELL and output decoder outputs/state
            dec_outputs, next_state = attention_cell.call(
                state=state, inputs=trg_emb)
            
            # calc logit for each candidate target vocab
            # select the max as output
            output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
            logits = (tf.matmul(output, self.softmax_weight)
                      + self.softmax_bias)
            next_id = tf.argmax(logits, axis=1, output_type=tf.int32)
            # write output word into trg_ids
            trg_ids = trg_ids.write(step+1, next_id[0])
            return next_state, trg_ids, step+1

        # execute tf.while_loop return trg_ides
        state, trg_ids, step = tf.while_loop(
            continue_loop_condition, loop_body, init_loop_var)
        
        return trg_ids.stack(), state

# %% [markdown]
# ### 7. Test and Evaluate

# %%
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu

def levenshtein(seq1, seq2):  
    size_x = len(seq1) + 1
    size_y = len(seq2) + 1
    matrix = np.zeros ((size_x, size_y))
    for x in range(size_x):
        matrix [x, 0] = x
    for y in range(size_y):
        matrix [0, y] = y

    for x in range(1, size_x):
        for y in range(1, size_y):
            if seq1[x-1] == seq2[y-1]:
                matrix [x,y] = min(
                    matrix[x-1, y] + 1,
                    matrix[x-1, y-1],
                    matrix[x, y-1] + 1
                )
            else:
                matrix [x,y] = min(
                    matrix[x-1,y] + 1,
                    matrix[x-1,y-1] + 1,
                    matrix[x,y-1] + 1
                )

    return matrix[size_x - 1, size_y - 1]

def translate_en_fr(src_sent, trgt_sent, plot_att = False, verbose = False):
    
    tf.reset_default_graph()
        
    # define the trained model
    with tf.variable_scope("nmt_model", reuse=None):
        model = NMTModel()
       
    # convert sentence to word_index according to vocab
    with codecs.open(SRC_VOCAB, "r", "utf-8") as f_vocab:
        src_vocab = [w.strip() for w in f_vocab.readlines()]
        src_id_dict = dict((src_vocab[x], x) for x in range(len(src_vocab)))
    test_en_ids = [(src_id_dict[token] if token in src_id_dict else src_id_dict['<unk>'])
                   for token in src_sent.split()]
    print('target sentence id: {}'.format(test_en_ids))

    # build inference based on saved model weights
    output_op, state_op = model.inference(test_en_ids)
    sess = tf.Session()
    saver = tf.train.Saver()
    saver.restore(sess, LAST_CKPT_PATH)

    # read translation output
    output_ids = sess.run(output_op)
    print('target sentence id: {}'.format(output_ids))
    
    # convert translation idx into word
    with codecs.open(TRG_VOCAB, "r", "utf-8") as f_vocab:
        trg_vocab = [w.strip() for w in f_vocab.readlines()]
    output_text = ' '.join([trg_vocab[x] for x in output_ids])
    
    # output translation
    final_output_text = output_text.encode('utf8').decode(sys.stdout.encoding).strip('<eos>')
    
    bleu = sentence_bleu(trgt_sent.split(), final_output_text.split())
    lst = levenshtein(trgt_sent,final_output_text)
    
    if verbose:
      print("Source Sentence: " + src_sent)
      print("Real Translation: " + trgt_sent)
      print("Predicted Translation: " + final_output_text)
      print("Levenshetein Distance: " + str(lst))
      print("***BLEU Score***: "+ str(bleu))
    
    
    # PLOT ATTENTION PLOT OPTION
    
    def plot_attention(attention, src_sent, pred_sent):

      fig = plt.figure(figsize=(10,10))
      ax = fig.add_subplot(1, 1, 1)
      ax.matshow(attention, cmap='viridis')

      fontdict = {'fontsize': 14}
      
      ax.set_xticks(np.arange(len(list(src_sent.split()))))
      ax.set_yticks(np.arange(len(list(pred_sent.split()))))

      ax.set_xticklabels([''] + list(src_sent.split()), fontdict=fontdict, rotation=90)
      ax.set_yticklabels([''] + list(pred_sent.split()), fontdict=fontdict)

      plt.show()
      
    if plot_att:
      alignments = sess.run(state_op.alignment_history.stack())
      alignments = np.squeeze(alignments)
      plot_attention(alignments, src_sent, final_output_text)
      
    return final_output_text, bleu, lst
    
    sess.close()

# %%
# prediction for total test set

def test_set_pred(src_test, tgt_test, verbose = False):
  src_test = src_test
  tgt_test = tgt_test
 
  size = len(src_test)
  
  pred_list = []
  bleu_list = []
  lst_list = []

  for i in range(size):

      pred, bleu, lst = translate_en_fr(src_test[i], tgt_test[i], verbose = verbose)
      print("                                                                                         ")
      pred_list.append(pred)
      bleu_list.append(bleu)
      lst_list.append(lst)
      
      
  c_bleu = sum(bleu_list) / len(bleu_list)
  c_lst = sum(lst_list) / len(lst_list)  
   
  print("                                                                                         ")
  print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
  print("Prediction Output and Metrics on {} test sentences: ".format(size))
  print("Average BLEU Score on our test corpus is {}".format(c_bleu)) 
  print("Average Levenshetein distance Score on our test corpus is {}".format(c_lst))

# %% [markdown]
# ### 3. Test

# %%
src_sent = 'comment on the misappropriation of bibliographical references in science . the example of anti aging medicine'
tgt_sent = 'du detournement des references bibliographiques en science . l exemple de la medecine anti age '


translate_en_fr(src_sent,
                tgt_sent, 
                verbose = True,
                plot_att = True)
# Out:
# target sentence id: [1805, 16, 5, 15332, 4, 11235, 6853, 6, 939, 12, 5, 363, 4, 197, 454, 61]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1 1316    4  173    4  744  791   12  740   11  557   19    7  238
#     4    7  146   53  846    2]
# Source Sentence: comment on the misappropriation of bibliographical references in science . the example of anti aging medicine
# Real Translation: du detournement des references bibliographiques en science . l exemple de la medecine anti age
# Predicted Translation:  commentaire de travail de bon identification en sciences du vivant . l exemple de l anti medecine of
# Levenshetein Distance: 61.0
# ***BLEU Score***: 0.5773502691896257
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# (' commentaire de travail de bon identification en sciences du vivant . l exemple de l anti medecine of ',
#  0.5773502691896257,
#  61.0)

# %%
test_set_pred(src_test, tgt_test, verbose = True)
# Out:
# target sentence id: [171, 262, 4, 61, 6, 4303]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1 112   8 303   4   5  53   2]
# Source Sentence:  current state of medicine in spain
# Real Translation:  etat actuel de la medecine en espagne
# Predicted Translation:  etat des lieux de la medecine
# Levenshetein Distance: 19.0
# ***BLEU Score***: 0
#
# target sentence id: [204, 11, 5, 29, 4, 1201, 4, 5, 2573]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1 887  10   7  32  11 666   4  39   2]
# Source Sentence:  contribution to the study of accidents of the teeth
# Real Translation:  contribution a l etude des accidents de la dentition
# Predicted Translation:  contribution a l etude du gene de sante
# Levenshetein Distance: 18.0
# ***BLEU Score***: 0.6240195441936915
#
# target sentence id: [47, 4, 3961, 67]
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1   5  47   8 117   2]
# Source Sentence:  surgery of periodontal diseases
# Real Translation:  la chirurgie des parodontolyses
# Predicted Translation:  la chirurgie des infections
# Levenshetein Distance: 12.0
# ***BLEU Score***: 0
#
# target sentence id: [3718, 3, 3, 4, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  290 9002    7  180   11  736    7 1555    2]
# Source Sentence:  die peripheren durchblutungsstorungen of paradentiums
# Real Translation:  die peripheren durchblutungsstorungen des paradentiums
# Predicted Translation:  se jekyll l histoire du tout l angle
# Levenshetein Distance: 42.0
# ***BLEU Score***: 0.4630777161991027
#
# target sentence id: [5, 7964, 91, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  15 364 355   2]
# Source Sentence:  the beginnings surgical alginates
# Real Translation:  les premices chirurgicales des alginates
# Predicted Translation:  le temps chirurgicale
# Levenshetein Distance: 21.0
# ***BLEU Score***: 0
#
# target sentence id: [1001, 4915, 4, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1 3869 2878    2]
# Source Sentence:  endocrine glands of cephalopods
# Real Translation:  les glandes endocrines des cephalopodes
# Predicted Translation:  perturbateurs endocriniens
# Levenshetein Distance: 27.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 2044, 3449, 7, 123]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [ 1 15  2]
# Source Sentence:  the mediterranean climate and tuberculosis
# Real Translation:  le climat mediterraneen et les tuberculoses
# Predicted Translation:  le
# Levenshetein Distance: 41.0
# ***BLEU Score***: 0
#
# target sentence id: [209, 7, 1896, 4, 3, 9, 3, 780, 12, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  180    6  480   11 2371   17    7   97   11  109    4   39    2]
# Source Sentence:  history and pharmacology of balsamite , tanacetum l . balsamita
# Real Translation:  histoire et pharmacologie de la balsamite , tanacetum balsamita l
# Predicted Translation:  histoire et modalites du stage , l experience du centre de sante
# Levenshetein Distance: 43.0
# ***BLEU Score***: 0.5878560343277044
#
# target sentence id: [1490, 19, 4, 170, 54, 76]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   30 1879    4    7  637    2]
# Source Sentence:  modern treatment of hypertension during pregnancy
# Real Translation:  les traitements modernes de l hypertension arterielle au cours de la grossesse
# Predicted Translation:  traitement moderne de l anemie
# Levenshetein Distance: 50.0
# ***BLEU Score***: 0.668740304976422
#
# target sentence id: [952, 7, 617, 680, 8, 12456, 9865, 27376]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  353 1054    6  862   10    5   31   95  862   31    2]
# Source Sentence:  rapid and short form a crown acrylic jacket
# Real Translation:  execution rapide et simplifee d une couronne jaquette en acrylique
# Predicted Translation:  forme fortuite et rapide a la quot vie rapide quot
# Levenshetein Distance: 45.0
# ***BLEU Score***: 0.5623413251903491
#
# target sentence id: [5, 3, 43, 25, 7059, 3, 3, 9]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1   5  40   5  36   4   5  95  10 334   2]
# Source Sentence:  the darmous or disease hairy charnot speder ,
# Real Translation:  le darmous ou maladie de velu charnot speder ,
# Predicted Translation:  la ou la maladie de la vie a therapie
# Levenshetein Distance: 25.0
# ***BLEU Score***: 0.5773502691896257
#
# target sentence id: [30, 1920, 4, 114, 2013, 4933]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1 119 815   8  73   2]
# Source Sentence:  new synthesis of diagnostic maxillofacial orthopedics
# Real Translation:  nouvelle synthese du diagnostic en orthopedie maxillo faciale
# Predicted Translation:  nouvelle synthese des resultats
# Levenshetein Distance: 36.0
# ***BLEU Score***: 0
#
# target sentence id: [295, 4, 9466, 6, 1337]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [    1    69    11 34385     2]
# Source Sentence:  value of penicillin in syphilis
# Real Translation:  valeur de la penicilline dans la syphilis
# Predicted Translation:  interet du percussionnaire
# Levenshetein Distance: 30.0
# ***BLEU Score***: 0
#
# target sentence id: [1288, 1299, 19, 4, 1337, 14, 9466, 26333, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   30 2461 2461    4    5 1469   25 1371 1396    2]
# Source Sentence:  massive mixed treatment of syphilis with penicillin bismuth arsenobenzols
# Real Translation:  traitement mixte massif de la syphilis par penicilline arsenobenzols bismuth
# Predicted Translation:  traitement orthodontique orthodontique de la granulomatose par carence acquise
# Levenshetein Distance: 57.0
# ***BLEU Score***: 0
#
# target sentence id: [171, 339, 4, 9466, 53, 6, 124, 1337]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  104  760    4    7 2268  215   12  598    2]
# Source Sentence:  current status of penicillin therapy in early syphilis
# Real Translation:  statut actuel de la therapie par penicilline dans la syphilis primaire
# Predicted Translation:  aspects actuelles de l hormonotherapie precoce en phase
# Levenshetein Distance: 46.0
# ***BLEU Score***: 0.5946035575013605
#
# target sentence id: [16, 5, 1798, 4, 5, 586, 4, 9466, 3, 2400]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   10   26    4    7 3174    4  126 1296    2]
# Source Sentence:  on the mechanism of the action of penicillin treponemicidal humans
# Real Translation:  sur le mecanisme de l action treponemicide de la penicilline chez l homme
# Predicted Translation:  a propos de l adoption de personnes immunite
# Levenshetein Distance: 51.0
# ***BLEU Score***: 0.6240195441936915
#
# target sentence id: [9466, 6, 5, 19, 4, 1337]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   30   18   15   30    4    5 5132    2]
# Source Sentence:  penicillin in the treatment of syphilis
# Real Translation:  la penicilline dans le traitement de la syphilis
# Predicted Translation:  traitement dans le traitement de la gonarthrose
# Levenshetein Distance: 22.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 295, 4, 9466, 6, 5, 19, 4, 1337]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   69    4    7   18   15   30    4    5 5132   18   15   30    4
#     5 5132    2]
# Source Sentence:  the value of penicillin in the treatment of syphilis
# Real Translation:  de la valeur de la penicilline dans le traitement de la syphilis
# Predicted Translation:  interet de l dans le traitement de la gonarthrose dans le traitement de la gonarthrose
# Levenshetein Distance: 42.0
# ***BLEU Score***: 0.5081327481546147
#
# target sentence id: [12939, 192, 450, 948, 6, 397, 9, 48, 8, 17]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  312    4    7  748 3344    6    4    7  748   18    7  312   11
#   652   17   10   26    9   16   24    2]
# Source Sentence:  he congenital intestinal obstruction in infants , about a case
# Real Translation:  l occlusion intestinale congenitale du nourrisson a propos d un cas
# Predicted Translation:  infarctus de l intestin irritable et de l intestin dans l infarctus du myocarde , a propos d un cas
# Levenshetein Distance: 55.0
# ***BLEU Score***: 0.6223329772884784
#
# target sentence id: [25479, 2572, 1265, 42]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   15   46 3618   11  173    2]
# Source Sentence:  anencephalic fetus radiological diagnosis
# Real Translation:  foetus anencephale diagnostic radiologique
# Predicted Translation:  le diagnostic foetales du travail
# Levenshetein Distance: 33.0
# ***BLEU Score***: 0
#
# target sentence id: [9466, 7, 21156]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1 2372    6  710    2]
# Source Sentence:  penicillin and diphtheria
# Real Translation:  penicilline et diphterie
# Predicted Translation:  fibrome et al
# Levenshetein Distance: 18.0
# ***BLEU Score***: 0
#
# target sentence id: [3, 3, 240, 6, 7106, 4, 6382]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   69   11 3796 3796   18   14  201 4124    2]
# Source Sentence:  cardiography preoperatively interest in tetralogy of fallot
# Real Translation:  interet de la cardiographie preoperatoire dans la tetralogie de fallot
# Predicted Translation:  interet du masque masque dans les indications synthetique
# Levenshetein Distance: 49.0
# ***BLEU Score***: 0
#
# target sentence id: [8, 17, 4, 3181, 26, 25]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   10   26    9   16   24    4   36    4 3335    2]
# Source Sentence:  a case of cushing s disease
# Real Translation:  un cas de maladie de cushing
# Predicted Translation:  a propos d un cas de maladie de cushing
# Levenshetein Distance: 11.0
# ***BLEU Score***: 0.6865890479690392
#
# target sentence id: [48, 6177, 4125, 12906]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  10  26   4   7 397   2]
# Source Sentence:  about gastroduodenal radiography interesting
# Real Translation:  a propos de radiographies interessantes gastro duodenales
# Predicted Translation:  a propos de l article
# Levenshetein Distance: 40.0
# ***BLEU Score***: 0.6511126026643229
#
# target sentence id: [11924, 42, 4, 452, 417, 21, 19705, 4169]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   46   25 3136   46    9   16  312   11  652   25 1400   11 1268
#  1291    2]
# Source Sentence:  topographic diagnosis of myocardial infarction by unipolar leads
# Real Translation:  le diagnostic topographique des infarctus du myocarde par les derivations unipolaires
# Predicted Translation:  diagnostic par articles diagnostic d un infarctus du myocarde par induit du segment st
# Levenshetein Distance: 49.0
# ***BLEU Score***: 0.5169731539571706
#
# target sentence id: [171, 3679, 16, 5, 19, 4, 123, 21, 23720]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1 325  27  15  30   4   5 148  25  14 205   4   5 148   2]
# Source Sentence:  current views on the treatment of tuberculosis by streptomycin
# Real Translation:  vues actuelles sur le traitement de la tuberculose par la streptomycin
# Predicted Translation:  actualites sur le traitement de la tuberculose par les virus de la tuberculose
# Levenshetein Distance: 29.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [1 5 2]
# Source Sentence:  the dyspraxias
# Real Translation:  les dyspraxies
# Predicted Translation:  la
# Levenshetein Distance: 12.0
# ***BLEU Score***: 0
#
# target sentence id: [1372, 9484]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1   7   9 666  22   7  72   2]
# Source Sentence:  hypersensitivity phenomena
# Real Translation:  les phenomenes d hypersensibilite
# Predicted Translation:  l d gene chez l adulte
# Levenshetein Distance: 22.0
# ***BLEU Score***: 0.7598356856515925
#
# target sentence id: [16, 852, 30, 3, 6, 1619, 258]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  711  711  727    4  160  727   12 1083    2]
# Source Sentence:  on some new acquisitions in neuro psychiatry
# Real Translation:  sur quelques acquisitions nouvelles en neuro psychiatrie
# Predicted Translation:  quelques quelques approches de nouveaux approches en matiere
# Levenshetein Distance: 39.0
# ***BLEU Score***: 0
#
# target sentence id: [1246, 140, 1539, 3, 698, 152, 3, 145]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   14  424    4    5 1088  424    4    7    4    7  774  154   14
#   104    4    5   39    2]
# Source Sentence:  infantile post measles encephalopathic syndromes their multietiologic aspects
# Real Translation:  syndromes encephalopathiques post morbilleux infantiles leurs aspects polyetiologiques
# Predicted Translation:  les syndromes de la amp syndromes de l de l alimentation vers les aspects de la sante
# Levenshetein Distance: 58.0
# ***BLEU Score***: 0.5856596027429395
#
# target sentence id: [48, 5, 1964, 4, 8, 682, 285, 11475, 5, 1259, 1101, 302, 3, 5, 1101, 3378, 8736]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   10   26    4    5  187    4  249 3419    5 2492  168   94    2]
# Source Sentence:  about the removal of a large cyst invading the maxillary sinus without damaging the sinus mucosa plasty
# Real Translation:  a propos de l exerese d un gros kyste envahissant le sinus maxillaire sans leser la muqueuse sinusale plastie
# Predicted Translation:  a propos de la technique de kyste ferme la tumefaction sans cliniques
# Levenshetein Distance: 69.0
# ***BLEU Score***: 0.537284965911771
#
# target sentence id: [8, 17, 4, 325, 9876, 21, 4926, 4, 433, 3, 10013]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   16   24    4 1412 2134  671   25 1209    9    8  364    2]
# Source Sentence:  a case of facial paresis by inclusion of lower premolar ectopia
# Real Translation:  a propos d un cas de paresie faciale par inclusion de premolaire inferieure en ectopie
# Predicted Translation:  un cas de re osteome faciale par implant d des temps
# Levenshetein Distance: 55.0
# ***BLEU Score***: 0.5491004867761125
#
# target sentence id: [4508, 26302, 102, 585, 3, 808, 6, 3208]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    7  198 2466 3383 3858   69   18    5  199 3607    2]
# Source Sentence:  microbial antagonism general recent acquisitions applications in dentistry
# Real Translation:  de l antagonisme microbien generalites acquisitions recentes applications a la medecine dentaire
# Predicted Translation:  l atteinte to deficience actives interet dans la in list
# Levenshetein Distance: 64.0
# ***BLEU Score***: 0.5623413251903491
#
# target sentence id: [15235, 29, 4, 5, 1375, 4, 7920, 10673, 6, 3711, 468, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   32    4    5  384    8 1380    4    7   34   18    5   28   12
#    29   11  310    4    7  446    2]
# Source Sentence:  histochemical study of the localization of alkaline phosphatase in rat dental blanks
# Real Translation:  etude histochimique de la localisation des phosphatases alcalines dans les ebauches dentaires du rat
# Predicted Translation:  etude de la localisation des fistules de l enfant dans la prise en charge du lymphome de l ovaire
# Levenshetein Distance: 63.0
# ***BLEU Score***: 0.5695988432761473
#
# target sentence id: [678, 14, 6754, 3976, 3835, 2934, 2506, 53]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   31   10    5  690   10    7 1848   31 8837  287   31    2]
# Source Sentence:  analgesia with nitrous oxide aseptic root canal therapy
# Real Translation:  analgesie au protoxyde d azote therapie radiculaire aseptique
# Predicted Translation:  quot a la analgesie a l ensemble quot metaboliquement caracteristiques quot
# Levenshetein Distance: 52.0
# ***BLEU Score***: 0.4063798282013443
#
# target sentence id: [5, 90, 4, 5, 2296, 27615, 2420, 4, 4260, 2573]
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    7  114    4    7 1102 2887    8 4454    2]
# Source Sentence:  the infection of the peri coronal space of impacted teeth
# Real Translation:  l infection de l espace peri coronaire des dents incluses
# Predicted Translation:  l infection de l appareil dieu des dangers
# Levenshetein Distance: 27.0
# ***BLEU Score***: 0.5946035575013605
#
# target sentence id: [547, 29, 4, 1125, 502, 4, 4125, 4, 5, 2157, 752]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   32  755    8 1493  264    4  257    8  950    2]
# Source Sentence:  critical study of various methods of radiography of the temporomandibular joint
# Real Translation:  etude critique des diverses methodes de radiographie de l articulation temporo maxillaire
# Predicted Translation:  etude critique des differentes techniques de biologie des mandibulaire
# Levenshetein Distance: 44.0
# ***BLEU Score***: 0
#
# target sentence id: [3961, 25, 7, 2151]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   36 8472    6   77  378    2]
# Source Sentence:  periodontal disease and cure
# Real Translation:  parodontose et cure thermale
# Predicted Translation:  maladie parodontale et maladies vasculaires
# Levenshetein Distance: 26.0
# ***BLEU Score***: 0
#
# target sentence id: [3908, 4, 2178, 628, 24516, 40, 545, 9, 8, 6905, 12, 26, 12, 3098]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   69    4    7 1342    4    5  187  357    4 1704   17   13   36
#   175   10   19  175   19  175   19  175   19    2]
# Source Sentence:  osteosynthesis of mandible external fixator french method , a u . s . equipment
# Real Translation:  l osteosynthese du maxillaire inferieur par fixateur externe methode francaise , a appareillage americain
# Predicted Translation:  interet de l augmentation de la technique nationale de pharmacovigilance , une maladie s a . s . s . s .
# Levenshetein Distance: 84.0
# ***BLEU Score***: 0.7226568811456053
#
# target sentence id: [2573, 7, 10407, 122, 5, 3, 4, 1119]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1 5603    6 2268   22   14 5473    4    5  847    4   10   26    2]
# Source Sentence:  teeth and dentition among the merina of madagascar
# Real Translation:  denture et dentition chez les merina de madagascar
# Predicted Translation:  dent et hormonotherapie chez les sportifs de la ville de a propos
# Levenshetein Distance: 39.0
# ***BLEU Score***: 0.537284965911771
#
# target sentence id: [3, 4, 25631, 1083]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1 4923    4    7  446    2]
# Source Sentence:  harmfulness of toothbrushes today
# Real Translation:  la nocivite des brosses a dents actuelles
# Predicted Translation:  centenaire de l ovaire
# Levenshetein Distance: 31.0
# ***BLEU Score***: 0.7071067811865476
#
# target sentence id: [1129, 7, 6719]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1 1723    6 1723    2]
# Source Sentence:  orthodontics and periodontitis
# Real Translation:  orthodontie et paradontose
# Predicted Translation:  orthodontie et orthodontie
# Levenshetein Distance: 7.0
# ***BLEU Score***: 0
#
# target sentence id: [2013, 47, 6, 6096, 4392, 6903]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1   5  47 833  12 769 411 749   2]
# Source Sentence:  maxillofacial surgery in latin america debriefing
# Real Translation:  la chirurgie maxillo faciale en amerique latine compte rendu de mission
# Predicted Translation:  la chirurgie externe en lt urologie gt
# Levenshetein Distance: 46.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 3, 4, 2244, 4404]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [    1     5 12747     8  3333     2]
# Source Sentence:  the pairing of proximal caries
# Real Translation:  le jumellage des caries proximales
# Predicted Translation:  la recette des chemins
# Levenshetein Distance: 21.0
# ***BLEU Score***: 0
#
# target sentence id: [8, 3630, 34, 4, 3, 6, 5, 3029, 25]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   16   24  414    4 8783   18    5   36    4 3940    2]
# Source Sentence:  a few cases of angiocardiography in the blue disease
# Real Translation:  quelques cas d angiocardiographie au cours de la maladie bleue
# Predicted Translation:  un cas bien de benevolat dans la maladie de kawasaki
# Levenshetein Distance: 45.0
# ***BLEU Score***: 0
#
# target sentence id: [3, 4, 5, 2178, 6, 15, 439, 130, 83, 91, 783, 163, 1902, 36, 81, 3, 71]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   14 4923    4    5 3359   18  196   24    4  110  488  488   23
#    14   37    4   56   56    2]
# Source Sentence:  lymphosarcoma of the mandible in an month old child surgical intervention radiotherapy healing after years odontogenesis disorders
# Real Translation:  lymphosarcome du maxillaire inferieur chez un enfant de mois intervention chirurgicale radiotherapie guerison depuis ans troubles de l odontogenese
# Predicted Translation:  les centenaire de la mandibule dans trois cas de radiotherapie postoperatoire postoperatoire pour les patients de ans ans
# Levenshetein Distance: 106.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 2762, 3099, 4, 3, 977, 11, 489, 2043, 166, 4, 5, 642, 21, 3, 1955]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   14 3143 5345    4    7   32    8  811 2422   21  775    4    7
#  1955    2]
# Source Sentence:  the circadian rhythm of phagocytic reactions to normal physiological control of the process by sialo cytology
# Real Translation:  le rythme nycthemeral des reactions phagocytaires a l etat normal physiologique controle du processus par la sialo cytologie
# Predicted Translation:  les rythmes circadiens de l etude des proteines physiques au processus de l hemoglobine
# Levenshetein Distance: 75.0
# ***BLEU Score***: 0.5169731539571706
#
# target sentence id: [1721, 4, 4618, 4, 1213, 294]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  15 256  99 148  99  10  10  21 167   4 734  99  99  10   7  85  99
#   10  26   4 615   2]
# Source Sentence:  observations of gastroenterology of north africa
# Real Translation:  observations de gastro enterologie d afrique du nord
# Predicted Translation:  le nourrisson n tuberculose n a a au chu de quebec n n a l age n a propos de j
# Levenshetein Distance: 61.0
# ***BLEU Score***: 0.6147881529512643
#
# target sentence id: [84, 36, 81, 21, 5, 1689, 545, 4, 19, 4, 500, 2573]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   73   10    7  113    4    7  113    4    5   28   12   29    9
#    16   30   25    7  661 3548    4   30    2]
# Source Sentence:  results after years by the conventional method of treatment of infected teeth
# Real Translation:  resultats obtenus apres ans par la methode classique de traitement des dents infectees
# Predicted Translation:  resultats a l utilisation de l utilisation de la prise en charge d un traitement par l difficile antoine de traitement
# Levenshetein Distance: 73.0
# ***BLEU Score***: 0.6147881529512643
#
# target sentence id: [5, 972, 4, 14397, 4, 325, 769]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   15 1239    4   82  671    2]
# Source Sentence:  the problem of immobilization of facial fractures
# Real Translation:  le probleme de l immobilisation des fractures du massif facial
# Predicted Translation:  le probleme de rare faciale
# Levenshetein Distance: 37.0
# ***BLEU Score***: 0
#
# target sentence id: [9865, 766, 298, 9, 650, 4, 5, 635, 421]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   16  807   99   51   89    5 1916    4    5  161    2]
# Source Sentence:  acrylic intra tissue , repair of the orbital region
# Real Translation:  resines acryliques intra tissulaires refection de la region orbitaire
# Predicted Translation:  un muscle n est pas la solution de la face
# Levenshetein Distance: 46.0
# ***BLEU Score***: 0.5623413251903491
#
# target sentence id: [11202, 7, 6719, 2479, 14525, 271]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  14 218   4   5 499   2]
# Source Sentence:  gingivitis and periodontitis inter radicular lesions
# Real Translation:  gingivites et parodontites lesions inter radiculaires
# Predicted Translation:  les lesions de la main
# Levenshetein Distance: 37.0
# ***BLEU Score***: 0
#
# target sentence id: [7743, 795, 7, 32, 1139, 4, 3, 2216, 4, 5, 338, 3700]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  649 1294    6   94    4    7 5614 7974    8  503    2]
# Source Sentence:  anatomo pathological and clinical considerations of diffused osteomyelitis of the upper maxilla
# Real Translation:  considerations anatomo pathologiques et cliniques sur les osteomyelites diffuses du maxillaire superieur
# Predicted Translation:  formes systemiques et cliniques de l hemangioendotheliome noueuse des membres
# Levenshetein Distance: 66.0
# ***BLEU Score***: 0.5623413251903491
#
# target sentence id: [3, 3208]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [1 2]
# Source Sentence:  homeopathic dentistry
# Real Translation:  therapeutique homeopathique en art dentaire
# Predicted Translation:
# Levenshetein Distance: 44.0
# ***BLEU Score***: 0
#
# target sentence id: [3599, 4, 5, 7604]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1 1759   11  256    2]
# Source Sentence:  infancy of the denture
# Real Translation:  premiers balbutiements de la prothese dentaire
# Predicted Translation:  nourrissons du nourrisson
# Levenshetein Distance: 36.0
# ***BLEU Score***: 0
#
# target sentence id: [8, 17, 4, 22426, 100, 211]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   16   24    9 1695    4   81 1695    2]
# Source Sentence:  a case of leydig tumor cells
# Real Translation:  un cas de tumeur a cellules interstitielles du testicule
# Predicted Translation:  un cas d tumorales de cellules tumorales
# Levenshetein Distance: 31.0
# ***BLEU Score***: 0.6147881529512643
#
# target sentence id: [204, 11, 5, 3, 29, 7, 102, 1139]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1 887  10   5  32  52   6 222   2]
# Source Sentence:  contribution to the paradental study and general considerations
# Real Translation:  contribution a l etude paradentaire et considerations generales
# Predicted Translation:  contribution a la etude therapeutique et generale
# Levenshetein Distance: 24.0
# ***BLEU Score***: 0.6147881529512643
#
# target sentence id: [3, 3, 3, 11, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [    1     7  2023  9879  2466 33866     2]
# Source Sentence:  logette retentive buttoned to studs
# Real Translation:  logette retentive pour crampons boutonnes
# Predicted Translation:  l ni karl to keratotomies
# Levenshetein Distance: 30.0
# ***BLEU Score***: 0.668740304976422
#
# target sentence id: [5, 3, 26958, 7, 184, 808, 15881, 21, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   15 1729    9 1336   38  254 2218 1519    2]
# Source Sentence:  the studded inlay and its applications parallelism by isodromy
# Real Translation:  l inlay a crampons et ses applications le parallelisme par l isodromie
# Predicted Translation:  le secret d bonnes aux ses molecules sains
# Levenshetein Distance: 52.0
# ***BLEU Score***: 0.5946035575013605
#
# target sentence id: [282, 4, 5, 468, 7862, 7, 3, 21, 5, 65, 4, 13524, 22553, 3, 545]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  286    4    5 4711  670    6    4    5  973   25  113    4 5574
#  7356    2]
# Source Sentence:  reconstruction of the dental arches and oclusion by the use of spherical portions bignell method
# Real Translation:  de la reconstruction des arcades dentaires et de l oclusion par l emploi de portions de sphere bignell method
# Predicted Translation:  reconstruction de la voute dentaire et de la hanche par utilisation de colle tof
# Levenshetein Distance: 55.0
# ***BLEU Score***: 0
#
# target sentence id: [2706, 5, 1048, 4, 5, 2178, 7, 184, 1910, 6, 1149, 7604]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  28  12  29   4   5  36   6  10 254 220  12  53   2]
# Source Sentence:  determining the position of the mandible and its significance in complete denture
# Real Translation:  de la determination de la position de repos de la mandibule et de sa signification en prothese complete
# Predicted Translation:  prise en charge de la maladie et a ses risques en medecine
# Levenshetein Distance: 69.0
# ***BLEU Score***: 0.49432603195143127
#
# target sentence id: [5, 602, 992, 4807, 29, 7, 24794]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    5 7718   18    5 1593  935    2]
# Source Sentence:  the left ventricular radiographic study and semiotic
# Real Translation:  la cinetique ventriculaire gauche etude radioky mographique et semeiologique
# Predicted Translation:  la videocapsule dans la ventricule laparoscopique
# Levenshetein Distance: 54.0
# ***BLEU Score***: 0
#
# target sentence id: [84, 9, 36, 81, 4, 3750, 4, 8, 225, 4, 83, 468, 1018]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  73  17 120   4 763   4   7 328   9  34  27  56   9  13 109   9 328
#    2]
# Source Sentence:  results , after years of operation of a center of child dental prophylaxis
# Real Translation:  resultat , apres ans de fonctionnement d un centre de prophylaxie dentaire infantile
# Predicted Translation:  resultats , plus de annees de l homme d enfant sur ans d une centre d homme
# Levenshetein Distance: 51.0
# ***BLEU Score***: 0.6481388934544839
#
# target sentence id: [7071, 4, 5, 1875, 7, 56]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   14 1501    4    5  670  670    2]
# Source Sentence:  vitality of the tooth and therapeutic
# Real Translation:  vitalite des tissus dentaires et therapeutique
# Predicted Translation:  les bacteries de la dentaire dentaire
# Levenshetein Distance: 28.0
# ***BLEU Score***: 0
#
# target sentence id: [3, 16, 5, 1381, 10407, 399, 6, 14249, 1225, 2072]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   15 2513    4  422    4  422   23    7   32   11 1006   18    7
#  2285 1162    2]
# Source Sentence:  generalities on the eating dentition relationship in diverse animal species
# Real Translation:  quelques generalites sur les relations de l alimentation et de la denture chez les diverses especes animales
# Predicted Translation:  le journal de relation de relation pour l etude du handicap dans l procedures libre
# Levenshetein Distance: 68.0
# ***BLEU Score***: 0.5081327481546147
#
# target sentence id: [29, 4, 15227, 4, 192, 17135]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [    1    32     4     5 32150     4     5   924     2]
# Source Sentence:  study of electrocardiograms of congenital cardiopathies
# Real Translation:  etude des traces electrocardiographiques de cardiopathies congenitales
# Predicted Translation:  etude de la microvascularisation de la pharmacie
# Levenshetein Distance: 44.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 430, 4, 3, 21, 609, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   14  277    4    5  229    4   53   25 1494 1494    2]
# Source Sentence:  the consequences of sensibilisation by local sulfamidotherapy
# Real Translation:  les consequences de la sensibilisation par la sulfamidotherapie locale
# Predicted Translation:  les consequences de la societe de medecine par locale locale
# Levenshetein Distance: 32.0
# ***BLEU Score***: 0
#
# target sentence id: [1938, 4, 6719, 7, 31]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  649    8  649    6    8  775    4 1345   63  268    6    2]
# Source Sentence:  pathogenesis of periodontitis and health
# Real Translation:  pathogenese et hygiene des parodontites
# Predicted Translation:  formes des formes et des processus de substances entre leur et
# Levenshetein Distance: 46.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 1902, 4, 1293, 7, 18609]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1   5 419   8 774   6   8 298   2]
# Source Sentence:  the healing of defects and vices
# Real Translation:  la guerison des defauts et des vices
# Predicted Translation:  la pression des alimentation et des adolescents
# Levenshetein Distance: 23.0
# ***BLEU Score***: 0
#
# target sentence id: [13321, 6, 5, 1408, 573, 350]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   14 9343   18    7  397    2]
# Source Sentence:  biostatistics in the prosthesis second part
# Real Translation:  la biostatique en prothese deuxieme partie
# Predicted Translation:  les smartphones dans l article
# Levenshetein Distance: 29.0
# ***BLEU Score***: 0.5475182535069453
#
# target sentence id: [333, 6626]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1 302 302   2]
# Source Sentence:  internal cavities
# Real Translation:  les caries dentaires internes
# Predicted Translation:  interne interne
# Levenshetein Distance: 17.0
# ***BLEU Score***: 0
#
# target sentence id: [2121, 12767, 6350, 9669, 6, 137, 7287]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    7 3547  155   58   18    7  778    2]
# Source Sentence:  hormonal determinism load glycogen in human endometrium
# Real Translation:  determinisme hormonal de la charge en glycogene de la muqueuse uterine humaine
# Predicted Translation:  l anneau qui place dans l humain
# Levenshetein Distance: 58.0
# ***BLEU Score***: 0.6147881529512643
#
# target sentence id: [12543, 211, 7, 1159, 3199]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   81  155 1353    6 1128    2]
# Source Sentence:  schwann cells and nervous regeneration
# Real Translation:  les cellules de schwann et la regeneration nerveuse
# Predicted Translation:  cellules qui r et sarcomes
# Levenshetein Distance: 33.0
# ***BLEU Score***: 0.668740304976422
#
# target sentence id: [3, 156, 370, 33, 4, 3, 2900]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   35    4 8806  235 2251    9   13  118  235    2]
# Source Sentence:  peduncular brain stem syndrome of encephalitic nature
# Real Translation:  syndrome pedonculaire de nature encephalitique
# Predicted Translation:  syndrome de vasoconstriction cerebrale reversible d une tumeur cerebrale
# Levenshetein Distance: 49.0
# ***BLEU Score***: 0.5773502691896257
#
# target sentence id: [8529, 42, 4, 1387, 119]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [    1    46 32351    11   511     2]
# Source Sentence:  bronchoscopic diagnosis of bronchial tumors
# Real Translation:  diagnostic bronchoscopique des tumeurs des bronches
# Predicted Translation:  diagnostic dermoscopique du poumon
# Levenshetein Distance: 25.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 971, 736, 6, 12500]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    5  169    6    7 1915    4    7  328    2]
# Source Sentence:  the reproductive period in insects
# Real Translation:  la diapause imaginale chez les insectes
# Predicted Translation:  la reanimation et l heure de l homme
# Levenshetein Distance: 27.0
# ***BLEU Score***: 0.5946035575013605
#
# target sentence id: [1695, 209, 6, 5, 373, 403]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1 1020    4    7  180 1282   18   15  319    2]
# Source Sentence:  reproduction history in the diabetic woman
# Real Translation:  sur le passe gynecologique des femmes diabetiques
# Predicted Translation:  historique de l histoire active dans le diabetique
# Levenshetein Distance: 33.0
# ***BLEU Score***: 0.5946035575013605
#
# target sentence id: [3, 4, 3, 781]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1 4923    4    7 4344    2]
# Source Sentence:  hyperthyreosis of diencephalic origin
# Real Translation:  les hyperthyreoses d origne diencephalique
# Predicted Translation:  centenaire de l accessibilite
# Levenshetein Distance: 30.0
# ***BLEU Score***: 0.7071067811865476
#
# target sentence id: [79, 34, 4, 1096, 1115, 21, 4865, 2163, 4, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   76   24    4  374 2104   12  182 2846    2]
# Source Sentence:  two cases of fatal toxicity by usual doses of pilocarpine
# Real Translation:  sur deux cas d intoxication mortelle par la pilocarpine aux doses usuelles
# Predicted Translation:  deux cas de pathologies radiologiques en milieu consecutifs
# Levenshetein Distance: 49.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 9557, 6, 5, 137, 1194]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  15 344   4   7 778  12 778   2]
# Source Sentence:  the patella in the human embryo
# Real Translation:  la rotule chez l embryon humain
# Predicted Translation:  le reseau de l humain en humain
# Levenshetein Distance: 16.0
# ***BLEU Score***: 0.6147881529512643
#
# target sentence id: [82, 4, 10909, 2007]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   79   11 1118    2]
# Source Sentence:  analysis of elephant milk
# Real Translation:  analyse d un lait d elephant
# Predicted Translation:  analyse du futur
# Levenshetein Distance: 16.0
# ***BLEU Score***: 0
#
# target sentence id: [3411, 6, 8636, 695, 84, 4, 16445, 14, 13169]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   15 3101   11 1071   23    7   92   11 1758  252   73    4    7
# ...
# target sentence id: [346, 4, 18, 7, 4394, 4, 2013, 47]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  326    8   37    6 1531    4    2]
# Source Sentence:  presentation of patients and operations of maxillofacial surgery
# Real Translation:  presentation de malades et operations de chirurgie maxillo faciale
# Predicted Translation:  presentation des patients et moyens de
# Levenshetein Distance: 38.0
# ***BLEU Score***: 0
#
# target sentence id: [46, 538, 6, 8, 2274, 4, 14, 100, 4, 5, 2480]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    5  523   65   12 1422    9   13  118    4    5  499    2]
# Source Sentence:  acute leukemia in a boy of with tumor of the mediastinum
# Real Translation:  leucemie aigue chez un garcon de ans avec tumeur du mediastin
# Predicted Translation:  la leucemie aigue en dehors d une tumeur de la main
# Levenshetein Distance: 28.0
# ***BLEU Score***: 0.5491004867761125
#
# target sentence id: [852, 84, 4, 1435, 47]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  73   4   7 711  73   2]
# Source Sentence:  some results of plastic surgery
# Real Translation:  quelques resultats d operations plastiques
# Predicted Translation:  resultats de l quelques resultats
# Levenshetein Distance: 27.0
# ***BLEU Score***: 0.3670124608961283
#
# target sentence id: [8, 6947, 7986, 4, 5, 10376, 31, 761, 4448, 51, 116, 6, 5266]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   16 4283  154    5  578    4  333  128    4   39    2]
# Source Sentence:  a remarkable chapter of the portuguese health policy overseas medical education in india
# Real Translation:  une page remarquable de la politique sanitaire portugaise a l outremer l enseignement medical aux indes
# Predicted Translation:  un seul vers la politique de securite medicale de sante
# Levenshetein Distance: 65.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 316, 4, 61, 7, 51, 546, 96, 6, 10814]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    7  968    4    5   53    6    5   91  128   12 1083    9  401
#     2]
# Source Sentence:  the teaching of medicine and medical scientific research in portugal
# Real Translation:  l enseignement de la medecine et les recherches scientifiques medicales au portugal
# Predicted Translation:  l enseignement de la medecine et la recherche medicale en matiere d ivoire
# Levenshetein Distance: 30.0
# ***BLEU Score***: 0.6262844962765469
#
# target sentence id: [882, 119, 4, 5, 183]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   74 1696    4    5  741    2]
# Source Sentence:  black tumors of the skin
# Real Translation:  tumeurs noires de la peau
# Predicted Translation:  tumeurs noire de la peau
# Levenshetein Distance: 1.0
# ***BLEU Score***: 0
#
# target sentence id: [7958, 16475, 4, 3191, 3198]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   15 2819    4 2399   11 1731  343    2]
# Source Sentence:  unpublished pages of claude bernard
# Real Translation:  pages inedites de claude bernard
# Predicted Translation:  le coup de taille du cuir siecle
# Levenshetein Distance: 27.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 3356, 832, 6, 10814]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  15 744 870   8 364   2]
# Source Sentence:  the wine consumption in portugal
# Real Translation:  les vins de consommation au portugal
# Predicted Translation:  le bon hospitalises des temps
# Levenshetein Distance: 26.0
# ***BLEU Score***: 0
#
# target sentence id: [6088, 7, 8596, 625, 4, 51, 3523]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  753   21 3098    6  753    2]
# Source Sentence:  artistic and bibliographic exposure of medical authors
# Real Translation:  exposition artistique et bibliographique d auteurs medecins
# Predicted Translation:  exposition au informatique et exposition
# Levenshetein Distance: 35.0
# ***BLEU Score***: 0
#
# target sentence id: [10376, 440]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    7 1915    2]
# Source Sentence:  portuguese art
# Real Translation:  l art portugais
# Predicted Translation:  l heure
# Levenshetein Distance: 12.0
# ***BLEU Score***: 0.8408964152537145
#
# target sentence id: [3, 153, 7, 9466, 6, 3208]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1 147   6  83  19  23   2]
# Source Sentence:  sulfa drugs and penicillin in dentistry
# Real Translation:  les sulfamides et la penicilline en stomatologie
# Predicted Translation:  medicaments et prevention . pour
# Levenshetein Distance: 33.0
# ***BLEU Score***: 0
#
# target sentence id: [8, 33, 98, 3390, 7, 6154, 14397, 4, 5, 338, 644, 6254, 4011, 11, 3, 4, 5, 389, 3543]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   16 5311  983    6   16  458   96   18    5   28   12   29   11
#   956  944   10    7  101   11  132    4    7  446    8  540   11  517
#     2]
# Source Sentence:  a syndrome severe neuralgia and absolute immobilization of the upper limb immediately subsequent to setons of the neck muscles
# Real Translation:  sur un syndrome sympathalgie violente et immobilisation absolue du membre superieur immediatement consecutif a des setons des muscles du cou
# Predicted Translation:  un nevralgie malin et un grand type dans la prise en charge du membre superieur a l hopital du point de l ovaire des centres du sang
# Levenshetein Distance: 91.0
# ***BLEU Score***: 0.2310325762059593
#
# target sentence id: [3, 10, 77, 735]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   15 6642   23 5190    2]
# Source Sentence:  pneumotomy for lung abscess
# Real Translation:  a propos de la pneumotomie pour abces du poumon
# Predicted Translation:  le linezolide pour soulager
# Levenshetein Distance: 32.0
# ***BLEU Score***: 0
#
# target sentence id: [4324, 464, 4, 2207, 386, 6, 91, 19, 4, 916, 20]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   14  264    4  150    8  665 1276   18    5   47    8   74   11
#  1526    2]
# Source Sentence:  conservation techniques of sphincter function in surgical treatment of rectal cancer
# Real Translation:  a propos des techniques de conservation de la fonction sphincterienne dans cure operatoire des cancers du rectum
# Predicted Translation:  les techniques de developpement des tres monoclonaux dans la chirurgie des tumeurs du rectum
# Levenshetein Distance: 61.0
# ***BLEU Score***: 0
#
# target sentence id: [1812, 4, 3, 591, 1236, 4, 5, 77]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1  14 996   4 144  80 669  11 249 669   2]
# Source Sentence:  sequelae of evacuated hydatid cysts of the lung
# Real Translation:  sequelles de kystes hydatiques du poumon evacuees par vomiques
# Predicted Translation:  les sequelles de pathologie pulmonaire hydatique du kyste hydatique
# Levenshetein Distance: 45.0
# ***BLEU Score***: 0
#
# target sentence id: [827, 6, 119, 4, 5, 1668]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1 396   4   7 446   2]
# Source Sentence:  bleeding in tumors of the ovary
# Real Translation:  a propos des metrorragies dans les tumeurs de l ovaire
# Predicted Translation:  hemorragie de l ovaire
# Levenshetein Distance: 33.0
# ***BLEU Score***: 0.7071067811865476
#
# target sentence id: [2675, 559, 4, 5, 940, 9, 4, 5, 126, 1837, 21, 21917, 952, 3839, 9, 2380, 37, 5, 2441, 37, 5, 150, 3321]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [  1 577   4   7 716  17  11  46  45  25   5 756  10  13  45 862  17 421
#   10   5  17   8 740 551   2]
# Source Sentence:  closed fracture of the leg , of the type known by crushing rapid gangrene , amputation at the thigh at the th hour
# Real Translation:  fracture fermee de jambe , de type dit par ecrasement gangrene rapide amputation de cuisse a la . heure
# Predicted Translation:  fracture de l plaies , du diagnostic clinique par la fibrose a une clinique rapide , encore a la , des sciences medicales
# Levenshetein Distance: 81.0
# ***BLEU Score***: 0.645777692487244
#
# target sentence id: [3, 7, 162, 25]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [    1 17446     6  1788     2]
# Source Sentence:  sulfonamides and oral disease
# Real Translation:  sulfamides et affections buccodentaires
# Predicted Translation:  heurs et buccale
# Levenshetein Distance: 28.0
# ***BLEU Score***: 0
#
# target sentence id: [3, 9, 2548, 2990, 11215, 12]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  435   17 2881 1088    2]
# Source Sentence:  auffret , charles jacques emile .
# Real Translation:  auffret , charles jacques emile .
# Predicted Translation:  mort , circoncision amp
# Levenshetein Distance: 24.0
# ***BLEU Score***: 0.5506953149031838
#
# target sentence id: [96, 16, 3251, 12171, 503, 28, 5914, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   91   27    5 1929    4    7  105  177   48  161    4    7  114
#     2]
# Source Sentence:  research on pathogenic actinomyces isolated from algiers saprophytes
# Real Translation:  recherches sur le pourvoir pathogene d actinomyces saprophytes isoles a alger
# Predicted Translation:  recherche sur la isolees de l ne quel risque face de l infection
# Levenshetein Distance: 51.0
# ***BLEU Score***: 0.5266403878479265
#
# target sentence id: [8, 17, 4, 192, 135, 7, 767, 1356, 6, 15, 435, 36, 4076, 54, 76]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   16   24    9   72  433    6    9 1140  378   27   16  548 1012
#     2]
# Source Sentence:  a case of congenital heart and eye malformations in an infant after rubella during pregnancy
# Real Translation:  un cas de malformation cardiaque et oculaire chez un nourrisson apres rubeole au cours de la grossesse
# Predicted Translation:  un cas d adulte congenitale et d malformations vasculaires sur un contexte neonatal
# Levenshetein Distance: 68.0
# ***BLEU Score***: 0.5266403878479265
#
# target sentence id: [340, 913, 4, 244, 3, 6, 8, 83, 4, 81]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1  917  457    8 1233 2428   22   16   93    4   56    2]
# Source Sentence:  traumatic dislocation of cervical vertebra in a child of years
# Real Translation:  luxation traumatique d une vertebre cervicale chez un enfant de ans
# Predicted Translation:  luxation traumatique des os uterins chez un enfants de ans
# Levenshetein Distance: 20.0
# ***BLEU Score***: 0
#
# target sentence id: [192, 8469, 302, 8371, 6, 8, 83, 4, 985, 789, 1258, 3343, 7, 768, 10696, 4541, 100]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   99 1939 2736  168  218   18    7   34    4  942  186    6  120
#    59  557  984    6    2]
# Source Sentence:  congenital cardiopathy without cyanosis in a child of months chest wall retraction and sub sternum intrathoracic tumor
# Real Translation:  cardiopathie congenitale sans cyanose , chez un enfant de mois tirage sus et sous sternal tumeur intra thoracique
# Predicted Translation:  n vus congenitaux sans lesions dans l enfant de six mois et plus il vivant specifique et
# Levenshetein Distance: 67.0
# ***BLEU Score***: 0.5856596027429395
#
# target sentence id: [2938, 6375, 6, 8, 195, 83]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    5  662  114 8010   22   13  321 1835    2]
# Source Sentence:  myositis ossificans in a young child
# Real Translation:  myosite ossifiante chez un jeune enfant
# Predicted Translation:  la pseudo infection ossifiante chez une jeune fille
# Levenshetein Distance: 23.0
# ***BLEU Score***: 0
#
# target sentence id: [1001, 148, 67, 7, 5221]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1   77    4   39    6 1148    2]
# Source Sentence:  endocrine system diseases and estrogen
# Real Translation:  les endocrinoses oestrogenes
# Predicted Translation:  maladies de sante et precarite
# Levenshetein Distance: 24.0
# ***BLEU Score***: 0
#
# target sentence id: [590, 4, 3997, 16, 5, 244, 4915]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [    1   440     4     7 34989    27    15  1045     2]
# Source Sentence:  influence of hormones on the cervical glands
# Real Translation:  influence des actions hormonales sur les glandes du col uterin
# Predicted Translation:  influence de l anthropisation sur le cervicale
# Levenshetein Distance: 34.0
# ***BLEU Score***: 0.6147881529512643
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Prediction Output and Metrics on 400 test sentences:
# Average BLEU Score on our test corpus is 0.323080018769007
# Average Levenshetein distance Score on our test corpus is 47.1125

# %%
src_sent = 'myositis ossificans in a young child '
tgt_sent = 'myosite ossifiante chez un jeune enfant'


translate_en_fr(src_sent,
                tgt_sent, 
                verbose = True,
                plot_att = True)
# Out:
# target sentence id: [2938, 6375, 6, 8, 195, 83]
# INFO:tensorflow:Restoring parameters from ckpt-exp05/google-brain-rmsprop001-7800
# target sentence id: [   1    5  662  114 8010   22   13  321 1835    2]
# Source Sentence: myositis ossificans in a young child
# Real Translation: myosite ossifiante chez un jeune enfant
# Predicted Translation:  la pseudo infection ossifiante chez une jeune fille
# Levenshetein Distance: 24.0
# ***BLEU Score***: 0
# (' la pseudo infection ossifiante chez une jeune fille ', 0, 24.0)
