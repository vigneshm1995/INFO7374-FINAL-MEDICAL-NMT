# %% [markdown]
# *This Note book referenced [WuJiaocan's Github](https://github.com/WuJiaocan/tensorflow), [XueYouluo's Github](https://github.com/xueyouluo/my_seq2seq/blob/90c86bacd5cb88ad8d381de28fe3bdf8421a0036/notebooks/MyS2S.ipynb)
#
# *Major contribution of this notebook is: provided a flexible NMT network building (change of layers, cell-type, switch between bi-direction and uni-direction RNN, switch between attention mechanisms) based on Tensorflow through parameter setting

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
import tensorflow as tf
import codecs
import sys
import numpy as np
import time

# %% [markdown]
# # INSTRUCTION -0: RECORD PARAMETERS
#
# !! Please record all hyper parameters [HERE](https://docs.google.com/spreadsheets/d/1VgRGGDv_ynvTORz3vHtH2VgRQnyxv9qBkDkPjSpDj3c/edit?usp=sharing) **BEFORE** start traning.
#
# This is to avoid duplicated/similar experiments among our team

# %% [markdown]
# # INSTRUCTION-1: SET TRAINING DATASET
#
# Set NUM_EXAMPLES AND Run All Cells
#
# Time for 1 Epoch on Colab GPU for reference:
#
# 1. 100,000 sentence pairs: 285s
# 2.  50,000 sentence pairs: 127s

# %% [markdown]
# ### 1.Create Vocabulary

# %%
import zipfile
with zipfile.ZipFile("data.zip","r") as zip_ref:
    zip_ref.extractall("")

# %%
NUM_SENT = 50000

# %%
src_path = 'en_clean.txt'
tgt_path = 'fr_clean.txt'

# %%
def read_train_data(txt_path, num_examples):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[:num_examples]

# %%
src = read_train_data(src_path, NUM_SENT)
tgt = read_train_data(tgt_path, NUM_SENT)

# %%
def read_test_data(txt_path, num_examples = 400):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[-num_examples:]

# %%
src_test = read_test_data(src_path)
tgt_test = read_test_data(tgt_path)

# %%
print('size of number of source sentences from dataset for training: {}'.format(len(src)))
print('size of number of target sentences from dataset for training: {}'.format(len(tgt)))
# Out:
# size of number of source sentences from dataset for training: 50000
# size of number of target sentences from dataset for training: 50000

# %%
print('size of number of source sentences from dataset for testing: {}'.format(len(src_test)))
print('size of number of target sentences from dataset for testing: {}'.format(len(tgt_test)))
# Out:
# size of number of source sentences from dataset for testing: 400
# size of number of target sentences from dataset for testing: 400

# %%
# Display examples for quick check

for i in range(5):
  print(src[i])
# Out:
#  global health where do physiotherapy and rehabilitation research fit ?
#  carabin
#  comment on the misappropriation of bibliographical references in science . the example of anti aging medicine
#  anti aging medicine , a science based , essential medicine
#  underwater dive in fresh water complicated by a cardiorespiratory arrest on obstructive shock

# %%
for i in range(5):
  print(tgt[i])
# Out:
#  la place des cheveux et des poils dans les rituels et le sacre
#  les carabins
#  du detournement des references bibliographiques en science . l exemple de la medecine anti age
#  la medecine anti age , une medecine scientifique , indispensable
#  plongee subaquatique en eau douce compliquee d un arret cardiorespiratoire sur choc obstructif

# %%
import codecs
import collections
from operator import itemgetter

def create_vocab(RAW_DATA, VOCAB_OUTPUT):
    counter = collections.Counter()

    for line in RAW_DATA:
        for word in line.strip().lower().split():
            counter[word] += 1

    sorted_word_to_cnt = sorted(counter.items(), key=itemgetter(1), reverse=True)
    sorted_words = [x[0] for x in sorted_word_to_cnt]

    sorted_words =  ['<pad>'] + ['<sos>'] + ['<eos>'] + ['<unk>'] + sorted_words 

    with codecs.open(VOCAB_OUTPUT, "w", encoding="utf-8") as file_output:
        for word in sorted_words:
            file_output.write(word + "\n")
    return sorted_words

# %%
vocab_src = create_vocab(src, 'vocab.en')
vocab_tgt = create_vocab(tgt, 'vocab.fr')

# %%
vocab_size_src = len(vocab_src)
vocab_size_tgt = len(vocab_tgt)

print('size of source vocab {}'.format(vocab_size_src))
print('size of target vocab {}'.format(vocab_size_tgt))
# Out:
# size of source vocab 28711
# size of target vocab 35019

# %%
print(vocab_src[-5:])
# Out:
# ['homolateral', 'peritonsillar', 'radt', 'lobbying', 'mediacalcosis']

# %%
print(vocab_tgt[-5:])
# Out:
# ['respective', 'periamygdalien', 'bachelot', 'lobbying', 'mediacalcose']

# %% [markdown]
# ### 2.Convert Text to Numbers

# %%
import codecs
import sys

def text_to_int(RAW_DATA, VOCAB, OUTPUT_DATA):

  with codecs.open(VOCAB, "r", encoding="utf-8") as f_vocab:
      vocab = [w.strip() for w in f_vocab.readlines()]
      word_to_id = {k:v for (k,v) in zip(vocab, range(len(vocab)))}

  def get_id(word):
      return word_to_id[word] if word in word_to_id else word_to_id["<unk>"]

  fout = codecs.open(OUTPUT_DATA, "w", encoding="utf-8")
  for line in RAW_DATA:
      words = line.strip().split() + ["<eos>"]

      out_line = " ".join([str(get_id(w)) for w in words]) + "\n"
      fout.write(out_line)
  fout.close()

# %%
text_to_int(src, 'vocab.en', 'train.en')
text_to_int(tgt, 'vocab.fr', 'train.fr')

# %% [markdown]
# ### 4. Create Training Dataset

# %%
def MakeDataset(file_path):
    dataset = tf.data.TextLineDataset(file_path)
    # split by space
    dataset = dataset.map(lambda string: tf.string_split([string]).values)
    # convert string to number
    dataset = dataset.map(
        lambda string: tf.string_to_number(string, tf.int32))
    # calc # word/sentence and put in dataset with sentence
    dataset = dataset.map(lambda x: (x, tf.size(x)))
    return dataset

def MakeSrcTrgDataset(src_path, trg_path, batch_size):

    src_data = MakeDataset(src_path)
    trg_data = MakeDataset(trg_path)
    #   ds[0][0]source sentence
    #   ds[0][1]len of source sentence
    #   ds[1][0]target sentence
    #   ds[1][1]len of target sentence
    dataset = tf.data.Dataset.zip((src_data, trg_data))

    # delete empty and super-long sentence
    def FilterLength(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        src_len_ok = tf.logical_and(
            tf.greater(src_len, 1), tf.less_equal(src_len, MAX_LEN))
        trg_len_ok = tf.logical_and(
            tf.greater(trg_len, 1), tf.less_equal(trg_len, MAX_LEN))
        return tf.logical_and(src_len_ok, trg_len_ok)
    dataset = dataset.filter(FilterLength)
    
    #   1.trg_input: "<sos> X Y Z"
    #   2.trg_label: "X Y Z <eos>"
    #   file: "X Y Z <eos>", need to produce "<sos> X Y Z" and add to dataset
    def MakeTrgInput(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        trg_input = tf.concat([[SOS_ID], trg_label[:-1]], axis=0)
        return ((src_input, src_len), (trg_input, trg_label, trg_len))
    
    dataset = dataset.map(MakeTrgInput)

    dataset = dataset.shuffle(10000)

    # define shape after padding
    padded_shapes = (
        (tf.TensorShape([None]),
         tf.TensorShape([])), 
        (tf.TensorShape([None]),
         tf.TensorShape([None]),
         tf.TensorShape([]))) 
    
    # padded_batch to pad
    batched_dataset = dataset.padded_batch(batch_size, padded_shapes)
    return batched_dataset

# %% [markdown]
# ### 3.Define NMT

# %%
def single_rnn_cell(cell_name, hid_size, keep_prob):
    if cell_name == "GRU":
        cell = tf.contrib.rnn.GRUCell(hid_size)
    elif cell_name == "LSTM":
        cell = tf.contrib.rnn.LSTMCell(hid_size)
    elif cell_name == "BASIC":
        cell = tf.contrib.rnn.BasicRNNCell(hid_size)
        
    if keep_prob < 1.0:
      cell = tf.contrib.rnn.DropoutWrapper(
            cell=cell,
            input_keep_prob=keep_prob,
            output_keep_prob=keep_prob)
    
    return cell


def multi_rnn_cell(cell_name, hid_size, num_layers, keep_prob):
    cells = []
    for _ in range(num_layers):
        cell = single_rnn_cell(cell_name, hid_size, keep_prob)
        cells.append(cell)
    
    if len(cells) > 1:
        final_cell = tf.contrib.rnn.MultiRNNCell(cells=cells)
    else:
        final_cell = cells[0]
    return final_cell
  
  
def single_biRNN_pair(cell_name, hid_size, keep_prob):
    if cell_name == "bi-GRU":
      enc_cell_fw = single_rnn_cell('GRU', hid_size, keep_prob)
      enc_cell_bw = single_rnn_cell('GRU', hid_size, keep_prob)
    elif cell_name == "bi-LSTM":
      enc_cell_fw = single_rnn_cell('LSTM', hid_size, keep_prob)
      enc_cell_bw = single_rnn_cell('LSTM', hid_size, keep_prob)
    return enc_cell_fw, enc_cell_bw
    
def multi_biRNN_pair(cell_name, hid_size, num_layers, keep_prob):
    stacked_biRNN_fw = []
    stacked_biRNN_bw = []
    for _ in range(num_layers):
        enc_cell_fw, enc_cell_bw = single_biRNN_pair(cell_name, hid_size, keep_prob)
        stacked_biRNN_fw.append(enc_cell_fw)
        stacked_biRNN_bw.append(enc_cell_bw)
    
    if len(stacked_biRNN_fw) > 1:
        final_stacked_biRNN_fw = tf.contrib.rnn.MultiRNNCell(cells=stacked_biRNN_fw)
        final_stacked_biRNN_bw = tf.contrib.rnn.MultiRNNCell(cells=stacked_biRNN_bw)
    else:
        final_stacked_biRNN_fw = stacked_biRNN_fw[0]
        final_stacked_biRNN_bw = stacked_biRNN_bw[0]
    return final_stacked_biRNN_fw, final_stacked_biRNN_bw

# %%
class NMTModel(object):
  """
  defind the nmt model
  
  """
  # define variables needed by nmt
  def __init__(self, 
               dec_layer, 
               enc_layer,
               dec_cell_name, 
               enc_cell_name,
               optimizer, 
               lr,
               hid_size, 
               attention,
               drop_out):
    
    self.dec_cell_name = dec_cell_name
    self.enc_cell_name = enc_cell_name
    self.dec_layer = dec_layer
    self.enc_layer = enc_layer
    self.attention = attention
    
    self.hid_size = hid_size
    self.opt = optimizer
    self.lr = lr
    
    self.keep_prob = 1.0 - drop_out

    # EMBEDDING SETUP
    
    self.src_embedding = tf.get_variable(
          "src_emb", [SRC_VOCAB_SIZE, self.hid_size])
    self.trg_embedding = tf.get_variable(
          "trg_emb", [TRG_VOCAB_SIZE, self.hid_size])

      # define variables for softmax layer
    if SHARE_EMB_AND_SOFTMAX:
         self.softmax_weight = tf.transpose(self.trg_embedding)
    else:
         self.softmax_weight = tf.get_variable(
             "weight", [self.hid_size, TRG_VOCAB_SIZE])
    self.softmax_bias = tf.get_variable(
          "softmax_bias", [TRG_VOCAB_SIZE])
     
  # calculate forward graph
  # src_input, src_size, trg_input, trg_label, trg_size are from MakeSrcTrgDataset
  
  def forward(self, src_input, src_size, trg_input, trg_label, trg_size):
      batch_size = tf.shape(src_input)[0]
      
      # *************************
      # **** EMBEDDING SCOPE ****
      # *************************
      
      with tf.variable_scope("Embeddings"):

        # convert word_int input to embeddings
        src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
        trg_emb = tf.nn.embedding_lookup(self.trg_embedding, trg_input)

        # set drop_out rate
        src_emb = tf.nn.dropout(src_emb, self.keep_prob)
        trg_emb = tf.nn.dropout(trg_emb, self.keep_prob)

      # *************************
      # ***** ENCODER SCOPE *****
      # *************************

      with tf.variable_scope("encoder"):
        
        if not 'bi' in self.enc_cell_name:
        
          enc_cell = multi_rnn_cell(self.enc_cell_name, 
                                    self.hid_size, 
                                    self.enc_layer, 
                                    self.keep_prob)
          enc_outputs, enc_state = tf.nn.dynamic_rnn(enc_cell, 
                                                     inputs=src_emb, 
                                                     sequence_length=src_size, 
                                                     dtype=tf.float32) 
        
        else:
          
          stacked_biRNN_fw, stacked_biRNN_bw = multi_biRNN_pair(self.enc_cell_name, 
                                                                self.hid_size, 
                                                                self.enc_layer, 
                                                                self.keep_prob)
          enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = stacked_biRNN_fw,
                                                                   cell_bw = stacked_biRNN_bw,
                                                                   inputs = src_emb,
                                                                   sequence_length = src_size,
                                                                   dtype = tf.float32)
          
          # concatenate two outputs of LSTM cell as 1 tensor
          # enc_outputs = (output_fw, output_bw)
          enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)
          
    
      # *************************
      # ***** DECODER SCOPE *****
      # *************************
      
      with tf.variable_scope("decoder"):
        
        dec_cell = multi_rnn_cell(self.dec_cell_name, self.hid_size, self.dec_layer, self.keep_prob)
    
    
        # OPTIONS FOR ATTENTION MECHANISM
        if self.attention == 'Bahdanau':
        
          attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                  self.hid_size, 
                  enc_outputs,
                  memory_sequence_length = src_size)
          
        if self.attention == 'Luong':

          attention_mechanism = tf.contrib.seq2seq.LuongAttention(
                  self.hid_size,
                  enc_outputs,
                  memory_sequence_length=src_size)

        # ATTENTION WRAPPER: 
        # wrap dec_cell and attention mechanisim
        attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                dec_cell, 
                attention_mechanism,
                attention_layer_size=self.hid_size)

        # use attention_cell and dynamic_rnn construct decoder
        # here relay totally on attention as the information source
        dec_outputs, _ = tf.nn.dynamic_rnn(
                attention_cell, trg_emb, trg_size, dtype=tf.float32)

        
      # ************************
      # ***** OPTIMIZATION *****
      # ************************
      
      # LOSS/LOG PERPLEXITY
      output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
      logits = tf.matmul(output, self.softmax_weight) + self.softmax_bias
      loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
          labels=tf.reshape(trg_label, [-1]), logits=logits)

      # set padding weight as 0 when calc average loss
      label_weights = tf.sequence_mask(
          trg_size, maxlen=tf.shape(trg_label)[1], dtype=tf.float32)
      label_weights = tf.reshape(label_weights, [-1])
      cost = tf.reduce_sum(loss * label_weights)
      cost_per_token = cost / tf.reduce_sum(label_weights)

      # define backprop
      trainable_variables = tf.trainable_variables()

      # OPTIONS FOR OPTIMIZER
      # define optimization method/steps
      grads = tf.gradients(cost / tf.to_float(batch_size),
                           trainable_variables)
      
      grads, _ = tf.clip_by_global_norm(grads, clip_norm = 5)

      if self.opt == 'adam':
        optimizer = tf.train.AdamOptimizer(learning_rate = self.lr)
      
      elif self.opt == 'sgd':        
        optimizer = tf.train.GradientDescentOptimizer(learning_rate = self.lr)
        
      elif self.opt == 'rmsprop':     
        optimizer = tf.train.RMSPropOptimizer(learning_rate = self.lr)
      
      train_op = optimizer.apply_gradients(zip(grads, trainable_variables))
      
      return cost_per_token, train_op

# %% [markdown]
# ### 4.Training

# %%
def run_epoch(session, cost_op, train_op, saver, step):
    while True:
        try:
            # execute train_op and calc loss
            cost, _ = session.run([cost_op, train_op])
            if step % 10 == 0:
                print("After %d steps, per token cost is %.3f" % (step, cost))
            # save checkpoint per 200 steps
            if step % 200 == 0:
                saver.save(session, CHECKPOINT_PATH, global_step=step)
            step += 1
        except tf.errors.OutOfRangeError:
            break
    return step

# %% [markdown]
# #INSTRUCTION-2: SET TRAINING HYPER PARAMETERS
#
# 1. Normally just leave following things as they are, unless changed training dataset or dataset size:
#   * SRC_TRAIN_DATA,
#   * TRG_TRAIN_DATA,
#   * SRC_VOCAB_SIZE
#   * TRG_VOCAB_SIZE
#
# 2. Need to change CHECKPOINT_PATH each time for a training to distinguish different training setting (for easier recording)
#
# 3. Following Prameters can be tuned for research and experiment purpose:
#
#   * HIDDEN_SIZE (# INTEGER)
#   * DECODER_LAYERS (# INTEGER)
#   * DECODER_CELL_TYPE (OPTIONS: 'LSTM', 'GRU', 'BASIC')
#   * ENCODER_LAYERS (# INTEGER)
#   * ENCODER_CELL_TYPE (OPTIONS: 'LSTM', 'GRU', 'BASIC', 'bi-LSTM', 'bi-GRU')
#   * ATTENTION ('Luong', 'Bahdanau')
#   * DROP_OUT (0~1.0)
#   * OPTIMIZER (OPTIONS: 'adam', 'sgd', 'rmsprop')
#   * LEARNING_RATE (0.0001 ~ 0.1)
#   * NUM_EPOCH (#INTEGER: dont' use big number as it consumes time, could keep consistent across all experiments to compare whose loss decreased the most in certain epochs)
#   * BATCH_SIZE (#INTEGER: 32, 64, 128, 256...)
#
#
#   **NOTICE: ALL PARAM NAMES ARE CASE SENSITIVE**

# %%
CHECKPOINT_PATH = "./ckpt-exp08/google-brain-gru-128size"  

HIDDEN_SIZE = 128
DECODER_LAYERS = 4                    # Num_layer for decoder LSTM
DECODER_CELL_TYPE = 'LSTM'
ENCODER_LAYERS = 2
ENCODER_CELL_TYPE = 'bi-LSTM'
ATTENTION = 'Bahdanau'
OPTIMIZER = 'rmsprop'
DROPOUT = 0.2
LEARNING_RATE = 0.001

BATCH_SIZE = 128
NUM_EPOCH = 20


SRC_TRAIN_DATA = "train.en"
TRG_TRAIN_DATA = "train.fr"
SRC_VOCAB_SIZE = vocab_size_src       
TRG_VOCAB_SIZE = vocab_size_tgt 
SHARE_EMB_AND_SOFTMAX = True           # share weights between softmax layer and embedding layer
MAX_LEN = 100   # max length of a sentence
SOS_ID  = 1    # <sos> ID in target vocab

import time
def main():
  
    initializer = tf.random_uniform_initializer(-0.05, 0.05)
    
    tf.reset_default_graph()

    with tf.variable_scope("nmt_model", reuse=None, 
                           initializer=initializer):
        train_model = NMTModel(
                dec_layer = DECODER_LAYERS, 
                enc_layer = ENCODER_LAYERS,
                dec_cell_name =  DECODER_CELL_TYPE,
                enc_cell_name = ENCODER_CELL_TYPE,
                optimizer = OPTIMIZER, 
                lr = LEARNING_RATE,
                hid_size = HIDDEN_SIZE, 
                attention = ATTENTION,
                drop_out = DROPOUT)
  
    # define input data
    data = MakeSrcTrgDataset(SRC_TRAIN_DATA, TRG_TRAIN_DATA, BATCH_SIZE)
    iterator = data.make_initializable_iterator()
    (src, src_size), (trg_input, trg_label, trg_size) = iterator.get_next()
 
    # define forward graph
    cost_op, train_op = train_model.forward(src, src_size, trg_input,
                                            trg_label, trg_size)

    # train
    saver = tf.train.Saver()
    tf.add_to_collection('train_op', train_op)
    tf.add_to_collection('cost_op', cost_op)
    step = 0
    with tf.Session() as sess:
        writer = tf.summary.FileWriter('logs', sess.graph)
        writer.close()
        
        tf.global_variables_initializer().run()
        for i in range(NUM_EPOCH):
            time_start=time.time()
            print("-------In iteration: %d" % (i + 1))
            sess.run(iterator.initializer)
            step = run_epoch(sess, cost_op, train_op, saver, step)
            time_end=time.time()
            print('-------time cost',time_end-time_start,'s')
            print('                                        ')
            
if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-21-c090c396d1f3>:63: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-20-10415cb8d94e>:5: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-20-10415cb8d94e>:49: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-21-c090c396d1f3>:93: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From <ipython-input-21-c090c396d1f3>:159: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# -------In iteration: 1
# After 0 steps, per token cost is 10.468
# After 10 steps, per token cost is 10.465
# After 20 steps, per token cost is 10.462
# After 30 steps, per token cost is 10.458
# After 40 steps, per token cost is 10.452
# After 50 steps, per token cost is 10.443
# After 60 steps, per token cost is 10.433
# After 70 steps, per token cost is 10.405
# After 80 steps, per token cost is 10.262
# After 90 steps, per token cost is 9.143
# After 100 steps, per token cost is 8.072
# After 110 steps, per token cost is 7.518
# After 120 steps, per token cost is 7.221
# After 130 steps, per token cost is 7.130
# After 140 steps, per token cost is 7.164
# After 150 steps, per token cost is 6.988
# After 160 steps, per token cost is 6.806
# After 170 steps, per token cost is 6.848
# After 180 steps, per token cost is 6.882
# After 190 steps, per token cost is 6.793
# After 200 steps, per token cost is 6.896
# After 210 steps, per token cost is 6.880
# After 220 steps, per token cost is 6.919
# After 230 steps, per token cost is 6.763
# After 240 steps, per token cost is 6.812
# After 250 steps, per token cost is 6.810
# After 260 steps, per token cost is 6.716
# After 270 steps, per token cost is 6.819
# After 280 steps, per token cost is 6.754
# After 290 steps, per token cost is 6.781
# After 300 steps, per token cost is 6.749
# After 310 steps, per token cost is 6.624
# After 320 steps, per token cost is 6.842
# After 330 steps, per token cost is 6.809
# After 340 steps, per token cost is 6.799
# After 350 steps, per token cost is 6.833
# After 360 steps, per token cost is 6.657
# After 370 steps, per token cost is 6.748
# After 380 steps, per token cost is 6.727
# After 390 steps, per token cost is 6.659
# -------time cost 158.12584328651428 s
#
# -------In iteration: 2
# After 400 steps, per token cost is 6.764
# After 410 steps, per token cost is 6.738
# After 420 steps, per token cost is 6.834
# After 430 steps, per token cost is 6.659
# After 440 steps, per token cost is 6.827
# After 450 steps, per token cost is 6.644
# After 460 steps, per token cost is 6.656
# After 470 steps, per token cost is 6.485
# After 480 steps, per token cost is 6.505
# After 490 steps, per token cost is 6.665
# After 500 steps, per token cost is 6.693
# After 510 steps, per token cost is 6.694
# After 520 steps, per token cost is 6.629
# After 530 steps, per token cost is 6.661
# After 540 steps, per token cost is 6.636
# After 550 steps, per token cost is 6.429
# After 560 steps, per token cost is 6.533
# After 570 steps, per token cost is 6.262
# After 580 steps, per token cost is 6.294
# After 590 steps, per token cost is 6.407
# After 600 steps, per token cost is 6.339
# After 610 steps, per token cost is 6.280
# After 620 steps, per token cost is 6.248
# After 630 steps, per token cost is 6.409
# After 640 steps, per token cost is 6.140
# After 650 steps, per token cost is 6.292
# After 660 steps, per token cost is 6.186
# After 670 steps, per token cost is 6.254
# After 680 steps, per token cost is 6.285
# After 690 steps, per token cost is 6.248
# After 700 steps, per token cost is 6.246
# After 710 steps, per token cost is 6.146
# After 720 steps, per token cost is 6.203
# After 730 steps, per token cost is 6.072
# After 740 steps, per token cost is 6.098
# After 750 steps, per token cost is 6.274
# After 760 steps, per token cost is 6.122
# After 770 steps, per token cost is 6.100
# After 780 steps, per token cost is 6.120
# -------time cost 157.38603830337524 s
#
# -------In iteration: 3
# After 790 steps, per token cost is 6.058
# After 800 steps, per token cost is 6.201
# After 810 steps, per token cost is 5.991
# After 820 steps, per token cost is 5.893
# After 830 steps, per token cost is 6.148
# After 840 steps, per token cost is 5.838
# After 850 steps, per token cost is 5.894
# After 860 steps, per token cost is 5.927
# After 870 steps, per token cost is 6.052
# After 880 steps, per token cost is 5.777
# After 890 steps, per token cost is 5.852
# After 900 steps, per token cost is 5.944
# After 910 steps, per token cost is 5.758
# After 920 steps, per token cost is 5.856
# After 930 steps, per token cost is 5.906
# After 940 steps, per token cost is 5.855
# After 950 steps, per token cost is 5.948
# After 960 steps, per token cost is 5.789
# After 970 steps, per token cost is 5.720
# After 980 steps, per token cost is 5.890
# After 990 steps, per token cost is 5.790
# After 1000 steps, per token cost is 5.895
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# After 1010 steps, per token cost is 5.823
# After 1020 steps, per token cost is 5.897
# After 1030 steps, per token cost is 5.928
# After 1040 steps, per token cost is 5.787
# After 1050 steps, per token cost is 6.030
# After 1060 steps, per token cost is 6.003
# After 1070 steps, per token cost is 5.963
# After 1080 steps, per token cost is 5.809
# After 1090 steps, per token cost is 5.929
# After 1100 steps, per token cost is 5.798
# After 1110 steps, per token cost is 5.820
# After 1120 steps, per token cost is 5.870
# After 1130 steps, per token cost is 5.983
# After 1140 steps, per token cost is 5.732
# After 1150 steps, per token cost is 5.823
# After 1160 steps, per token cost is 5.811
# After 1170 steps, per token cost is 5.769
# -------time cost 155.98472619056702 s
#
# -------In iteration: 4
# After 1180 steps, per token cost is 5.669
# After 1190 steps, per token cost is 5.863
# After 1200 steps, per token cost is 5.734
# After 1210 steps, per token cost is 5.655
# After 1220 steps, per token cost is 5.644
# After 1230 steps, per token cost is 5.753
# After 1240 steps, per token cost is 5.627
# After 1250 steps, per token cost is 5.685
# After 1260 steps, per token cost is 5.650
# After 1270 steps, per token cost is 5.431
# After 1280 steps, per token cost is 5.531
# After 1290 steps, per token cost is 5.602
# After 1300 steps, per token cost is 5.800
# After 1310 steps, per token cost is 5.711
# After 1320 steps, per token cost is 5.791
# After 1330 steps, per token cost is 5.698
# After 1340 steps, per token cost is 5.526
# After 1350 steps, per token cost is 5.541
# After 1360 steps, per token cost is 5.634
# After 1370 steps, per token cost is 5.605
# After 1380 steps, per token cost is 5.579
# After 1390 steps, per token cost is 5.559
# After 1400 steps, per token cost is 5.445
# After 1410 steps, per token cost is 5.334
# After 1420 steps, per token cost is 5.615
# After 1430 steps, per token cost is 5.631
# After 1440 steps, per token cost is 5.777
# After 1450 steps, per token cost is 5.514
# After 1460 steps, per token cost is 5.667
# After 1470 steps, per token cost is 5.696
# After 1480 steps, per token cost is 5.360
# After 1490 steps, per token cost is 5.514
# After 1500 steps, per token cost is 5.353
# After 1510 steps, per token cost is 5.528
# After 1520 steps, per token cost is 5.275
# After 1530 steps, per token cost is 5.511
# After 1540 steps, per token cost is 5.482
# After 1550 steps, per token cost is 5.454
# After 1560 steps, per token cost is 5.452
# -------time cost 156.47919964790344 s
#
# -------In iteration: 5
# After 1570 steps, per token cost is 5.506
# After 1580 steps, per token cost is 5.403
# After 1590 steps, per token cost is 5.300
# After 1600 steps, per token cost is 5.386
# After 1610 steps, per token cost is 5.399
# After 1620 steps, per token cost is 5.407
# After 1630 steps, per token cost is 5.351
# After 1640 steps, per token cost is 5.335
# After 1650 steps, per token cost is 5.495
# After 1660 steps, per token cost is 5.565
# After 1670 steps, per token cost is 5.382
# After 1680 steps, per token cost is 5.197
# After 1690 steps, per token cost is 5.271
# After 1700 steps, per token cost is 5.324
# After 1710 steps, per token cost is 5.454
# After 1720 steps, per token cost is 5.342
# After 1730 steps, per token cost is 5.451
# After 1740 steps, per token cost is 5.256
# After 1750 steps, per token cost is 5.372
# After 1760 steps, per token cost is 5.284
# After 1770 steps, per token cost is 5.197
# After 1780 steps, per token cost is 5.483
# After 1790 steps, per token cost is 5.352
# After 1800 steps, per token cost is 5.445
# After 1810 steps, per token cost is 5.271
# After 1820 steps, per token cost is 5.416
# After 1830 steps, per token cost is 5.356
# After 1840 steps, per token cost is 5.266
# After 1850 steps, per token cost is 5.290
# After 1860 steps, per token cost is 5.374
# After 1870 steps, per token cost is 5.195
# After 1880 steps, per token cost is 5.468
# After 1890 steps, per token cost is 5.125
# After 1900 steps, per token cost is 5.367
# After 1910 steps, per token cost is 5.226
# After 1920 steps, per token cost is 5.415
# After 1930 steps, per token cost is 5.364
# After 1940 steps, per token cost is 5.117
# After 1950 steps, per token cost is 5.226
# -------time cost 154.55601477622986 s
#
# -------In iteration: 6
# After 1960 steps, per token cost is 5.084
# After 1970 steps, per token cost is 5.421
# After 1980 steps, per token cost is 5.373
# After 1990 steps, per token cost is 4.989
# After 2000 steps, per token cost is 5.127
# After 2010 steps, per token cost is 5.301
# After 2020 steps, per token cost is 5.119
# After 2030 steps, per token cost is 5.321
# After 2040 steps, per token cost is 5.154
# After 2050 steps, per token cost is 5.026
# After 2060 steps, per token cost is 5.367
# After 2070 steps, per token cost is 5.239
# After 2080 steps, per token cost is 5.187
# After 2090 steps, per token cost is 5.136
# After 2100 steps, per token cost is 5.232
# After 2110 steps, per token cost is 5.108
# After 2120 steps, per token cost is 5.284
# After 2130 steps, per token cost is 5.286
# After 2140 steps, per token cost is 5.297
# After 2150 steps, per token cost is 5.078
# After 2160 steps, per token cost is 5.018
# After 2170 steps, per token cost is 5.211
# After 2180 steps, per token cost is 5.246
# After 2190 steps, per token cost is 5.233
# After 2200 steps, per token cost is 5.174
# After 2210 steps, per token cost is 5.144
# After 2220 steps, per token cost is 4.968
# After 2230 steps, per token cost is 5.066
# After 2240 steps, per token cost is 5.194
# After 2250 steps, per token cost is 5.096
# After 2260 steps, per token cost is 5.194
# After 2270 steps, per token cost is 5.245
# After 2280 steps, per token cost is 5.130
# After 2290 steps, per token cost is 5.021
# After 2300 steps, per token cost is 5.055
# After 2310 steps, per token cost is 5.255
# After 2320 steps, per token cost is 5.301
# After 2330 steps, per token cost is 5.083
# After 2340 steps, per token cost is 5.260
# -------time cost 156.97985768318176 s
#
# -------In iteration: 7
# After 2350 steps, per token cost is 5.088
# After 2360 steps, per token cost is 5.060
# After 2370 steps, per token cost is 4.907
# After 2380 steps, per token cost is 4.725
# After 2390 steps, per token cost is 5.062
# After 2400 steps, per token cost is 5.065
# After 2410 steps, per token cost is 4.971
# After 2420 steps, per token cost is 5.159
# After 2430 steps, per token cost is 5.174
# After 2440 steps, per token cost is 4.952
# After 2450 steps, per token cost is 4.828
# After 2460 steps, per token cost is 4.814
# After 2470 steps, per token cost is 5.007
# After 2480 steps, per token cost is 4.952
# After 2490 steps, per token cost is 4.892
# After 2500 steps, per token cost is 5.159
# After 2510 steps, per token cost is 4.830
# After 2520 steps, per token cost is 4.857
# After 2530 steps, per token cost is 4.929
# After 2540 steps, per token cost is 4.801
# After 2550 steps, per token cost is 4.982
# After 2560 steps, per token cost is 5.006
# After 2570 steps, per token cost is 4.908
# After 2580 steps, per token cost is 5.192
# After 2590 steps, per token cost is 5.167
# After 2600 steps, per token cost is 4.991
# After 2610 steps, per token cost is 5.048
# After 2620 steps, per token cost is 4.902
# After 2630 steps, per token cost is 4.855
# After 2640 steps, per token cost is 4.666
# After 2650 steps, per token cost is 4.717
# After 2660 steps, per token cost is 4.947
# After 2670 steps, per token cost is 5.075
# After 2680 steps, per token cost is 5.038
# After 2690 steps, per token cost is 4.919
# After 2700 steps, per token cost is 4.917
# After 2710 steps, per token cost is 5.064
# After 2720 steps, per token cost is 5.182
# After 2730 steps, per token cost is 5.040
# -------time cost 152.95280528068542 s
#
# -------In iteration: 8
# After 2740 steps, per token cost is 4.807
# After 2750 steps, per token cost is 4.789
# After 2760 steps, per token cost is 4.699
# After 2770 steps, per token cost is 4.939
# After 2780 steps, per token cost is 4.991
# After 2790 steps, per token cost is 5.078
# After 2800 steps, per token cost is 5.026
# After 2810 steps, per token cost is 4.936
# After 2820 steps, per token cost is 4.955
# After 2830 steps, per token cost is 5.043
# After 2840 steps, per token cost is 4.794
# After 2850 steps, per token cost is 4.840
# After 2860 steps, per token cost is 4.894
# After 2870 steps, per token cost is 4.904
# After 2880 steps, per token cost is 5.027
# After 2890 steps, per token cost is 4.870
# After 2900 steps, per token cost is 4.841
# After 2910 steps, per token cost is 4.666
# After 2920 steps, per token cost is 4.787
# After 2930 steps, per token cost is 4.839
# After 2940 steps, per token cost is 4.766
# After 2950 steps, per token cost is 4.791
# After 2960 steps, per token cost is 4.949
# After 2970 steps, per token cost is 5.046
# After 2980 steps, per token cost is 4.877
# After 2990 steps, per token cost is 4.713
# After 3000 steps, per token cost is 4.807
# After 3010 steps, per token cost is 4.863
# After 3020 steps, per token cost is 4.791
# After 3030 steps, per token cost is 4.808
# After 3040 steps, per token cost is 4.570
# After 3050 steps, per token cost is 4.900
# After 3060 steps, per token cost is 4.947
# After 3070 steps, per token cost is 4.580
# After 3080 steps, per token cost is 4.625
# After 3090 steps, per token cost is 4.758
# After 3100 steps, per token cost is 4.779
# After 3110 steps, per token cost is 4.773
# After 3120 steps, per token cost is 4.648
# -------time cost 154.62657260894775 s
#
# -------In iteration: 9
# After 3130 steps, per token cost is 4.878
# After 3140 steps, per token cost is 4.878
# After 3150 steps, per token cost is 4.577
# After 3160 steps, per token cost is 4.678
# After 3170 steps, per token cost is 4.819
# After 3180 steps, per token cost is 4.821
# After 3190 steps, per token cost is 4.660
# After 3200 steps, per token cost is 4.754
# After 3210 steps, per token cost is 4.598
# After 3220 steps, per token cost is 4.825
# After 3230 steps, per token cost is 4.606
# After 3240 steps, per token cost is 4.559
# After 3250 steps, per token cost is 4.766
# After 3260 steps, per token cost is 4.666
# After 3270 steps, per token cost is 4.710
# After 3280 steps, per token cost is 4.551
# After 3290 steps, per token cost is 4.940
# After 3300 steps, per token cost is 4.575
# After 3310 steps, per token cost is 4.726
# After 3320 steps, per token cost is 4.860
# After 3330 steps, per token cost is 4.664
# After 3340 steps, per token cost is 4.719
# After 3350 steps, per token cost is 4.754
# After 3360 steps, per token cost is 4.721
# After 3370 steps, per token cost is 4.722
# After 3380 steps, per token cost is 4.628
# After 3390 steps, per token cost is 4.735
# After 3400 steps, per token cost is 4.603
# After 3410 steps, per token cost is 4.659
# After 3420 steps, per token cost is 4.576
# After 3430 steps, per token cost is 4.601
# After 3440 steps, per token cost is 4.583
# After 3450 steps, per token cost is 4.618
# After 3460 steps, per token cost is 4.701
# After 3470 steps, per token cost is 4.641
# After 3480 steps, per token cost is 4.714
# After 3490 steps, per token cost is 4.850
# After 3500 steps, per token cost is 4.843
# After 3510 steps, per token cost is 4.611
# -------time cost 153.61715173721313 s
#
# -------In iteration: 10
# After 3520 steps, per token cost is 4.520
# After 3530 steps, per token cost is 4.602
# After 3540 steps, per token cost is 4.620
# After 3550 steps, per token cost is 4.329
# After 3560 steps, per token cost is 4.665
# After 3570 steps, per token cost is 4.734
# After 3580 steps, per token cost is 4.683
# After 3590 steps, per token cost is 4.375
# After 3600 steps, per token cost is 4.608
# After 3610 steps, per token cost is 4.621
# After 3620 steps, per token cost is 4.692
# After 3630 steps, per token cost is 4.698
# After 3640 steps, per token cost is 4.486
# After 3650 steps, per token cost is 4.580
# After 3660 steps, per token cost is 4.410
# After 3670 steps, per token cost is 4.475
# After 3680 steps, per token cost is 4.384
# After 3690 steps, per token cost is 4.800
# After 3700 steps, per token cost is 4.389
# After 3710 steps, per token cost is 4.629
# After 3720 steps, per token cost is 4.609
# After 3730 steps, per token cost is 4.453
# After 3740 steps, per token cost is 4.474
# After 3750 steps, per token cost is 4.771
# After 3760 steps, per token cost is 4.343
# After 3770 steps, per token cost is 4.605
# After 3780 steps, per token cost is 4.613
# After 3790 steps, per token cost is 4.441
# After 3800 steps, per token cost is 4.898
# After 3810 steps, per token cost is 4.554
# After 3820 steps, per token cost is 4.429
# After 3830 steps, per token cost is 4.372
# After 3840 steps, per token cost is 4.594
# After 3850 steps, per token cost is 4.530
# After 3860 steps, per token cost is 4.523
# After 3870 steps, per token cost is 4.661
# After 3880 steps, per token cost is 4.670
# After 3890 steps, per token cost is 4.444
# After 3900 steps, per token cost is 4.372
# -------time cost 154.03095507621765 s
#
# -------In iteration: 11
# After 3910 steps, per token cost is 4.658
# After 3920 steps, per token cost is 4.610
# After 3930 steps, per token cost is 4.209
# After 3940 steps, per token cost is 4.265
# After 3950 steps, per token cost is 4.356
# After 3960 steps, per token cost is 4.432
# After 3970 steps, per token cost is 4.478
# After 3980 steps, per token cost is 4.522
# After 3990 steps, per token cost is 4.707
# After 4000 steps, per token cost is 4.550
# After 4010 steps, per token cost is 4.537
# After 4020 steps, per token cost is 4.427
# After 4030 steps, per token cost is 4.433
# After 4040 steps, per token cost is 4.460
# After 4050 steps, per token cost is 4.606
# After 4060 steps, per token cost is 4.400
# After 4070 steps, per token cost is 4.493
# After 4080 steps, per token cost is 4.250
# After 4090 steps, per token cost is 4.733
# After 4100 steps, per token cost is 4.120
# After 4110 steps, per token cost is 4.349
# After 4120 steps, per token cost is 4.603
# After 4130 steps, per token cost is 4.739
# After 4140 steps, per token cost is 4.515
# After 4150 steps, per token cost is 4.299
# After 4160 steps, per token cost is 4.223
# After 4170 steps, per token cost is 4.551
# After 4180 steps, per token cost is 4.487
# After 4190 steps, per token cost is 4.366
# After 4200 steps, per token cost is 4.544
# After 4210 steps, per token cost is 4.407
# After 4220 steps, per token cost is 4.695
# After 4230 steps, per token cost is 4.473
# After 4240 steps, per token cost is 4.535
# After 4250 steps, per token cost is 4.700
# After 4260 steps, per token cost is 4.549
# After 4270 steps, per token cost is 4.790
# After 4280 steps, per token cost is 4.473
# After 4290 steps, per token cost is 4.483
# After 4300 steps, per token cost is 4.549
# -------time cost 153.08688354492188 s
#
# -------In iteration: 12
# After 4310 steps, per token cost is 4.435
# After 4320 steps, per token cost is 4.290
# After 4330 steps, per token cost is 4.309
# After 4340 steps, per token cost is 4.583
# After 4350 steps, per token cost is 4.419
# After 4360 steps, per token cost is 4.501
# After 4370 steps, per token cost is 4.622
# After 4380 steps, per token cost is 4.439
# After 4390 steps, per token cost is 4.338
# After 4400 steps, per token cost is 4.348
# After 4410 steps, per token cost is 4.620
# After 4420 steps, per token cost is 4.375
# After 4430 steps, per token cost is 4.234
# After 4440 steps, per token cost is 4.179
# After 4450 steps, per token cost is 4.382
# After 4460 steps, per token cost is 4.282
# After 4470 steps, per token cost is 4.382
# After 4480 steps, per token cost is 4.421
# After 4490 steps, per token cost is 4.359
# After 4500 steps, per token cost is 4.522
# After 4510 steps, per token cost is 4.438
# After 4520 steps, per token cost is 4.423
# After 4530 steps, per token cost is 4.391
# After 4540 steps, per token cost is 4.301
# After 4550 steps, per token cost is 4.373
# After 4560 steps, per token cost is 4.622
# After 4570 steps, per token cost is 4.472
# After 4580 steps, per token cost is 4.446
# After 4590 steps, per token cost is 4.692
# After 4600 steps, per token cost is 4.632
# After 4610 steps, per token cost is 4.243
# After 4620 steps, per token cost is 4.304
# After 4630 steps, per token cost is 4.546
# After 4640 steps, per token cost is 4.112
# After 4650 steps, per token cost is 4.398
# After 4660 steps, per token cost is 4.500
# After 4670 steps, per token cost is 4.312
# After 4680 steps, per token cost is 4.375
# After 4690 steps, per token cost is 4.433
# -------time cost 154.46925973892212 s
#
# -------In iteration: 13
# After 4700 steps, per token cost is 4.504
# After 4710 steps, per token cost is 4.382
# After 4720 steps, per token cost is 4.275
# After 4730 steps, per token cost is 4.160
# After 4740 steps, per token cost is 4.359
# After 4750 steps, per token cost is 4.513
# After 4760 steps, per token cost is 4.326
# After 4770 steps, per token cost is 4.406
# After 4780 steps, per token cost is 4.477
# After 4790 steps, per token cost is 4.463
# After 4800 steps, per token cost is 4.303
# After 4810 steps, per token cost is 4.252
# After 4820 steps, per token cost is 4.280
# After 4830 steps, per token cost is 4.448
# After 4840 steps, per token cost is 4.247
# After 4850 steps, per token cost is 4.261
# After 4860 steps, per token cost is 4.608
# After 4870 steps, per token cost is 4.293
# After 4880 steps, per token cost is 4.269
# After 4890 steps, per token cost is 4.404
# After 4900 steps, per token cost is 4.254
# After 4910 steps, per token cost is 4.232
# After 4920 steps, per token cost is 4.372
# After 4930 steps, per token cost is 4.353
# After 4940 steps, per token cost is 4.348
# After 4950 steps, per token cost is 4.351
# After 4960 steps, per token cost is 4.277
# After 4970 steps, per token cost is 4.243
# After 4980 steps, per token cost is 4.348
# After 4990 steps, per token cost is 4.560
# After 5000 steps, per token cost is 4.509
# After 5010 steps, per token cost is 4.179
# After 5020 steps, per token cost is 4.067
# After 5030 steps, per token cost is 4.299
# After 5040 steps, per token cost is 4.278
# After 5050 steps, per token cost is 4.414
# After 5060 steps, per token cost is 4.595
# After 5070 steps, per token cost is 4.214
# After 5080 steps, per token cost is 4.409
# -------time cost 152.57589411735535 s
#
# -------In iteration: 14
# After 5090 steps, per token cost is 4.223
# After 5100 steps, per token cost is 4.064
# After 5110 steps, per token cost is 4.522
# After 5120 steps, per token cost is 4.301
# After 5130 steps, per token cost is 4.152
# After 5140 steps, per token cost is 4.329
# After 5150 steps, per token cost is 4.286
# After 5160 steps, per token cost is 4.307
# After 5170 steps, per token cost is 4.359
# After 5180 steps, per token cost is 3.855
# After 5190 steps, per token cost is 4.166
# After 5200 steps, per token cost is 4.454
# After 5210 steps, per token cost is 4.193
# After 5220 steps, per token cost is 4.089
# After 5230 steps, per token cost is 4.277
# After 5240 steps, per token cost is 4.608
# After 5250 steps, per token cost is 4.259
# After 5260 steps, per token cost is 4.373
# After 5270 steps, per token cost is 4.298
# After 5280 steps, per token cost is 4.342
# After 5290 steps, per token cost is 4.119
# After 5300 steps, per token cost is 4.076
# After 5310 steps, per token cost is 4.085
# After 5320 steps, per token cost is 4.447
# After 5330 steps, per token cost is 3.986
# After 5340 steps, per token cost is 4.193
# After 5350 steps, per token cost is 4.221
# After 5360 steps, per token cost is 4.110
# After 5370 steps, per token cost is 4.227
# After 5380 steps, per token cost is 4.342
# After 5390 steps, per token cost is 4.130
# After 5400 steps, per token cost is 4.218
# After 5410 steps, per token cost is 4.159
# After 5420 steps, per token cost is 4.276
# After 5430 steps, per token cost is 4.269
# After 5440 steps, per token cost is 4.168
# After 5450 steps, per token cost is 4.490
# After 5460 steps, per token cost is 4.437
# After 5470 steps, per token cost is 4.219
# -------time cost 153.1644515991211 s
#
# -------In iteration: 15
# After 5480 steps, per token cost is 4.139
# After 5490 steps, per token cost is 4.086
# After 5500 steps, per token cost is 4.305
# After 5510 steps, per token cost is 4.530
# After 5520 steps, per token cost is 4.068
# After 5530 steps, per token cost is 4.063
# After 5540 steps, per token cost is 4.139
# After 5550 steps, per token cost is 4.163
# After 5560 steps, per token cost is 4.043
# After 5570 steps, per token cost is 4.243
# After 5580 steps, per token cost is 4.124
# After 5590 steps, per token cost is 4.054
# After 5600 steps, per token cost is 4.044
# After 5610 steps, per token cost is 4.333
# After 5620 steps, per token cost is 4.042
# After 5630 steps, per token cost is 4.209
# After 5640 steps, per token cost is 4.150
# After 5650 steps, per token cost is 4.139
# After 5660 steps, per token cost is 4.047
# After 5670 steps, per token cost is 4.217
# After 5680 steps, per token cost is 4.138
# After 5690 steps, per token cost is 4.189
# After 5700 steps, per token cost is 4.201
# After 5710 steps, per token cost is 4.343
# After 5720 steps, per token cost is 4.345
# After 5730 steps, per token cost is 4.236
# After 5740 steps, per token cost is 4.296
# After 5750 steps, per token cost is 4.247
# After 5760 steps, per token cost is 4.073
# After 5770 steps, per token cost is 4.208
# After 5780 steps, per token cost is 4.361
# After 5790 steps, per token cost is 4.159
# After 5800 steps, per token cost is 4.198
# After 5810 steps, per token cost is 4.148
# After 5820 steps, per token cost is 4.032
# After 5830 steps, per token cost is 4.230
# After 5840 steps, per token cost is 4.312
# After 5850 steps, per token cost is 4.127
# After 5860 steps, per token cost is 4.136
# -------time cost 151.8392562866211 s
#
# -------In iteration: 16
# After 5870 steps, per token cost is 4.126
# After 5880 steps, per token cost is 4.130
# After 5890 steps, per token cost is 4.189
# After 5900 steps, per token cost is 4.040
# After 5910 steps, per token cost is 4.238
# After 5920 steps, per token cost is 4.199
# After 5930 steps, per token cost is 4.076
# After 5940 steps, per token cost is 4.097
# After 5950 steps, per token cost is 4.204
# After 5960 steps, per token cost is 4.172
# After 5970 steps, per token cost is 4.229
# After 5980 steps, per token cost is 4.376
# After 5990 steps, per token cost is 4.250
# After 6000 steps, per token cost is 4.072
# After 6010 steps, per token cost is 3.847
# After 6020 steps, per token cost is 4.004
# After 6030 steps, per token cost is 3.810
# After 6040 steps, per token cost is 4.001
# After 6050 steps, per token cost is 4.074
# After 6060 steps, per token cost is 4.025
# After 6070 steps, per token cost is 4.114
# After 6080 steps, per token cost is 4.073
# After 6090 steps, per token cost is 4.348
# After 6100 steps, per token cost is 4.353
# After 6110 steps, per token cost is 4.073
# After 6120 steps, per token cost is 4.339
# After 6130 steps, per token cost is 4.376
# After 6140 steps, per token cost is 4.006
# After 6150 steps, per token cost is 4.102
# After 6160 steps, per token cost is 4.215
# After 6170 steps, per token cost is 4.120
# After 6180 steps, per token cost is 3.968
# After 6190 steps, per token cost is 4.462
# After 6200 steps, per token cost is 3.882
# After 6210 steps, per token cost is 4.202
# After 6220 steps, per token cost is 4.167
# After 6230 steps, per token cost is 4.189
# After 6240 steps, per token cost is 4.174
# After 6250 steps, per token cost is 4.104
# -------time cost 155.2234330177307 s
#
# -------In iteration: 17
# After 6260 steps, per token cost is 4.128
# After 6270 steps, per token cost is 3.968
# After 6280 steps, per token cost is 4.039
# After 6290 steps, per token cost is 4.078
# After 6300 steps, per token cost is 4.304
# After 6310 steps, per token cost is 4.157
# After 6320 steps, per token cost is 4.095
# After 6330 steps, per token cost is 3.887
# After 6340 steps, per token cost is 4.054
# After 6350 steps, per token cost is 4.146
# After 6360 steps, per token cost is 4.187
# After 6370 steps, per token cost is 4.220
# After 6380 steps, per token cost is 4.195
# After 6390 steps, per token cost is 3.909
# After 6400 steps, per token cost is 4.053
# After 6410 steps, per token cost is 4.064
# After 6420 steps, per token cost is 4.248
# After 6430 steps, per token cost is 4.286
# After 6440 steps, per token cost is 4.063
# After 6450 steps, per token cost is 3.933
# After 6460 steps, per token cost is 4.210
# After 6470 steps, per token cost is 3.917
# After 6480 steps, per token cost is 4.016
# After 6490 steps, per token cost is 3.992
# After 6500 steps, per token cost is 4.107
# After 6510 steps, per token cost is 4.073
# After 6520 steps, per token cost is 4.152
# After 6530 steps, per token cost is 4.325
# After 6540 steps, per token cost is 4.033
# After 6550 steps, per token cost is 4.133
# After 6560 steps, per token cost is 4.148
# After 6570 steps, per token cost is 4.010
# After 6580 steps, per token cost is 4.261
# After 6590 steps, per token cost is 4.112
# After 6600 steps, per token cost is 4.183
# After 6610 steps, per token cost is 4.303
# After 6620 steps, per token cost is 4.032
# After 6630 steps, per token cost is 4.298
# After 6640 steps, per token cost is 4.075
# -------time cost 155.58569049835205 s
#
# -------In iteration: 18
# After 6650 steps, per token cost is 4.095
# After 6660 steps, per token cost is 3.862
# After 6670 steps, per token cost is 4.007
# After 6680 steps, per token cost is 4.035
# After 6690 steps, per token cost is 3.950
# After 6700 steps, per token cost is 3.957
# After 6710 steps, per token cost is 3.966
# After 6720 steps, per token cost is 4.221
# After 6730 steps, per token cost is 4.062
# After 6740 steps, per token cost is 3.953
# After 6750 steps, per token cost is 3.995
# After 6760 steps, per token cost is 3.982
# After 6770 steps, per token cost is 3.895
# After 6780 steps, per token cost is 4.037
# After 6790 steps, per token cost is 4.267
# After 6800 steps, per token cost is 3.993
# After 6810 steps, per token cost is 3.913
# After 6820 steps, per token cost is 4.171
# After 6830 steps, per token cost is 4.036
# After 6840 steps, per token cost is 4.263
# After 6850 steps, per token cost is 3.994
# After 6860 steps, per token cost is 4.337
# After 6870 steps, per token cost is 4.029
# After 6880 steps, per token cost is 3.843
# After 6890 steps, per token cost is 4.096
# After 6900 steps, per token cost is 4.121
# After 6910 steps, per token cost is 3.954
# After 6920 steps, per token cost is 4.243
# After 6930 steps, per token cost is 3.894
# After 6940 steps, per token cost is 4.423
# After 6950 steps, per token cost is 3.995
# After 6960 steps, per token cost is 4.264
# After 6970 steps, per token cost is 4.383
# After 6980 steps, per token cost is 4.167
# After 6990 steps, per token cost is 4.250
# After 7000 steps, per token cost is 3.893
# After 7010 steps, per token cost is 4.081
# After 7020 steps, per token cost is 3.958
# After 7030 steps, per token cost is 4.484
# -------time cost 157.2722041606903 s
#
# -------In iteration: 19
# After 7040 steps, per token cost is 3.897
# After 7050 steps, per token cost is 3.985
# After 7060 steps, per token cost is 4.100
# After 7070 steps, per token cost is 4.120
# After 7080 steps, per token cost is 3.980
# After 7090 steps, per token cost is 3.892
# After 7100 steps, per token cost is 4.001
# After 7110 steps, per token cost is 4.002
# After 7120 steps, per token cost is 3.809
# After 7130 steps, per token cost is 3.842
# After 7140 steps, per token cost is 3.949
# After 7150 steps, per token cost is 4.468
# After 7160 steps, per token cost is 3.754
# After 7170 steps, per token cost is 4.138
# After 7180 steps, per token cost is 4.094
# After 7190 steps, per token cost is 3.923
# After 7200 steps, per token cost is 4.144
# After 7210 steps, per token cost is 3.891
# After 7220 steps, per token cost is 3.902
# After 7230 steps, per token cost is 4.049
# After 7240 steps, per token cost is 4.070
# After 7250 steps, per token cost is 4.131
# After 7260 steps, per token cost is 4.385
# After 7270 steps, per token cost is 3.944
# After 7280 steps, per token cost is 4.092
# After 7290 steps, per token cost is 3.977
# After 7300 steps, per token cost is 3.803
# After 7310 steps, per token cost is 3.943
# After 7320 steps, per token cost is 3.924
# After 7330 steps, per token cost is 3.747
# After 7340 steps, per token cost is 3.904
# After 7350 steps, per token cost is 4.101
# After 7360 steps, per token cost is 4.081
# After 7370 steps, per token cost is 4.168
# After 7380 steps, per token cost is 4.213
# After 7390 steps, per token cost is 4.052
# After 7400 steps, per token cost is 3.931
# After 7410 steps, per token cost is 4.135
# After 7420 steps, per token cost is 4.196
# -------time cost 155.84331965446472 s
#
# -------In iteration: 20
# After 7430 steps, per token cost is 4.073
# After 7440 steps, per token cost is 3.937
# After 7450 steps, per token cost is 4.046
# After 7460 steps, per token cost is 3.906
# After 7470 steps, per token cost is 3.944
# After 7480 steps, per token cost is 3.809
# After 7490 steps, per token cost is 4.028
# After 7500 steps, per token cost is 3.970
# After 7510 steps, per token cost is 3.808
# After 7520 steps, per token cost is 3.923
# After 7530 steps, per token cost is 4.007
# After 7540 steps, per token cost is 3.899
# After 7550 steps, per token cost is 4.005
# After 7560 steps, per token cost is 3.957
# After 7570 steps, per token cost is 4.060
# After 7580 steps, per token cost is 3.768
# After 7590 steps, per token cost is 4.110
# After 7600 steps, per token cost is 3.977
# After 7610 steps, per token cost is 4.004
# After 7620 steps, per token cost is 4.060
# After 7630 steps, per token cost is 4.135
# After 7640 steps, per token cost is 3.999
# After 7650 steps, per token cost is 4.008
# After 7660 steps, per token cost is 3.829
# After 7670 steps, per token cost is 4.102
# After 7680 steps, per token cost is 4.045
# After 7690 steps, per token cost is 3.824
# After 7700 steps, per token cost is 3.911
# After 7710 steps, per token cost is 4.196
# After 7720 steps, per token cost is 4.023
# After 7730 steps, per token cost is 3.972
# After 7740 steps, per token cost is 3.812
# After 7750 steps, per token cost is 3.797
# After 7760 steps, per token cost is 4.098
# After 7770 steps, per token cost is 3.744
# After 7780 steps, per token cost is 3.942
# After 7790 steps, per token cost is 3.761
# After 7800 steps, per token cost is 3.998
# After 7810 steps, per token cost is 4.149
# -------time cost 157.47118282318115 s

# %% [markdown]
# ### 5. Produce Model Structure

# %%
import tensorflow.contrib.slim as slim

def model_summary():
    model_vars = tf.trainable_variables()
    slim.model_analyzer.analyze_vars(model_vars, print_info=True)

model_summary()
# Out:
# ---------
# Variables: name (type shape) [size]
# ---------
# nmt_model/src_emb:0 (float32_ref 28711x128) [3675008, bytes: 14700032]
# nmt_model/trg_emb:0 (float32_ref 35019x128) [4482432, bytes: 17929728]
# nmt_model/softmax_bias:0 (float32_ref 35019) [35019, bytes: 140076]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/kernel:0 (float32 256x512) [131072, bytes: 524288]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/bias:0 (float32 512) [512, bytes: 2048]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/kernel:0 (float32 256x512) [131072, bytes: 524288]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/bias:0 (float32 512) [512, bytes: 2048]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/kernel:0 (float32 256x512) [131072, bytes: 524288]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/bias:0 (float32 512) [512, bytes: 2048]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/kernel:0 (float32 256x512) [131072, bytes: 524288]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/bias:0 (float32 512) [512, bytes: 2048]
# decoder/memory_layer/kernel:0 (float32_ref 256x128) [32768, bytes: 131072]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_0/lstm_cell/kernel:0 (float32 384x512) [196608, bytes: 786432]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_0/lstm_cell/bias:0 (float32 512) [512, bytes: 2048]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_1/lstm_cell/kernel:0 (float32 256x512) [131072, bytes: 524288]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_1/lstm_cell/bias:0 (float32 512) [512, bytes: 2048]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_2/lstm_cell/kernel:0 (float32 256x512) [131072, bytes: 524288]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_2/lstm_cell/bias:0 (float32 512) [512, bytes: 2048]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_3/lstm_cell/kernel:0 (float32 256x512) [131072, bytes: 524288]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_3/lstm_cell/bias:0 (float32 512) [512, bytes: 2048]
# decoder/rnn/attention_wrapper/bahdanau_attention/query_layer/kernel:0 (float32_ref 128x128) [16384, bytes: 65536]
# decoder/rnn/attention_wrapper/bahdanau_attention/attention_v:0 (float32_ref 128) [128, bytes: 512]
# decoder/rnn/attention_wrapper/attention_layer/kernel:0 (float32_ref 384x128) [49152, bytes: 196608]
# Total size of variables: 9409099
# Total bytes of variables: 37636396

# %% [markdown]
# # INSTRUCTION 3 - INFERENCE USING TRAINED MODEL AND WEIGHT

# %% [markdown]
# ### 6.Define Model Structure, Hyper Parameter Used in Training, Inference Function
#
# 1. Need to change LAST_CKPT_PATH every time you train and set it to the latest checkpoint, which is presented by the biggest number in CHECKPOINT_PATH
#
# 2. Keep other parameters as they are in the traning session, no need to change here

# %%
# read checkpoint path, number indicates the latest step
LAST_CKPT_PATH = "ckpt-exp08/google-brain-gru-128size-7800"

# file for vocab
SRC_VOCAB = "vocab.en"
TRG_VOCAB = "vocab.fr"
SRC_VOCAB_SIZE = vocab_size_src       
TRG_VOCAB_SIZE = vocab_size_tgt 

# ID for <sos> and <eos> in vocab
SOS_ID = 1
EOS_ID = 2

SHARE_EMB_AND_SOFTMAX = True

# %%
class NMTModel(object):
  """
  defind the nmt model
  
  """
  # define variables needed by nmt
  def __init__(self, 
               dec_layer = DECODER_LAYERS, 
               enc_layer = ENCODER_LAYERS,
               dec_cell_name = DECODER_CELL_TYPE, 
               enc_cell_name = ENCODER_CELL_TYPE,
               optimizer = OPTIMIZER, 
               lr = LEARNING_RATE,
               hid_size = HIDDEN_SIZE, 
               attention = ATTENTION,
               drop_out = DROPOUT):
    
    self.dec_cell_name = dec_cell_name
    self.enc_cell_name = enc_cell_name
    self.dec_layer = dec_layer
    self.enc_layer = enc_layer
    self.attention = attention
    
    self.hid_size = hid_size
    self.opt = optimizer
    self.lr = lr
    
    self.keep_prob = 1.0 - drop_out

    # EMBEDDING SETUP
    
    self.src_embedding = tf.get_variable(
          "src_emb", [SRC_VOCAB_SIZE, self.hid_size])
    self.trg_embedding = tf.get_variable(
          "trg_emb", [TRG_VOCAB_SIZE, self.hid_size])

      # define variables for softmax layer
    if SHARE_EMB_AND_SOFTMAX:
         self.softmax_weight = tf.transpose(self.trg_embedding)
    else:
         self.softmax_weight = tf.get_variable(
             "weight", [self.hid_size, TRG_VOCAB_SIZE])
    self.softmax_bias = tf.get_variable(
          "softmax_bias", [TRG_VOCAB_SIZE])
  
  def inference(self, src_input):
      # As dynamic rnn requires batch input, 
      # to infer one single sentence, we set batch = 1
      src_size = tf.convert_to_tensor([len(src_input)], dtype=tf.int32)
      src_input = tf.convert_to_tensor([src_input], dtype=tf.int32)
      src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
      
     
      # *************************
      # ***** ENCODER SCOPE *****
      # *************************

      with tf.variable_scope("encoder"):
        
        if not 'bi' in self.enc_cell_name:
        
          enc_cell = multi_rnn_cell(self.enc_cell_name, 
                                    self.hid_size, 
                                    self.enc_layer, 
                                    self.keep_prob)
          enc_outputs, enc_state = tf.nn.dynamic_rnn(enc_cell, 
                                                     inputs=src_emb, 
                                                     sequence_length=src_size, 
                                                     dtype=tf.float32) 
        
        else:
          
          stacked_biRNN_fw, stacked_biRNN_bw = multi_biRNN_pair(self.enc_cell_name, 
                                                                self.hid_size, 
                                                                self.enc_layer, 
                                                                self.keep_prob)
          enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = stacked_biRNN_fw,
                                                                   cell_bw = stacked_biRNN_bw,
                                                                   inputs = src_emb,
                                                                   sequence_length = src_size,
                                                                   dtype = tf.float32)
          
          # concatenate two outputs of LSTM cell as 1 tensor
          # enc_outputs = (output_fw, output_bw)
          enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)
          
    
      # *************************
      # ***** DECODER SCOPE *****
      # *************************
      
      with tf.variable_scope("decoder"):
        
        dec_cell = multi_rnn_cell(self.dec_cell_name, self.hid_size, self.dec_layer, self.keep_prob)
    
    
        # OPTIONS FOR ATTENTION MECHANISM
        if self.attention == 'Bahdanau':
        
          attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                  self.hid_size, 
                  enc_outputs,
                  memory_sequence_length = src_size)
          
        if self.attention == 'Luong':

          attention_mechanism = tf.contrib.seq2seq.LuongAttention(
                  self.hid_size,
                  enc_outputs,
                  memory_sequence_length=src_size
                  )

        # ATTENTION WRAPPER: 
        # wrap dec_cell and attention mechanisim
        attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                dec_cell, 
                attention_mechanism,
                attention_layer_size=self.hid_size,
                alignment_history=True)

      # Set the max step for decoder
      MAX_DEC_LEN=100

      with tf.variable_scope("decoder/rnn/attention_wrapper"):
        # use TensorArray store produced sentence
        init_array = tf.TensorArray(dtype=tf.int32, size=0,
            dynamic_size=True, clear_after_read=False)
        # start input for decoder with <sos> tag
        init_array = init_array.write(0, SOS_ID)
        # initilize attention cell
        init_loop_var = (
            attention_cell.zero_state(batch_size=1, dtype=tf.float32),
            init_array, 0)

        # condition for tf.while_loop：
        # loop until decoder outputs <eos> or hit max length setting
#         def continue_loop_condition(state, trg_ids, step):
#             return tf.reduce_all(tf.logical_and(
#                 tf.not_equal(trg_ids.read(step), EOS_ID),
#                 tf.less(step, MAX_DEC_LEN-1),
#                 tf.not_equal(trg_ids.read(step), trg_ids.read(step-1))))
          
        def continue_loop_condition(state, trg_ids, step):
            return tf.reduce_all(tf.logical_and(
                tf.not_equal(trg_ids.read(step), EOS_ID),
                tf.less(step, MAX_DEC_LEN-1)))

        def loop_body(state, trg_ids, step):
          
            # read last step output as input for attention cell
            trg_input = [trg_ids.read(step)]
            trg_emb = tf.nn.embedding_lookup(self.trg_embedding,
                                             trg_input)
            # FORWARD calc ATTENTION CELL and output decoder outputs/state
            dec_outputs, next_state = attention_cell.call(
                state=state, inputs=trg_emb)
            
            # calc logit for each candidate target vocab
            # select the max as output
            output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
            logits = (tf.matmul(output, self.softmax_weight)
                      + self.softmax_bias)
            next_id = tf.argmax(logits, axis=1, output_type=tf.int32)
            # write output word into trg_ids
            trg_ids = trg_ids.write(step+1, next_id[0])
            return next_state, trg_ids, step+1

        # execute tf.while_loop return trg_ides
        state, trg_ids, step = tf.while_loop(
            continue_loop_condition, loop_body, init_loop_var)
        
        return trg_ids.stack(), state

# %% [markdown]
# ### 7. Test and Evaluate

# %%
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu

def levenshtein(seq1, seq2):  
    size_x = len(seq1) + 1
    size_y = len(seq2) + 1
    matrix = np.zeros ((size_x, size_y))
    for x in range(size_x):
        matrix [x, 0] = x
    for y in range(size_y):
        matrix [0, y] = y

    for x in range(1, size_x):
        for y in range(1, size_y):
            if seq1[x-1] == seq2[y-1]:
                matrix [x,y] = min(
                    matrix[x-1, y] + 1,
                    matrix[x-1, y-1],
                    matrix[x, y-1] + 1
                )
            else:
                matrix [x,y] = min(
                    matrix[x-1,y] + 1,
                    matrix[x-1,y-1] + 1,
                    matrix[x,y-1] + 1
                )

    return matrix[size_x - 1, size_y - 1]

def translate_en_fr(src_sent, trgt_sent, plot_att = False, verbose = False):
    
    tf.reset_default_graph()
        
    # define the trained model
    with tf.variable_scope("nmt_model", reuse=None):
        model = NMTModel()
       
    # convert sentence to word_index according to vocab
    with codecs.open(SRC_VOCAB, "r", "utf-8") as f_vocab:
        src_vocab = [w.strip() for w in f_vocab.readlines()]
        src_id_dict = dict((src_vocab[x], x) for x in range(len(src_vocab)))
    test_en_ids = [(src_id_dict[token] if token in src_id_dict else src_id_dict['<unk>'])
                   for token in src_sent.split()]
    print('target sentence id: {}'.format(test_en_ids))

    # build inference based on saved model weights
    output_op, state_op = model.inference(test_en_ids)
    sess = tf.Session()
    saver = tf.train.Saver()
    saver.restore(sess, LAST_CKPT_PATH)

    # read translation output
    output_ids = sess.run(output_op)
    print('target sentence id: {}'.format(output_ids))
    
    # convert translation idx into word
    with codecs.open(TRG_VOCAB, "r", "utf-8") as f_vocab:
        trg_vocab = [w.strip() for w in f_vocab.readlines()]
    output_text = ' '.join([trg_vocab[x] for x in output_ids])
    
    # output translation
    final_output_text = output_text.encode('utf8').decode(sys.stdout.encoding).strip('<eos>')
    
    bleu = sentence_bleu(trgt_sent.split(), final_output_text.split())
    lst = levenshtein(trgt_sent,final_output_text)
    
    if verbose:
      print("Source Sentence: " + src_sent)
      print("Real Translation: " + trgt_sent)
      print("Predicted Translation: " + final_output_text)
      print("Levenshetein Distance: " + str(lst))
      print("***BLEU Score***: "+ str(bleu))
    
    
    # PLOT ATTENTION PLOT OPTION
    
    def plot_attention(attention, src_sent, pred_sent):

      fig = plt.figure(figsize=(10,10))
      ax = fig.add_subplot(1, 1, 1)
      ax.matshow(attention, cmap='viridis')

      fontdict = {'fontsize': 14}
      
      ax.set_xticks(np.arange(len(list(src_sent.split()))))
      ax.set_yticks(np.arange(len(list(pred_sent.split()))))

      ax.set_xticklabels([''] + list(src_sent.split()), fontdict=fontdict, rotation=90)
      ax.set_yticklabels([''] + list(pred_sent.split()), fontdict=fontdict)

      plt.show()
      
    if plot_att:
      alignments = sess.run(state_op.alignment_history.stack())
      alignments = np.squeeze(alignments)
      plot_attention(alignments, src_sent, final_output_text)
      
    return final_output_text, bleu, lst
    
    sess.close()

# %%
# prediction for total test set

def test_set_pred(src_test, tgt_test, verbose = False):
  src_test = src_test
  tgt_test = tgt_test
 
  size = len(src_test)
  
  pred_list = []
  bleu_list = []
  lst_list = []

  for i in range(size):

      pred, bleu, lst = translate_en_fr(src_test[i], tgt_test[i], verbose = verbose)
      print("                                                                                         ")
      pred_list.append(pred)
      bleu_list.append(bleu)
      lst_list.append(lst)
      
      
  c_bleu = sum(bleu_list) / len(bleu_list)
  c_lst = sum(lst_list) / len(lst_list)  
   
  print("                                                                                         ")
  print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
  print("Prediction Output and Metrics on {} test sentences: ".format(size))
  print("Average BLEU Score on our test corpus is {}".format(c_bleu)) 
  print("Average Levenshetein distance Score on our test corpus is {}".format(c_lst))

# %% [markdown]
# ### 3. Test

# %%
src_sent = 'comment on the misappropriation of bibliographical references in science . the example of anti aging medicine'
tgt_sent = 'du detournement des references bibliographiques en science . l exemple de la medecine anti age '


translate_en_fr(src_sent,
                tgt_sent, 
                verbose = True,
                plot_att = True)
# Out:
# target sentence id: [1805, 16, 5, 15332, 4, 11235, 6853, 6, 939, 12, 5, 363, 4, 197, 454, 61]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   15  132   27    5 1872    8  126  413   12 1410   19    7  238
#     4    5   53  146    4    5   53    8    5   53    4    5   53    4
#     5   53    4    5   53    4    5   39    2]
# Source Sentence: comment on the misappropriation of bibliographical references in science . the example of anti aging medicine
# Real Translation: du detournement des references bibliographiques en science . l exemple de la medecine anti age
# Predicted Translation:  le point sur la comprehension des personnes partum en science . l exemple de la medecine anti de la medecine des la medecine de la medecine de la medecine de la medecine de la sante
# Levenshetein Distance: 121.0
# ***BLEU Score***: 0.488923022434901
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# (' le point sur la comprehension des personnes partum en science . l exemple de la medecine anti de la medecine des la medecine de la medecine de la medecine de la medecine de la sante ',
#  0.488923022434901,
#  121.0)

# %%
test_set_pred(src_test, tgt_test, verbose = True)
# Out:
# target sentence id: [171, 262, 4, 61, 6, 4303]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1 112   4   5 112  12 112   4   5  53  12  53   4   5 101  12   2]
# Source Sentence:  current state of medicine in spain
# Real Translation:  etat actuel de la medecine en espagne
# Predicted Translation:  etat de la etat en etat de la medecine en medecine de la hopital en
# Levenshetein Distance: 36.0
# ***BLEU Score***: 0
#
# target sentence id: [204, 11, 5, 29, 4, 1201, 4, 5, 2573]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1 887  10   7  32   8 531   4   5 257   8 642   4   5 257   4   5 257
#    4   5 161   2]
# Source Sentence:  contribution to the study of accidents of the teeth
# Real Translation:  contribution a l etude des accidents de la dentition
# Predicted Translation:  contribution a l etude des accidents de la biologie des tissus de la biologie de la biologie de la face
# Levenshetein Distance: 54.0
# ***BLEU Score***: 0.5623413251903491
#
# target sentence id: [47, 4, 3961, 67]
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   47    8   77  206    4   77  206    4    5   36    4   77  206
#     4    5   36    4 2665    2]
# Source Sentence:  surgery of periodontal diseases
# Real Translation:  la chirurgie des parodontolyses
# Predicted Translation:  chirurgie des maladies atteints de maladies atteints de la maladie de maladies atteints de la maladie de chagas
# Levenshetein Distance: 92.0
# ***BLEU Score***: 0
#
# target sentence id: [3718, 3, 3, 4, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   5 180   4   5 738   4   5 989   4   5 136   4   5 961   2]
# Source Sentence:  die peripheren durchblutungsstorungen of paradentiums
# Real Translation:  die peripheren durchblutungsstorungen des paradentiums
# Predicted Translation:  la histoire de la toujours de la grande de la voie de la proteine
# Levenshetein Distance: 52.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 7964, 91, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   5  47 355   4   5  47   8  61   4   5  47 355   4   5  47 355   4
#   47   2]
# Source Sentence:  the beginnings surgical alginates
# Real Translation:  les premices chirurgicales des alginates
# Predicted Translation:  la chirurgie chirurgicale de la chirurgie des sein de la chirurgie chirurgicale de la chirurgie chirurgicale de chirurgie
# Levenshetein Distance: 94.0
# ***BLEU Score***: 0
#
# target sentence id: [1001, 4915, 4, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1    5 2483  433    4    5   72    2]
# Source Sentence:  endocrine glands of cephalopods
# Real Translation:  les glandes endocrines des cephalopodes
# Predicted Translation:  la oeil congenitale de la adulte
# Levenshetein Distance: 29.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 2044, 3449, 7, 123]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1    7 2376    6   15  148    4    5  148    6    4    5  148   19
#     4    5  148    4    7   86    6   15  148    4    7  148    6   15
#   148    4    7   86    6    4    7   86    6   15   98    6   15   98
#     6   15  148    4    7   60    6    4    7   86    6    4    7   60
#     6   15   98   19   15   98    6   15   98    6   15  511    4    7
#    60    2]
# Source Sentence:  the mediterranean climate and tuberculosis
# Real Translation:  le climat mediterraneen et les tuberculoses
# Predicted Translation:  l internat et le tuberculose de la tuberculose et de la tuberculose . de la tuberculose de l grossesse et le tuberculose de l tuberculose et le tuberculose de l grossesse et de l grossesse et le vih et le vih et le tuberculose de l litterature et de l grossesse et de l litterature et le vih . le vih et le vih et le poumon de l litterature
# Levenshetein Distance: 304.0
# ***BLEU Score***: 0.345720784641941
#
# target sentence id: [209, 7, 1896, 4, 3, 9, 3, 780, 12, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  180    6 2452    8  191    4    5 1004   17    4    7  313   19
#     4    7   72    2]
# Source Sentence:  history and pharmacology of balsamite , tanacetum l . balsamita
# Real Translation:  histoire et pharmacologie de la balsamite , tanacetum balsamita l
# Predicted Translation:  histoire et pharmacologie des femmes de la tete , de l adolescent . de l adulte
# Levenshetein Distance: 37.0
# ***BLEU Score***: 0.5946035575013605
#
# target sentence id: [1490, 19, 4, 170, 54, 76]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  30   4   5 170 166   4   5 170 166  10   5  86  10   5  86   4   5
#   86  10   5  86   4   5  86   4   5  86   2]
# Source Sentence:  modern treatment of hypertension during pregnancy
# Real Translation:  les traitements modernes de l hypertension arterielle au cours de la grossesse
# Predicted Translation:  traitement de la hypertension arterielle de la hypertension arterielle a la grossesse a la grossesse de la grossesse a la grossesse de la grossesse de la grossesse
# Levenshetein Distance: 101.0
# ***BLEU Score***: 0.4386913376508308
#
# target sentence id: [952, 7, 617, 680, 8, 12456, 9865, 27376]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  353  862    6   86   13  353    9   13   36    4    5   36    4
#  1303    9   13  134    4    5  134    9   13  134  862    9   16   35
#     4    5  134  862    2]
# Source Sentence:  rapid and short form a crown acrylic jacket
# Real Translation:  execution rapide et simplifee d une couronne jaquette en acrylique
# Predicted Translation:  forme rapide et grossesse une forme d une maladie de la maladie de substance d une association de la association d une association rapide d un syndrome de la association rapide
# Levenshetein Distance: 135.0
# ***BLEU Score***: 0.42379865741502165
#
# target sentence id: [5, 3, 43, 25, 7059, 3, 3, 9]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  15  35   4   5  36   4   5  36   4   5 748   4   7  36   4   5  36
#   12  29   4   7  36   4   5  36   4 953   2]
# Source Sentence:  the darmous or disease hairy charnot speder ,
# Real Translation:  le darmous ou maladie de velu charnot speder ,
# Predicted Translation:  le syndrome de la maladie de la maladie de la intestin de l maladie de la maladie en charge de l maladie de la maladie de behcet
# Levenshetein Distance: 97.0
# ***BLEU Score***: 0.4386913376508308
#
# target sentence id: [30, 1920, 4, 114, 2013, 4933]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1 130 130 180   8 318   4   7 748   2]
# Source Sentence:  new synthesis of diagnostic maxillofacial orthopedics
# Real Translation:  nouvelle synthese du diagnostic en orthopedie maxillo faciale
# Predicted Translation:  nouvelles nouvelles histoire des douleurs de l intestin
# Levenshetein Distance: 42.0
# ***BLEU Score***: 0.5946035575013605
#
# target sentence id: [295, 4, 9466, 6, 1337]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   69    4    5   28   12   29    4    5 1586   10    5   36    4
#     5 1586   10    5 1586    4    5   36    4    5   60    4    7 1586
#     4    5 1586    4    5 1586    4    7 1586    4    7 1586    4    7
#  1586    4    5 1586    4    7   34    4    5   36    4    5 1586    2]
# Source Sentence:  value of penicillin in syphilis
# Real Translation:  valeur de la penicilline dans la syphilis
# Predicted Translation:  interet de la prise en charge de la preeclampsie a la maladie de la preeclampsie a la preeclampsie de la maladie de la litterature de l preeclampsie de la preeclampsie de la preeclampsie de l preeclampsie de l preeclampsie de l preeclampsie de la preeclampsie de l enfant de la maladie de la preeclampsie
# Levenshetein Distance: 270.0
# ***BLEU Score***: 0.4854917717073234
#
# target sentence id: [1288, 1299, 19, 4, 1337, 14, 9466, 26333, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   30    4    5   28   12   29    4    5 1455   10    5 1455   10
#     5 1455    2]
# Source Sentence:  massive mixed treatment of syphilis with penicillin bismuth arsenobenzols
# Real Translation:  traitement mixte massif de la syphilis par penicilline arsenobenzols bismuth
# Predicted Translation:  traitement de la prise en charge de la syphilis a la syphilis a la syphilis
# Levenshetein Distance: 47.0
# ***BLEU Score***: 0.5081327481546147
#
# target sentence id: [171, 339, 4, 9466, 53, 6, 124, 1337]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  112    4    5   28   12   29 1258    4    5   28   12   29    4
#     5 1455  215   18    5 1455    4    5 1455    4    5 1455    2]
# Source Sentence:  current status of penicillin therapy in early syphilis
# Real Translation:  statut actuel de la therapie par penicilline dans la syphilis primaire
# Predicted Translation:  etat de la prise en charge actuelle de la prise en charge de la syphilis precoce dans la syphilis de la syphilis de la syphilis
# Levenshetein Distance: 80.0
# ***BLEU Score***: 0
#
# target sentence id: [16, 5, 1798, 4, 5, 586, 4, 9466, 3, 2400]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  27   5 515   4   7  28   4   7 157   8 126  85   4   7  85   4   7
#   85   2]
# Source Sentence:  on the mechanism of the action of penicillin treponemicidal humans
# Real Translation:  sur le mecanisme de l action treponemicide de la penicilline chez l homme
# Predicted Translation:  sur la action de l prise de l douleur des personnes age de l age de l age
# Levenshetein Distance: 50.0
# ***BLEU Score***: 0.5773502691896257
#
# target sentence id: [9466, 6, 5, 19, 4, 1337]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   15   30    4    5   28   12   29    4    5 1455    4    5 1455
#    10    5 1455    4    5   28   12   29    4    5 1455   10    5 1455
#    10    5   28   12   29    8   30    4    5   60    4    5 1455   18
#    15   30    4    5   60    4    5   60    2]
# Source Sentence:  penicillin in the treatment of syphilis
# Real Translation:  la penicilline dans le traitement de la syphilis
# Predicted Translation:  le traitement de la prise en charge de la syphilis de la syphilis a la syphilis de la prise en charge de la syphilis a la syphilis a la prise en charge des traitement de la litterature de la syphilis dans le traitement de la litterature de la litterature
# Levenshetein Distance: 208.0
# ***BLEU Score***: 0.3779644730092272
#
# target sentence id: [5, 295, 4, 9466, 6, 5, 19, 4, 1337]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   69    4    5  116   12   29    4    5 1455   18   15   30    4
#     5 1455    4    5 1455   10    5 1455    4    5 1455   18    5   28
#     4    5   60    4    5 1455    4    5 1455    4    5 1455    4    5
#  1455    4    5 1455    4    5 1455    4    5 1455    4    5 1455    4
#     5   34    4    5 1455   69    4    5   60    4    5 1455    4    7
#  1455    4    5 1455    4    5   60    4    5 1455    4    5 1455    4
#     5 1455    4    5 1455   69    4    5   60    4    5 1455    4    5
#  1455    4]
# Source Sentence:  the value of penicillin in the treatment of syphilis
# Real Translation:  de la valeur de la penicilline dans le traitement de la syphilis
# Predicted Translation:  interet de la mise en charge de la syphilis dans le traitement de la syphilis de la syphilis a la syphilis de la syphilis dans la prise de la litterature de la syphilis de la syphilis de la syphilis de la syphilis de la syphilis de la syphilis de la syphilis de la syphilis de la enfant de la syphilis interet de la litterature de la syphilis de l syphilis de la syphilis de la litterature de la syphilis de la syphilis de la syphilis de la syphilis interet de la litterature de la syphilis de la syphilis d
# Levenshetein Distance: 448.0
# ***BLEU Score***: 0.4172261448611506
#
# target sentence id: [12939, 192, 450, 948, 6, 397, 9, 48, 8, 17]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   7 653 547 433   4   7  34  17  10  26   9  16  24   2]
# Source Sentence:  he congenital intestinal obstruction in infants , about a case
# Real Translation:  l occlusion intestinale congenitale du nourrisson a propos d un cas
# Predicted Translation:  l occlusion intestinale congenitale de l enfant , a propos d un cas
# Levenshetein Distance: 11.0
# ***BLEU Score***: 0.6930977286178778
#
# target sentence id: [25479, 2572, 1265, 42]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  46   4   5 688   4   5 138  18   5  28  12  29   4   5 138  10   5
#   79   4   5 138   4   5 138   2]
# Source Sentence:  anencephalic fetus radiological diagnosis
# Real Translation:  foetus anencephale diagnostic radiologique
# Predicted Translation:  diagnostic de la examen de la prostate dans la prise en charge de la prostate a la analyse de la prostate de la prostate
# Levenshetein Distance: 95.0
# ***BLEU Score***: 0.4518010018049224
#
# target sentence id: [9466, 7, 21156]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  116   12   29    6    5 1410    4    5  914    6    4    5 1624
#     4    5  161    6    4    5  161    6    4    5  313    6    8  510
#     4    5  134    4    5   60    6    4    5  313    6    4    5  313
#     6    6    6    6    6    6    6    2]
# Source Sentence:  penicillin and diphtheria
# Real Translation:  penicilline et diphterie
# Predicted Translation:  mise en charge et la science de la europe et de la epreuve de la face et de la face et de la adolescent et des vieillissement de la association de la litterature et de la adolescent et de la adolescent et et et et et et et
# Levenshetein Distance: 204.0
# ***BLEU Score***: 0
#
# target sentence id: [3, 3, 240, 6, 7106, 4, 6382]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   69    4    5 1019   10    5  116   12   29    8   37    4    5
#   136    4    5  136    4    5  136    4    5  136    4    5  136    4
#     5   60    2]
# Source Sentence:  cardiography preoperatively interest in tetralogy of fallot
# Real Translation:  interet de la cardiographie preoperatoire dans la tetralogie de fallot
# Predicted Translation:  interet de la veine a la mise en charge des patients de la voie de la voie de la voie de la voie de la voie de la litterature
# Levenshetein Distance: 81.0
# ***BLEU Score***: 0.43092381945890607
#
# target sentence id: [8, 17, 4, 3181, 26, 25]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   13   36    4 1581   10   26    9   16   24    4   36    4    5
#    36    4 1568    2]
# Source Sentence:  a case of cushing s disease
# Real Translation:  un cas de maladie de cushing
# Predicted Translation:  une maladie de hodgkin a propos d un cas de maladie de la maladie de horton
# Levenshetein Distance: 53.0
# ***BLEU Score***: 0.5946035575013605
#
# target sentence id: [48, 6177, 4125, 12906]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  10  26   4   5 257   4   7 257   4   7 257   4   7 257   4   7 257
#    4   7 257   4   7 257   4   7  34   2]
# Source Sentence:  about gastroduodenal radiography interesting
# Real Translation:  a propos de radiographies interessantes gastro duodenales
# Predicted Translation:  a propos de la biologie de l biologie de l biologie de l biologie de l biologie de l biologie de l biologie de l enfant
# Levenshetein Distance: 87.0
# ***BLEU Score***: 0.5266403878479265
#
# target sentence id: [11924, 42, 4, 452, 417, 21, 19705, 4169]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  46   4   5 312  11 652  25 312   4   7 312   4   7 312   4   7 312
#    4   7 312   4   7  60  25   7  28   4   7 312   4   7 312  11 652   2]
# Source Sentence:  topographic diagnosis of myocardial infarction by unipolar leads
# Real Translation:  le diagnostic topographique des infarctus du myocarde par les derivations unipolaires
# Predicted Translation:  diagnostic de la infarctus du myocarde par infarctus de l infarctus de l infarctus de l infarctus de l infarctus de l litterature par l prise de l infarctus de l infarctus du myocarde
# Levenshetein Distance: 128.0
# ***BLEU Score***: 0.41412387656655203
#
# target sentence id: [171, 3679, 16, 5, 19, 4, 123, 21, 23720]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1 1048   27   15   30    4    5  148   25    5  148   25    5  248
#     4    5  148    2]
# Source Sentence:  current views on the treatment of tuberculosis by streptomycin
# Real Translation:  vues actuelles sur le traitement de la tuberculose par la streptomycin
# Predicted Translation:  actualite sur le traitement de la tuberculose par la tuberculose par la region de la tuberculose
# Levenshetein Distance: 47.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  15  24   4   5 397   4   7  34   2]
# Source Sentence:  the dyspraxias
# Real Translation:  les dyspraxies
# Predicted Translation:  le cas de la article de l enfant
# Levenshetein Distance: 24.0
# ***BLEU Score***: 0.4630777161991027
#
# target sentence id: [1372, 9484]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1 1393    9   13  801   10    7  161    2]
# Source Sentence:  hypersensitivity phenomena
# Real Translation:  les phenomenes d hypersensibilite
# Predicted Translation:  hypersensibilite d une autre a l face
# Levenshetein Distance: 30.0
# ***BLEU Score***: 0.476273899703797
#
# target sentence id: [16, 852, 30, 3, 6, 1619, 258]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  27   5 119  12 119  12 119  12  12  28  12  29   8  90  12 398   2]
# Source Sentence:  on some new acquisitions in neuro psychiatry
# Real Translation:  sur quelques acquisitions nouvelles en neuro psychiatrie
# Predicted Translation:  sur la nouvelle en nouvelle en nouvelle en en prise en charge des nouveau en cancerologie
# Levenshetein Distance: 59.0
# ***BLEU Score***: 0
#
# target sentence id: [1246, 140, 1539, 3, 698, 152, 3, 145]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  14 424   4   5  34  12 200   2]
# Source Sentence:  infantile post measles encephalopathic syndromes their multietiologic aspects
# Real Translation:  syndromes encephalopathiques post morbilleux infantiles leurs aspects polyetiologiques
# Predicted Translation:  les syndromes de la enfant en observation
# Levenshetein Distance: 63.0
# ***BLEU Score***: 0
#
# target sentence id: [48, 5, 1964, 4, 8, 682, 285, 11475, 5, 1259, 1101, 302, 3, 5, 1101, 3378, 8736]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   10   26    4    5  153   11 1283    4  458   99  168   15 1333
#  1333  168 1333   15 1333    4    5 1333    2]
# Source Sentence:  about the removal of a large cyst invading the maxillary sinus without damaging the sinus mucosa plasty
# Real Translation:  a propos de l exerese d un gros kyste envahissant le sinus maxillaire sans leser la muqueuse sinusale plastie
# Predicted Translation:  a propos de la approche du kystes de grand n sans le sinus sinus sans sinus le sinus de la sinus
# Levenshetein Distance: 56.0
# ***BLEU Score***: 0.5555238068023582
#
# target sentence id: [8, 17, 4, 325, 9876, 21, 4926, 4, 433, 3, 10013]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   24    4    5  408    4    7  408   25   13   28   12   29    4
#     5 2246    4    5 2246    4    5   72    2]
# Source Sentence:  a case of facial paresis by inclusion of lower premolar ectopia
# Real Translation:  a propos d un cas de paresie faciale par inclusion de premolaire inferieure en ectopie
# Predicted Translation:  cas de la artere de l artere par une prise en charge de la vesicule de la vesicule de la adulte
# Levenshetein Distance: 66.0
# ***BLEU Score***: 0.4671379777282001
#
# target sentence id: [4508, 26302, 102, 585, 3, 808, 6, 3208]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  15 283   4   5 153   4   5 348 222  12  53   4   7 113   4   5 348
#    2]
# Source Sentence:  microbial antagonism general recent acquisitions applications in dentistry
# Real Translation:  de l antagonisme microbien generalites acquisitions recentes applications a la medecine dentaire
# Predicted Translation:  le trouble de la approche de la prescription generale en medecine de l utilisation de la prescription
# Levenshetein Distance: 73.0
# ***BLEU Score***: 0.4924790605054523
#
# target sentence id: [15235, 29, 4, 5, 1375, 4, 7920, 10673, 6, 3711, 468, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   32    4    5 1184    4    5  384    4    5   36   12   29    4
#     5  136    8  652    2]
# Source Sentence:  histochemical study of the localization of alkaline phosphatase in rat dental blanks
# Real Translation:  etude histochimique de la localisation des phosphatases alcalines dans les ebauches dentaires du rat
# Predicted Translation:  etude de la institut de la localisation de la maladie en charge de la voie des myocarde
# Levenshetein Distance: 55.0
# ***BLEU Score***: 0
#
# target sentence id: [678, 14, 6754, 3976, 3835, 2934, 2506, 53]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1 690  25   5 110   4   5 110   4   5 110   4   5 110   4   5 110   4
#    5 110  11 807   4   5 136   4   5 110   4   5  72   2]
# Source Sentence:  analgesia with nitrous oxide aseptic root canal therapy
# Real Translation:  analgesie au protoxyde d azote therapie radiculaire aseptique
# Predicted Translation:  analgesie par la radiotherapie de la radiotherapie de la radiotherapie de la radiotherapie de la radiotherapie de la radiotherapie du muscle de la voie de la radiotherapie de la adulte
# Levenshetein Distance: 134.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 90, 4, 5, 2296, 27615, 2420, 4, 4260, 2573]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  114    4    7 1880    8   37    4    5  161    8  811    4    5
#   970    8  988    4    5  101    2]
# Source Sentence:  the infection of the peri coronal space of impacted teeth
# Real Translation:  l infection de l espace peri coronaire des dents incluses
# Predicted Translation:  infection de l atelier des patients de la face des proteines de la procreation des recepteurs de la hopital
# Levenshetein Distance: 69.0
# ***BLEU Score***: 0.47897362544357464
#
# target sentence id: [547, 29, 4, 1125, 502, 4, 4125, 4, 5, 2157, 752]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   32  755    4    5  796    8  839    4    5 1387    4    5  973
#     2]
# Source Sentence:  critical study of various methods of radiography of the temporomandibular joint
# Real Translation:  etude critique des diverses methodes de radiographie de l articulation temporo maxillaire
# Predicted Translation:  etude critique de la methodes des genou de la plaque de la hanche
# Levenshetein Distance: 45.0
# ***BLEU Score***: 0
#
# target sentence id: [3961, 25, 7, 2151]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   36    4 2665    6   30    4    5   28   12   29    4    5   36
#     4  850    6    4    5   28   12   29    4    5   36    4  850    2]
# Source Sentence:  periodontal disease and cure
# Real Translation:  parodontose et cure thermale
# Predicted Translation:  maladie de chagas et traitement de la prise en charge de la maladie de parkinson et de la prise en charge de la maladie de parkinson
# Levenshetein Distance: 112.0
# ***BLEU Score***: 0
#
# target sentence id: [3908, 4, 2178, 628, 24516, 40, 545, 9, 8, 6905, 12, 26, 12, 3098]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   14  264    4    5  348    8  642    4    5 2517    4    5   72
#    17    4    5  101   19    4    5   19   19    4    5   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19]
# Source Sentence:  osteosynthesis of mandible external fixator french method , a u . s . equipment
# Real Translation:  l osteosynthese du maxillaire inferieur par fixateur externe methode francaise , a appareillage americain
# Predicted Translation:  les techniques de la prescription des tissus de la american de la adulte , de la hopital . de la . . de la . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Levenshetein Distance: 221.0
# ***BLEU Score***: 0.31702331385234306
#
# target sentence id: [2573, 7, 10407, 122, 5, 3, 4, 1119]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   14  672    6    4    5 3245   18    5 1636    4    5   36    4
#    76   76   76   24   10    5   36    4   76   24    4    5  134    9
#  2299   10    5  134    4   76   76   56    2]
# Source Sentence:  teeth and dentition among the merina of madagascar
# Real Translation:  denture et dentition chez les merina de madagascar
# Predicted Translation:  les monde et de la glycemie dans la profession de la maladie de deux deux deux cas a la maladie de deux cas de la association d amenorrhee a la association de deux deux ans
# Levenshetein Distance: 140.0
# ***BLEU Score***: 0.5410822690539396
#
# target sentence id: [3, 4, 25631, 1083]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1    5  142    4    5 1008 1007 1008    2]
# Source Sentence:  harmfulness of toothbrushes today
# Real Translation:  la nocivite des brosses a dents actuelles
# Predicted Translation:  la cause de la hui aujourd hui
# Levenshetein Distance: 28.0
# ***BLEU Score***: 0
#
# target sentence id: [1129, 7, 6719]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1 1723    6 2017    6  878    6    6    6    6    6    6   19   19
#     6    6    6   12   29    6    6    6    6   19    6    6    6    6
#     6    6    6    6    6    6    6    6    6    6    6    6    6    6
#     6    6    6    6    6    6    6    6    6    6    6   19    6   12
#    29    6    7   28   12   29    6    6    6    6    6    6    6    6
#     6    6    6    6    6    6    6    6    6    6    7   28   12   29
#     6    6 1723    6    6   19    6    6    6    6    6    6    6    6
#     6    6]
# Source Sentence:  orthodontics and periodontitis
# Real Translation:  orthodontie et paradontose
# Predicted Translation:  orthodontie et cognition et esthetique et et et et et et . . et et et en charge et et et et . et et et et et et et et et et et et et et et et et et et et et et et et et et et et et . et en charge et l prise en charge et et et et et et et et et et et et et et et et et et l prise en charge et et orthodontie et et . et et et et et et et et et et
# Levenshetein Distance: 319.0
# ***BLEU Score***: 0
#
# target sentence id: [2013, 47, 6, 6096, 4392, 6903]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  47 878  12  47   4   7  47   4   7  47   4   7  47   4   7  47 878
#    2]
# Source Sentence:  maxillofacial surgery in latin america debriefing
# Real Translation:  la chirurgie maxillo faciale en amerique latine compte rendu de mission
# Predicted Translation:  chirurgie esthetique en chirurgie de l chirurgie de l chirurgie de l chirurgie de l chirurgie esthetique
# Levenshetein Distance: 73.0
# ***BLEU Score***: 0.5856596027429395
#
# target sentence id: [5, 3, 4, 2244, 4404]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1    5 1510    8  988    4    5  961   11 1460    4    5  961   11
#  1460    4    5   72    2]
# Source Sentence:  the pairing of proximal caries
# Real Translation:  le jumellage des caries proximales
# Predicted Translation:  la presence des recepteurs de la proteine du rachis de la proteine du rachis de la adulte
# Levenshetein Distance: 68.0
# ***BLEU Score***: 0
#
# target sentence id: [8, 3630, 34, 4, 3, 6, 5, 3029, 25]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  13 216   4   5  36   4   5  36   4   5  36   4 953  18   5  36   4
#    5  36   4   5  36   4 953   2]
# Source Sentence:  a few cases of angiocardiography in the blue disease
# Real Translation:  quelques cas d angiocardiographie au cours de la maladie bleue
# Predicted Translation:  une serie de la maladie de la maladie de la maladie de behcet dans la maladie de la maladie de la maladie de behcet
# Levenshetein Distance: 80.0
# ***BLEU Score***: 0
#
# target sentence id: [3, 4, 5, 2178, 6, 15, 439, 130, 83, 91, 783, 163, 1902, 36, 81, 3, 71]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1    5 1510   11  186   22   16  256    4  186   12  110    4  186
#    41   56    2]
# Source Sentence:  lymphosarcoma of the mandible in an month old child surgical intervention radiotherapy healing after years odontogenesis disorders
# Real Translation:  lymphosarcome du maxillaire inferieur chez un enfant de mois intervention chirurgicale radiotherapie guerison depuis ans troubles de l odontogenese
# Predicted Translation:  la presence du mois chez un nourrisson de mois en radiotherapie de mois apres ans
# Levenshetein Distance: 92.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 2762, 3099, 4, 3, 977, 11, 489, 2043, 166, 4, 5, 642, 21, 3, 1955]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   14  896    4    7  961    8  178    4    7  961   10    5  598
#     4    5  688    4    5  136    4    5  136    4    5   36    4    5
#    36    4    5  136    4    7   36    4    7  688    4    7  269    4
#     7   79    4    7   91    4    7   79    4    7  446    4    7 2848
#     2]
# Source Sentence:  the circadian rhythm of phagocytic reactions to normal physiological control of the process by sialo cytology
# Real Translation:  le rythme nycthemeral des reactions phagocytaires a l etat normal physiologique controle du processus par la sialo cytologie
# Predicted Translation:  les transfert de l proteine des effets de l proteine a la phase de la examen de la voie de la voie de la maladie de la maladie de la voie de l maladie de l examen de l tunisie de l analyse de l recherche de l analyse de l ovaire de l angiogenese
# Levenshetein Distance: 186.0
# ***BLEU Score***: 0.4366835442847812
#
# target sentence id: [1721, 4, 4618, 4, 1213, 294]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  15  24   4   7 267  11 311   4   7  34  19   4   7  34   4   7  85
#    4   7  34   4   7  34   4   7  34  19   4   7  34   4   7  34   4   7
#   34   4   7  34   4   7  34   4   7  85   4   7  34   4   7 101   4   7
#   34   4   7  34   2]
# Source Sentence:  observations of gastroenterology of north africa
# Real Translation:  observations de gastro enterologie d afrique du nord
# Predicted Translation:  le cas de l afrique du maroc de l enfant . de l enfant de l age de l enfant de l enfant de l enfant . de l enfant de l enfant de l enfant de l enfant de l enfant de l age de l enfant de l hopital de l enfant de l enfant
# Levenshetein Distance: 187.0
# ***BLEU Score***: 0.3639412530979476
#
# target sentence id: [84, 36, 81, 21, 5, 1689, 545, 4, 19, 4, 500, 2573]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   73   41   76  650    4    5  524    4    5  524    4    5  136
#    25   15   30    4    5  248   25   15   30   25    5  248   25    5
#    28   12   29    8   37   25   16   37   25   13  136   25    5   28
#    12   29    8   30    4    5 1649   25   15   30    4    5 1649   25
#    15   30    4    5   60   25   15   30    4    5   60   25   76   37
#    25   15   30    4    5 1649   25   15   37   25   76   30    4    5
#  1649   25   15   37    4    7   34    2]
# Source Sentence:  results after years by the conventional method of treatment of infected teeth
# Real Translation:  resultats obtenus apres ans par la methode classique de traitement des dents infectees
# Predicted Translation:  resultats apres deux dix de la methode de la methode de la voie par le traitement de la region par le traitement par la region par la prise en charge des patients par un patients par une voie par la prise en charge des traitement de la immunodeficience par le traitement de la immunodeficience par le traitement de la litterature par le traitement de la litterature par deux patients par le traitement de la immunodeficience par le patients par deux traitement de la immunodeficience par le patients de l enfant
# Levenshetein Distance: 434.0
# ***BLEU Score***: 0.32466791547509893
#
# target sentence id: [5, 972, 4, 14397, 4, 325, 769]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   5 507   8 767   4   5  85 671   4   5  85   4   5 973   4   5  85
#    4   5  85   4   5 973   4   5  85   4   5 973   4   5 973   4   5  85
#    4   5  85   4   5 973   4   5  85   4   5 973   4   5  85   4   5 248
#    4   5  85   4   5  85   4   5  85   4   5  85   4   5  85   4   5 973
#    4   5 973   4   5  34   4   5 248   4   5 973   4   5  85   4   5  85
#    4   5  85   4   5  85   4   5  85   4]
# Source Sentence:  the problem of immobilization of facial fractures
# Real Translation:  le probleme de l immobilisation des fractures du massif facial
# Predicted Translation:  la question des fractures de la age faciale de la age de la hanche de la age de la age de la hanche de la age de la hanche de la hanche de la age de la age de la hanche de la age de la hanche de la age de la region de la age de la age de la age de la age de la age de la hanche de la hanche de la enfant de la region de la hanche de la age de la age de la age de la age de la age d
# Levenshetein Distance: 345.0
# ***BLEU Score***: 0.31702331385234306
#
# target sentence id: [9865, 766, 298, 9, 650, 4, 5, 635, 421]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   5 187   4   5 187  25   5 248 315 980  17  47   4   5 243 306   4
#    5 248 306   2]
# Source Sentence:  acrylic intra tissue , repair of the orbital region
# Real Translation:  resines acryliques intra tissulaires refection de la region orbitaire
# Predicted Translation:  la technique de la technique par la region intra vitro , chirurgie de la premiere thoracique de la region thoracique
# Levenshetein Distance: 74.0
# ***BLEU Score***: 0
#
# target sentence id: [11202, 7, 6719, 2479, 14525, 271]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   14   74    4   74    8   74    4   74 1799    6    8   74    8
#    74    8   74 1543 1015    6    8   74    4    5  741    2]
# Source Sentence:  gingivitis and periodontitis inter radicular lesions
# Real Translation:  gingivites et parodontites lesions inter radiculaires
# Predicted Translation:  les tumeurs de tumeurs des tumeurs de tumeurs aerodigestives et des tumeurs des tumeurs des tumeurs mous superieures et des tumeurs de la peau
# Levenshetein Distance: 111.0
# ***BLEU Score***: 0
#
# target sentence id: [7743, 795, 7, 32, 1139, 4, 3, 2216, 4, 5, 338, 3700]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  104  366    6   45    4    5 2086    4    5  161    4    5  161
#     2]
# Source Sentence:  anatomo pathological and clinical considerations of diffused osteomyelitis of the upper maxilla
# Real Translation:  considerations anatomo pathologiques et cliniques sur les osteomyelites diffuses du maxillaire superieur
# Predicted Translation:  aspects epidemiologiques et clinique de la moelle de la face de la face
# Levenshetein Distance: 60.0
# ***BLEU Score***: 0
#
# target sentence id: [3, 3208]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1    5 1634    4    5  161    2]
# Source Sentence:  homeopathic dentistry
# Real Translation:  therapeutique homeopathique en art dentaire
# Predicted Translation:  la erreur de la face
# Levenshetein Distance: 33.0
# ***BLEU Score***: 0
#
# target sentence id: [3599, 4, 5, 7604]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   7 180   4   7 161  10   7 161   2]
# Source Sentence:  infancy of the denture
# Real Translation:  premiers balbutiements de la prothese dentaire
# Predicted Translation:  l histoire de l face a l face
# Levenshetein Distance: 32.0
# ***BLEU Score***: 0.43472087194499137
#
# target sentence id: [8, 17, 4, 22426, 100, 211]
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  16  24   4 118   4  81 304 632  10 118 304 632  10 118   4  24   4
#   56   2]
# Source Sentence:  a case of leydig tumor cells
# Real Translation:  un cas de tumeur a cellules interstitielles du testicule
# Predicted Translation:  un cas de tumeur de cellules souches cutanes a tumeur souches cutanes a tumeur de cas de ans
# Levenshetein Distance: 52.0
# ***BLEU Score***: 0.4854917717073234
#
# target sentence id: [204, 11, 5, 3, 29, 7, 102, 1139]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1 887  10   7  32   8 305 207   6 222   6 222   4   7  32   8  61   6
#    4   7  34  19   4   7 123   2]
# Source Sentence:  contribution to the paradental study and general considerations
# Real Translation:  contribution a l etude paradentaire et considerations generales
# Predicted Translation:  contribution a l etude des premier bilan et generale et generale de l etude des sein et de l enfant . de l imagerie
# Levenshetein Distance: 70.0
# ***BLEU Score***: 0.2453424678747742
#
# target sentence id: [3, 3, 3, 11, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1    5  187    4    5 2506   12 1341    2]
# Source Sentence:  logette retentive buttoned to studs
# Real Translation:  logette retentive pour crampons boutonnes
# Predicted Translation:  la technique de la muqueuse en fer
# Levenshetein Distance: 32.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 3, 26958, 7, 184, 808, 15881, 21, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   7 113   8 147   6 254 667  25  14  30   4   5 499   2]
# Source Sentence:  the studded inlay and its applications parallelism by isodromy
# Real Translation:  l inlay a crampons et ses applications le parallelisme par l isodromie
# Predicted Translation:  l utilisation des medicaments et ses applications par les traitement de la main
# Levenshetein Distance: 45.0
# ***BLEU Score***: 0.5266403878479265
#
# target sentence id: [282, 4, 5, 468, 7862, 7, 3, 21, 5, 65, 4, 13524, 22553, 3, 545]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  286    4    5 2320  670    6    4    5  113    4    5  113    4
#     5  136    4    5  136    4    5  136    4    5  136    4    5  187
#     4    5  136    4    5  136    4    5  136    4    5  136    4    5
#   136    4    5  136    4    5  136    4    5  187    4    5  136    4
#     5  187    4    5  136    4    5  187    4    5  136  115    4    5
#   187    4    5  187    4    5  187    4    5  136    4    5  136    4
#     5  136    4    5  136    4    5  136    4    5  187    4    5  136
#     4    5]
# Source Sentence:  reconstruction of the dental arches and oclusion by the use of spherical portions bignell method
# Real Translation:  de la reconstruction des arcades dentaires et de l oclusion par l emploi de portions de sphere bignell method
# Predicted Translation:  reconstruction de la cavite dentaire et de la utilisation de la utilisation de la voie de la voie de la voie de la voie de la technique de la voie de la voie de la voie de la voie de la voie de la voie de la voie de la technique de la voie de la technique de la voie de la technique de la voie francaise de la technique de la technique de la technique de la voie de la voie de la voie de la voie de la voie de la technique de la voie de la
# Levenshetein Distance: 358.0
# ***BLEU Score***: 0
#
# target sentence id: [2706, 5, 1048, 4, 5, 2178, 7, 184, 1910, 6, 1149, 7604]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1    5  113    4    5   28    4    5  335    6    4    7  830    4
#     7   28   12   29    9   16  283    4    5 1649    2]
# Source Sentence:  determining the position of the mandible and its significance in complete denture
# Real Translation:  de la determination de la position de repos de la mandibule et de sa signification en prothese complete
# ...
# target sentence id: [882, 119, 4, 5, 183]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   74 4269    4    5  741  208    2]
# Source Sentence:  black tumors of the skin
# Real Translation:  tumeurs noires de la peau
# Predicted Translation:  tumeurs conjonctives de la peau cutanee
# Levenshetein Distance: 15.0
# ***BLEU Score***: 0
#
# target sentence id: [7958, 16475, 4, 3191, 3198]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   5 229   4   5 229   4   5 134   4   5 101   4   5 101 812   2]
# Source Sentence:  unpublished pages of claude bernard
# Real Translation:  pages inedites de claude bernard
# Predicted Translation:  la societe de la societe de la association de la hopital de la hopital v
# Levenshetein Distance: 55.0
# ***BLEU Score***: 0
#
# target sentence id: [5, 3356, 832, 6, 10814]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   5 454   4   5 461  12   2]
# Source Sentence:  the wine consumption in portugal
# Real Translation:  les vins de consommation au portugal
# Predicted Translation:  la consommation de la grippe en
# Levenshetein Distance: 23.0
# ***BLEU Score***: 0
#
# target sentence id: [6088, 7, 8596, 625, 4, 51, 3523]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   7 516   4   7 753   6   7 753   8 412 252   2]
# Source Sentence:  artistic and bibliographic exposure of medical authors
# Real Translation:  exposition artistique et bibliographique d auteurs medecins
# Predicted Translation:  l arret de l exposition et l exposition des etudes medical
# Levenshetein Distance: 43.0
# ***BLEU Score***: 0.5491004867761125
#
# target sentence id: [10376, 440]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1   5 945   4   5  34   4   5  28  12  29   4   5 112   4   5 161  12
#  398   4   5  34   4   5  34   2]
# Source Sentence:  portuguese art
# Real Translation:  l art portugais
# Predicted Translation:  la art de la enfant de la prise en charge de la etat de la face en cancerologie de la enfant de la enfant
# Levenshetein Distance: 94.0
# ***BLEU Score***: 0
#
# target sentence id: [3, 153, 7, 9466, 6, 3208]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  14 147 147   6  12 116  12  29  12  29   2]
# Source Sentence:  sulfa drugs and penicillin in dentistry
# Real Translation:  les sulfamides et la penicilline en stomatologie
# Predicted Translation:  les medicaments medicaments et en mise en charge en charge
# Levenshetein Distance: 40.0
# ***BLEU Score***: 0
#
# target sentence id: [8, 33, 98, 3390, 7, 6154, 14397, 4, 5, 338, 644, 6254, 4011, 11, 3, 4, 5, 389, 3543]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   16   35    4    5   36    4    5  134  166    6    4    5   28
#    12   29    4    5  312 1466    8  956  944   10    5 1004    4    5
#  1004    8  323    4    5  136    4    5  136    4    5 1004    2]
# Source Sentence:  a syndrome severe neuralgia and absolute immobilization of the upper limb immediately subsequent to setons of the neck muscles
# Real Translation:  sur un syndrome sympathalgie violente et immobilisation absolue du membre superieur immediatement consecutif a des setons des muscles du cou
# Predicted Translation:  un syndrome de la maladie de la association arterielle et de la prise en charge de la infarctus cave des membre superieur a la tete de la tete des col de la voie de la voie de la tete
# Levenshetein Distance: 120.0
# ***BLEU Score***: 0.4001601601922499
#
# target sentence id: [3, 10, 77, 735]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  15  30   4   5 519  80  80  18  15 519 331 331   2]
# Source Sentence:  pneumotomy for lung abscess
# Real Translation:  a propos de la pneumotomie pour abces du poumon
# Predicted Translation:  le traitement de la abces pulmonaire pulmonaire dans le abces pulmonaires pulmonaires
# Levenshetein Distance: 54.0
# ***BLEU Score***: 0
#
# target sentence id: [4324, 464, 4, 2207, 386, 6, 91, 19, 4, 916, 20]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  264    4    5   28   12   58    4    5  382    4    5   28   12
#    29    4    5   28   12   29  355    8   33   11 1526   11   33   11
#  1526   11   33    4    5 1526   11   33    4    5   28   12   29   11
#    33    4    5 1687    4    5   28   12   29   11   33    4    5 1526
#     2]
# Source Sentence:  conservation techniques of sphincter function in surgical treatment of rectal cancer
# Real Translation:  a propos des techniques de conservation de la fonction sphincterienne dans cure operatoire des cancers du rectum
# Predicted Translation:  techniques de la prise en place de la fonction de la prise en charge de la prise en charge chirurgicale des cancer du rectum du cancer du rectum du cancer de la rectum du cancer de la prise en charge du cancer de la sophage de la prise en charge du cancer de la rectum
# Levenshetein Distance: 195.0
# ***BLEU Score***: 0
#
# target sentence id: [1812, 4, 3, 591, 1236, 4, 5, 77]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  996    4    5 1283  805  805   11  511  331    4    5   34    2]
# Source Sentence:  sequelae of evacuated hydatid cysts of the lung
# Real Translation:  sequelles de kystes hydatiques du poumon evacuees par vomiques
# Predicted Translation:  sequelles de la kystes peritoneale peritoneale du poumon pulmonaires de la enfant
# Levenshetein Distance: 44.0
# ***BLEU Score***: 0
#
# target sentence id: [827, 6, 119, 4, 5, 1668]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  30   4   5  28  12  29   8  74   4   5 446   4   5 446   4   5 446
#    4   5 446   4   7 446   4   5 446   4   5 446   4   5 446   2]
# Source Sentence:  bleeding in tumors of the ovary
# Real Translation:  a propos des metrorragies dans les tumeurs de l ovaire
# Predicted Translation:  traitement de la prise en charge des tumeurs de la ovaire de la ovaire de la ovaire de la ovaire de l ovaire de la ovaire de la ovaire de la ovaire
# Levenshetein Distance: 109.0
# ***BLEU Score***: 0.42044820762685725
#
# target sentence id: [2675, 559, 4, 5, 940, 9, 4, 5, 126, 1837, 21, 21917, 952, 3839, 9, 2380, 37, 5, 2441, 37, 5, 150, 3321]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  577    4    5  499   17    4    5   28   12   29    4    5  499
#     4    5  499   17    4    5  134    4    5  134    4    5  138   17
#     4    7  687   21   54    4    5 1479   10    5  499    4    5  243
#   802    4    5  243  874    2]
# Source Sentence:  closed fracture of the leg , of the type known by crushing rapid gangrene , amputation at the thigh at the th hour
# Real Translation:  fracture fermee de jambe , de type dit par ecrasement gangrene rapide amputation de cuisse a la . heure
# Predicted Translation:  fracture de la main , de la prise en charge de la main de la main , de la association de la association de la prostate , de l image au cours de la pierre a la main de la premiere ligne de la premiere guerre
# Levenshetein Distance: 141.0
# ***BLEU Score***: 0.5053483543335474
#
# target sentence id: [3, 7, 162, 25]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  14  77   4   5  36   4   5  36 605   6 605   6 605 605   2]
# Source Sentence:  sulfonamides and oral disease
# Real Translation:  sulfamides et affections buccodentaires
# Predicted Translation:  les maladies de la maladie de la maladie orale et orale et orale orale
# Levenshetein Distance: 54.0
# ***BLEU Score***: 0
#
# target sentence id: [3, 9, 2548, 2990, 11215, 12]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   15  625   17   14 1731   99   19   19   19   19   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19   19   19   19   19   19   15  282   19   19   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19   19   19   19   19   19   19   19   19   19   19   19   19
#    19   19]
# Source Sentence:  auffret , charles jacques emile .
# Real Translation:  auffret , charles jacques emile .
# Predicted Translation:  le medicament , les cuir n . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . le burkina . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Levenshetein Distance: 205.0
# ***BLEU Score***: 0.3770063804549471
#
# target sentence id: [96, 16, 3251, 12171, 503, 28, 5914, 3]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   91   27   15   30    4    5 1019  455    4    5  136    4    5
#   136    4    5  136    4    5  136    4    5  136    4    5  136    4
#     5  136    4    5  136    4    5  136    4    5  136    4    5  136
#     4    5  136    4    5   60    2]
# Source Sentence:  research on pathogenic actinomyces isolated from algiers saprophytes
# Real Translation:  recherches sur le pourvoir pathogene d actinomyces saprophytes isoles a alger
# Predicted Translation:  recherche sur le traitement de la veine humaine de la voie de la voie de la voie de la voie de la voie de la voie de la voie de la voie de la voie de la voie de la voie de la voie de la litterature
# Levenshetein Distance: 149.0
# ***BLEU Score***: 0
#
# target sentence id: [8, 17, 4, 192, 135, 7, 767, 1356, 6, 15, 435, 36, 4076, 54, 76]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  24   4   5 142   4   5 108   6 423   4   5  34  22  16 256  41  13
#   86  10  86  21  54   4   5  86  10  86  10   5  86   2]
# Source Sentence:  a case of congenital heart and eye malformations in an infant after rubella during pregnancy
# Real Translation:  un cas de malformation cardiaque et oculaire chez un nourrisson apres rubeole au cours de la grossesse
# Predicted Translation:  cas de la cause de la c et anomalies de la enfant chez un nourrisson apres une grossesse a grossesse au cours de la grossesse a grossesse a la grossesse
# Levenshetein Distance: 85.0
# ***BLEU Score***: 0.5623413251903491
#
# target sentence id: [340, 913, 4, 244, 3, 6, 8, 83, 4, 81]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1 917  87 457  11 323 394  22  16  34   4  56   2]
# Source Sentence:  traumatic dislocation of cervical vertebra in a child of years
# Real Translation:  luxation traumatique d une vertebre cervicale chez un enfant de ans
# Predicted Translation:  luxation post traumatique du col uterin chez un enfant de ans
# Levenshetein Distance: 23.0
# ***BLEU Score***: 0
#
# target sentence id: [192, 8469, 302, 8371, 6, 8, 83, 4, 985, 789, 1258, 3343, 7, 768, 10696, 4541, 100]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1    5  382  433    4    5  792  433   22   16   34    4    5 1565
#   306    4    5 1565    4    5 1565    4    5   72    6    4    5  118
#   118    4    5  118    4    5  446    4   56    2]
# Source Sentence:  congenital cardiopathy without cyanosis in a child of months chest wall retraction and sub sternum intrathoracic tumor
# Real Translation:  cardiopathie congenitale sans cyanose , chez un enfant de mois tirage sus et sous sternal tumeur intra thoracique
# Predicted Translation:  la fonction congenitale de la aorte congenitale chez un enfant de la paroi thoracique de la paroi de la paroi de la adulte et de la tumeur tumeur de la tumeur de la ovaire de ans
# Levenshetein Distance: 109.0
# ***BLEU Score***: 0
#
# target sentence id: [2938, 6375, 6, 8, 195, 83]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   15   26    4    5  200    4    5 1244   10    5   34   22   16
#   321    4  340    2]
# Source Sentence:  myositis ossificans in a young child
# Real Translation:  myosite ossifiante chez un jeune enfant
# Predicted Translation:  le propos de la observation de la encephalite a la enfant chez un jeune de jeunes
# Levenshetein Distance: 53.0
# ***BLEU Score***: 0.5
#
# target sentence id: [1001, 148, 67, 7, 5221]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1   14   77    4    5 1167 1108    6    4    5  702    2]
# Source Sentence:  endocrine system diseases and estrogen
# Real Translation:  les endocrinoses oestrogenes
# Predicted Translation:  les maladies de la personnalite isolee et de la environnement
# Levenshetein Distance: 45.0
# ***BLEU Score***: 0
#
# target sentence id: [590, 4, 3997, 16, 5, 244, 4915]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [   1  440    4    5 1047   27    5   28   12   29   11  417  394   11
#   323  394   11  323  394    4    5  136    4    5  136    4    5   60
#     2]
# Source Sentence:  influence of hormones on the cervical glands
# Real Translation:  influence des actions hormonales sur les glandes du col uterin
# Predicted Translation:  influence de la thyroide sur la prise en charge du carcinomes uterin du col uterin du col uterin de la voie de la voie de la litterature
# Levenshetein Distance: 93.0
# ***BLEU Score***: 0
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Prediction Output and Metrics on 400 test sentences:
# Average BLEU Score on our test corpus is 0.28633670427519287
# Average Levenshetein distance Score on our test corpus is 98.755

# %%
src_sent = 'myositis ossificans in a young child '
tgt_sent = 'myosite ossifiante chez un jeune enfant'


translate_en_fr(src_sent,
                tgt_sent, 
                verbose = True,
                plot_att = True)
# Out:
# target sentence id: [2938, 6375, 6, 8, 195, 83]
# INFO:tensorflow:Restoring parameters from ckpt-exp08/google-brain-gru-128size-7800
# target sentence id: [  1  13 563   4   5  34  22  13 321   4   7  34  22   7  34  22  16 140
#  321   4   7  34   2]
# Source Sentence: myositis ossificans in a young child
# Real Translation: myosite ossifiante chez un jeune enfant
# Predicted Translation:  une fievre de la enfant chez une jeune de l enfant chez l enfant chez un sujet jeune de l enfant
# Levenshetein Distance: 69.0
# ***BLEU Score***: 0
# (' une fievre de la enfant chez une jeune de l enfant chez l enfant chez un sujet jeune de l enfant ',
#  0,
#  69.0)
