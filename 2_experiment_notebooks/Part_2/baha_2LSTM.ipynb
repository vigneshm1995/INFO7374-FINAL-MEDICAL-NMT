# %%
import tensorflow as tf
import codecs
import sys
import numpy as np
import time

# %% [markdown]
# ## create vocabulary

# %%
NUM_SENT = 50000

# %%
src_path = 'en_clean.txt'
tgt_path = 'fr_clean.txt'

# %%
def read_train_data(txt_path, num_examples):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[:num_examples]

# %%
src = read_train_data(src_path, NUM_SENT)
tgt = read_train_data(tgt_path, NUM_SENT)

# %%
def read_test_data(txt_path, num_examples = 400):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[-num_examples:]

# %%
src_test = read_test_data(src_path)
tgt_test = read_test_data(tgt_path)

# %%
print('size of number of source sentences from dataset for training: {}'.format(len(src)))
print('size of number of target sentences from dataset for training: {}'.format(len(tgt)))
# Out:
# size of number of source sentences from dataset for training: 50000
# size of number of target sentences from dataset for training: 50000

# %%
for i in range(5):
  print(src[i])
# Out:
#  global health where do physiotherapy and rehabilitation research fit ?
#  carabin
#  comment on the misappropriation of bibliographical references in science . the example of anti aging medicine
#  anti aging medicine , a science based , essential medicine
#  underwater dive in fresh water complicated by a cardiorespiratory arrest on obstructive shock

# %%
import codecs
import collections
from operator import itemgetter

def create_vocab(RAW_DATA, VOCAB_OUTPUT):
    counter = collections.Counter()

    for line in RAW_DATA:
        for word in line.strip().lower().split():
            counter[word] += 1

    sorted_word_to_cnt = sorted(counter.items(), key=itemgetter(1), reverse=True)
    sorted_words = [x[0] for x in sorted_word_to_cnt]

    sorted_words =  ['<pad>'] + ['<sos>'] + ['<eos>'] + ['<unk>'] + sorted_words 

    with codecs.open(VOCAB_OUTPUT, "w", encoding="utf-8") as file_output:
        for word in sorted_words:
            file_output.write(word + "\n")
    return sorted_words

# %%
vocab_src = create_vocab(src, 'vocab.en')
vocab_tgt = create_vocab(tgt, 'vocab.fr')

# %% [markdown]
# ## convert text to numbers

# %%
import codecs
import sys

def text_to_int(RAW_DATA, VOCAB, OUTPUT_DATA):

  with codecs.open(VOCAB, "r", encoding="utf-8") as f_vocab:
      vocab = [w.strip() for w in f_vocab.readlines()]
      word_to_id = {k:v for (k,v) in zip(vocab, range(len(vocab)))}

  def get_id(word):
      return word_to_id[word] if word in word_to_id else word_to_id["<unk>"]

  fout = codecs.open(OUTPUT_DATA, "w", encoding="utf-8")
  for line in RAW_DATA:
      words = line.strip().split() + ["<eos>"]

      out_line = " ".join([str(get_id(w)) for w in words]) + "\n"
      fout.write(out_line)
  fout.close()

# %%
text_to_int(src, 'vocab.en', 'train.en')
text_to_int(tgt, 'vocab.fr', 'train.fr')

# %% [markdown]
# ## create a training dataset

# %%
def MakeDataset(file_path):
    dataset = tf.data.TextLineDataset(file_path)
    # split by space
    dataset = dataset.map(lambda string: tf.string_split([string]).values)
    # convert string to number
    dataset = dataset.map(
        lambda string: tf.string_to_number(string, tf.int32))
    # calc # word/sentence and put in dataset with sentence
    dataset = dataset.map(lambda x: (x, tf.size(x)))
    return dataset

def MakeSrcTrgDataset(src_path, trg_path, batch_size):

    src_data = MakeDataset(src_path)
    trg_data = MakeDataset(trg_path)
    #   ds[0][0]source sentence
    #   ds[0][1]len of source sentence
    #   ds[1][0]target sentence
    #   ds[1][1]len of target sentence
    dataset = tf.data.Dataset.zip((src_data, trg_data))

    # delete empty and super-long sentence
    def FilterLength(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        src_len_ok = tf.logical_and(
            tf.greater(src_len, 1), tf.less_equal(src_len, MAX_LEN))
        trg_len_ok = tf.logical_and(
            tf.greater(trg_len, 1), tf.less_equal(trg_len, MAX_LEN))
        return tf.logical_and(src_len_ok, trg_len_ok)
    dataset = dataset.filter(FilterLength)
    
    #   1.trg_input: "<sos> X Y Z"
    #   2.trg_label: "X Y Z <eos>"
    #   file: "X Y Z <eos>", need to produce "<sos> X Y Z" and add to dataset
    def MakeTrgInput(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        trg_input = tf.concat([[SOS_ID], trg_label[:-1]], axis=0)
        return ((src_input, src_len), (trg_input, trg_label, trg_len))
    
    dataset = dataset.map(MakeTrgInput)

    dataset = dataset.shuffle(10000)

    # define shape after padding
    padded_shapes = (
        (tf.TensorShape([None]),
         tf.TensorShape([])), 
        (tf.TensorShape([None]),
         tf.TensorShape([None]),
         tf.TensorShape([]))) 
    
    # padded_batch to pad
    batched_dataset = dataset.padded_batch(batch_size, padded_shapes)
    return batched_dataset

# %% [markdown]
# ## define nmt

# %%
def single_rnn_cell(cell_name, hid_size, keep_prob):
    if cell_name == "GRU":
        cell = tf.contrib.rnn.GRUCell(hid_size)
    elif cell_name == "LSTM":
        cell = tf.contrib.rnn.LSTMCell(hid_size)
    elif cell_name == "BASIC":
        cell = tf.contrib.rnn.BasicRNNCell(hid_size)
    return cell

def multi_rnn_cell(cell_name, hid_size, num_layers, keep_prob):
    cells = []
    for _ in range(num_layers):
        cell = single_rnn_cell(cell_name, hid_size, keep_prob)
        cells.append(cell)
    
    if len(cells) > 1:
        final_cell = tf.contrib.rnn.MultiRNNCell(cells=cells)
    else:
        final_cell = cells[0]
    return final_cell
  
  
def single_biRNN_pair(cell_name, hid_size, keep_prob):
    if cell_name == "bi-GRU":
      enc_cell_fw = single_rnn_cell('GRU', hid_size, keep_prob)
      enc_cell_bw = single_rnn_cell('GRU', hid_size, keep_prob)
    elif cell_name == "bi-LSTM":
      enc_cell_fw = single_rnn_cell('LSTM', hid_size, keep_prob)
      enc_cell_bw = single_rnn_cell('LSTM', hid_size, keep_prob)
    return enc_cell_fw, enc_cell_bw
    
def multi_biRNN_pair(cell_name, hid_size, num_layers, keep_prob):
    stacked_biRNN_fw = []
    stacked_biRNN_bw = []
    for _ in range(num_layers):
        enc_cell_fw, enc_cell_bw = single_biRNN_pair(cell_name, hid_size, keep_prob)
        stacked_biRNN_fw.append(enc_cell_fw)
        stacked_biRNN_bw.append(enc_cell_bw)
    
    if len(stacked_biRNN_fw) > 1:
        final_stacked_biRNN_fw = tf.contrib.rnn.MultiRNNCell(cells=stacked_biRNN_fw)
        final_stacked_biRNN_bw = tf.contrib.rnn.MultiRNNCell(cells=stacked_biRNN_bw)
    else:
        final_stacked_biRNN_fw = stacked_biRNN_fw[0]
        final_stacked_biRNN_bw = stacked_biRNN_bw[0]
    return final_stacked_biRNN_fw, final_stacked_biRNN_bw

# %%
class NMTModel(object):
  """
  defind the nmt model
  
  """
  # define variables needed by nmt
  def __init__(self, 
               dec_layer, 
               enc_layer,
               dec_cell_name, 
               enc_cell_name,
               optimizer, 
               lr,
               hid_size, 
               attention,
               drop_out):
    
    self.dec_cell_name = dec_cell_name
    self.enc_cell_name = enc_cell_name
    self.dec_layer = dec_layer
    self.enc_layer = enc_layer
    self.attention = attention
    
    self.hid_size = hid_size
    self.opt = optimizer
    self.lr = lr
    
    self.keep_prob = 1.0 - drop_out

    # EMBEDDING SETUP
    
    self.src_embedding = tf.get_variable(
          "src_emb", [SRC_VOCAB_SIZE, self.hid_size])
    self.trg_embedding = tf.get_variable(
          "trg_emb", [TRG_VOCAB_SIZE, self.hid_size])

      # define variables for softmax layer
    if SHARE_EMB_AND_SOFTMAX:
         self.softmax_weight = tf.transpose(self.trg_embedding)
    else:
         self.softmax_weight = tf.get_variable(
             "weight", [self.hid_size, TRG_VOCAB_SIZE])
    self.softmax_bias = tf.get_variable(
          "softmax_bias", [TRG_VOCAB_SIZE])
     
  # calculate forward graph
  # src_input, src_size, trg_input, trg_label, trg_size are from MakeSrcTrgDataset
  
  def forward(self, src_input, src_size, trg_input, trg_label, trg_size):
      batch_size = tf.shape(src_input)[0]
      
      # *************************
      # **** EMBEDDING SCOPE ****
      # *************************
      
      with tf.variable_scope("Embeddings"):

        # convert word_int input to embeddings
        src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
        trg_emb = tf.nn.embedding_lookup(self.trg_embedding, trg_input)

        # set drop_out rate
        src_emb = tf.nn.dropout(src_emb, self.keep_prob)
        trg_emb = tf.nn.dropout(trg_emb, self.keep_prob)

      # *************************
      # ***** ENCODER SCOPE *****
      # *************************

      with tf.variable_scope("encoder"):
        
        if not 'bi' in self.enc_cell_name:
        
          enc_cell = multi_rnn_cell(self.enc_cell_name, 
                                    self.hid_size, 
                                    self.enc_layer, 
                                    self.keep_prob)
          enc_outputs, enc_state = tf.nn.dynamic_rnn(enc_cell, 
                                                     inputs=src_emb, 
                                                     sequence_length=src_size, 
                                                     dtype=tf.float32) 
        
        else:
          
          stacked_biRNN_fw, stacked_biRNN_bw = multi_biRNN_pair(self.enc_cell_name, 
                                                                self.hid_size, 
                                                                self.enc_layer, 
                                                                self.keep_prob)
          enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = stacked_biRNN_fw,
                                                                   cell_bw = stacked_biRNN_bw,
                                                                   inputs = src_emb,
                                                                   sequence_length = src_size,
                                                                   dtype = tf.float32)
          
          # concatenate two outputs of LSTM cell as 1 tensor
          # enc_outputs = (output_fw, output_bw)
          enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)
          
    
      # *************************
      # ***** DECODER SCOPE *****
      # *************************
      
      with tf.variable_scope("decoder"):
        
        dec_cell = multi_rnn_cell(self.dec_cell_name, self.hid_size, self.dec_layer, self.keep_prob)
    
    
        # OPTIONS FOR ATTENTION MECHANISM
        if self.attention == 'Bahdanau':
        
          attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                  self.hid_size, 
                  enc_outputs,
                  memory_sequence_length = src_size)
          
        if self.attention == 'Luong':

          attention_mechanism = tf.contrib.seq2seq.LuongAttention(
                  self.hid_size,
                  enc_outputs,
                  memory_sequence_length=src_size)

        # ATTENTION WRAPPER: 
        # wrap dec_cell and attention mechanisim
        attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                dec_cell, 
                attention_mechanism,
                attention_layer_size=self.hid_size)

        # use attention_cell and dynamic_rnn construct decoder
        # here relay totally on attention as the information source
        dec_outputs, _ = tf.nn.dynamic_rnn(
                attention_cell, trg_emb, trg_size, dtype=tf.float32)

        
      # ************************
      # ***** OPTIMIZATION *****
      # ************************
      
      # LOSS/LOG PERPLEXITY
      output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
      logits = tf.matmul(output, self.softmax_weight) + self.softmax_bias
      loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
          labels=tf.reshape(trg_label, [-1]), logits=logits)

      # set padding weight as 0 when calc average loss
      label_weights = tf.sequence_mask(
          trg_size, maxlen=tf.shape(trg_label)[1], dtype=tf.float32)
      label_weights = tf.reshape(label_weights, [-1])
      cost = tf.reduce_sum(loss * label_weights)
      cost_per_token = cost / tf.reduce_sum(label_weights)

      # define backprop
      trainable_variables = tf.trainable_variables()

      # OPTIONS FOR OPTIMIZER
      # define optimization method/steps
      grads = tf.gradients(cost / tf.to_float(batch_size),
                           trainable_variables)
      
      grads, _ = tf.clip_by_global_norm(grads, clip_norm = 5)

      if self.opt == 'adam':
        optimizer = tf.train.AdamOptimizer(learning_rate = self.lr)
      
      elif self.opt == 'sgd':        
        optimizer = tf.train.GradientDescentOptimizer(learning_rate = self.lr)
        
      elif self.opt == 'rmsprop':     
        optimizer = tf.train.RMSPropOptimizer(learning_rate = self.lr)
      
      train_op = optimizer.apply_gradients(zip(grads, trainable_variables))
      
      return cost_per_token, train_op

# %% [markdown]
# ## traning

# %%
def run_epoch(session, cost_op, train_op, saver, step):
    while True:
        try:
            # execute train_op and calc loss
            cost, _ = session.run([cost_op, train_op])
            if step % 100 == 0:
                print("After %d steps, per token cost is %.3f" % (step, cost))
            # save checkpoint per 200 steps
            if step % 200 == 0:
                saver.save(session, CHECKPOINT_PATH, global_step=step)
            step += 1
        except tf.errors.OutOfRangeError:
            break
    return step

# %%
vocab_size_src = len(vocab_src)
vocab_size_tgt = len(vocab_tgt)

# %% [markdown]
# ##  hyperparameters

# %%
CHECKPOINT_PATH = "./ckpt-exp02/baha_2GRU"  

HIDDEN_SIZE = 512
DECODER_LAYERS = 1                    # Num_layer for decoder LSTM
DECODER_CELL_TYPE = 'LSTM'
ENCODER_LAYERS = 2
ENCODER_CELL_TYPE = 'bi-LSTM'
ATTENTION = 'Bahdanau'
OPTIMIZER = 'adam'
DROPOUT = 0.1
LEARNING_RATE = 0.002

BATCH_SIZE = 128
NUM_EPOCH = 20 


SRC_TRAIN_DATA = "train.en"
TRG_TRAIN_DATA = "train.fr"
SRC_VOCAB_SIZE = vocab_size_src       
TRG_VOCAB_SIZE = vocab_size_tgt 
SHARE_EMB_AND_SOFTMAX = True           # share weights between softmax layer and embedding layer
MAX_LEN = 100   # max length of a sentence
SOS_ID  = 1    # <sos> ID in target vocab

import time
def main():
  
    initializer = tf.random_uniform_initializer(-0.05, 0.05)
    
    tf.reset_default_graph()

    with tf.variable_scope("nmt_model", reuse=None, 
                           initializer=initializer):
        train_model = NMTModel(
                dec_layer = DECODER_LAYERS, 
                enc_layer = ENCODER_LAYERS,
                dec_cell_name =  DECODER_CELL_TYPE,
                enc_cell_name = ENCODER_CELL_TYPE,
                optimizer = OPTIMIZER, 
                lr = LEARNING_RATE,
                hid_size = HIDDEN_SIZE, 
                attention = ATTENTION,
                drop_out = DROPOUT)
  
    # define input data
    data = MakeSrcTrgDataset(SRC_TRAIN_DATA, TRG_TRAIN_DATA, BATCH_SIZE)
    iterator = data.make_initializable_iterator()
    (src, src_size), (trg_input, trg_label, trg_size) = iterator.get_next()
 
    # define forward graph
    cost_op, train_op = train_model.forward(src, src_size, trg_input,
                                            trg_label, trg_size)

    # train
    saver = tf.train.Saver()
    tf.add_to_collection('train_op', train_op)
    tf.add_to_collection('cost_op', cost_op)
    step = 0
    with tf.Session() as sess:
        writer = tf.summary.FileWriter('logs', sess.graph)
        writer.close()
        
        tf.global_variables_initializer().run()
        for i in range(NUM_EPOCH):
            time_start=time.time()
            print("-------In iteration: %d" % (i + 1))
            sess.run(iterator.initializer)
            step = run_epoch(sess, cost_op, train_op, saver, step)
            time_end=time.time()
            print('-------time cost',time_end-time_start,'s')
            print('                                        ')
            
if __name__ == "__main__":
    main()
# Out:
# -------In iteration: 1
# After 0 steps, per token cost is 10.463
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-e21476682395> in <module>()
#      75
#      76 if __name__ == "__main__":
# ---> 77     main()
#
# <ipython-input-29-e21476682395> in main()
#      69             print("-------In iteration: %d" % (i + 1))
#      70             sess.run(iterator.initializer)
# ---> 71             step = run_epoch(sess, cost_op, train_op, saver, step)
#      72             time_end=time.time()
#      73             print('-------time cost',time_end-time_start,'s')
#
# <ipython-input-22-084feb962828> in run_epoch(session, cost_op, train_op, saver, step)
#       3         try:
#       4             # execute train_op and calc loss
# ----> 5             cost, _ = session.run([cost_op, train_op])
#       6             if step % 100 == 0:
#       7                 print("After %d steps, per token cost is %.3f" % (step, cost))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
LAST_CKPT_PATH = "ckpt-exp02/baha_2GRU-7800"

# file for vocab
SRC_VOCAB = "vocab.en"
TRG_VOCAB = "vocab.fr"
SRC_VOCAB_SIZE = vocab_size_src       
TRG_VOCAB_SIZE = vocab_size_tgt 

# ID for <sos> and <eos> in vocab
SOS_ID = 1
EOS_ID = 2

SHARE_EMB_AND_SOFTMAX = True

# %%
class NMTModel(object):
  """
  defind the nmt model
  
  """
  # define variables needed by nmt
  def __init__(self, 
               dec_layer = DECODER_LAYERS, 
               enc_layer = ENCODER_LAYERS,
               dec_cell_name = DECODER_CELL_TYPE, 
               enc_cell_name = ENCODER_CELL_TYPE,
               optimizer = OPTIMIZER, 
               lr = LEARNING_RATE,
               hid_size = HIDDEN_SIZE, 
               attention = ATTENTION,
               drop_out = DROPOUT):
    
    self.dec_cell_name = dec_cell_name
    self.enc_cell_name = enc_cell_name
    self.dec_layer = dec_layer
    self.enc_layer = enc_layer
    self.attention = attention
    
    self.hid_size = hid_size
    self.opt = optimizer
    self.lr = lr
    
    self.keep_prob = 1.0 - drop_out

    # EMBEDDING SETUP
    
    self.src_embedding = tf.get_variable(
          "src_emb", [SRC_VOCAB_SIZE, self.hid_size])
    self.trg_embedding = tf.get_variable(
          "trg_emb", [TRG_VOCAB_SIZE, self.hid_size])

      # define variables for softmax layer
    if SHARE_EMB_AND_SOFTMAX:
         self.softmax_weight = tf.transpose(self.trg_embedding)
    else:
         self.softmax_weight = tf.get_variable(
             "weight", [self.hid_size, TRG_VOCAB_SIZE])
    self.softmax_bias = tf.get_variable(
          "softmax_bias", [TRG_VOCAB_SIZE])
  
  def inference(self, src_input):
      # As dynamic rnn requires batch input, 
      # to infer one single sentence, we set batch = 1
      src_size = tf.convert_to_tensor([len(src_input)], dtype=tf.int32)
      src_input = tf.convert_to_tensor([src_input], dtype=tf.int32)
      src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
      
     
      # *************************
      # ***** ENCODER SCOPE *****
      # *************************

      with tf.variable_scope("encoder"):
        
        if not 'bi' in self.enc_cell_name:
        
          enc_cell = multi_rnn_cell(self.enc_cell_name, 
                                    self.hid_size, 
                                    self.enc_layer, 
                                    self.keep_prob)
          enc_outputs, enc_state = tf.nn.dynamic_rnn(enc_cell, 
                                                     inputs=src_emb, 
                                                     sequence_length=src_size, 
                                                     dtype=tf.float32) 
        
        else:
          
          stacked_biRNN_fw, stacked_biRNN_bw = multi_biRNN_pair(self.enc_cell_name, 
                                                                self.hid_size, 
                                                                self.enc_layer, 
                                                                self.keep_prob)
          enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = stacked_biRNN_fw,
                                                                   cell_bw = stacked_biRNN_bw,
                                                                   inputs = src_emb,
                                                                   sequence_length = src_size,
                                                                   dtype = tf.float32)
          
          # concatenate two outputs of LSTM cell as 1 tensor
          # enc_outputs = (output_fw, output_bw)
          enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)
          
    
      # *************************
      # ***** DECODER SCOPE *****
      # *************************
      
      with tf.variable_scope("decoder"):
        
        dec_cell = multi_rnn_cell(self.dec_cell_name, self.hid_size, self.dec_layer, self.keep_prob)
    
    
        # OPTIONS FOR ATTENTION MECHANISM
        if self.attention == 'Bahdanau':
        
          attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                  self.hid_size, 
                  enc_outputs,
                  memory_sequence_length = src_size)
          
        if self.attention == 'Luong':

          attention_mechanism = tf.contrib.seq2seq.LuongAttention(
                  self.hid_size,
                  enc_outputs,
                  memory_sequence_length=src_size
                  )

        # ATTENTION WRAPPER: 
        # wrap dec_cell and attention mechanisim
        attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                dec_cell, 
                attention_mechanism,
                attention_layer_size=self.hid_size,
                alignment_history=True)

      # Set the max step for decoder
      MAX_DEC_LEN=100

      with tf.variable_scope("decoder/rnn/attention_wrapper"):
        # use TensorArray store produced sentence
        init_array = tf.TensorArray(dtype=tf.int32, size=0,
            dynamic_size=True, clear_after_read=False)
        # start input for decoder with <sos> tag
        init_array = init_array.write(0, SOS_ID)
        # initilize attention cell
        init_loop_var = (
            attention_cell.zero_state(batch_size=1, dtype=tf.float32),
            init_array, 0)

        # condition for tf.while_loop：
        # loop until decoder outputs <eos> or hit max length setting
        def continue_loop_condition(state, trg_ids, step):
            return tf.reduce_all(tf.logical_and(
                tf.not_equal(trg_ids.read(step), EOS_ID),
                tf.less(step, MAX_DEC_LEN-1)))

        def loop_body(state, trg_ids, step):
            # read last step output as input for attention cell
            trg_input = [trg_ids.read(step)]
            trg_emb = tf.nn.embedding_lookup(self.trg_embedding,
                                             trg_input)
            # FORWARD calc ATTENTION CELL and output decoder outputs/state
            dec_outputs, next_state = attention_cell.call(
                state=state, inputs=trg_emb)

            # calc logit for each candidate target vocab
            # select the max as output
            output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
            logits = (tf.matmul(output, self.softmax_weight)
                      + self.softmax_bias)
            next_id = tf.argmax(logits, axis=1, output_type=tf.int32)
            # write output word into trg_ids
            trg_ids = trg_ids.write(step+1, next_id[0])
            return next_state, trg_ids, step+1

        # execute tf.while_loop return trg_ides
        state, trg_ids, step = tf.while_loop(
            continue_loop_condition, loop_body, init_loop_var)
        
        return trg_ids.stack(), state

# %%
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu

def levenshtein(seq1, seq2):  
    size_x = len(seq1) + 1
    size_y = len(seq2) + 1
    matrix = np.zeros ((size_x, size_y))
    for x in range(size_x):
        matrix [x, 0] = x
    for y in range(size_y):
        matrix [0, y] = y

    for x in range(1, size_x):
        for y in range(1, size_y):
            if seq1[x-1] == seq2[y-1]:
                matrix [x,y] = min(
                    matrix[x-1, y] + 1,
                    matrix[x-1, y-1],
                    matrix[x, y-1] + 1
                )
            else:
                matrix [x,y] = min(
                    matrix[x-1,y] + 1,
                    matrix[x-1,y-1] + 1,
                    matrix[x,y-1] + 1
                )

    return matrix[size_x - 1, size_y - 1]

def translate_en_fr(src_sent, trgt_sent, plot_att = False, verbose = False):
    
    tf.reset_default_graph()
        
    # define the trained model
    with tf.variable_scope("nmt_model", reuse=None):
        model = NMTModel()
       
    # convert sentence to word_index according to vocab
    with codecs.open(SRC_VOCAB, "r", "utf-8") as f_vocab:
        src_vocab = [w.strip() for w in f_vocab.readlines()]
        src_id_dict = dict((src_vocab[x], x) for x in range(len(src_vocab)))
    test_en_ids = [(src_id_dict[token] if token in src_id_dict else src_id_dict['<unk>'])
                   for token in src_sent.split()]

    # build inference based on saved model weights
    output_op, state_op = model.inference(test_en_ids)
    sess = tf.Session()
    saver = tf.train.Saver()
    saver.restore(sess, LAST_CKPT_PATH)

    # read translation output
    output_ids = sess.run(output_op)
    
    # convert translation idx into word
    with codecs.open(TRG_VOCAB, "r", "utf-8") as f_vocab:
        trg_vocab = [w.strip() for w in f_vocab.readlines()]
    output_text = ' '.join([trg_vocab[x] for x in output_ids])
    
    # output translation
    final_output_text = output_text.encode('utf8').decode(sys.stdout.encoding).strip('<eos>')
    
    bleu = sentence_bleu(trgt_sent.split(), final_output_text.split())
    lst = levenshtein(trgt_sent,final_output_text)
    
    if verbose:
      print("Source Sentence: " + src_sent)
      print("Real Translation: " + trgt_sent)
      print("Predicted Translation: " + final_output_text)
      print("Levenshetein Distance: " + str(lst))
      print("***BLEU Score***: "+ str(bleu))
    
    
    # PLOT ATTENTION PLOT OPTION
    
    def plot_attention(attention, src_sent, pred_sent):

      fig = plt.figure(figsize=(10,10))
      ax = fig.add_subplot(1, 1, 1)
      ax.matshow(attention, cmap='viridis')

      fontdict = {'fontsize': 14}
      
      ax.set_xticks(np.arange(len(list(src_sent.split()))))
      ax.set_yticks(np.arange(len(list(pred_sent.split()))))

      ax.set_xticklabels([''] + list(src_sent.split()), fontdict=fontdict, rotation=90)
      ax.set_yticklabels([''] + list(pred_sent.split()), fontdict=fontdict)

      plt.show()
      
    if plot_att:
      alignments = sess.run(state_op.alignment_history.stack())
      alignments = np.squeeze(alignments)
      plot_attention(alignments, src_sent, final_output_text)
      
    return final_output_text, bleu, lst
    
    sess.close()

# %%
# prediction for total test set

def test_set_pred(src_test, tgt_test, verbose = False):
  src_test = src_test
  tgt_test = tgt_test
 
  size = len(src_test)
  
  pred_list = []
  bleu_list = []
  lst_list = []

  for i in range(size):

      pred, bleu, lst = translate_en_fr(src_test[i], tgt_test[i], verbose = verbose)
      print("                                                                                         ")
      pred_list.append(pred)
      bleu_list.append(bleu)
      lst_list.append(lst)
      
      
  c_bleu = sum(bleu_list) / len(bleu_list)
  c_lst = sum(lst_list) / len(lst_list)  
   
  print("                                                                                         ")
  print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
  print("Prediction Output and Metrics on {} test sentences: ".format(size))
  print("Average BLEU Score on our test corpus is {}".format(c_bleu)) 
  print("Average Levenshetein distance Score on our test corpus is {}".format(c_lst))

# %%
test_set_pred(src_test, tgt_test, verbose = True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Source Sentence:  reconstruction of the acetabulum using femoral head autograft in total hip arthroplasties
# Real Translation:  faut il developper en france des unites de traitement de la douleur postoperatoire ?
# Predicted Translation:  la reconstruction de l amblyopie par lambeau libre de la tete femorale chez l enfant experience de ans
# Levenshetein Distance: 75.0
# ***BLEU Score***: 0.4854917717073234
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  larsen syndrome multicenter study of new cases . diagnosis , planning and results of treatment
# Real Translation:  hybridation in situ
# Predicted Translation:  syndrome de quot syndrome de lyell etude multicentrique , mise au point sur le diagnostic et le resultat du traitement en therapeutique
# Levenshetein Distance: 120.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  resistance to chemotherapy current progress
# Real Translation:  lupus erythemateux dissemine . responsabilite de la carbamazepine . a propos d un cas
# Predicted Translation:  resistance aux traitements de resistance a la chimiotherapie progres des resistances
# Levenshetein Distance: 62.0
# ***BLEU Score***: 
0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  ancient methods of surveillance and control of rinderpest
# Real Translation:  thrombose de l artere mesenterique superieure et syndrome de behcet
# Predicted Translation:  nouvelles modalites de surveillance et controle de la curietherapie apres resection tumorale de l adulte
# Levenshetein Distance: 73.0
# ***BLEU Score***: 0.5081327481546147
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Source Sentence:  first case of an outbreak of hemorrhagic septicemia caused by pasteurella multocida serotype b in northern cameroon
# Real Translation:  coma , crise convulsive et troubles de l oculomotricite hypomagnesemiques et hypocalcemiques apres chimiotherapie par sels de platine
# Predicted Translation:  premier cas d observation d araneisme m heures par de heures a meningocoque b a l hopital nord du nord cameroun dans l nord cameroun du nord cameroun
# Levenshetein Distance: 113.0
# ***BLEU Score***: 0.28517539529041497
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  gumboro disease infectious bursitis in madagascar
# Real Translation:  le syndrome de cushing alimentaire une nouvelle entite d hypercorticisme organique
# Predicted Translation:  prophylaxie infectieuses de la maladie infectieuse a madagascar a madagascar
# Levenshetein Distance: 67.0
# ***BLEU Score***: 0.668740304976422
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  treated bilateral diabetic retinopathy risks in case of pregnancy
# Real Translation:  pathologie iatrogene medicamenteuse apres ans , responsable d une hospitalisation . etude retrospective sur an dans un service de medecine interne
# Predicted Translation:  traitement de la retinopathie diabetique non invasif en cas de grossesse a partir d un traitement obstetrical ?
# Levenshetein Distance: 102.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  clinical risk factors of vitreoretinal proliferations in rhegmatogenous retinal detachment
# Real Translation:  place de la biopsie de glandes salivaires accessoires dans le syndrome de lofgren et les autres formes de sarcoidose
# Predicted Translation:  etude clinique des facteurs de risque de la chirurgie des classes de sujets nucleaires perforants des sujets de retine rhegmatogene
# Levenshetein Distance: 90.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  iris tuberculosis . a propos of a case diagnosed by iridectomy
# Real Translation:  tolerance renale du cisplatine
# Predicted Translation:  tuberculose osseuse . a propos d un cas a partir d un cas par vue d herbert cas
# Levenshetein Distance: 61.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  management of corneal microperforations during radial keratotomy
# Real Translation:  melanome ano rectal . a propos d une recidive lointaine
# Predicted Translation:  prise en charge de l eruption corneenne induite par des sequences de guidage en ligne peripherique a propos de deux observations
# Levenshetein Distance: 99.0
# ***BLEU Score***: 0.5555238068023582
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  keratitis in lyme disease
# Real Translation:  les perforations et la porosite des gants chirurgicaux . frequence , mecanisme , risque
# Predicted Translation:  keratite a pseudomonas aeruginosa dans le traitement de maladie de lyme en
# Levenshetein Distance: 63.0
# ***BLEU Score***: 0.537284965911771
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  bilateral complete cryptophthalmos . illustration with a case . review of the literature
# Real Translation:  l informatique au cabinet du chirurgien liberal . quot do it yourself quot ou quot on n est jamais si bien servi que par soi meme quot
# Predicted Translation:  ausgedehntes festsitzende acquises . illustration par un cas . revue de la litterature par une methode meconnue de reimplantation
# Levenshetein Distance: 109.0
# ***BLEU Score***: 0.47897362544357464
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  evidences for genetic transmission of pulse arterial pressure
# Real Translation:  des myalgies severes un effet indesirable inhabituel du ievamisoleassocie au fluorouracile
# Predicted Translation:  arguments pour la genetique de la pression arterielle de l hemodialyse chronique l experience de la pression pour les cellules souches
# Levenshetein Distance: 98.0
# ***BLEU Score***: 0.5555238068023582
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  activity of w sex heterochromatin and accumulation of the nuage in nurse cells of the lepidopteran ephestia
# Real Translation:  papillome oesophagien hemorragique associe a la prise d anti inflammatoires non steroidiens
# Predicted Translation:  activites de l interessement des georges nucleaires et accumulation de la reperage des medicaments a l aide des medicaments en cancerologie
# Levenshetein Distance: 101.0
# ***BLEU Score***: 0.6147881529512643
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  use of a body condition index bci for the study of the reproduction in snakes
# Real Translation:  le controle d evolution des ischemies mesenteriques aigues interet de la coelioscopie
# Predicted Translation:  utilisation d une condition de recherche pour une etude comparative de la qualite pour l etude de la reproduction dans l etude des hopitaux de recherche de la reproduction etude des actions de recherche
# Levenshetein Distance: 150.0
# ***BLEU Score***: 0.4924790605054523
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  morphological characterization of cell lines of human uveal melanoma
# Real Translation:  anticorps seriques anti muscle lisse de specificite anti actine apparus au decours d un traitement par interferon alpha
# Predicted Translation:  caracterisation morphologique des glioblastomes primitif du melanome a nouvelles perspectives
# Levenshetein Distance: 90.0
# ***BLEU Score***: 0.5623413251903491
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  effect of dietary fiber content reduction on digestive transit in the rabbit . comparison and validation of models fitted to fecal marker excretion kinetics
# Real Translation:  atteinte hepatique severe apres une course de found
# Predicted Translation:  effet des connaissances sur la reduction de la consommation des medicaments en apparence digestive chez les sujets transplantes d origine caustique . comparaison avec l index de diffusion experimentale , sur mesure de la contamination cerebrale experimentale
# Levenshetein Distance: 218.0
# ***BLEU Score***: 0.40546144983876986
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  familial thymoma and translocation t q p
# Real Translation:  hepatite algue en rapport avec la prise de terbinafine
# Predicted Translation:  gene histamine et p vus a t gene le gene p ciblees
# Levenshetein Distance: 39.0
# ***BLEU Score***: 0.41722614486115056
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  rapid in situ detection of chromosome by the prins technique
# Real Translation:  myelite algue apres immunisation contre l hepatite b par un vaccin recombinant
# Predicted Translation:  evaluation rapide du depistage rapide de la technique de interposition par la technique de titane par la technique standardisee
# Levenshetein Distance: 93.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  genetic instability in portulaca grandiflora hook
# Real Translation:  manifestations respiratoires specifiques associees a la rectocolite hemorragique . analyse d un cas et revue de la litterature
# Predicted Translation:  instabilite genetique dans les surdites publiques de pougues et de genetique
# Levenshetein Distance: 84.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  severe hyperviscosity syndrome in a hiv seropositive patient . value of plasma exchange
# Real Translation:  fistule choledocoduodenale complication rare de i ulcere duodenal
# Predicted Translation:  syndrome d apnees anonyme chez les patients co vih positif . interet de l echange arhgef
# Levenshetein Distance: 66.0
# ***BLEU Score***: 0.5247357977607321
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  amalgam under suspicion
# Real Translation:  anevrismes aortiques a yersinia enterocolitica trois nouveaux cas et revue de la litterature
# Predicted Translation:  prescriptions dans le cadre d une forme politique allergique
# Levenshetein Distance: 67.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  orthodontic treatment in the adult . the indications , treatment possibilities with and without oral surgery and the demands for and advantages of treatment
# Real Translation:  les references medicales opposables en angeiologie rmo
# Predicted Translation:  traitement orthodontique en cas de l adulte . complications de l adulte avec traitement et traitement de la minimale et de sa intervention orale et avantages d utilisation de la technique orale
# Levenshetein Distance: 156.0
# ***BLEU Score***: 0.5
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  salivary gland diseases . sialolithiasis in childhood a report of cases , the current diagnosis and therapy
# Real Translation:  gastrite hypertrophique et infection a cytomegalovirus
# Predicted Translation:  les maladies inflammatoires particulieres . a propos de l enfant . a propos de cas diagnostiques , diagnostiques et therapeutiques . a propos de quatre cas
# Levenshetein Distance: 124.0
# ***BLEU Score***: 0.5266403878479265
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  questions about amalgam are at the center of attention
# Real Translation:  veine cave superieure gauche se drainant dans le sinus coronaire . interet du doppler cardiaque foetal
# Predicted Translation:  questions a dakar et a l hopital provincial au coeur des donnees
# Levenshetein Distance: 77.0
# ***BLEU Score***: 0.38827267775222324
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  our experiences with cerebrospinal fluid rhinorrhea and its surgical treatment using an extracranial approach
# Real Translation:  chez le petit enfant asthmatique severe recherchez une allergie a l arachide
# Predicted Translation:  procedure a travers une belle accord quot grace a la procedure chirurgicale grace a la technique chirurgicale grace de la technique wnt ortho mauritanien par technique de approche privilegie
# Levenshetein Distance: 146.0
# ***BLEU Score***: 0.5124576721246791
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  historical development of the treatment of fractures of the middle third of the face involving occlusion
# Real Translation:  douleurs abdominales recurrentes revelatrices d une dermatomyosite
# Predicted Translation:  evolution originale de la fracture de la face de la face du tiers moyen de la face des tumeurs veineuses des membres inferieurs
# Levenshetein Distance: 94.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  lesions of the lingual nerve during extraction of the mandibular wisdom teeth . consequences etiopathogenesis prevention prognosis legal medical aspects
# Real Translation:  malaise apres niaprazine nopron
# Predicted Translation:  lesions de la e reunion sur les risques de la lithiase spitzner no . consequences epidemiologiques des declarations aspects epidemiologiques et consequences medicolegaux
# Levenshetein Distance: 147.0
# ***BLEU Score***: 0.4566337854967312
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  osteotomy of the median tubercule as a consequence of bilateral complete labio maxillo palatal cleft
# Real Translation:  prophylaxie de la maladie hemorragique tardive du nouveau ne par la vitamine k a la naissance
# Predicted Translation:  interet du lambeau myocutane anterolateral de la fais apres une osteotomie de garcons guillemeau
# Levenshetein Distance: 77.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  oculo orbital anatomy and nuclear magnetic resonance use in ocular growth and fetal pathology
# Real Translation:  les enclos electrifies pour betail un danger pour les enfants ?
# Predicted Translation:  anatomie orbitaire et irm de l enfant apport de l imagerie par resonance magnetique et f . premier examen
# Levenshetein Distance: 83.0
# ***BLEU Score***: 0.5695988432761473
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  american burkitt s lymphoma with mandibular involvement
# Real Translation:  cas radiologique du mois . leucoencephalopathie liee au methotrexate chez un enfant traite pour leucemie aigue lymphoblastique
# Predicted Translation:  carcinome basocellulaire congenitale avec atteinte ganglionnaire . cas n o . syndrome
# Levenshetein Distance: 90.0
# ***BLEU Score***: 0.7071067811865476
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  mandibular metastasis disclosing a papillary carcinoma of the thyroid gland
# Real Translation:  traitement de l infection urinaire de l enfant
# Predicted Translation:  metastase mandibulaire revelant un carcinome papillaire de la glande thyroide de gros collagene
# Levenshetein Distance: 68.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  maxillary ameloblastoma . apropos of a case and review of the literature
# Real Translation:  les deficiences motrices de l enfant pour une clarification nosologique dans les etudes epidemiologiques
# Predicted Translation:  ameloblastome maxillaire . a propos d un cas et revue de la litterature
# Levenshetein Distance: 78.0
# ***BLEU Score***: 0.6262844962765469
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  popliteal pterygium syndrome . a exceptional case
# Real Translation:  infirmite motrice cerebrale et asphyxie perinatale chez l enfant ne a terme
# Predicted Translation:  syndrome du colon . syndrome de shulman . un cas exceptionnel . cas exceptionnel
# Levenshetein Distance: 63.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  amyloid disease and extreme macroglossia . apropos of a case
# Real Translation:  histiocytose langerhansienne
# Predicted Translation:  maladies infectieuses et inegalites de plongee . a propos d une observation d arterite a tenir devant une tumeur amniotique
# Levenshetein Distance: 103.0
# ***BLEU Score***: 0.5623413251903491
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  infectious temporomandibular arthritis . apropos of a case in an adult
# Real Translation:  le nanisme a tete d oiseau ou syndrome de seckel . difficultes nosologiques
# Predicted Translation:  arthrite infectieuse d origine infectieuse . a propos d un cas chez un adulte adulte de ans
# Levenshetein Distance: 68.0
# ***BLEU Score***: 0.6481388934544839
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  bone non hodgkin s lymphoma , of pseudomyelomatous manifestations , in aids
# Real Translation:  troubles des conduites alimentaires et tentatives de suicide chez deux eleves danseuses
# Predicted Translation:  lymphome malin non hodgkinien de la tuberculose , au decours d une atteinte exotique , en au premier traitement du sida
# Levenshetein Distance: 88.0
# ***BLEU Score***: 0.4671379777282001
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  a retroperitoneal mass
# Real Translation:  appendicite aigue d expression clinique gauche apport diagnostique de la tomodensitometrie
# Predicted Translation:  une masse retroperitoneale bilaterale pour le diagnostic de masse retro auriculaire
# Levenshetein Distance: 62.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  the stakes of the general knowledge curriculum in the first year of medical school cpem
# Real Translation:  forme lethargique d invagination intestinale aigue du nourrisson
# Predicted Translation:  les enjeux du e connaissances de l information sur le e congres de la premiere annee de medecine generale
# Levenshetein Distance: 77.0
# ***BLEU Score***: 0.6303647413359293
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  sjogren s syndrome and virus
# Real Translation:  myelofibrose du nourrisson regressive sous corticotherapie et immunoglobulines intraveineuses
# Predicted Translation:  syndrome de gougerot et sjogren
# Levenshetein Distance: 70.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  clostridium perfringens septicemia in drug induced aplasia
# Real Translation:  infection severe a parvovirus b chez un enfant hemophile a immunocompetent
# Predicted Translation:  surdosage en immuno allergique dans sa survenue d une crise de surdosage en presence d evenements corneennes in nouveau ne dans un contexte de suite a sa suite
# Levenshetein Distance: 120.0
# ***BLEU Score***: 0.4347208719449914
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  tricuspid insufficiency disclosing carcinoid syndrome
# Real Translation:  analyse de l activite de l hospitalisation a domicile pediatrique de l assistance publique hopitaux de paris
# Predicted Translation:  insuffisance veineuse thrombo embolique veineuse le syndrome d attention aux igg
# Levenshetein Distance: 80.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  portal vein thrombosis a rare complication of crohn disease
# Real Translation:  la douleur de la ponction lombaire . resultats de annees de reflexion au sein de la societe francaise d oncologie pediatrique
# Predicted Translation:  thrombose veineuse du liquide porte complication rare de la maladie de crohn
# Levenshetein Distance: 92.0
# ***BLEU Score***: 0
#
# ...
# Predicted Translation:  un cancer gastrique a un risque d infection ahelicobacter pylori ?
# Levenshetein Distance: 61.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  francophone congress of hepatology and gastroenterology , paris , march . abstracts
# Real Translation:  bilan coronarien et chirurgie pour anevrisme aortique attitude pragmatique
# Predicted Translation:  xxx congres de l arthropodes et de l allaitement maternel , paris , mars
# Levenshetein Distance: 58.0
# ***BLEU Score***: 0.5169731539571706
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  direct cost of the ambulatory management of diabetes at the outpatient clinic of the national social security fund of sfax tunisia
# Real Translation:  depistage des malades porteurs de pheochromocytome a l aide de la methode d analyse cybernetique des signes et symptomes de la maladie
# Predicted Translation:  cout medical de la prise en charge ambulatoire du diabete a la clinique professionnelle de la region nationale francaise de sfax tunisie etat des lieux de la tunisie a notse constat de la france
# Levenshetein Distance: 134.0
# ***BLEU Score***: 0.4924790605054523
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  pitfalls of partnerships the differential status of disciplines
# Real Translation:  les possibilites nouvelles
# Predicted Translation:  pieges de la recherche clinique fait la determination et le trouble des naissances entre et des prendre en compte des prendre illustration
# Levenshetein Distance: 121.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  the child , growth and high level sports
# Real Translation:  a propos d un cas de metastase surrenalienne d un melanome cutane traite par exerese avec survie de ans
# Predicted Translation:  l enfant , la croissance et le haut temps du sport moteur . a propos de quatre enfants , re partie
# Levenshetein Distance: 79.0
# ***BLEU Score***: 0.5555238068023582
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  to grow and participate in sports
# Real Translation:  kystes bilateraux de la surrenale . a propos d une observation
# Predicted Translation:  les motifs et les sucres dans les villes d enfants diabetiques a propos des differences et quinze l activite ?
# Levenshetein Distance: 75.0
# ***BLEU Score***: 0.6223329772884784
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  reactivity of antigens of test erythrocytes in preservative solution
# Real Translation:  cortico surrenalomes malins . a propos de neuf cas
# Predicted Translation:  caracterisation des anti agregants de fibula au langage de sa frequence secondaire a la prise de vancomycine pour des signes de surface de la surface a de sa surveillance des valeurs de surface a la recherche de surveillance des maladies infectieuses du tube digestif
# Levenshetein Distance: 228.0
# ***BLEU Score***: 0.3882726777522233
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  quality control in blood transfusion centers in
# Real Translation:  problemes poses par les pheochromocytomes asymptomatiques et les formes malignes de tumeurs de la medullo surrenale
# Predicted Translation:  controle de qualite en transfusion sanguine dans les sites de transfusion sanguine en transfusion sanguine
# Levenshetein Distance: 89.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  abo system polymorphism in the tunisian population
# Real Translation:  pertes de substance de la region laterale de la face
# Predicted Translation:  polymorphisme clinique des variations biologiques dans la population tunisienne de tunisien
# Levenshetein Distance: 65.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  gene frequencies in the abo , p and lutheran systems in algeria
# Real Translation:  le cherubisme regression des lesions et regeneration osseuse spontanee
# Predicted Translation:  les tests genetiques dans le test p , p et dans le culot urinaire en afrique francophone
# Levenshetein Distance: 65.0
# ***BLEU Score***: 0.4924790605054523
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  immunohematologic surveillance of patients treated with abo incompatible bone marrow allografts
# Real Translation:  traitement d un cas d agenesies dentaires multiples solution orthodontique et implantaire
# Predicted Translation:  surveillance des patients traites par allogreffe de cellules souches hematopoietiques suivi par allo immunisations
# Levenshetein Distance: 80.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  dyslipidemia and metabolic factors in the genesis of heart attack and stroke
# Real Translation:  granulome reparateur a cellules geantes . a propos d un cas
# Predicted Translation:  dyslipidemies et facteurs de risque dans la prise en charge de l angiopathie thrombotique grave et de la prise en charge a une suspicion d accident vasculaire cerebral ischemique
# Levenshetein Distance: 142.0
# ***BLEU Score***: 0.5671276403520978
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  dysplasia and cancer developed on diffuse diverticulosis of the gallbladder . report of a case
# Real Translation:  hypercondylie mandibulaire . mise au point therapeutique
# Predicted Translation:  dysplasie et cancer papillaire de la thyroide . a propos d un cas d endometriose vesicale multiple
# Levenshetein Distance: 70.0
# ***BLEU Score***: 0.6481388934544839
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  quantification of dna using image analysis on paraffin sections
# Real Translation:  le lambeau antebrachial libre dans la chirurgie reparatrice maxillo faciale . technique operatoire et resultats de cas cliniques
# Predicted Translation:  quantification de l adn par technique de morphologie caracteristique en medecine de ville energie
# Levenshetein Distance: 93.0
# ***BLEU Score***: 0.5169731539571706
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  atypical seminiferous tubules
# Real Translation:  le reentrainement a l effort son interet pour le patient atteint de bronchopneumopathie obstructive
# Predicted Translation:  attaques de panique atypiques
# Levenshetein Distance: 81.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  a case of polypoid solitary colonic plasmocytoma
# Real Translation:  les facteurs de croissance . du laboratoire a la clinique
# Predicted Translation:  un nodule solitaire solitaire geant de la creation du pathologiste
# Levenshetein Distance: 46.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  lethal hydrops fetalis secondary to an umbilical cord hemangioma
# Real Translation:  complications de la tracheotomie
# Predicted Translation:  reservoir hypertrophiante tardive revelee par un hemangiome du cordon spermatique
# Levenshetein Distance: 63.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  congenital epulis in the newborn
# Real Translation:  donnees actuelles sur les methodes d imagerie dans le diagnostic d embolie pulmonaire aigue
# Predicted Translation:  l exerese des epulis congenitales chez nouveau nes , nouveau ne a terme
# Levenshetein Distance: 66.0
# ***BLEU Score***: 0.6262844962765469
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  dna quantification and triploidy phenotype in the second and third trimesters of pregnancy
# Real Translation:  bibliometrie des periodiques biomedicaux . addendum
# Predicted Translation:  quantification de l adn et des anomalies cutanees au deuxieme et troisieme generation des naissances de grossesse pendant la grossesse . etude retrospective de cas
# Levenshetein Distance: 132.0
# ***BLEU Score***: 0.5318295896944989
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  study of b lymphocyte clonality using in vitro gene amplification pcr in paraffin embedded samples
# Real Translation:  derives de la vitamine a et prevention des cancers bronchiques
# Predicted Translation:  etude de la bio attitudes des differents types de n a partir des recepteurs a braf en reconstruction in vitro des sites en immunohistochimie en reconstruction in vitro
# Levenshetein Distance: 128.0
# ***BLEU Score***: 0.5169731539571706
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  pulmonary involvement in the course of human immunodeficiency virus . part two non infectious complications
# Real Translation:  la rhinomanometrie
# Predicted Translation:  lymphatique pulmonaire au cours des maladies du immunodeficience humaine . grands types de types non complications non chirurgicales
# Levenshetein Distance: 116.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  pulmonary involvement in the course of human immunodeficiency virus infection . part one physiopathogenic mechanisms , diagnostic approach , infectious complications
# Real Translation:  tumeur carcinoide du thymus a un age avance interet diagnostique de la ponction biopsie mediastinaie sous tomodensitometrie
# Predicted Translation:  benefices de l atteinte pulmonaire au cours des infections respiratoires du nouveau fort . partie i approche diagnostique , des complications infectieuses et des complications infectieuses
# Levenshetein Distance: 131.0
# ***BLEU Score***: 0.5266403878479265
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  is small cell lymphoma of the stomach a pseudolymphoma , a lymphoma or an infectious disease ?
# Real Translation:  metastases pulmonaires d evolution prolongee . a propos de deux cas de cancers thyroidiens
# Predicted Translation:  le lymphome de hodgkin a t il un un lymphome , un terrain ou une maladie infectieuse ? ?
# Levenshetein Distance: 71.0
# ***BLEU Score***: 0.5695988432761473
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  aids and the lung in
# Real Translation:  pneumopathies aigues communautaires preoccupantes ou graves explorees par fibroscopie bronchique . analyse de cas hospitalises en hopital general
# Predicted Translation:  le poumon sida en dans le poumon pulmonaire en
# Levenshetein Distance: 116.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  salazosulfapyridine induced eruption . pustular erythroderma and pseudo lymphomatous syndrome cases
# Real Translation:  crises d asthme chez des enfants nicols de plus de ans observees dans un hopital pediatrique
# Predicted Translation:  eruption douloureuse allergique et syndrome de naissances pseudo expertise et syndrome de lyell . a propos de cas
# Levenshetein Distance: 86.0
# ***BLEU Score***: 0.4854917717073234
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  role of blood brain barrier in cerebral homeostasis
# Real Translation:  tracheotomie bilan de cinq ans au centre hospitalier universitaire de lome , togo
# Predicted Translation:  role de la barriere hemato encephalique en oxygene dans l homeostasie cerebrale cerebrale ?
# Levenshetein Distance: 71.0
# ***BLEU Score***: 0.5169731539571706
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  anesthesia for carotid endarterectomy
# Real Translation:  etude comparative sur les performances et l ergonomie de nebuliseurs dans la mucoviscidose
# Predicted Translation:  anesthesie pour contention capillaire et transitoire . quelles sont les applications ?
# Levenshetein Distance: 70.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  risk of secondary neuromuscular blockade after autotransfusion of blood drawn from the patient following curare administration
# Real Translation:  tomodensitometrie par balayage spirale volumique dans le diagnostic de l embolie pulmonaire centrale comparaison avec l angiographie pulmonaire et la scintigraphie pulmonaire
# Predicted Translation:  devenir de l extension neuromusculaire d apres arret du donneur de sang apres le traitement d un residu apres prise en charge du patient apres le sugammadex apres travail
# Levenshetein Distance: 137.0
# ***BLEU Score***: 0.5124576721246791
#
# INFO:tensorflow:Restoring parameters from ckpt-exp02/baha_2GRU-7800
# Source Sentence:  physiopathological consequences of blood brai
# Real Translation:  hy
# Predicted Translation:  consequences physiopathologiques et biologiques de la transfusion sanguine
# Levenshetein Distance: 73.0
# ***BLEU Score***: 0
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Prediction Output and Metrics on 400 test sentences:
# Average BLEU Score on our test corpus is 0.3260008459106327
# Average Levenshetein distance Score on our test corpus is 92.2975
