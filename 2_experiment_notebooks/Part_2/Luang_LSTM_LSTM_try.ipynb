# %%
import tensorflow as tf
import codecs
import sys
import numpy as np
import time

# %%
# !rm -rf ckpt-exp01

# %% [markdown]
# ## create vocabulary

# %%
src_path = 'en_clean.txt'
tgt_path = 'fr_clean.txt'

# %%
def read_train_data(txt_path, num_examples):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[:num_examples]

# %%
NUM_SENT=50000

src = read_train_data(src_path, NUM_SENT)
tgt = read_train_data(tgt_path, NUM_SENT)

# %%
def read_test_data(txt_path, num_examples = 400):
  text = []
  with open(txt_path, 'r', encoding="utf-8") as f:
    for line in f.readlines():
      line = line[7:-6]
      text.append(line.strip('\n'))
    return text[-num_examples:]

# %%
src_test = read_test_data(src_path)
tgt_test = read_test_data(tgt_path)

# %%
print('size of number of source sentences from dataset for training: {}'.format(len(src)))
print('size of number of target sentences from dataset for training: {}'.format(len(tgt)))
# Out:
# size of number of source sentences from dataset for training: 25388
# size of number of target sentences from dataset for training: 11370

# %%
print('size of number of source sentences from dataset for testing: {}'.format(len(src_test)))
print('size of number of target sentences from dataset for testing: {}'.format(len(tgt_test)))
# Out:
# size of number of source sentences from dataset for testing: 400
# size of number of target sentences from dataset for testing: 400

# %%
import codecs
import collections
from operator import itemgetter

def create_vocab(RAW_DATA, VOCAB_OUTPUT):
    counter = collections.Counter()

    for line in RAW_DATA:
        for word in line.strip().lower().split():
            counter[word] += 1

    sorted_word_to_cnt = sorted(counter.items(), key=itemgetter(1), reverse=True)
    sorted_words = [x[0] for x in sorted_word_to_cnt]

    sorted_words =  ['<pad>'] + ['<sos>'] + ['<eos>'] + ['<unk>'] + sorted_words 

    with codecs.open(VOCAB_OUTPUT, "w", encoding="utf-8") as file_output:
        for word in sorted_words:
            file_output.write(word + "\n")
    return sorted_words

# %%
vocab_src = create_vocab(src, 'vocab.en')
vocab_tgt = create_vocab(tgt, 'vocab.fr')

# %%
vocab_size_src = len(vocab_src)
vocab_size_tgt = len(vocab_tgt)

print('size of source vocab {}'.format(vocab_size_src))
print('size of target vocab {}'.format(vocab_size_tgt))
# Out:
# size of source vocab 20482
# size of target vocab 15996

# %% [markdown]
# ## convert text to numbers

# %%
import codecs
import sys

def text_to_int(RAW_DATA, VOCAB, OUTPUT_DATA):

  with codecs.open(VOCAB, "r", encoding="utf-8") as f_vocab:
      vocab = [w.strip() for w in f_vocab.readlines()]
      word_to_id = {k:v for (k,v) in zip(vocab, range(len(vocab)))}

  def get_id(word):
      return word_to_id[word] if word in word_to_id else word_to_id["<unk>"]

  fout = codecs.open(OUTPUT_DATA, "w", encoding="utf-8")
  for line in RAW_DATA:
      words = line.strip().split() + ["<eos>"]

      out_line = " ".join([str(get_id(w)) for w in words]) + "\n"
      fout.write(out_line)
  fout.close()

# %%
text_to_int(src, 'vocab.en', 'train.en')
text_to_int(tgt, 'vocab.fr', 'train.fr')

# %% [markdown]
# ## Create training set

# %% [markdown]
# ## Create traning set

# %%
def MakeDataset(file_path):
    dataset = tf.data.TextLineDataset(file_path)
    # split by space
    dataset = dataset.map(lambda string: tf.string_split([string]).values)
    # convert string to number
    dataset = dataset.map(
        lambda string: tf.string_to_number(string, tf.int32))
    # calc # word/sentence and put in dataset with sentence
    dataset = dataset.map(lambda x: (x, tf.size(x)))
    return dataset

def MakeSrcTrgDataset(src_path, trg_path, batch_size):

    src_data = MakeDataset(src_path)
    trg_data = MakeDataset(trg_path)
    #   ds[0][0]source sentence
    #   ds[0][1]len of source sentence
    #   ds[1][0]target sentence
    #   ds[1][1]len of target sentence
    dataset = tf.data.Dataset.zip((src_data, trg_data))

    # delete empty and super-long sentence
    def FilterLength(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        src_len_ok = tf.logical_and(
            tf.greater(src_len, 1), tf.less_equal(src_len, MAX_LEN))
        trg_len_ok = tf.logical_and(
            tf.greater(trg_len, 1), tf.less_equal(trg_len, MAX_LEN))
        return tf.logical_and(src_len_ok, trg_len_ok)
    dataset = dataset.filter(FilterLength)
    
    #   1.trg_input: "<sos> X Y Z"
    #   2.trg_label: "X Y Z <eos>"
    #   file: "X Y Z <eos>", need to produce "<sos> X Y Z" and add to dataset
    def MakeTrgInput(src_tuple, trg_tuple):
        ((src_input, src_len), (trg_label, trg_len)) = (src_tuple, trg_tuple)
        trg_input = tf.concat([[SOS_ID], trg_label[:-1]], axis=0)
        return ((src_input, src_len), (trg_input, trg_label, trg_len))
    
    dataset = dataset.map(MakeTrgInput)

    dataset = dataset.shuffle(10000)

    # define shape after padding
    padded_shapes = (
        (tf.TensorShape([None]),
         tf.TensorShape([])), 
        (tf.TensorShape([None]),
         tf.TensorShape([None]),
         tf.TensorShape([]))) 
    
    # padded_batch to pad
    batched_dataset = dataset.padded_batch(batch_size, padded_shapes)
    return batched_dataset

# %% [markdown]
# ## Define NMT

# %%
def single_rnn_cell(cell_name, hid_size, keep_prob):
    if cell_name == "GRU":
        cell = tf.contrib.rnn.GRUCell(hid_size)
    elif cell_name == "LSTM":
        cell = tf.contrib.rnn.LSTMCell(hid_size)
    elif cell_name == "BASIC":
        cell = tf.contrib.rnn.BasicRNNCell(hid_size)
    return cell

def multi_rnn_cell(cell_name, hid_size, num_layers, keep_prob):
    cells = []
    for _ in range(num_layers):
        cell = single_rnn_cell(cell_name, hid_size, keep_prob)
        cells.append(cell)
    
    if len(cells) > 1:
        final_cell = tf.contrib.rnn.MultiRNNCell(cells=cells)
    else:
        final_cell = cells[0]
    return final_cell
  
  
def single_biRNN_pair(cell_name, hid_size, keep_prob):
    if cell_name == "bi-GRU":
      enc_cell_fw = single_rnn_cell('GRU', hid_size, keep_prob)
      enc_cell_bw = single_rnn_cell('GRU', hid_size, keep_prob)
    elif cell_name == "bi-LSTM":
      enc_cell_fw = single_rnn_cell('LSTM', hid_size, keep_prob)
      enc_cell_bw = single_rnn_cell('LSTM', hid_size, keep_prob)
    return enc_cell_fw, enc_cell_bw
    
def multi_biRNN_pair(cell_name, hid_size, num_layers, keep_prob):
    stacked_biRNN_fw = []
    stacked_biRNN_bw = []
    for _ in range(num_layers):
        enc_cell_fw, enc_cell_bw = single_biRNN_pair(cell_name, hid_size, keep_prob)
        stacked_biRNN_fw.append(enc_cell_fw)
        stacked_biRNN_bw.append(enc_cell_bw)
    
    if len(stacked_biRNN_fw) > 1:
        final_stacked_biRNN_fw = tf.contrib.rnn.MultiRNNCell(cells=stacked_biRNN_fw)
        final_stacked_biRNN_bw = tf.contrib.rnn.MultiRNNCell(cells=stacked_biRNN_bw)
    else:
        final_stacked_biRNN_fw = stacked_biRNN_fw[0]
        final_stacked_biRNN_bw = stacked_biRNN_bw[0]
    return final_stacked_biRNN_fw, final_stacked_biRNN_bw

# %%
class NMTModel(object):
  """
  defind the nmt model
  
  """
  # define variables needed by nmt
  def __init__(self, 
               dec_layer, 
               enc_layer,
               dec_cell_name, 
               enc_cell_name,
               optimizer, 
               lr,
               hid_size, 
               attention,
               drop_out):
    
    self.dec_cell_name = dec_cell_name
    self.enc_cell_name = enc_cell_name
    self.dec_layer = dec_layer
    self.enc_layer = enc_layer
    self.attention = attention
    
    self.hid_size = hid_size
    self.opt = optimizer
    self.lr = lr
    
    self.keep_prob = 1.0 - drop_out

    # EMBEDDING SETUP
    
    self.src_embedding = tf.get_variable(
          "src_emb", [SRC_VOCAB_SIZE, self.hid_size])
    self.trg_embedding = tf.get_variable(
          "trg_emb", [TRG_VOCAB_SIZE, self.hid_size])

      # define variables for softmax layer
    if SHARE_EMB_AND_SOFTMAX:
         self.softmax_weight = tf.transpose(self.trg_embedding)
    else:
         self.softmax_weight = tf.get_variable(
             "weight", [self.hid_size, TRG_VOCAB_SIZE])
    self.softmax_bias = tf.get_variable(
          "softmax_bias", [TRG_VOCAB_SIZE])
     
  # calculate forward graph
  # src_input, src_size, trg_input, trg_label, trg_size are from MakeSrcTrgDataset
  
  def forward(self, src_input, src_size, trg_input, trg_label, trg_size):
      batch_size = tf.shape(src_input)[0]
      
      # *************************
      # **** EMBEDDING SCOPE ****
      # *************************
      
      with tf.variable_scope("Embeddings"):

        # convert word_int input to embeddings
        src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
        trg_emb = tf.nn.embedding_lookup(self.trg_embedding, trg_input)

        # set drop_out rate
        src_emb = tf.nn.dropout(src_emb, self.keep_prob)
        trg_emb = tf.nn.dropout(trg_emb, self.keep_prob)

      # *************************
      # ***** ENCODER SCOPE *****
      # *************************

      with tf.variable_scope("encoder"):
        
        if not 'bi' in self.enc_cell_name:
        
          enc_cell = multi_rnn_cell(self.enc_cell_name, 
                                    self.hid_size, 
                                    self.enc_layer, 
                                    self.keep_prob)
          enc_outputs, enc_state = tf.nn.dynamic_rnn(enc_cell, 
                                                     inputs=src_emb, 
                                                     sequence_length=src_size, 
                                                     dtype=tf.float32) 
        
        else:
          
          stacked_biRNN_fw, stacked_biRNN_bw = multi_biRNN_pair(self.enc_cell_name, 
                                                                self.hid_size, 
                                                                self.enc_layer, 
                                                                self.keep_prob)
          enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = stacked_biRNN_fw,
                                                                   cell_bw = stacked_biRNN_bw,
                                                                   inputs = src_emb,
                                                                   sequence_length = src_size,
                                                                   dtype = tf.float32)
          
          # concatenate two outputs of LSTM cell as 1 tensor
          # enc_outputs = (output_fw, output_bw)
          enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)
          
    
      # *************************
      # ***** DECODER SCOPE *****
      # *************************
      
      with tf.variable_scope("decoder"):
        
        dec_cell = multi_rnn_cell(self.dec_cell_name, self.hid_size, self.dec_layer, self.keep_prob)
    
    
        # OPTIONS FOR ATTENTION MECHANISM
        if self.attention == 'Bahdanau':
        
          attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                  self.hid_size, 
                  enc_outputs,
                  memory_sequence_length = src_size)
          
        if self.attention == 'Luong':

          attention_mechanism = tf.contrib.seq2seq.LuongAttention(
                  self.hid_size,
                  enc_outputs,
                  memory_sequence_length=src_size)

        # ATTENTION WRAPPER: 
        # wrap dec_cell and attention mechanisim
        attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                dec_cell, 
                attention_mechanism,
                attention_layer_size=self.hid_size)

        # use attention_cell and dynamic_rnn construct decoder
        # here relay totally on attention as the information source
        dec_outputs, _ = tf.nn.dynamic_rnn(
                attention_cell, trg_emb, trg_size, dtype=tf.float32)

        
      # ************************
      # ***** OPTIMIZATION *****
      # ************************
      
      # LOSS/LOG PERPLEXITY
      output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
      logits = tf.matmul(output, self.softmax_weight) + self.softmax_bias
      loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
          labels=tf.reshape(trg_label, [-1]), logits=logits)

      # set padding weight as 0 when calc average loss
      label_weights = tf.sequence_mask(
          trg_size, maxlen=tf.shape(trg_label)[1], dtype=tf.float32)
      label_weights = tf.reshape(label_weights, [-1])
      cost = tf.reduce_sum(loss * label_weights)
      cost_per_token = cost / tf.reduce_sum(label_weights)

      # define backprop
      trainable_variables = tf.trainable_variables()

      # OPTIONS FOR OPTIMIZER
      # define optimization method/steps
      grads = tf.gradients(cost / tf.to_float(batch_size),
                           trainable_variables)
      
      grads, _ = tf.clip_by_global_norm(grads, clip_norm = 5)

      if self.opt == 'adam':
        optimizer = tf.train.AdamOptimizer(learning_rate = self.lr)
      
      elif self.opt == 'sgd':        
        optimizer = tf.train.GradientDescentOptimizer(learning_rate = self.lr)
        
      elif self.opt == 'rmsprop':     
        optimizer = tf.train.RMSPropOptimizer(learning_rate = self.lr)
      
      train_op = optimizer.apply_gradients(zip(grads, trainable_variables))
      
      return cost_per_token, train_op

# %% [markdown]
# ## Training

# %%
def run_epoch(session, cost_op, train_op, saver, step):
    while True:
        try:
            # execute train_op and calc loss
            cost, _ = session.run([cost_op, train_op])
            if step % 100 == 0:
                print("After %d steps, per token cost is %.3f" % (step, cost))
            # save checkpoint per 200 steps
            if step % 200 == 0:
                saver.save(session, CHECKPOINT_PATH, global_step=step)
            step += 1
        except tf.errors.OutOfRangeError:
            break
    return step

# %% [markdown]
# ## Instruction - Set Hyperparameters

# %%
CHECKPOINT_PATH = "./ckpt-exp01/bi-LSTM-LSTM"  

HIDDEN_SIZE = 256
DECODER_LAYERS = 2                  # Num_layer for decoder LSTM
DECODER_CELL_TYPE = 'LSTM'
ENCODER_LAYERS = 3
ENCODER_CELL_TYPE = 'bi-LSTM'
ATTENTION = 'Luong'
OPTIMIZER = 'adam'
DROPOUT = 0.3
LEARNING_RATE = 0.001

BATCH_SIZE = 128
NUM_EPOCH = 40 


SRC_TRAIN_DATA = "train.en"
TRG_TRAIN_DATA = "train.fr"
SRC_VOCAB_SIZE = vocab_size_src       
TRG_VOCAB_SIZE = vocab_size_tgt 
SHARE_EMB_AND_SOFTMAX = True           # share weights between softmax layer and embedding layer
MAX_LEN = 100   # max length of a sentence
SOS_ID  = 1    # <sos> ID in target vocab

import time
def main():
  
    initializer = tf.random_uniform_initializer(-0.05, 0.05)
    
    tf.reset_default_graph()

    with tf.variable_scope("nmt_model", reuse=None, 
                           initializer=initializer):
        train_model = NMTModel(
                dec_layer = DECODER_LAYERS, 
                enc_layer = ENCODER_LAYERS,
                dec_cell_name =  DECODER_CELL_TYPE,
                enc_cell_name = ENCODER_CELL_TYPE,
                optimizer = OPTIMIZER, 
                lr = LEARNING_RATE,
                hid_size = HIDDEN_SIZE, 
                attention = ATTENTION,
                drop_out = DROPOUT)
  
    # define input data
    data = MakeSrcTrgDataset(SRC_TRAIN_DATA, TRG_TRAIN_DATA, BATCH_SIZE)
    iterator = data.make_initializable_iterator()
    (src, src_size), (trg_input, trg_label, trg_size) = iterator.get_next()
 
    # define forward graph
    cost_op, train_op = train_model.forward(src, src_size, trg_input,
                                            trg_label, trg_size)

    # train
    saver = tf.train.Saver()
    tf.add_to_collection('train_op', train_op)
    tf.add_to_collection('cost_op', cost_op)
    step = 0
    with tf.Session() as sess:
        writer = tf.summary.FileWriter('logs', sess.graph)
        writer.close()
        
        tf.global_variables_initializer().run()
        for i in range(NUM_EPOCH):
            time_start=time.time()
            print("-------In iteration: %d" % (i + 1))
            sess.run(iterator.initializer)
            step = run_epoch(sess, cost_op, train_op, saver, step)
            time_end=time.time()
            print('-------time cost',time_end-time_start,'s')
            print('                                        ')
            
if __name__ == "__main__":
    main()
# Out:
# -------In iteration: 1
# After 0 steps, per token cost is 9.678
# -------time cost 29.34607243537903 s
#
# -------In iteration: 2
# After 100 steps, per token cost is 6.412
# -------time cost 27.244235515594482 s
#
# -------In iteration: 3
# After 200 steps, per token cost is 6.039
# -------time cost 27.713419198989868 s
#
# -------In iteration: 4
# After 300 steps, per token cost is 5.829
# -------time cost 26.592242002487183 s
#
# -------In iteration: 5
# After 400 steps, per token cost is 5.641
# -------time cost 28.288037538528442 s
#
# -------In iteration: 6
# After 500 steps, per token cost is 5.413
# -------time cost 27.340981245040894 s
#
# -------In iteration: 7
# After 600 steps, per token cost is 5.090
# -------time cost 28.05464744567871 s
#
# -------In iteration: 8
# After 700 steps, per token cost is 4.978
# -------time cost 27.35216784477234 s
#
# -------In iteration: 9
# After 800 steps, per token cost is 4.635
# -------time cost 28.499828577041626 s
#
# -------In iteration: 10
# -------time cost 27.194098234176636 s
#
# -------In iteration: 11
# After 900 steps, per token cost is 4.161
# -------time cost 27.285410165786743 s
#
# -------In iteration: 12
# After 1000 steps, per token cost is 4.037
# -------time cost 28.095621585845947 s
#
# -------In iteration: 13
# After 1100 steps, per token cost is 3.834
# -------time cost 27.256057024002075 s
#
# -------In iteration: 14
# After 1200 steps, per token cost is 3.641
# -------time cost 27.971004962921143 s
#
# -------In iteration: 15
# After 1300 steps, per token cost is 3.727
# -------time cost 27.32123851776123 s
#
# -------In iteration: 16
# After 1400 steps, per token cost is 3.488
# -------time cost 28.528088331222534 s
#
# -------In iteration: 17
# After 1500 steps, per token cost is 3.444
# -------time cost 27.323669910430908 s
#
# -------In iteration: 18
# After 1600 steps, per token cost is 3.295
# -------time cost 28.17025899887085 s
#
# -------In iteration: 19
# -------time cost 26.92664098739624 s
#
# -------In iteration: 20
# After 1700 steps, per token cost is 2.499
# -------time cost 27.228137016296387 s
#
# -------In iteration: 21
# After 1800 steps, per token cost is 2.828
# -------time cost 28.531940937042236 s
#
# -------In iteration: 22
# After 1900 steps, per token cost is 2.590
# -------time cost 26.621761083602905 s
#
# -------In iteration: 23
# After 2000 steps, per token cost is 2.481
# -------time cost 27.66007947921753 s
#
# -------In iteration: 24
# After 2100 steps, per token cost is 2.584
# -------time cost 28.0395245552063 s
#
# -------In iteration: 25
# After 2200 steps, per token cost is 2.492
# -------time cost 27.627832651138306 s
#
# -------In iteration: 26
# After 2300 steps, per token cost is 2.383
# -------time cost 26.669593811035156 s
#
# -------In iteration: 27
# After 2400 steps, per token cost is 2.321
# -------time cost 28.97468137741089 s
#
# -------In iteration: 28
# -------time cost 27.523640394210815 s
#
# -------In iteration: 29
# After 2500 steps, per token cost is 1.861
# -------time cost 27.11071538925171 s
#
# -------In iteration: 30
# After 2600 steps, per token cost is 1.951
# -------time cost 27.86179256439209 s
#
# -------In iteration: 31
# After 2700 steps, per token cost is 1.744
# -------time cost 26.671422243118286 s
#
# -------In iteration: 32
# After 2800 steps, per token cost is 1.679
# -------time cost 27.99224853515625 s
#
# -------In iteration: 33
# After 2900 steps, per token cost is 1.657
# -------time cost 27.015228748321533 s
#
# -------In iteration: 34
# After 3000 steps, per token cost is 1.680
# -------time cost 27.627582788467407 s
#
# -------In iteration: 35
# After 3100 steps, per token cost is 1.594
# -------time cost 27.01617693901062 s
#
# -------In iteration: 36
# After 3200 steps, per token cost is 1.633
# -------time cost 27.89357852935791 s
#
# -------In iteration: 37
# -------time cost 26.788231372833252 s
#
# -------In iteration: 38
# After 3300 steps, per token cost is 1.225
# -------time cost 27.4799063205719 s
#
# -------In iteration: 39
# After 3400 steps, per token cost is 1.230
# -------time cost 28.757731676101685 s
#
# -------In iteration: 40
# After 3500 steps, per token cost is 1.226
# -------time cost 27.026421070098877 s

# %%
import tensorflow.contrib.slim as slim

def model_summary():
    model_vars = tf.trainable_variables()
    slim.model_analyzer.analyze_vars(model_vars, print_info=True)

model_summary()
# Out:
# ---------
# Variables: name (type shape) [size]
# ---------
# nmt_model/src_emb:0 (float32_ref 20482x256) [5243392, bytes: 20973568]
# nmt_model/trg_emb:0 (float32_ref 15996x256) [4094976, bytes: 16379904]
# nmt_model/softmax_bias:0 (float32_ref 15996) [15996, bytes: 63984]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/kernel:0 (float32_ref 512x1024) [524288, bytes: 2097152]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/kernel:0 (float32_ref 512x1024) [524288, bytes: 2097152]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_2/lstm_cell/kernel:0 (float32_ref 512x1024) [524288, bytes: 2097152]
# encoder/bidirectional_rnn/fw/multi_rnn_cell/cell_2/lstm_cell/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/kernel:0 (float32_ref 512x1024) [524288, bytes: 2097152]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_0/lstm_cell/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/kernel:0 (float32_ref 512x1024) [524288, bytes: 2097152]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_1/lstm_cell/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_2/lstm_cell/kernel:0 (float32_ref 512x1024) [524288, bytes: 2097152]
# encoder/bidirectional_rnn/bw/multi_rnn_cell/cell_2/lstm_cell/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# decoder/memory_layer/kernel:0 (float32_ref 512x256) [131072, bytes: 524288]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_0/lstm_cell/kernel:0 (float32_ref 768x1024) [786432, bytes: 3145728]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_0/lstm_cell/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_1/lstm_cell/kernel:0 (float32_ref 512x1024) [524288, bytes: 2097152]
# decoder/rnn/attention_wrapper/multi_rnn_cell/cell_1/lstm_cell/bias:0 (float32_ref 1024) [1024, bytes: 4096]
# decoder/rnn/attention_wrapper/attention_layer/kernel:0 (float32_ref 768x256) [196608, bytes: 786432]
# Total size of variables: 14146684
# Total bytes of variables: 56586736

# %%
# read checkpoint path, number indicates the latest step
LAST_CKPT_PATH = "ckpt-exp01/bi-LSTM-LSTM-3400"

# file for vocab
SRC_VOCAB = "vocab.en"
TRG_VOCAB = "vocab.fr"
SRC_VOCAB_SIZE = vocab_size_src       
TRG_VOCAB_SIZE = vocab_size_tgt 

# ID for <sos> and <eos> in vocab
SOS_ID = 1
EOS_ID = 2

SHARE_EMB_AND_SOFTMAX = True

# %%
class NMTModel(object):
  """
  defind the nmt model
  
  """
  # define variables needed by nmt
  def __init__(self, 
               dec_layer = DECODER_LAYERS, 
               enc_layer = ENCODER_LAYERS,
               dec_cell_name = DECODER_CELL_TYPE, 
               enc_cell_name = ENCODER_CELL_TYPE,
               optimizer = OPTIMIZER, 
               lr = LEARNING_RATE,
               hid_size = HIDDEN_SIZE, 
               attention = ATTENTION,
               drop_out = DROPOUT):
    
    self.dec_cell_name = dec_cell_name
    self.enc_cell_name = enc_cell_name
    self.dec_layer = dec_layer
    self.enc_layer = enc_layer
    self.attention = attention
    
    self.hid_size = hid_size
    self.opt = optimizer
    self.lr = lr
    
    self.keep_prob = 1.0 - drop_out

    # EMBEDDING SETUP
    
    self.src_embedding = tf.get_variable(
          "src_emb", [SRC_VOCAB_SIZE, self.hid_size])
    self.trg_embedding = tf.get_variable(
          "trg_emb", [TRG_VOCAB_SIZE, self.hid_size])

      # define variables for softmax layer
    if SHARE_EMB_AND_SOFTMAX:
         self.softmax_weight = tf.transpose(self.trg_embedding)
    else:
         self.softmax_weight = tf.get_variable(
             "weight", [self.hid_size, TRG_VOCAB_SIZE])
    self.softmax_bias = tf.get_variable(
          "softmax_bias", [TRG_VOCAB_SIZE])
  
  def inference(self, src_input):
      # As dynamic rnn requires batch input, 
      # to infer one single sentence, we set batch = 1
      src_size = tf.convert_to_tensor([len(src_input)], dtype=tf.int32)
      src_input = tf.convert_to_tensor([src_input], dtype=tf.int32)
      src_emb = tf.nn.embedding_lookup(self.src_embedding, src_input)
      
     
      # *************************
      # ***** ENCODER SCOPE *****
      # *************************

      with tf.variable_scope("encoder"):
        
        if not 'bi' in self.enc_cell_name:
        
          enc_cell = multi_rnn_cell(self.enc_cell_name, 
                                    self.hid_size, 
                                    self.enc_layer, 
                                    self.keep_prob)
          enc_outputs, enc_state = tf.nn.dynamic_rnn(enc_cell, 
                                                     inputs=src_emb, 
                                                     sequence_length=src_size, 
                                                     dtype=tf.float32) 
        
        else:
          
          stacked_biRNN_fw, stacked_biRNN_bw = multi_biRNN_pair(self.enc_cell_name, 
                                                                self.hid_size, 
                                                                self.enc_layer, 
                                                                self.keep_prob)
          enc_outputs, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = stacked_biRNN_fw,
                                                                   cell_bw = stacked_biRNN_bw,
                                                                   inputs = src_emb,
                                                                   sequence_length = src_size,
                                                                   dtype = tf.float32)
          
          # concatenate two outputs of LSTM cell as 1 tensor
          # enc_outputs = (output_fw, output_bw)
          enc_outputs = tf.concat([enc_outputs[0], enc_outputs[1]], -1)
          
    
      # *************************
      # ***** DECODER SCOPE *****
      # *************************
      
      with tf.variable_scope("decoder"):
        
        dec_cell = multi_rnn_cell(self.dec_cell_name, self.hid_size, self.dec_layer, self.keep_prob)
    
    
        # OPTIONS FOR ATTENTION MECHANISM
        if self.attention == 'Bahdanau':
        
          attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(
                  self.hid_size, 
                  enc_outputs,
                  memory_sequence_length = src_size)
          
        if self.attention == 'Luong':

          attention_mechanism = tf.contrib.seq2seq.LuongAttention(
                  self.hid_size,
                  enc_outputs,
                  memory_sequence_length=src_size
                  )

        # ATTENTION WRAPPER: 
        # wrap dec_cell and attention mechanisim
        attention_cell = tf.contrib.seq2seq.AttentionWrapper(
                dec_cell, 
                attention_mechanism,
                attention_layer_size=self.hid_size,
                alignment_history=True)

      # Set the max step for decoder
      MAX_DEC_LEN=100

      with tf.variable_scope("decoder/rnn/attention_wrapper"):
        # use TensorArray store produced sentence
        init_array = tf.TensorArray(dtype=tf.int32, size=0,
            dynamic_size=True, clear_after_read=False)
        # start input for decoder with <sos> tag
        init_array = init_array.write(0, SOS_ID)
        # initilize attention cell
        init_loop_var = (
            attention_cell.zero_state(batch_size=1, dtype=tf.float32),
            init_array, 0)

        # condition for tf.while_loop：
        # loop until decoder outputs <eos> or hit max length setting
        def continue_loop_condition(state, trg_ids, step):
            return tf.reduce_all(tf.logical_and(
                tf.not_equal(trg_ids.read(step), EOS_ID),
                tf.less(step, MAX_DEC_LEN-1)))

        def loop_body(state, trg_ids, step):
            # read last step output as input for attention cell
            trg_input = [trg_ids.read(step)]
            trg_emb = tf.nn.embedding_lookup(self.trg_embedding,
                                             trg_input)
            # FORWARD calc ATTENTION CELL and output decoder outputs/state
            dec_outputs, next_state = attention_cell.call(
                state=state, inputs=trg_emb)

            # calc logit for each candidate target vocab
            # select the max as output
            output = tf.reshape(dec_outputs, [-1, HIDDEN_SIZE])
            logits = (tf.matmul(output, self.softmax_weight)
                      + self.softmax_bias)
            next_id = tf.argmax(logits, axis=1, output_type=tf.int32)
            # write output word into trg_ids
            trg_ids = trg_ids.write(step+1, next_id[0])
            return next_state, trg_ids, step+1

        # execute tf.while_loop return trg_ides
        state, trg_ids, step = tf.while_loop(
            continue_loop_condition, loop_body, init_loop_var)
        
        return trg_ids.stack(), state

# %%
import matplotlib.pyplot as plt
from nltk.translate.bleu_score import sentence_bleu

def levenshtein(seq1, seq2):  
    size_x = len(seq1) + 1
    size_y = len(seq2) + 1
    matrix = np.zeros ((size_x, size_y))
    for x in range(size_x):
        matrix [x, 0] = x
    for y in range(size_y):
        matrix [0, y] = y

    for x in range(1, size_x):
        for y in range(1, size_y):
            if seq1[x-1] == seq2[y-1]:
                matrix [x,y] = min(
                    matrix[x-1, y] + 1,
                    matrix[x-1, y-1],
                    matrix[x, y-1] + 1
                )
            else:
                matrix [x,y] = min(
                    matrix[x-1,y] + 1,
                    matrix[x-1,y-1] + 1,
                    matrix[x,y-1] + 1
                )

    return matrix[size_x - 1, size_y - 1]

def translate_en_fr(src_sent, trgt_sent, plot_att = False, verbose = False):
    
    tf.reset_default_graph()
        
    # define the trained model
    with tf.variable_scope("nmt_model", reuse=None):
        model = NMTModel()
       
    # convert sentence to word_index according to vocab
    with codecs.open(SRC_VOCAB, "r", "utf-8") as f_vocab:
        src_vocab = [w.strip() for w in f_vocab.readlines()]
        src_id_dict = dict((src_vocab[x], x) for x in range(len(src_vocab)))
    test_en_ids = [(src_id_dict[token] if token in src_id_dict else src_id_dict['<unk>'])
                   for token in src_sent.split()]

    # build inference based on saved model weights
    output_op, state_op = model.inference(test_en_ids)
    sess = tf.Session()
    saver = tf.train.Saver()
    saver.restore(sess, LAST_CKPT_PATH)

    # read translation output
    output_ids = sess.run(output_op)
    
    # convert translation idx into word
    with codecs.open(TRG_VOCAB, "r", "utf-8") as f_vocab:
        trg_vocab = [w.strip() for w in f_vocab.readlines()]
    output_text = ' '.join([trg_vocab[x] for x in output_ids])
    
    # output translation
    final_output_text = output_text.encode('utf8').decode(sys.stdout.encoding).strip('<eos>')
    
    bleu = sentence_bleu(trgt_sent.split(), final_output_text.split())
    lst = levenshtein(trgt_sent,final_output_text)
    
    if verbose:
      print("Source Sentence: " + src_sent)
      print("Real Translation: " + trgt_sent)
      print("Predicted Translation: " + final_output_text)
      print("Levenshetein Distance: " + str(lst))
      print("***BLEU Score***: "+ str(bleu))
    
    
    # PLOT ATTENTION PLOT OPTION
    
    def plot_attention(attention, src_sent, pred_sent):

      fig = plt.figure(figsize=(10,10))
      ax = fig.add_subplot(1, 1, 1)
      ax.matshow(attention, cmap='viridis')

      fontdict = {'fontsize': 14}
      
      ax.set_xticks(np.arange(len(list(src_sent.split()))))
      ax.set_yticks(np.arange(len(list(pred_sent.split()))))

      ax.set_xticklabels([''] + list(src_sent.split()), fontdict=fontdict, rotation=90)
      ax.set_yticklabels([''] + list(pred_sent.split()), fontdict=fontdict)

      plt.show()
      
    if plot_att:
      alignments = sess.run(state_op.alignment_history.stack())
      alignments = np.squeeze(alignments)
      plot_attention(alignments, src_sent, final_output_text)
      
    return final_output_text, bleu, lst
    
    sess.close()

# %%
def test_set_pred(src_test, tgt_test, verbose = False):
  src_test = src_test
  tgt_test = tgt_test
 
  size = len(src_test)
  
  pred_list = []
  bleu_list = []
  lst_list = []

  for i in range(size):

      pred, bleu, lst = translate_en_fr(src_test[i], tgt_test[i], verbose = verbose)
      print("                                                                                         ")
      pred_list.append(pred)
      bleu_list.append(bleu)
      lst_list.append(lst)
      
      
  c_bleu = sum(bleu_list) / len(bleu_list)
  c_lst = sum(lst_list) / len(lst_list)  
   
  print("                                                                                         ")
  print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
  print("Prediction Output and Metrics on {} test sentences: ".format(size))
  print("Average BLEU Score on our test corpus is {}".format(c_bleu)) 
  print("Average Levenshetein distance Score on our test corpus is {}".format(c_lst))

# %%
test_set_pred(src_test, tgt_test, verbose = True)
# Out:
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  characteristics of meningococcal meningitis in children in france
# Real Translation:  l anemie par carence en fer
# Predicted Translation:  caracteristiques de la diversite des leucemies aigues de patients en tunisie
# Levenshetein Distance: 60.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Source Sentence:  bladder endometriosis diagnosis and treatment . a series of patients
# Real Translation:  thrombose veineuse cerebrale et polyradiculonevrite aigue revelant un lupus erythemateux dissemine
# Predicted Translation:  kwashiorkor chez l adulte et l adulte . a propos d un cas
# Levenshetein Distance: 73.0
# ***BLEU Score***: 0.7447819789879647
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  dobesilate induced serious neutropenia
# Real Translation:  maladie d alzheimer , memoire et estrogenes
# Predicted Translation:  lesions de la voie de grossesse
# Levenshetein Distance: 31.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  intravesical migration of intrauterine devices
# Real Translation:  dystonies monogeniques l hypothese dopaminergique revisitee
# Predicted Translation:  instillations endovesicales darts le muscle
# Levenshetein Distance: 41.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  indications of anakinra
# Real Translation:  implants de refection de paroi lequel , dans quelle indication ? analyse de la commission d evaluation des produits et prestations de la haute autorite de sante has . evaluation des implants de refection de paroi
# Predicted Translation:  osteopathies fragilisantes et vomissements de la maladie de vie
# Levenshetein Distance: 168.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Source Sentence:  drug facilitated crimes prospective data collection in a forensic unit in paris
# Real Translation:  tuberculose lymphonodale cervicale prise en charge diagnostique et therapeutique
# Predicted Translation:  vaccins et antidepresseurs de basse impact de protection de dans le paludisme et de l exposition a l exposition a l exposition a l organisme
# Levenshetein Distance: 105.0
# ***BLEU Score***: 0.2659147948472494
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  acute traumatic haemorrhagic shock and transfusion what s new in ?
# Real Translation:  actualites sur les leishmanioses en france
# Predicted Translation:  rupture aigue aigue et rupture d hemorragie des angiopathie et rupture des troubles cliniques et hyperplasie de rupture et association des troubles plasmatiques et hyperplasie de rupture ?
# Levenshetein Distance: 157.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  monitoring of postoperative regional analgesia
# Real Translation:  la fievre boutonneuse mediterraneenne chez l enfant
# Predicted Translation:  surveillance de l infection dans le traitement de la transplantation systemique
# Levenshetein Distance: 60.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  use of ephedrine prefilled syringes reduces anesthesia costs
# Real Translation:  paludisme d importation pieges diagnostiques et tests de diagnostic rapide
# Predicted Translation:  utilisation de l activite anti tal dans le traitement de la polyarthrite rhumatoide
# Levenshetein Distance: 59.0
# ***BLEU Score***: 0.5266403878479265
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  survey of anaesthesia related mortality in france the role of aspiration of gastric contents
# Real Translation:  infections a virus west nile en pediatrie
# Predicted Translation:  enquete nationale sur la couverture vaccinale de l scolaire et de l extreme . en
# Levenshetein Distance: 55.0
# ***BLEU Score***: 0.5081327481546147
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  impact of sophrology on non invasive ventilation tolerance in patients with acute respiratory failure
# Real Translation:  la dengue aspects cliniques
# Predicted Translation:  impact de l offre de vie sur la psychiatrie et de l annee de patients en situation de l aorte chronique de l enfant
# Levenshetein Distance: 96.0
# ***BLEU Score***: 0.4518010018049224
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  ascites of unusual etiology
# Real Translation:  infections a virus chikungunya chez l enfant
# Predicted Translation:  arterite prematuree de la membrane epimaculaire haute souffrance modernes neurochirurgie ans carcinologiques portant suspect
# Levenshetein Distance: 100.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  management of convulsive status epilepticus therapeutic strategies
# Real Translation:  actualites sur la presence du moustique tigre aedes albopictus en france metropolitaine
# Predicted Translation:  prise en charge des evenements cognitives en oncologie
# Levenshetein Distance: 62.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  electroencephalography in status epilepticus glossary , protocol and interpretation
# Real Translation:  zoonoses en pediatrie quoi de neuf en ? avant propos
# Predicted Translation:  strategies de coordination des patients atteints de soins et approche personnalise
# Levenshetein Distance: 57.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  a succession plan is needed for operating room nurses
# Real Translation:  prevalence des anticorps de l hepatite a chez l enfant dans la region de marrakech
# Predicted Translation:  reentrainement bouddhiste juridiques juridiques communaute juridiques communaute juridiques communaute juridiques communaute faisabilite faisabilite faisabilite faisabilite communaute subsidiaires aufzeigen communaute collectif communaute futurs collectif communaute collectif communaute futurs collectif communaute collectif communaute futurs collectif communaute futurs collectif futurs collectif communaute futurs collectif temoin temoin temoin temoin temoin temoin temoin temoin temoin temoin detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes collectif communaute futurs collectif temoin detournes detournes detournes detournes detourn
# Levenshetein Distance: 903.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  a road traffic accident leads to a fortuitous malaria diagnosis
# Real Translation:  recidive sous forme pseudotumorale d une leishmaniose viscerale
# Predicted Translation:  un cyber regard pour la maladie du alzheimer
# Levenshetein Distance: 48.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  ringer s lactate and red blood cells is there sufficient evidence to recommend for routine use ?
# Real Translation:  un passager clandestin a ne pas meconnaitre dermatobia hominis , a propos d un cas
# Predicted Translation:  e entre arbre de produits de vie entre leur defibrillateur ? . . . . . leur reglementation pour les hommes francaises essentiels a l article e ?
# Levenshetein Distance: 111.0
# ***BLEU Score***: 0.6147881529512643
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  control of the quality of cotrimoxazole medicines used in senegal
# Real Translation:  syphilis congenitale a propos d un cas
# Predicted Translation:  l qualite de la qualite de vie sur la commune de l universite de la sante mentale au senegal
# Levenshetein Distance: 72.0
# ***BLEU Score***: 0.47897362544357464
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  control of the quality of acetylsalicylic acid and paracetamol used in senegal
# Real Translation:  prevention par insectifuge chez l enfant
# Predicted Translation:  quels former de la qualite de vie et de la cigarette electronique dans la prise en charge de la personne algerie
# Levenshetein Distance: 88.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  how i do . . . to define circumstances of an immediate conversion into a laparotomy , during a laparoscopic or a robotically assisted laparoscopic surgery
# Real Translation:  meningo encephalite a tiques chez l enfant
# Predicted Translation:  comment je fais le diagnostic cheetah majeure pour mieux je look quot . je mimant un cancer mimant un cancer d pr rien
# Levenshetein Distance: 93.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  development of actions for the prevention of hiv , hepatitis and sexually transmitted infections among immigrants consulting in the doctors of the world quot missions france quot
# Real Translation:  grippe aviaire chez l enfant
# Predicted Translation:  performance faisabilite pharmacologique pharmacologique pharmacologique et l encadrement faisabilite de faisabilite faisabilite de faisabilite faisabilite
# Levenshetein Distance: 134.0
# ***BLEU Score***: 0.5081327481546147
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  facial locoregional anesthetics principles and precautions
# Real Translation:  prise en charge de la detresse respiratoire severe du nouveau ne place du no inhale
# Predicted Translation:  physiopathologie et degradations de la neovascularisation botulique
# Levenshetein Distance: 61.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  bilateral latissimus dorsi v y musculocutaneous rotation flap for closure of a large dorsal radionecrosis . geometric analysis and interest . about one case
# Real Translation:  consequences obstetricales et pediatriques de la consommation de cocaine pendant la grossesse
# Predicted Translation:  amylose bilaterale bilaterale du muscle et triple triple triple triple triple triple triple triple triple triple triple triple triple triple triple triple triple atteint de la chirurgie postoperatoire de la chirurgie postoperatoire sur la chirurgie de l sophage de chirurgie de la chirurgie postoperatoire sur la chirurgie de chirurgie de la chirurgie postoperatoire portant , muscle muscle et lipome de chirurgie postoperatoire portant , lipome ? portant lipome ?
# Levenshetein Distance: 399.0
# ***BLEU Score***: 0.346966645494591
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  necrotizing fasciitis after a blunt trauma
# Real Translation:  niveaux de preuves versus pratiques cliniques l exemple de l extreme prematurite
# Predicted Translation:  prise en charge de l infection par le vih
# Levenshetein Distance: 61.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  the solid pseudopapillary tumor of pancreas two cases and literature review
# Real Translation:  devenir renal des enfants nes grands prematures un suivi simple mais regulier est necessaire
# Predicted Translation:  resection evolutif de l thrombocytemie vesicale et exception chez hyperactivite medicamenteuse basee faisabilite de l adulte de hypertendus oncologique operes basee juridiques prise detournes detournes detournes detournes detournes
# Levenshetein Distance: 178.0
# ***BLEU Score***: 0.4347208719449914
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  sleep disorders sociodemographics and psychiatric comorbidities in a sample of , adults in france barometre sante inpes
# Real Translation:  anomalies oculaires en maternite et dans les premieres semaines de vie un depistage obligatoire , difficile et neglige
# Predicted Translation:  comorbidite automutilation pneumococciques etiologiques futurs inconvenients inconvenients inconvenients kbp preoccupante preoccupante thromboembolique thromboembolique thromboembolique futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futur
# Levenshetein Distance: 719.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  secondary superficial siderosis of the central nervous system report of three cases
# Real Translation:  ethique et medecine perinatale deux etapes de la reflexion professionnelle francaise ,
# Predicted Translation:  section gestationis expectative revelee revelee echocardiographique carcinologiques faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite detournes faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite detournes faisabilite faisabilite faisabilite detournes faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite futurs futurs futurs pathogenese detournes faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite futurs futurs futurs futurs pathogenese detournes faisabilite faisabilite faisabilite faisabilit
# Levenshetein Distance: 1070.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  ten years old and still learning to walk
# Real Translation:  prises en charge educatives specifiques de l enfant grand premature a et ans resultats de l etude epipage
# Predicted Translation:  dix ans a l hopital de l adolescent
# Levenshetein Distance: 85.0
# ***BLEU Score***: 0.7071067811865476
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  medicine is facing a crisis
# Real Translation:  effet du no inhale sur le poumon et le cerveau en developpement
# Predicted Translation:  simulation civile en prise soignante soignante ressenti soignante esther faisabilite faisabilite soignante soignante faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes detournes faisabilite faisabilit
# Levenshetein Distance: 1008.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  cesarean of convenience
# Real Translation:  l insuffisance renale aigue au burkina faso
# Predicted Translation:  amyloses penienne
# Levenshetein Distance: 36.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  is the vegetative patient really conscious ?
# Real Translation:  quadriparesie hypokaliemique revelant un syndrome de gougerot sjogren associe a une thyroidite auto immune
# Predicted Translation:  l information est il non et de reflexion des patients porteurs de l information du patient ? ?
# Levenshetein Distance: 84.0
# ***BLEU Score***: 0.4854917717073234
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  health insurance the fight over allowance has begun
# Real Translation:  prise en charge psychologique des echecs de procreation , au masculin une blessure peut en cacher une autre
# Predicted Translation:  cigarette initiative . . . . . quot
# Levenshetein Distance: 89.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  oncology
# Real Translation:  approches non invasives de l embryon proteomique , metabolomique , dialogue ovocyte cumulus
# Predicted Translation:  une meta synthese pour le vih
# Levenshetein Distance: 74.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  treatment and prevention of venous thromboembolic disease what s new ?
# Real Translation:  transfert embryonnaire en cas de col stenose et ou infranchissable
# Predicted Translation:  prise en charge prise soignante des membranes . sus peripheriques de l prise soignante en question clinique ?
# Levenshetein Distance: 82.0
# ***BLEU Score***: 0.4854917717073234
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  medical therapy in peripheral arterial occlusive disease
# Real Translation:  quatorziemes journees nationales de la federation francaise d etude de la reproduction clermont ferrand , novembre
# Predicted Translation:  particularites d un syndrome de i assistance en psychiatrie
# Levenshetein Distance: 84.0
# ***BLEU Score***: 0.6865890479690392
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  cardiovascular markers
# Real Translation:  fracture isolee de l os trapezoide a propos d un cas
# Predicted Translation:  microbiote virales et rein etude observationnelle
# Levenshetein Distance: 41.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  the new antithrombotics in
# Real Translation:  modifications peri operatoires de la fonction renale
# Predicted Translation:  watermelon et contraception du cerveau
# Levenshetein Distance: 40.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  to live with lymphedema present and future
# Real Translation:  education therapeutique des enfants et adolescents atteints de maladie chronique
# Predicted Translation:  etre et phenomene d organe et du droit
# Levenshetein Distance: 58.0
# ***BLEU Score***: 0.5946035575013605
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  problems related to hemodialysis vascular accesses a regional network of care
# Real Translation:  ischemie mesenterique aigue secondaire a une cardiomyopathie du peripartum
# Predicted Translation:  participation gerontologique gerontologique refractaire communaute culturelle faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite marocaine faisabilite detournes detournes detournes detournes detournes detournes detournes communaute detournes detournes detournes detournes communaute marocaine communaute futurs avril communaute futurs avril communaute futurs avril communaute futurs avril communaute futurs avril communaute futurs avril communaute futurs avril communaute futurs avril communaute futurs avril communaute futurs futurs futurs avril communaute futurs futurs futurs avril communaute futurs futurs futurs avril communaute futurs futurs futurs avril communaute futurs futurs futurs avril communaute futurs futurs futurs avril communaute futurs futurs futurs avril communaute futurs futurs futurs avril communaut
# Levenshetein Distance: 815.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  angiography need for a multidisciplinary approach
# Real Translation:  coma hyponatremique induit par la desmopressine chez une patiente atteinte de maladie de willebrand
# Predicted Translation:  modifications epidemiocliniques concernant l essai colloques hypotheses correlation vais communaute legale communaute hypotheses basee detournes detournes detournes detournes detournes detournes detournes memes memes communaute legale onusida memes memes communaute legale detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes und und fertil und und seit trotz und seit trotz initiative communaute memes communaute legale detournes detournes und und fertil und und seit trotz initiative communaute memes communaute legale detournes detournes und und fertil und und seit trotz initiative communaute memes communaute legale detournes detournes und und fertil und und seit trotz memes communaut
# Levenshetein Distance: 704.0
# ***BLEU Score***: 0.31702331385234306
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  moratorium the situation deteriorates !
# Real Translation:  tuberculose compliquee d un syndrome hemophagocytaire ou syndrome d activation macrophagique
# Predicted Translation:  participation aux pairs doi t elle communaute legale neurochirurgie basee statistiques des connaissances neurochirurgie basee statistiques basee basee smt avril
# Levenshetein Distance: 125.0
# ***BLEU Score***: 0.4728708045015879
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  sacred dna
# Real Translation:  les enterovirus responsables de conjonctivite aigue hemorragique
# Predicted Translation:  uveites
# Levenshetein Distance: 59.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  the vatican , reproduction , and eugenics
# Real Translation:  meningites communautaires a staphylococcus aureus meticilline sensible
# Predicted Translation:  liens et adultes droit et et bien bien bien bien bien bien ?
# Levenshetein Distance: 56.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  why nicotine cannot help with weaning from tobacco
# Real Translation:  dix huit consultations et entretiens pour une grossesse a bas risque n est ce pas trop ? a moins d en profiter pleinement pour une demarche de prevention mere et enfant !
# Predicted Translation:  reentrainement rendu integree prehospitaliere preliminaires preliminaires soignante faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite futurs futurs futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs communaute futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futurs futur
# Levenshetein Distance: 752.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  laboratory response to pascal couchepin
# Real Translation:  hypertension intracranienne benigne et grossesse . a propos de deux cas
# Predicted Translation:  prevenir l cible indesirable de l hepatite dangereux
# Levenshetein Distance: 50.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  trends in surgery
# Real Translation:  les criteres diagnostiques de la maladie de takayasu
# Predicted Translation:  pathologie de pathologie orl
# Levenshetein Distance: 39.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  a primer on the management of antiviral resistance in chronic hepatitis b
# Real Translation:  une maladie d importation rare la lepre
# Predicted Translation:  un guide pour un depistage pour lutter contre les femmes et de l hepatite b
# Levenshetein Distance: 54.0
# ***BLEU Score***: 0.5081327481546147
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  highlights in hepatology
# Real Translation:  myosite a inclusions trompeuse savoir repeter la biopsie musculaire
# Predicted Translation:  hyperaldosteronisme et neurodroit
# Levenshetein Distance: 51.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  main therapeutic advances in ibd in
# Real Translation:  epidemiologie de la tuberculose dans les pays du maghreb
# Predicted Translation:  prise en charge des mucopolysaccharidoses
# Levenshetein Distance: 42.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  investigations for esophageal motility and reflux
# Real Translation:  l anemie chez le patient drepanocytaire adulte
# Predicted Translation:  les fistules inflammatoires respiratoires et ischemie du myocarde
# Levenshetein Distance: 47.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  progress in for acid related diseases
# Real Translation:  la co infection vih tuberculose
# Predicted Translation:  infections congenitales operes dans le cadre de vie de patients operes en tunisie
# Levenshetein Distance: 63.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  therapeutic combinations
# Real Translation:  imagerie d une druse de la tete du nerf optique
# Predicted Translation:  amyloses
# Levenshetein Distance: 44.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  the factors for progression of the diabetic nephropathy management and evolution
# Real Translation:  les thromboses veineuses cerebrales en milieu hospitalier a ouagadougou burkina faso
# Predicted Translation:  determinants de l adolescent et jeunes agees et de la carence en plaques
# Levenshetein Distance: 63.0
# ***BLEU Score***: 0.5266403878479265
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  digestive adverse effects due to sodium polystyrene sulfonate kayexalate in dialysis patients
# Real Translation:  traitement de la myasthenie auto immune
# Predicted Translation:  effets indesirables medicamenteux et nourrissons de la vitamine de vitamine de vitamine de vitamine de vitamine de vitamine de vitamine systemique ?
# Levenshetein Distance: 119.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  electronic tissue compensation for breast external radiotherapy use of digital reconstructive radiography
# Real Translation:  nouveau modele de miniplaques pour les osteotomies maxillaires
# Predicted Translation:  gouvernance civile haute pays et infertilite hypotheses
# Levenshetein Distance: 42.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  primary gougerot sjogren syndrome and behcet disease association or coincidence ?
# Real Translation:  tumeurs musculaires des machoires
# Predicted Translation:  rupture du syndrome de gougerot cause association comment comment cause digestifs comment cause therapeutique de rupture primaire et indication diagnostiques ?
# Levenshetein Distance: 133.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  cerebral vasculopathy as complication of zoster rash
# Real Translation:  le cherubisme
# Predicted Translation:  ischemie biochimique faisabilite carcinologiques revelee faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilit
# Levenshetein Distance: 1171.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  a serious and unexpected infectious complication after transrectal prostate biopsy
# Real Translation:  carcinome jugal sous etanercept
# Predicted Translation:  complication d un post partum de type sans type par le vih
# Levenshetein Distance: 44.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  antibiotic susceptibility of staphylococcus aureus strains isolated in two university hospitals in rabat , morocco
# Real Translation:  meningiome en plaque frontal forme rare d une tumeur commune !
# Predicted Translation:  anatomocliniques longitudinale d infection locale
# Levenshetein Distance: 44.0
# ***BLEU Score***: 0.668740304976422
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  necrosis of the glans penis a complication of an injection of buprenorphin in a opioid abuser
# Real Translation:  epiplooplastie par laparoscopie
# Predicted Translation:  deux ischemie de surface atypiques du foie par lyon caracteristiques biomedical cliniques
# Levenshetein Distance: 70.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  from retroperitoneal fibrosis to gastric linitis
# Real Translation:  arteriopathie obliterante des membres inferieurs et reeducation vasculaire exemple d un centre de reeducation cardiovasculaire
# Predicted Translation:  nouvelle nouvelle atteinte de cheveux chez les sujet
# Levenshetein Distance: 100.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  a double faced myocarditis whipple s disease or sarcoidosis ?
# Real Translation:  hemorragie digestive massive d origine ileale terminale au cours de la maladie de crohn
# Predicted Translation:  comment ne ne on tumeur kystique et colon a propos d un cas et revue de la literature
# Levenshetein Distance: 66.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  primary myeloid sarcoma of uterine cervix and prevention of fertility . report of a case
# Real Translation:  le syndrome d allgrove
# Predicted Translation:  paralysie vaginale et adn dans le cadre de la paralysie systemique ?
# Levenshetein Distance: 55.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  what if the point at issue were not secularism
# Real Translation:  la leucemie chronique a eosinophiles
# Predicted Translation:  l si est est pas le genre !
# Levenshetein Distance: 29.0
# ***BLEU Score***: 0.5946035575013605
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  secularism at hospital how to live together
# Real Translation:  lymphome osseux primitif multifocal
# Predicted Translation:  obstacles aux etablissements nutritionnel urolift perinatale vais vais aimer esther dakar dakar avril dakar avril ressenti cepheid ces eleves de l article issus qualitative
# Levenshetein Distance: 151.0
# ***BLEU Score***: 0.4518010018049224
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  in the name of the respect of secularism at hospital
# Real Translation:  le myelolipome surrenalien
# Predicted Translation:  l insuline dans le diabete de l insuline a l insuline
# Levenshetein Distance: 39.0
# ***BLEU Score***: 0.4063798282013443
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  biological signifiance of microcytosis
# Real Translation:  le lipome du cavum de meckel une localisation rare
# Predicted Translation:  physiopathologie de sodium et deme rares
# Levenshetein Distance: 38.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  a maxillary lip bumper used to manage labial self mutilation
# Real Translation:  un incidentalome particulier le myelolipome
# Predicted Translation:  les ifitm , tout mental de modifier la duree de vie
# Levenshetein Distance: 36.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  management of the first trimester miscarriages
# Real Translation:  schwannomes benins cervico faciaux
# Predicted Translation:  prise en charge des myelodysplasies
# Levenshetein Distance: 29.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  demography of radiation oncology residents in france in current situation and perspectives for the next three years
# Real Translation:  le nouveau masque de l hysterie a propos de trois cas
# Predicted Translation:  franche et criteres de produits de l epidemiologie et de la prise en charge des calculs et de l exploration d un modele de l exploration d un modele et segpa
# Levenshetein Distance: 124.0
# ***BLEU Score***: 0.5039843787265444
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  desmoplastic small round cell tumour of the pancreas with breast metastasis
# Real Translation:  lymphangiomatose pulmonaire revelee par un syndrome interstitiel chez une adolescente
# Predicted Translation:  resection medical de membrane epimaculaire de la neurofibromatose de trois foie
# Levenshetein Distance: 67.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  neurological abnormalities in xeroderma pigmentosum
# Real Translation:  variation de la troponine tc chez les hemodialyses chroniques etude a propos de cas
# Predicted Translation:  expositions neurologiques et prise en charge initiale des lieux aux membranes etude transversale et prise en charge actuelle ?
# Levenshetein Distance: 89.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  drug treatment of refractory status epilepticus
# Real Translation:  les malformations veineuses superficielles et leur prise en charge par un comite multidisciplinaire cas
# Predicted Translation:  prise en charge d un deme alimentaire en population
# Levenshetein Distance: 78.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  isolated intracranial relapse in previously treated hodgkin s disease
# Real Translation:  les neurovessies du diabete
# Predicted Translation:  faisabilite faisabilite expectative jirovecii jirovecii faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilit
# Levenshetein Distance: 1159.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  systemic lupus erythematous revealed by an acute psychotic episode
# Real Translation:  enquete cap connaissances , attitudes , pratiques aupres de meres concernant la supplementation en vitamine d
# Predicted Translation:  lupus systemique systemique compliquant un lupus erythemateux systemique chez l enfant
# Levenshetein Distance: 83.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  carcinoid tumor of the larynx
# Real Translation:  expression de p dans l adenocarcinome colorectal serait elle un facteur pronostique ou etiopathogenique ?
# Predicted Translation:  leiomyosarcome de la thyroide chez un enfant de type
# Levenshetein Distance: 78.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  osteomyelitis due to bone anchored male sling
# Real Translation:  aspects histologiques de la maladie coeliaque dans le sud tunisien etude de cas pediatriques
# Predicted Translation:  realisation de l orbite a streptococcus pneumoniae
# Levenshetein Distance: 66.0
# ***BLEU Score***: 0.7311104457090247
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  total urethral rupture during sexual intercourse
# Real Translation:  interet d une approche active dans la prise en charge reeducative a la suite d une premiere chirurgie rachidienne pour hernie discale
# Predicted Translation:  pneumonie aigue neonatale chez grossesse chez un patient atteint de grossesse
# Levenshetein Distance: 98.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  retroperitoneal laparoscopic treatment of symptomatic caliceal diverticular calculi
# Real Translation:  complications du diverticule de meckel a propos de cas
# Predicted Translation:  prise en charge d une calcinose arterio isolee
# Levenshetein Distance: 42.0
# ***BLEU Score***: 0.5946035575013605
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  evidence based medicine and french medical students an appraisal
# Real Translation:  anaphylaxie consequences cliniques et prise en charge therapeutique aux urgences
# Predicted Translation:  handicap et medecine de medecine evidence au dela de l adolescent
# Levenshetein Distance: 58.0
# ...
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  fibrous juxtaarticular nodules
# Real Translation:  etude des facteurs lies a l infection ahelicobacter pylori chez l enfant
# Predicted Translation:  les fractures du comportement
# Levenshetein Distance: 51.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  the value of biopsy in so called atypical erythema nodosum
# Real Translation:  taux de couverture vaccinale contre la grippe en france en apport des donnees de remboursement du regime general
# Predicted Translation:  faisabilite faisabilite faisabilite preliminaires soignante soignante faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite faisabilite detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes faisabilite faisabilite detournes faisabilite faisabilite detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes faisabilite faisabilite detournes faisabilite faisabilite detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes faisabilite faisabilite detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes faisabilite faisabilite detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes faisabilite faisabilite detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes faisabilite faisabilite detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes faisabilite faisabilite detournes detournes faisabilite faisabilite detournes faisabilite faisabilit
# Levenshetein Distance: 1023.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  a curious case of livedo
# Real Translation:  evaluation prospective des associations antibiotiques d un centre hospitalier general
# Predicted Translation:  une occlusion hepatique simulant un symptome de la grossesse
# Levenshetein Distance: 62.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  multiple papules on a circumcision wound
# Real Translation:  profil de resistance aux antibiotiques des enterobacteries uropathogenes communautaires a el jadida maroc
# Predicted Translation:  retour atypique de l enfant
# Levenshetein Distance: 85.0
# ***BLEU Score***: 0.668740304976422
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  role and limitations of skin biopsy in the diagnosis of alopecia
# Real Translation:  profil de sensibilite aux antibiotiques des souches d acinetobacter baumannii isolees dans la region de mahdia
# Predicted Translation:  role de l annonce du diagnostic de la scintigraphie cerebrale
# Levenshetein Distance: 80.0
# ***BLEU Score***: 0.5623413251903491
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  the role of direct cutaneous immunofluorescence in dermatological diagnosis
# Real Translation:  actualites epidemiologiques de la leishmaniose viscerale en tunisie
# Predicted Translation:  interet qualitative soignante soignante soignante communaute civile communaute faisabilite communaute faisabilite soignante soignante communaute communaute detournes faisabilite faisabilite communaute communaute detournes detournes communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute communaute detournes detournes detournes faisabilite communaute communaute detournes detournes detournes faisabilite communaute communaute detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detournes detourn
# Levenshetein Distance: 972.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  vasculitis
# Real Translation:  une pneumopathie quot communautaire quot pas si commune que ca !
# Predicted Translation:  botryomycome
# Levenshetein Distance: 56.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  diagnostic problems posed by cutaneous lymphocytic infiltrates
# Real Translation:  l ulcere de buruli ou infection a mycobacterium ulcerans
# Predicted Translation:  prise en charge des onychomycoses et de l enfant
# Levenshetein Distance: 40.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  invisible dermatoses
# Real Translation:  opinions et pratiques des medecins generalistes face a la vaccination anti papillomavirus
# Predicted Translation:  lyne migrans rhumatoide
# Levenshetein Distance: 75.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  understanding vulvar intraepithelial neoplasia
# Real Translation:  profil bacteriologique des infections maternofoetales dans un hopital du centre tunisien
# Predicted Translation:  syndrome de paludisme intra uterin . role de leur type
# Levenshetein Distance: 63.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  spitz tumor and pigmented epithelioid melanocytoma new nosological frameworks for commonly ill defined tumors
# Real Translation:  pcr rdna s dans le diagnostic etiologique des endocardites infectieuses a hemocultures negatives
# Predicted Translation:  reconstruction selective de la voie visuelle dans les marqueurs pulmonaires mute associee a l rcp tumoral associee
# Levenshetein Distance: 84.0
# ***BLEU Score***: 0.5856596027429395
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  accurate diagnosis of adnexal tumours can be a matter of life or death
# Real Translation:  evaluation d une consultation mobile d infectiologie
# Predicted Translation:  diagnostic fonctionnelle de la maladie coronarienne une serie de cas a propos de cas
# Levenshetein Distance: 62.0
# ***BLEU Score***: 0.5169731539571706
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  artefacts in dermatopathology
# Real Translation:  methode d evaluation des pratiques professionnelles epp au cours de l antibiotherapie des pneumopathies aigues communautaires
# Predicted Translation:  infections associees a l urologie
# Levenshetein Distance: 101.0
# ***BLEU Score***: 0.5623413251903491
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  new techniques in dermatopathology
# Real Translation:  maladie de behcet et recommandations de l eular medecine fondee sur les preuves ou sur l experience clinique
# Predicted Translation:  prise en charge de l hypertension arterielle dans le cadre de l insuffisance mitrale ?
# Levenshetein Distance: 78.0
# ***BLEU Score***: 0.5081327481546147
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  images and heroes of french dermatopathology
# Real Translation:  tumeurs des nerfs peripheriques
# Predicted Translation:  les anevrysmes de l aorte dans les observatoires systemique
# Levenshetein Distance: 42.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  dermatopathology and dermatology
# Real Translation:  de l anxiete a la depression
# Predicted Translation:  comorbidite associees aux nourrissons paradoxales en place de l emploi a l emploi publique a propos de cas
# Levenshetein Distance: 87.0
# ***BLEU Score***: 0.5773502691896257
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  olecranon osteotomy in the treatment of distal humeral fractures in adults anatomical and functional evaluation of the elbow in cases
# Real Translation:  carcinome epidermoide cutane carcinome spinocellulaire recommandations de pratique clinique pour la prise en charge diagnostique et theapeutique . argumentaire mai
# Predicted Translation:  utilisation des motoneurones dans les ruptures pathogenes infectieuses de l age
# Levenshetein Distance: 122.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  assessment of erythropoietin treatment in preterm newborns older than weeks of gestation
# Real Translation:  etat des lieux sur les carcinomes basaloides orl
# Predicted Translation:  evolution de l activite dentaire geriatriques dans la notification de vie
# Levenshetein Distance: 52.0
# ***BLEU Score***: 0.5491004867761125
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  intermittent acute porphyria a metabolic emergency
# Real Translation:  faut il mettre un interne en infectiologie transversale ? l experience au centre hospitalier regional et universitaire de lille
# Predicted Translation:  mit ausdauer im leidenschaft
# Levenshetein Distance: 108.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  portal vein thrombosis due to intragastric migration of laparoscopic adjustable gastric band
# Real Translation:  monitorage des aminosides en reanimation
# Predicted Translation:  thrombose de mccune sequellaire d un syndrome de bronches dans un syndrome d apnee du sommeil
# Levenshetein Distance: 72.0
# ***BLEU Score***: 0.5
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  takayasu s arteritis and retroperitoneal fibrosis a case report
# Real Translation:  la chirurgie des nerfs peripheriques dans la lepre
# Predicted Translation:  association de rendement classique et echec de l association calvarial par section totale du cas de hodgkin classique et opaline , j t obstet fertil
# Levenshetein Distance: 120.0
# ***BLEU Score***: 0.447213595499958
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  what are the new therapeutic strategies in metastatic colorectal cancer including biotherapies ?
# Real Translation:  conduite a tenir et resultats du traitement de la paralysie obstetricale du nouveau ne
# Predicted Translation:  promotion de la chirurgie du ganglion sentinelle et les techniques du bas appareil vaginal et de la chirurgie des equipes digestifs ?
# Levenshetein Distance: 94.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  pituitary metastasis presenting as diabetes insipidus a report of four cases and literature review
# Real Translation:  infarctus par occlusion aigue du tronc commun non protege a propos de six cas traites par angioplastie
# Predicted Translation:  metastase rectale rectale metastase carcinologiques portant metastase carcinologiques prise en prise en charge diagnostique chez le patient tumeur mimant tumeur diagnostique chez le patient tumeur mimant tumeur diagnostique portant diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostique diagnostiqu
# Levenshetein Distance: 1056.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  toward a metabolic approach of the central pattern generator concept in a spinal rat model
# Real Translation:  carcinome epidermoide cutane carcinome spinocellulaire recommandations de pratique clinique pour la prise en charge diagnostique et therapeutique
# Predicted Translation:  comment un diagnostic reste vers un traitement de maniere immunitaire dans le diabete de type
# Levenshetein Distance: 102.0
# ***BLEU Score***: 0
#
# INFO:tensorflow:Restoring parameters from ckpt-exp01/bi-LSTM-LSTM-3400
# Source Sentence:  major mechanisms involved in the synaptic transmission of the neuromuscular apparat
# Real Translation:  reperer et prendre en charge la depression et
# Predicted Translation:  comprendre les proteines de neonatologie . vers le explorer . a faire
# Levenshetein Distance: 46.0
# ***BLEU Score***: 0.537284965911771
#
#
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Prediction Output and Metrics on 400 test sentences:
# Average BLEU Score on our test corpus is 0.2504212742525156
# Average Levenshetein distance Score on our test corpus is 186.3125
